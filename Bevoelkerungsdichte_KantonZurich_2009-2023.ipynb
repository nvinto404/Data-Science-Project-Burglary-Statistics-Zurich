# %% [markdown]
# Connect to the Swiss Open Data API to retrieve the Bevoelkerungsidchte Data for the Canton of Zurich. Afterwards load the Data into a Dataframe and save the originally retrieved data into csv, before the cleaning of the Data.

# %%
import requests    
import json         
import pandas as pd 
import os

package = 'bevolkerungsdichte-einw-km2'

# Base url for the open data swiss API
base_url = 'https://opendata.swiss/api/3/action/package_show?id='

# Construct the url including package 
package_information_url = base_url + package

# HTTP request
package_information = requests.get(package_information_url)

# Use the json module to load CKAN's response into a dictionary
package_dict = json.loads(package_information.content)

assert package_dict['success'] is True  
package_dict = package_dict['result']   
print(package_dict)
# Out:
# {'license_title': None, 'maintainer': 'Statistisches Amt des Kantons Zürich, Data Shop', 'issued': '2016-01-20T20:16:00+01:00', 'title_for_slug': 'bevolkerungsdichte-einw-km2', 'qualified_relations': [], 'private': False, 'maintainer_email': 'datashop@statistik.zh.ch', 'num_tags': 6, 'contact_points': [{'email': 'datashop@statistik.zh.ch', 'name': 'Statistisches Amt des Kantons Zürich, Data Shop'}], 'keywords': {'fr': [], 'de': ['gemeinden', 'kantonzuerich', 'bevoelkerungsdichte', 'bevoelkerung', 'bezirke', 'flaeche'], 'en': [], 'it': []}, 'temporals': [{'start_date': '1962-12-31T00:00:00', 'end_date': '2023-12-31T23:59:59.999999'}], 'id': '7de2bc70-8df7-4838-a485-56e54d74e07f', 'metadata_created': '2021-01-14T18:01:26.570702', 'documentation': [], 'conforms_to': [], 'metadata_modified': '2024-04-09T05:17:39.387929', 'author': None, 'author_email': None, 'isopen': False, 'relations': [{'url': 'https://www.zh.ch/de/politik-staat/gesetze-beschluesse/gesetzessammlung/zhlex-os/erlass-431_1-70-359.html', 'label': 'legal_basis'}, {'url': 'https://openzh.github.io/starter-code-openZH/', 'label': 'Vorbereiteter Code in R oder Python für jedes Dataset mit csv-Datei(en)'}], 'state': 'active', 'version': None, 'relationships_as_object': [], 'license_id': None, 'see_alsos': [{'dataset_identifier': '204@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '285@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '283@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '68@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '87@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '284@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '298@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '280@statistisches-amt-kanton-zuerich'}], 'type': 'dataset', 'resources': [{'byte_size': 1978539, 'cache_last_updated': None, 'issued': '2016-01-21T16:30:35+01:00', 'uri': '', 'package_id': '7de2bc70-8df7-4838-a485-56e54d74e07f', 'temporal_resolution': '', 'datastore_contains_all_records_of_source_file': False, 'datastore_active': False, 'id': '67ceace0-2ac4-4dd9-9e5a-be74225a3e1d', 'size': None, 'rights': 'NonCommercialAllowed-CommercialAllowed-ReferenceRequired', 'display_name': {'fr': '', 'de': 'Bevölkerungsdichte [Einw./km2]', 'en': '', 'it': ''}, 'title': {'fr': '', 'de': 'Bevölkerungsdichte [Einw./km2]', 'en': '', 'it': ''}, 'download_url': 'https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv', 'state': 'active', 'media_type': 'text/csv', 'hash': '', 'description': {'fr': '', 'de': '', 'en': '', 'it': ''}, 'format': 'CSV', 'language': ['de'], 'mimetype_inner': None, 'url_type': None, 'name': {'fr': '', 'de': 'Bevölkerungsdichte [Einw./km2]', 'en': '', 'it': ''}, 'mimetype': 'text/csv', 'cache_url': None, 'license': 'NonCommercialAllowed-CommercialAllowed-ReferenceRequired', 'access_services': [], 'created': '2022-12-12T03:07:17.816346', 'url': 'https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv', 'documentation': [], 'modified': '2024-03-04T13:59:47+01:00', 'last_modified': None, 'position': 0, 'revision_id': '7a9314c3-9e28-4573-8b8e-20c95161d4f5', 'resource_type': None}], 'num_resources': 1, 'description': {'fr': '', 'de': 'Bevölkerung pro Gemeindefläche [Einwohner pro Quadratkilometer]', 'en': '', 'it': ''}, 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'bevoelkerung', 'id': '02ee2964-66bd-4173-9058-f9e354696b86', 'name': 'bevoelkerung'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'bevoelkerungsdichte', 'id': '639f54c0-8897-479a-8331-95275576d1bd', 'name': 'bevoelkerungsdichte'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'bezirke', 'id': '1545b490-60bb-4ea8-bbf7-ae3169ab0d5e', 'name': 'bezirke'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'flaeche', 'id': 'e11c13e3-d156-40f1-ab72-7e4d70b7bf52', 'name': 'flaeche'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'gemeinden', 'id': 'bd203e69-5ef0- ...

# %%
# Get the url for the data from the dictionary
data_url = package_dict['resources'][0]['url']
print('Data url:' + data_url)

# Print the data format
data_format = package_dict['resources'][0]['format']
print('Data format:' + data_format)
# Out:
# Data url:https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv
# Data format:CSV

# %%
csv = ['comma-separated-values', 'CSV', 'csv']
if any(s in data_format for s in csv):     
     Bevoelkerungsdichte_df = pd.read_csv(data_url)
else:
    print('Sorry, the data format is not supported')
Bevoelkerungsdichte_df
# Out:
#        BFS_NR             GEBIET_NAME                THEMA_NAME  \
# 0           1             Aeugst a.A.  Bevölkerung und Soziales
# 1           1             Aeugst a.A.  Bevölkerung und Soziales
# 2           1             Aeugst a.A.  Bevölkerung und Soziales
# 3           1             Aeugst a.A.  Bevölkerung und Soziales
# 4           1             Aeugst a.A.  Bevölkerung und Soziales
# ...       ...                     ...                       ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12255       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12256       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12257       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12258       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
#
#                                 SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 1      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 2      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 3      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 4      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# ...                                  ...                  ...           ...
# 12254  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12255  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12256  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12257  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12258  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
#
#                        INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0      Bevölkerungsdichte [Einw./km2]            1962             90.2
# 1      Bevölkerungsdichte [Einw./km2]            1963             91.5
# 2      Bevölkerungsdichte [Einw./km2]            1964             89.6
# 3      Bevölkerungsdichte [Einw./km2]            1965             88.3
# 4      Bevölkerungsdichte [Einw./km2]            1966             94.7
# ...                               ...             ...              ...
# 12254  Bevölkerungsdichte [Einw./km2]            2019            942.4
# 12255  Bevölkerungsdichte [Einw./km2]            2020            951.5
# 12256  Bevölkerungsdichte [Einw./km2]            2021            958.3
# 12257  Bevölkerungsdichte [Einw./km2]            2022            967.6
# 12258  Bevölkerungsdichte [Einw./km2]            2023            990.5
#
#       EINHEIT_KURZ                    EINHEIT_LANG  Unnamed: 11
# 0        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 1        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 2        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 3        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 4        Einw./km2  Einwohner pro Quadratkilometer          NaN
# ...            ...                             ...          ...
# 12254    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12255    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12256    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12257    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12258    Einw./km2  Einwohner pro Quadratkilometer          NaN
#
# [12259 rows x 12 columns]

# %%
#Save original data files to csv, if the folder is not aleady created, it will be created
directory = 'Original_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Bevoelkerungsdichte_KantonZurich_2010_2023.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

Bevoelkerungsdichte_df.to_csv(csv_path, index=False)
print(Bevoelkerungsdichte_df)
# Out:
#        BFS_NR             GEBIET_NAME                THEMA_NAME  \
# 0           1             Aeugst a.A.  Bevölkerung und Soziales
# 1           1             Aeugst a.A.  Bevölkerung und Soziales
# 2           1             Aeugst a.A.  Bevölkerung und Soziales
# 3           1             Aeugst a.A.  Bevölkerung und Soziales
# 4           1             Aeugst a.A.  Bevölkerung und Soziales
# ...       ...                     ...                       ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12255       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12256       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12257       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12258       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
#
#                                 SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 1      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 2      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 3      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 4      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# ...                                  ...                  ...           ...
# 12254  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12255  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12256  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12257  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12258  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
#
#                        INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0      Bevölkerungsdichte [Einw./km2]            1962             90.2
# 1      Bevölkerungsdichte [Einw./km2]            1963             91.5
# 2      Bevölkerungsdichte [Einw./km2]            1964             89.6
# 3      Bevölkerungsdichte [Einw./km2]            1965             88.3
# 4      Bevölkerungsdichte [Einw./km2]            1966             94.7
# ...                               ...             ...              ...
# 12254  Bevölkerungsdichte [Einw./km2]            2019            942.4
# 12255  Bevölkerungsdichte [Einw./km2]            2020            951.5
# 12256  Bevölkerungsdichte [Einw./km2]            2021            958.3
# 12257  Bevölkerungsdichte [Einw./km2]            2022            967.6
# 12258  Bevölkerungsdichte [Einw./km2]            2023            990.5
#
#       EINHEIT_KURZ                    EINHEIT_LANG  Unnamed: 11
# 0        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 1        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 2        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 3        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 4        Einw./km2  Einwohner pro Quadratkilometer          NaN
# ...            ...                             ...          ...
# 12254    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12255    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12256    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12257    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12258    Einw./km2  Einwohner pro Quadratkilometer          NaN
#
# [12259 rows x 12 columns]

# %% [markdown]
# Drop not needed Columns, Filter the Data to the years 2009-2023, Delete the summarized Datarows an as well unify the Region Names so the data can be analyzed with the other available datasets. Afterwards save a Cleaned csv file to the Cleaned CSV Files folder.

# %%
Bevoelkerungsdichte_df.drop(['THEMA_NAME','SET_NAME','SUBSET_NAME','INDIKATOR_ID','EINHEIT_KURZ','Unnamed: 11'], axis=1, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR             GEBIET_NAME                  INDIKATOR_NAME  \
# 0           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 1           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 2           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 3           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 4           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# ...       ...                     ...                             ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12255       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12256       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12257       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12258       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
#
#        INDIKATOR_JAHR  INDIKATOR_VALUE                    EINHEIT_LANG
# 0                1962             90.2  Einwohner pro Quadratkilometer
# 1                1963             91.5  Einwohner pro Quadratkilometer
# 2                1964             89.6  Einwohner pro Quadratkilometer
# 3                1965             88.3  Einwohner pro Quadratkilometer
# 4                1966             94.7  Einwohner pro Quadratkilometer
# ...               ...              ...                             ...
# 12254            2019            942.4  Einwohner pro Quadratkilometer
# 12255            2020            951.5  Einwohner pro Quadratkilometer
# 12256            2021            958.3  Einwohner pro Quadratkilometer
# 12257            2022            967.6  Einwohner pro Quadratkilometer
# 12258            2023            990.5  Einwohner pro Quadratkilometer
#
# [12259 rows x 6 columns]

# %%
Jahresindizes_zu_loeschen = Bevoelkerungsdichte_df[Bevoelkerungsdichte_df['INDIKATOR_JAHR'] < 2009].index
Bevoelkerungsdichte_df.drop(Jahresindizes_zu_loeschen, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR             GEBIET_NAME                  INDIKATOR_NAME  \
# 47          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 48          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 49          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 50          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 51          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# ...       ...                     ...                             ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12255       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12256       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12257       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12258       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
#
#        INDIKATOR_JAHR  INDIKATOR_VALUE                    EINHEIT_LANG
# 47               2009            220.7  Einwohner pro Quadratkilometer
# 48               2010            231.5  Einwohner pro Quadratkilometer
# 49               2011            242.8  Einwohner pro Quadratkilometer
# 50               2012            248.9  Einwohner pro Quadratkilometer
# 51               2013            250.3  Einwohner pro Quadratkilometer
# ...               ...              ...                             ...
# 12254            2019            942.4  Einwohner pro Quadratkilometer
# 12255            2020            951.5  Einwohner pro Quadratkilometer
# 12256            2021            958.3  Einwohner pro Quadratkilometer
# 12257            2022            967.6  Einwohner pro Quadratkilometer
# 12258            2023            990.5  Einwohner pro Quadratkilometer
#
# [2915 rows x 6 columns]

# %%
# Loesche alle Indizes, die den Wert '0' in der Spalte 'BFS_NR' haben da diese zusammengefasste Informationen pro Bezirk/Region enthalten
indizes_zu_loeschen = Bevoelkerungsdichte_df[Bevoelkerungsdichte_df['BFS_NR'] == 0].index
Bevoelkerungsdichte_df.drop(indizes_zu_loeschen, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2009
# 48          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2010
# 49          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2011
# 50          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2012
# 51          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2555 rows x 6 columns]

# %%
#Einige Datensätze beinhalten im Gemeindenamen (bis *) um zu indizieren dass die Rechnung sich auf die angegbenen JAhre bezieht. Um Redundanzen zu vermeiden, werden diese entfernt
indizesBis_zu_loeschen = Bevoelkerungsdichte_df[Bevoelkerungsdichte_df['GEBIET_NAME'].str.contains("\(bis ", na=False)].index
Bevoelkerungsdichte_df.drop(indizesBis_zu_loeschen, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2009
# 48          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2010
# 49          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2011
# 50          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2012
# 51          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2391 rows x 6 columns]

# %%
# Vereinheitlichen der Gemeindenamen
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Aeugst a.A.', 'Aeugst', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Affoltern a.A.', 'Affoltern', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Hausen a.A.', 'Hausen', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Kappel a.A.', 'Kappel', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Wettswil a.A.', 'Wettswil', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Berg a.I.', 'Berg', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Buch a.I.', 'Buch', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Thalheim a.d.Th.', 'Thalheim', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Langnau a.A.', 'Langnau', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Oetwil a.S.', 'Oetwil', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Uetikon a.S.', 'Uetikon', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Ellikon a.d.Th.', 'Ellikon', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Oetwil a.d.L.', 'Oetwil an der Limmat', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Aesch ZH', 'Aesch', regex=False)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2009
# 48          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2010
# 49          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2011
# 50          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2012
# 51          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2391 rows x 6 columns]

# %%
directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Bevoelkerungsdichte_KantonZurich_2010_2023_Cleaned.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

Bevoelkerungsdichte_df.to_csv(csv_path, index=False)
print(Bevoelkerungsdichte_df)
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2009
# 48          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2010
# 49          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2011
# 50          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2012
# 51          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2391 rows x 6 columns]

# %% [markdown]
# Print the Information for the Dataframe so we can create the Table for the Database correspondingly.

# %%
Bevoelkerungsdichte_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2391 entries, 47 to 10770
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2391 non-null   int64
#  1   GEBIET_NAME      2391 non-null   object
#  2   INDIKATOR_NAME   2391 non-null   object
#  3   INDIKATOR_JAHR   2391 non-null   int64
#  4   INDIKATOR_VALUE  2391 non-null   float64
#  5   EINHEIT_LANG     2391 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 130.8+ KB

# %% [markdown]
# Connect to the database and create a new table called Bevoelkerungsdichte. If the table is already existing drop it.

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

# MySQL connection parameters
host = 'localhost'
user = 'admin'
password = 'Criminal1234'
database = 'CriminalDataDB'  
try:
    connection = mysql.connector.connect(host=host,
                                         user=user,
                                         password=password,
                                         database=database)

    if connection.is_connected():
        print("Connected to MySQL server")
        cursor = connection.cursor()

        # SQL command to drop the table if it already exists becuase before that line of code the data was already inserted multiple times
        drop_table_query = "DROP TABLE IF EXISTS Bevoelkerungsdichte;"
        cursor.execute(drop_table_query)
        print("Table 'Bevoelkerungsdichte' dropped if it existed alreadyy")

        create_table_query = """
        CREATE TABLE IF NOT EXISTS Bevoelkerungsdichte (
            BFS_NR INT,
            GEBIET_NAME VARCHAR(255),
            INDIKATOR_NAME VARCHAR(255),
            INDIKATOR_JAHR INT,
            INDIKATOR_VALUE FLOAT,
            EINHEIT_LANG VARCHAR(255)
        )
        """

        cursor.execute(create_table_query)
        print("Table 'Bevoelkerungsdichte' created successfully")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Table 'Bevoelkerungsdichte' dropped if it existed alreadyy
# Table 'Bevoelkerungsdichte' created successfully
# MySQL connection closed

# %% [markdown]
# Insert the Cleanaed data from the Cleaned Csv file which was created before.

# %%
import mysql.connector 
from mysql.connector import Error
import pandas as pd

# MySQL connection parameters
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB',
    'allow_local_infile': True
}

directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()
csv_file_path = os.path.join(current_directory, directory, 'Bevoelkerungsdichte_KantonZurich_2010_2023_Cleaned.csv')

try:
    with mysql.connector.connect(**connection_params) as connection:
        print("Connected to MySQL server")

        Bevoelkerungsdichte_df_to_sql = pd.read_csv(csv_file_path)

        cursor = connection.cursor()
        insert_query = """
        LOAD DATA LOCAL INFILE %s 
        INTO TABLE Bevoelkerungsdichte 
        FIELDS TERMINATED BY ',' 
        ENCLOSED BY '"' 
        LINES TERMINATED BY '\n' 
        IGNORE 1 LINES
        """

        cursor.execute(insert_query, (csv_file_path,))
        connection.commit()

        print("Data from CSV file successfully inserted into MySQL table 'Bevoelkerungsdichte'")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Data from CSV file successfully inserted into MySQL table 'Bevoelkerungsdichte'

# %% [markdown]
# Check if the Data upload to the table was successfully by creating a query to the sql table.

# %%
import mysql.connector
from mysql.connector import Error

# MySQL connection parameters
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB'
}

try:
    connection = mysql.connector.connect(**connection_params)
    print("Connected to MySQL server")

    with connection.cursor() as cursor:
        select_query = "SELECT * FROM Bevoelkerungsdichte"

        cursor.execute(select_query)
        rows = cursor.fetchall()

        for row in rows:
            print(row)

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if 'connection' in locals() and connection.is_connected():
        # Close connection
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2009, 220.7, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2010, 231.5, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2011, 242.8, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2012, 248.9, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2013, 250.3, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2014, 248.0, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2015, 252.4, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2016, 250.2, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2017, 245.7, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2018, 250.5, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2019, 250.8, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2020, 254.6, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2021, 251.4, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2022, 252.0, 'Einwohner pro Quadratkilometer')
# (1, 'Aeugst', 'Bevölkerungsdichte [Einw./km2]', 2023, 252.5, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2009, 1009.9, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2010, 1043.7, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2011, 1050.9, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2012, 1062.7, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2013, 1070.0, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2014, 1088.7, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2015, 1103.3, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2016, 1119.6, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2017, 1139.6, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2018, 1158.7, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2019, 1168.9, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2020, 1163.0, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2021, 1173.6, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2022, 1189.4, 'Einwohner pro Quadratkilometer')
# (2, 'Affoltern', 'Bevölkerungsdichte [Einw./km2]', 2023, 1216.7, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2009, 686.6, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2010, 693.2, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2011, 693.4, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2012, 696.8, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2013, 705.2, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2014, 708.6, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2015, 714.4, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2016, 727.8, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2017, 737.0, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2018, 744.5, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2019, 749.5, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2020, 754.0, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2021, 757.0, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2022, 755.2, 'Einwohner pro Quadratkilometer')
# (3, 'Bonstetten', 'Bevölkerungsdichte [Einw./km2]', 2023, 760.3, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2009, 241.7, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2010, 245.8, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2011, 245.8, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2012, 246.5, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2013, 249.7, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2014, 253.6, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2015, 254.1, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2016, 259.9, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2017, 266.5, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2018, 270.9, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2019, 275.1, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2020, 278.6, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2021, 282.5, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2022, 284.1, 'Einwohner pro Quadratkilometer')
# (4, 'Hausen', 'Bevölkerungsdichte [Einw./km2]', 2023, 290.7, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2009, 521.3, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2010, 521.9, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2011, 530.5, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2012, 536.9, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2013, 549.0, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2014, 558.2, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2015, 559.7, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2016, 561.6, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2017, 563.2, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2018, 568.4, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2019, 575.5, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2020, 578.2, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2021, 575.8, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2022, 589.0, 'Einwohner pro Quadratkilometer')
# (5, 'Hedingen', 'Bevölkerungsdichte [Einw./km2]', 2023, 600.8, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2009, 112.6, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2010, 117.2, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2011, 121.6, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2012, 117.8, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2013, 122.0, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2014, 129.5, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 2015, 131.4, 'Einwohner pro Quadratkilometer')
# (6, 'Kappel', 'Bevölkerungsdichte [Einw./km2]', 
 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2011, 103.8, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2012, 102.7, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2013, 103.5, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2014, 106.0, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2015, 106.1, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2016, 111.3, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2017, 110.3, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2018, 111.1, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2019, 110.5, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2020, 110.4, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2021, 110.9, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2022, 111.4, 'Einwohner pro Quadratkilometer')
# (40, 'Trüllikon', 'Bevölkerungsdichte [Einw./km2]', 2023, 114.0, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2009, 107.0, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2010, 107.2, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2011, 105.9, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2012, 105.0, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2013, 101.8, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2014, 104.5, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2015, 106.8, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2016, 105.9, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2017, 107.7, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2018, 108.6, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2019, 105.5, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2020, 102.3, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2021, 102.7, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2022, 105.5, 'Einwohner pro Quadratkilometer')
# (41, 'Truttikon', 'Bevölkerungsdichte [Einw./km2]', 2023, 107.0, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2009, 94.5, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2010, 94.8, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2011, 93.9, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2012, 95.1, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2013, 93.3, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2014, 103.7, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2015, 103.7, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2016, 102.8, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2017, 103.1, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2018, 110.4, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2019, 115.9, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2020, 116.8, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2021, 119.5, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2022, 116.2, 'Einwohner pro Quadratkilometer')
# (43, 'Volken', 'Bevölkerungsdichte [Einw./km2]', 2023, 115.9, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2009, 884.1, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2010, 901.9, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2011, 930.5, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2012, 934.5, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2013, 941.3, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2014, 947.3, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2015, 938.5, 'Einwohner pro Quadratkilometer')
# (51, 'Bachenbülach', 'Bevölkerungsdichte [Einw./km2]', 2016, 945.9, 'Einwohner pro Quadratkilometer')
# ...
# (249, 'Unterengstringen', 'Bevölkerungsdichte [Einw./km2]', 2020, 1185.1, 'Einwohner pro Quadratkilometer')
# (249, 'Unterengstringen', 'Bevölkerungsdichte [Einw./km2]', 2021, 1221.1, 'Einwohner pro Quadratkilometer')
# (249, 'Unterengstringen', 'Bevölkerungsdichte [Einw./km2]', 2022, 1224.1, 'Einwohner pro Quadratkilometer')
# (249, 'Unterengstringen', 'Bevölkerungsdichte [Einw./km2]', 2023, 1279.2, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2009, 1195.8, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2010, 1186.1, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2011, 1221.8, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2012, 1249.1, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2013, 1255.6, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2014, 1269.6, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2015, 1277.8, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2016, 1273.6, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2017, 1290.4, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2018, 1297.2, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2019, 1316.0, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2020, 1320.4, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2021, 1347.1, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2022, 1362.4, 'Einwohner pro Quadratkilometer')
# (250, 'Urdorf', 'Bevölkerungsdichte [Einw./km2]', 2023, 1370.7, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2009, 772.6, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2010, 783.1, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2011, 789.1, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2012, 792.8, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2013, 803.7, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2014, 816.1, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2015, 835.2, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2016, 879.3, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2017, 881.5, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2018, 890.2, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2019, 887.2, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2020, 897.8, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2021, 898.7, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2022, 901.5, 'Einwohner pro Quadratkilometer')
# (251, 'Weiningen', 'Bevölkerungsdichte [Einw./km2]', 2023, 935.1, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2009, 4153.6, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2010, 4232.6, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2011, 4277.7, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2012, 4322.1, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2013, 4365.3, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2014, 4442.3, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2015, 4505.4, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2016, 4563.6, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2017, 4635.3, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2018, 4707.8, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2019, 4765.8, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2020, 4787.2, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 2021, 4802.1, 'Einwohner pro Quadratkilometer')
# (261, 'Zürich', 'Bevölkerungsdichte [Einw./km2]', 