# %% [markdown]
# Connect to the Swiss Open Data API to retrieve the Bevoelkerungsidchte Data for the Canton of Zurich. Afterwards load the Data into a Dataframe and save the originally retrieved data into csv, before the cleaning of the Data.

# %%
import requests    
import json         
import pandas as pd 
import os

package = 'bevolkerungsdichte-einw-km2'

# Base url for the open data swiss API
base_url = 'https://opendata.swiss/api/3/action/package_show?id='

# Construct the url including package 
package_information_url = base_url + package

# HTTP request
package_information = requests.get(package_information_url)

# Use the json module to load CKAN's response into a dictionary
package_dict = json.loads(package_information.content)

assert package_dict['success'] is True  
package_dict = package_dict['result']   
print(package_dict)
# Out:
# {'license_title': None, 'maintainer': 'Statistisches Amt des Kantons Zürich, Data Shop', 'issued': '2016-01-20T20:16:00+01:00', 'title_for_slug': 'bevolkerungsdichte-einw-km2', 'qualified_relations': [], 'private': False, 'maintainer_email': 'datashop@statistik.zh.ch', 'num_tags': 6, 'contact_points': [{'email': 'datashop@statistik.zh.ch', 'name': 'Statistisches Amt des Kantons Zürich, Data Shop'}], 'keywords': {'fr': [], 'de': ['flaeche', 'gemeinden', 'kantonzuerich', 'bevoelkerung', 'bevoelkerungsdichte', 'bezirke'], 'en': [], 'it': []}, 'temporals': [{'start_date': '1962-12-31T00:00:00', 'end_date': '2023-12-31T23:59:59.999999'}], 'id': '7de2bc70-8df7-4838-a485-56e54d74e07f', 'metadata_created': '2021-01-14T18:01:26.570702', 'documentation': [], 'conforms_to': [], 'metadata_modified': '2024-05-09T04:16:08.656338', 'author': None, 'author_email': None, 'isopen': False, 'relations': [{'url': 'https://openzh.github.io/starter-code-openZH/', 'label': 'Vorbereiteter Code in R oder Python für jedes Dataset mit csv-Datei(en)'}, {'url': 'https://www.zh.ch/de/politik-staat/gesetze-beschluesse/gesetzessammlung/zhlex-os/erlass-431_1-70-359.html', 'label': 'legal_basis'}], 'state': 'active', 'version': None, 'relationships_as_object': [], 'license_id': None, 'see_alsos': [{'dataset_identifier': '204@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '68@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '87@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '285@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '298@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '280@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '284@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '283@statistisches-amt-kanton-zuerich'}], 'type': 'dataset', 'resources': [{'byte_size': 1978539, 'cache_last_updated': None, 'issued': '2016-01-21T16:30:35+01:00', 'uri': '', 'package_id': '7de2bc70-8df7-4838-a485-56e54d74e07f', 'temporal_resolution': '', 'datastore_contains_all_records_of_source_file': False, 'datastore_active': False, 'id': '67ceace0-2ac4-4dd9-9e5a-be74225a3e1d', 'size': None, 'rights': 'NonCommercialAllowed-CommercialAllowed-ReferenceRequired', 'display_name': {'fr': '', 'de': 'Bevölkerungsdichte [Einw./km2]', 'en': '', 'it': ''}, 'title': {'fr': '', 'de': 'Bevölkerungsdichte [Einw./km2]', 'en': '', 'it': ''}, 'download_url': 'https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv', 'state': 'active', 'media_type': 'text/csv', 'hash': '', 'description': {'fr': '', 'de': '', 'en': '', 'it': ''}, 'format': 'CSV', 'language': ['de'], 'mimetype_inner': None, 'url_type': None, 'name': {'fr': '', 'de': 'Bevölkerungsdichte [Einw./km2]', 'en': '', 'it': ''}, 'mimetype': 'text/csv', 'cache_url': None, 'license': 'NonCommercialAllowed-CommercialAllowed-ReferenceRequired', 'access_services': [], 'created': '2022-12-12T03:07:17.816346', 'url': 'https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv', 'documentation': [], 'modified': '2024-03-04T13:59:47+01:00', 'last_modified': None, 'position': 0, 'revision_id': '7a9314c3-9e28-4573-8b8e-20c95161d4f5', 'resource_type': None}], 'num_resources': 1, 'description': {'fr': '', 'de': 'Bevölkerung pro Gemeindefläche [Einwohner pro Quadratkilometer]', 'en': '', 'it': ''}, 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'bevoelkerung', 'id': '02ee2964-66bd-4173-9058-f9e354696b86', 'name': 'bevoelkerung'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'bevoelkerungsdichte', 'id': '639f54c0-8897-479a-8331-95275576d1bd', 'name': 'bevoelkerungsdichte'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'bezirke', 'id': '1545b490-60bb-4ea8-bbf7-ae3169ab0d5e', 'name': 'bezirke'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'flaeche', 'id': 'e11c13e3-d156-40f1-ab72-7e4d70b7bf52', 'name': 'flaeche'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'gemeinden', 'id': 'bd203e69-5ef0- ...

# %%
# Get the url for the data from the dictionary
data_url = package_dict['resources'][0]['url']
print('Data url:' + data_url)

# Print the data format
data_format = package_dict['resources'][0]['format']
print('Data format:' + data_format)
# Out:
# Data url:https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_460.csv
# Data format:CSV

# %%
csv = ['comma-separated-values', 'CSV', 'csv']
if any(s in data_format for s in csv):     
     Bevoelkerungsdichte_df = pd.read_csv(data_url)
else:
    print('Sorry, the data format is not supported')
Bevoelkerungsdichte_df
# Out:
#        BFS_NR             GEBIET_NAME                THEMA_NAME  \
# 0           1             Aeugst a.A.  Bevölkerung und Soziales
# 1           1             Aeugst a.A.  Bevölkerung und Soziales
# 2           1             Aeugst a.A.  Bevölkerung und Soziales
# 3           1             Aeugst a.A.  Bevölkerung und Soziales
# 4           1             Aeugst a.A.  Bevölkerung und Soziales
# ...       ...                     ...                       ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12255       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12256       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12257       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12258       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
#
#                                 SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 1      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 2      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 3      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 4      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# ...                                  ...                  ...           ...
# 12254  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12255  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12256  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12257  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12258  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
#
#                        INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0      Bevölkerungsdichte [Einw./km2]            1962             90.2
# 1      Bevölkerungsdichte [Einw./km2]            1963             91.5
# 2      Bevölkerungsdichte [Einw./km2]            1964             89.6
# 3      Bevölkerungsdichte [Einw./km2]            1965             88.3
# 4      Bevölkerungsdichte [Einw./km2]            1966             94.7
# ...                               ...             ...              ...
# 12254  Bevölkerungsdichte [Einw./km2]            2019            942.4
# 12255  Bevölkerungsdichte [Einw./km2]            2020            951.5
# 12256  Bevölkerungsdichte [Einw./km2]            2021            958.3
# 12257  Bevölkerungsdichte [Einw./km2]            2022            967.6
# 12258  Bevölkerungsdichte [Einw./km2]            2023            990.5
#
#       EINHEIT_KURZ                    EINHEIT_LANG  Unnamed: 11
# 0        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 1        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 2        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 3        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 4        Einw./km2  Einwohner pro Quadratkilometer          NaN
# ...            ...                             ...          ...
# 12254    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12255    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12256    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12257    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12258    Einw./km2  Einwohner pro Quadratkilometer          NaN
#
# [12259 rows x 12 columns]

# %%
#Save original data files to csv, if the folder is not aleady created, it will be created
directory = 'Original_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Bevoelkerungsdichte_KantonZurich_2010_2023.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

Bevoelkerungsdichte_df.to_csv(csv_path, index=False)
print(Bevoelkerungsdichte_df)
# Out:
#        BFS_NR             GEBIET_NAME                THEMA_NAME  \
# 0           1             Aeugst a.A.  Bevölkerung und Soziales
# 1           1             Aeugst a.A.  Bevölkerung und Soziales
# 2           1             Aeugst a.A.  Bevölkerung und Soziales
# 3           1             Aeugst a.A.  Bevölkerung und Soziales
# 4           1             Aeugst a.A.  Bevölkerung und Soziales
# ...       ...                     ...                       ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12255       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12256       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12257       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
# 12258       0  Zürich - ganzer Kanton  Bevölkerung und Soziales
#
#                                 SET_NAME          SUBSET_NAME  INDIKATOR_ID  \
# 0      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 1      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 2      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 3      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 4      Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# ...                                  ...                  ...           ...
# 12254  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12255  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12256  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12257  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
# 12258  Bevölkerungsbestand und Haushalte  Bevölkerungsbestand           460
#
#                        INDIKATOR_NAME  INDIKATOR_JAHR  INDIKATOR_VALUE  \
# 0      Bevölkerungsdichte [Einw./km2]            1962             90.2
# 1      Bevölkerungsdichte [Einw./km2]            1963             91.5
# 2      Bevölkerungsdichte [Einw./km2]            1964             89.6
# 3      Bevölkerungsdichte [Einw./km2]            1965             88.3
# 4      Bevölkerungsdichte [Einw./km2]            1966             94.7
# ...                               ...             ...              ...
# 12254  Bevölkerungsdichte [Einw./km2]            2019            942.4
# 12255  Bevölkerungsdichte [Einw./km2]            2020            951.5
# 12256  Bevölkerungsdichte [Einw./km2]            2021            958.3
# 12257  Bevölkerungsdichte [Einw./km2]            2022            967.6
# 12258  Bevölkerungsdichte [Einw./km2]            2023            990.5
#
#       EINHEIT_KURZ                    EINHEIT_LANG  Unnamed: 11
# 0        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 1        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 2        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 3        Einw./km2  Einwohner pro Quadratkilometer          NaN
# 4        Einw./km2  Einwohner pro Quadratkilometer          NaN
# ...            ...                             ...          ...
# 12254    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12255    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12256    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12257    Einw./km2  Einwohner pro Quadratkilometer          NaN
# 12258    Einw./km2  Einwohner pro Quadratkilometer          NaN
#
# [12259 rows x 12 columns]

# %% [markdown]
# Drop not needed Columns, Filter the Data to the years 2009-2023, Delete the summarized Datarows an as well unify the Region Names so the data can be analyzed with the other available datasets. Afterwards save a Cleaned csv file to the Cleaned CSV Files folder.

# %%
Bevoelkerungsdichte_df.drop(['THEMA_NAME','SET_NAME','SUBSET_NAME','INDIKATOR_ID','EINHEIT_KURZ','Unnamed: 11'], axis=1, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR             GEBIET_NAME                  INDIKATOR_NAME  \
# 0           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 1           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 2           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 3           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 4           1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# ...       ...                     ...                             ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12255       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12256       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12257       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12258       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
#
#        INDIKATOR_JAHR  INDIKATOR_VALUE                    EINHEIT_LANG
# 0                1962             90.2  Einwohner pro Quadratkilometer
# 1                1963             91.5  Einwohner pro Quadratkilometer
# 2                1964             89.6  Einwohner pro Quadratkilometer
# 3                1965             88.3  Einwohner pro Quadratkilometer
# 4                1966             94.7  Einwohner pro Quadratkilometer
# ...               ...              ...                             ...
# 12254            2019            942.4  Einwohner pro Quadratkilometer
# 12255            2020            951.5  Einwohner pro Quadratkilometer
# 12256            2021            958.3  Einwohner pro Quadratkilometer
# 12257            2022            967.6  Einwohner pro Quadratkilometer
# 12258            2023            990.5  Einwohner pro Quadratkilometer
#
# [12259 rows x 6 columns]

# %%
Jahresindizes_zu_loeschen = Bevoelkerungsdichte_df[Bevoelkerungsdichte_df['INDIKATOR_JAHR'] < 2009].index
Bevoelkerungsdichte_df.drop(Jahresindizes_zu_loeschen, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR             GEBIET_NAME                  INDIKATOR_NAME  \
# 47          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 48          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 49          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 50          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# 51          1             Aeugst a.A.  Bevölkerungsdichte [Einw./km2]
# ...       ...                     ...                             ...
# 12254       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12255       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12256       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12257       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
# 12258       0  Zürich - ganzer Kanton  Bevölkerungsdichte [Einw./km2]
#
#        INDIKATOR_JAHR  INDIKATOR_VALUE                    EINHEIT_LANG
# 47               2009            220.7  Einwohner pro Quadratkilometer
# 48               2010            231.5  Einwohner pro Quadratkilometer
# 49               2011            242.8  Einwohner pro Quadratkilometer
# 50               2012            248.9  Einwohner pro Quadratkilometer
# 51               2013            250.3  Einwohner pro Quadratkilometer
# ...               ...              ...                             ...
# 12254            2019            942.4  Einwohner pro Quadratkilometer
# 12255            2020            951.5  Einwohner pro Quadratkilometer
# 12256            2021            958.3  Einwohner pro Quadratkilometer
# 12257            2022            967.6  Einwohner pro Quadratkilometer
# 12258            2023            990.5  Einwohner pro Quadratkilometer
#
# [2915 rows x 6 columns]

# %%
# Loesche alle Indizes, die den Wert '0' in der Spalte 'BFS_NR' haben da diese zusammengefasste Informationen pro Bezirk/Region enthalten
indizes_zu_loeschen = Bevoelkerungsdichte_df[Bevoelkerungsdichte_df['BFS_NR'] == 0].index
Bevoelkerungsdichte_df.drop(indizes_zu_loeschen, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2009
# 48          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2010
# 49          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2011
# 50          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2012
# 51          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2555 rows x 6 columns]

# %%
#Einige Datensätze beinhalten im Gemeindenamen (bis *) um zu indizieren dass die Rechnung sich auf die angegbenen JAhre bezieht. Um Redundanzen zu vermeiden, werden diese entfernt
indizesBis_zu_loeschen = Bevoelkerungsdichte_df[Bevoelkerungsdichte_df['GEBIET_NAME'].str.contains("\(bis ", na=False)].index
Bevoelkerungsdichte_df.drop(indizesBis_zu_loeschen, inplace=True)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2009
# 48          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2010
# 49          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2011
# 50          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2012
# 51          1   Aeugst a.A.  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2391 rows x 6 columns]

# %%
# Vereinheitlichen der Gemeindenamen
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Aeugst a.A.', 'Aeugst', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Affoltern a.A.', 'Affoltern', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Hausen a.A.', 'Hausen', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Kappel a.A.', 'Kappel', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Wettswil a.A.', 'Wettswil', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Berg a.I.', 'Berg', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Buch a.I.', 'Buch', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Thalheim a.d.Th.', 'Thalheim', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Langnau a.A.', 'Langnau', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Oetwil a.S.', 'Oetwil', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Uetikon a.S.', 'Uetikon', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Ellikon a.d.Th.', 'Ellikon', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Oetwil a.d.L.', 'Oetwil an der Limmat', regex=False)
Bevoelkerungsdichte_df['GEBIET_NAME'] = Bevoelkerungsdichte_df['GEBIET_NAME'].str.replace('Aesch ZH', 'Aesch', regex=False)
Bevoelkerungsdichte_df
# Out:
#        BFS_NR   GEBIET_NAME                  INDIKATOR_NAME  INDIKATOR_JAHR  \
# 47          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2009
# 48          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2010
# 49          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2011
# 50          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2012
# 51          1        Aeugst  Bevölkerungsdichte [Einw./km2]            2013
# ...       ...           ...                             ...             ...
# 10766     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2019
# 10767     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2020
# 10768     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2021
# 10769     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2022
# 10770     298  Wiesendangen  Bevölkerungsdichte [Einw./km2]            2023
#
#        INDIKATOR_VALUE                    EINHEIT_LANG
# 47               220.7  Einwohner pro Quadratkilometer
# 48               231.5  Einwohner pro Quadratkilometer
# 49               242.8  Einwohner pro Quadratkilometer
# 50               248.9  Einwohner pro Quadratkilometer
# 51               250.3  Einwohner pro Quadratkilometer
# ...                ...                             ...
# 10766            345.1  Einwohner pro Quadratkilometer
# 10767            346.9  Einwohner pro Quadratkilometer
# 10768            348.1  Einwohner pro Quadratkilometer
# 10769            350.2  Einwohner pro Quadratkilometer
# 10770            351.4  Einwohner pro Quadratkilometer
#
# [2391 rows x 6 columns]

# %%
# Tabelle umformen mit pivot_table
pivot_df = Bevoelkerungsdichte_df.pivot_table(index=['BFS_NR', 'GEBIET_NAME', 'INDIKATOR_JAHR'], 
                                     columns='INDIKATOR_NAME', 
                                     values=['INDIKATOR_VALUE'])

pivot_df.columns = [f'{col[0]}_{col[1]}' for col in pivot_df.columns]

pivot_df.reset_index(inplace=True)

# Spalte umbenennen
pivot_df.rename(columns={'INDIKATOR_VALUE_Bevölkerungsdichte [Einw./km2]': 'Einwohner pro Quadratkilometer'}, inplace=True)
pivot_df.rename(columns={'GEBIET_NAME': 'Gemeindename'}, inplace=True)
pivot_df.rename(columns={'INDIKATOR_JAHR': 'Jahr'}, inplace=True)

print(pivot_df)
# Out:
#       BFS_NR  Gemeindename  Jahr  Einwohner pro Quadratkilometer
# 0          1        Aeugst  2009                           220.7
# 1          1        Aeugst  2010                           231.5
# 2          1        Aeugst  2011                           242.8
# 3          1        Aeugst  2012                           248.9
# 4          1        Aeugst  2013                           250.3
# ...      ...           ...   ...                             ...
# 2386     298  Wiesendangen  2019                           345.1
# 2387     298  Wiesendangen  2020                           346.9
# 2388     298  Wiesendangen  2021                           348.1
# 2389     298  Wiesendangen  2022                           350.2
# 2390     298  Wiesendangen  2023                           351.4
#
# [2391 rows x 4 columns]

# %%
directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Bevoelkerungsdichte_KantonZurich_2010_2023_Cleaned.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

pivot_df.to_csv(csv_path, index=False)
print(pivot_df)
# Out:
#       BFS_NR  Gemeindename  Jahr  Einwohner pro Quadratkilometer
# 0          1        Aeugst  2009                           220.7
# 1          1        Aeugst  2010                           231.5
# 2          1        Aeugst  2011                           242.8
# 3          1        Aeugst  2012                           248.9
# 4          1        Aeugst  2013                           250.3
# ...      ...           ...   ...                             ...
# 2386     298  Wiesendangen  2019                           345.1
# 2387     298  Wiesendangen  2020                           346.9
# 2388     298  Wiesendangen  2021                           348.1
# 2389     298  Wiesendangen  2022                           350.2
# 2390     298  Wiesendangen  2023                           351.4
#
# [2391 rows x 4 columns]

# %% [markdown]
# Print the Information for the Dataframe so we can create the Table for the Database correspondingly.

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2391 entries, 0 to 2390
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BFS_NR                          2391 non-null   int64
#  1   Gemeindename                    2391 non-null   object
#  2   Jahr                            2391 non-null   int64
#  3   Einwohner pro Quadratkilometer  2391 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 74.8+ KB

# %% [markdown]
# Connect to the database and create a new table called Bevoelkerungsdichte. If the table is already existing drop it.

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

# MySQL connection parameters
host = 'localhost'
user = 'admin'
password = 'Criminal1234'
database = 'CriminalDataDB'  
try:
    connection = mysql.connector.connect(host=host,
                                         user=user,
                                         password=password,
                                         database=database)

    if connection.is_connected():
        print("Connected to MySQL server")
        cursor = connection.cursor()

        # SQL command to drop the table if it already exists becuase before that line of code the data was already inserted multiple times
        drop_table_query = "DROP TABLE IF EXISTS Bevoelkerungsdichte;"
        cursor.execute(drop_table_query)
        print("Table 'Bevoelkerungsdichte' dropped if it existed alreadyy")

        create_table_query = """
        CREATE TABLE IF NOT EXISTS Bevoelkerungsdichte (
            BFS_NR INT,
            Gemeindename VARCHAR(255),
            Jahr INT,
            Einwohner_pro_Quadratkilometer FLOAT
        )
        """

        cursor.execute(create_table_query)
        print("Table 'Bevoelkerungsdichte' created successfully")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Table 'Bevoelkerungsdichte' dropped if it existed alreadyy
# Table 'Bevoelkerungsdichte' created successfully
# MySQL connection closed

# %% [markdown]
# Insert the Cleanaed data from the Cleaned Csv file which was created before.

# %%
import mysql.connector 
from mysql.connector import Error
import pandas as pd

# MySQL connection parameters
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB',
    'allow_local_infile': True
}

directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()
csv_file_path = os.path.join(current_directory, directory, 'Bevoelkerungsdichte_KantonZurich_2010_2023_Cleaned.csv')

try:
    with mysql.connector.connect(**connection_params) as connection:
        print("Connected to MySQL server")

        Bevoelkerungsdichte_df_to_sql = pd.read_csv(csv_file_path)

        cursor = connection.cursor()
        insert_query = """
        LOAD DATA LOCAL INFILE %s 
        INTO TABLE Bevoelkerungsdichte 
        FIELDS TERMINATED BY ',' 
        ENCLOSED BY '"' 
        LINES TERMINATED BY '\n' 
        IGNORE 1 LINES
        """

        cursor.execute(insert_query, (csv_file_path,))
        connection.commit()

        print("Data from CSV file successfully inserted into MySQL table 'Bevoelkerungsdichte'")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Data from CSV file successfully inserted into MySQL table 'Bevoelkerungsdichte'

# %% [markdown]
# Check if the Data upload to the table was successfully by creating a query to the sql table.

# %%
import mysql.connector
from mysql.connector import Error

# MySQL connection parameters
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB'
}

try:
    connection = mysql.connector.connect(**connection_params)
    print("Connected to MySQL server")

    with connection.cursor() as cursor:
        select_query = "SELECT * FROM Bevoelkerungsdichte"

        cursor.execute(select_query)
        rows = cursor.fetchall()

        for row in rows:
            print(row)

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if 'connection' in locals() and connection.is_connected():
        # Close connection
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# (1, 'Aeugst', 2009, 220.7)
# (1, 'Aeugst', 2010, 231.5)
# (1, 'Aeugst', 2011, 242.8)
# (1, 'Aeugst', 2012, 248.9)
# (1, 'Aeugst', 2013, 250.3)
# (1, 'Aeugst', 2014, 248.0)
# (1, 'Aeugst', 2015, 252.4)
# (1, 'Aeugst', 2016, 250.2)
# (1, 'Aeugst', 2017, 245.7)
# (1, 'Aeugst', 2018, 250.5)
# (1, 'Aeugst', 2019, 250.8)
# (1, 'Aeugst', 2020, 254.6)
# (1, 'Aeugst', 2021, 251.4)
# (1, 'Aeugst', 2022, 252.0)
# (1, 'Aeugst', 2023, 252.5)
# (2, 'Affoltern', 2009, 1009.9)
# (2, 'Affoltern', 2010, 1043.7)
# (2, 'Affoltern', 2011, 1050.9)
# (2, 'Affoltern', 2012, 1062.7)
# (2, 'Affoltern', 2013, 1070.0)
# (2, 'Affoltern', 2014, 1088.7)
# (2, 'Affoltern', 2015, 1103.3)
# (2, 'Affoltern', 2016, 1119.6)
# (2, 'Affoltern', 2017, 1139.6)
# (2, 'Affoltern', 2018, 1158.7)
# (2, 'Affoltern', 2019, 1168.9)
# (2, 'Affoltern', 2020, 1163.0)
# (2, 'Affoltern', 2021, 1173.6)
# (2, 'Affoltern', 2022, 1189.4)
# (2, 'Affoltern', 2023, 1216.7)
# (3, 'Bonstetten', 2009, 686.6)
# (3, 'Bonstetten', 2010, 693.2)
# (3, 'Bonstetten', 2011, 693.4)
# (3, 'Bonstetten', 2012, 696.8)
# (3, 'Bonstetten', 2013, 705.2)
# (3, 'Bonstetten', 2014, 708.6)
# (3, 'Bonstetten', 2015, 714.4)
# (3, 'Bonstetten', 2016, 727.8)
# (3, 'Bonstetten', 2017, 737.0)
# (3, 'Bonstetten', 2018, 744.5)
# (3, 'Bonstetten', 2019, 749.5)
# (3, 'Bonstetten', 2020, 754.0)
# (3, 'Bonstetten', 2021, 757.0)
# (3, 'Bonstetten', 2022, 755.2)
# (3, 'Bonstetten', 2023, 760.3)
# (4, 'Hausen', 2009, 241.7)
# (4, 'Hausen', 2010, 245.8)
# (4, 'Hausen', 2011, 245.8)
# (4, 'Hausen', 2012, 246.5)
# (4, 'Hausen', 2013, 249.7)
# (4, 'Hausen', 2014, 253.6)
# (4, 'Hausen', 2015, 254.1)
# (4, 'Hausen', 2016, 259.9)
# (4, 'Hausen', 2017, 266.5)
# (4, 'Hausen', 2018, 270.9)
# (4, 'Hausen', 2019, 275.1)
# (4, 'Hausen', 2020, 278.6)
# (4, 'Hausen', 2021, 282.5)
# (4, 'Hausen', 2022, 284.1)
# (4, 'Hausen', 2023, 290.7)
# (5, 'Hedingen', 2009, 521.3)
# (5, 'Hedingen', 2010, 521.9)
# (5, 'Hedingen', 2011, 530.5)
# (5, 'Hedingen', 2012, 536.9)
# (5, 'Hedingen', 2013, 549.0)
# (5, 'Hedingen', 2014, 558.2)
# (5, 'Hedingen', 2015, 559.7)
# (5, 'Hedingen', 2016, 561.6)
# (5, 'Hedingen', 2017, 563.2)
# (5, 'Hedingen', 2018, 568.4)
# (5, 'Hedingen', 2019, 575.5)
# (5, 'Hedingen', 2020, 578.2)
# (5, 'Hedingen', 2021, 575.8)
# (5, 'Hedingen', 2022, 589.0)
# (5, 'Hedingen', 2023, 600.8)
# (6, 'Kappel', 2009, 112.6)
# (6, 'Kappel', 2010, 117.2)
# (6, 'Kappel', 2011, 121.6)
# (6, 'Kappel', 2012, 117.8)
# (6, 'Kappel', 2013, 122.0)
# (6, 'Kappel', 2014, 129.5)
# (6, 'Kappel', 2015, 131.4)
# (6, 'Kappel', 2016, 141.8)
# (6, 'Kappel', 2017, 143.6)
# (6, 'Kappel', 2018, 148.1)
# (6, 'Kappel', 2019, 156.1)
# (6, 'Kappel', 2020, 159.1)
# (6, 'Kappel', 2021, 164.6)
# (6, 'Kappel', 2022, 168.9)
# (6, 'Kappel', 2023, 169.1)
# (7, 'Knonau', 2009, 267.1)
# (7, 'Knonau', 2010, 276.8)
# (7, 'Knonau', 2011, 290.9)
# (7, 'Knonau', 2012, 304.0)
# (7, 'Knonau', 2013, 307.1)
# (7, 'Knonau', 2014, 312.3)
# (7, 'Knonau', 2015, 321.7)
# (7, 'Knonau', 2016, 331.5)
# (7, 'Knonau', 2017, 353.5)
# (7, 'Knonau', 2018, 365.3)
# (7, 'Knonau', 2019, 365.6)
# (7, 'Knonau', 2020, 364.9)
# (7, 'Knonau', 2021, 376.9)
# (7, 'Knonau', 2022, 371.5)
# (7, 'Knonau', 2023, 376.0)
# (8, 'Maschwanden', 2009, 125.6)
# (8, 'Maschwanden', 2010, 130.8)
# (8, 'Maschwanden', 2011, 137.0)
# (8, 'Maschwanden', 2012, 137.0)
# (8, 'Maschwanden', 2013, 141.9)
# (8, 'Maschwanden', 2014, 141.9)
# (8, 'Maschwanden', 2015, 136.3)
# (8, 'Maschwanden', 2016, 132.5)
# (8, 'Maschwanden', 2017, 135.9)
# (8, 'Maschwanden', 2018, 138.5)
# (8, 'Maschwanden', 2019, 136.8)
# (8, 'Maschwanden', 2020, 135.9)
# (8, 'Maschwanden', 2021, 137.0)
# (8, 'Maschwanden', 2022, 137.6)
# (8, 'Maschwanden', 2023, 137.2)
# (9, 'Mettmenstetten', 2009, 316.8)
# (9, 'Mettmenstetten', 2010, 325.3)
# (9, 'Mettmenstetten', 2011, 335.3)
# (9, 'Mettmenstetten', 2012, 338.2)
# (9, 'Mettmenstetten', 2013, 338.7)
# (9, 'Mettmenstetten', 2014, 342.0)
# (9, 'Mettmenstetten', 2015, 357.0)
# (9, 'Mettmenstetten', 2016, 371.2)
# (9, 'Mettmenstetten', 2017, 372.8)
# (9, 'Mettmenstetten', 2018, 389.7)
# (9, 'Mettmenstetten', 2019, 397.8)
# (9, 'Mettmenstetten', 2020, 411.5)
# (9, 'Mettmenstetten', 2021, 425.9)
# (9, 'Mettmenstetten', 2022, 430.4)
# (9, 'Mettmenstetten', 2023, 434.8)
# (10, 'Obfelden', 2009, 614.6)
# (10, 'Obfelden', 2010, 620.1)
# (10, 'Obfelden', 2011, 629.9)
# (10, 'Obfelden', 2012, 639.5)
# (10, 'Obfelden', 2013, 643.8)
# (10, 'Obfelden', 2014, 652.3)
# (10, 'Obfelden', 2015, 663.2)
# (10, 'Obfelden', 2016, 678.0)
# (10, 'Obfelden', 2017, 707.3)
# (10, 'Obfelden', 2018, 738.1)
# (10, 'Obfelden', 2019, 757.3)
# (10, 'Obfelden', 2020, 764.3)
# (10, 'Obfelden', 2021, 761.2)
# (10, 'Obfelden', 2022, 764.4)
# (10, 'Obfelden', 2023, 772.8)
# (11, 'Ottenbach', 2009, 478.7)
# (11, 'Ottenbach', 2010, 484.3)
# (11, 'Ottenbach', 2011, 493.8)
# (11, 'Ottenbach', 2012, 497.8)
# (11, 'Ottenbach', 2013, 497.0)
# (11, 'Ottenbach', 2014, 510.4)
# (11, 'Ottenbach', 2015, 515.3)
# (11, 'Ottenbach', 2016, 517.7)
# (11, 'Ottenbach', 2017, 513.3)
# (11, 'Ottenbach', 2018, 509.6)
# (11, 'Ottenbach', 2019, 517.6)
# (11, 'Ottenbach', 2020, 540.1)
# (11, 'Ottenbach', 2021, 547.5)
# (11, 'Ottenbach', 2022, 568.3)
# (11, 'Ottenbach', 2023, 588.8)
# (12, 'Rifferswil', 2009, 133.3)
# (12, 'Rifferswil', 2010, 137.0)
# (12, 'Rifferswil', 2011, 142.0)
# (12, 'Rifferswil', 2012, 145.7)
# (12, 'Rifferswil', 2013, 146.0)
# (12, 'Rifferswil', 2014, 152.1)
# (12, 'Rifferswil', 2015, 160.7)
# (12, 'Rifferswil', 2016, 163.6)
# (12, 'Rifferswil', 2017, 166.8)
# (12, 'Rifferswil', 2018, 170.5)
# (12, 'Rifferswil', 2019, 171.6)
# (12, 'Rifferswil', 2020, 174.6)
# (12, 'Rifferswil', 2021, 174.9)
# (12, 'Rifferswil', 2022, 174.8)
# (12, 'Rifferswil', 2023, 174.0)
# (13, 'Stallikon', 2009, 251.4)
# (13, 'Stallikon', 2010, 263.1)
# (13, 'Stallikon', 2011, 271.9)
# (13, 'Stallikon', 2012, 274.5)
# (13, 'Stallikon', 2013, 276.5)
# (13, 'Stallikon', 2014, 273.9)
# (13, 'Stallikon', 2015, 286.3)
# (13, 'Stallikon', 2016, 302.2)
# (13, 'Stallikon', 2017, 307.0)
# (13, 'Stallikon', 2018, 305.8)
# (13, 'Stallikon', 2019, 312.2)
# (13, 'Stallikon', 2020, 314.9)
# (13, 'Stallikon', 2021, 318.4)
# (13, 'Stallikon', 2022, 320.7)
# (13, 'Stallikon', 2023, 321.2)
# (14, 'Wettswil', 2009, 1180.1)
# (14, 'Wettswil', 2010, 1197.6)
# (14, 'Wettswil', 2011, 1217.2)
# (14, 'Wettswil', 2012, 1213.3)
# (14, 'Wettswil', 2013, 1228.9)
# (14, 'Wettswil', 2014, 1249.6)
# (14, 'Wettswil', 2015, 1305.0)
# (14, 'Wettswil', 2016, 1354.1)
# (14, 'Wettswil', 2017, 1352.0)
# (14, 'Wettswil', 2018, 1379.2)
# (14, 'Wettswil', 2019, 1396.0)
# (14, 'Wettswil', 2020, 1407.5)
# (14, 'Wettswil', 2021, 1409.6)
# (14, 'Wettswil', 2022, 1408.3)
# (14, 'Wettswil', 2023, 1414.9)
# (22, 'Benken', 2009, 136.7)
# (22, 'Benken', 2010, 140.9)
# (22, 'Benken', 2011, 144.4)
# (22, 'Benken', 2012, 145.1)
# (22, 'Benken', 2013, 146.0)
# (22, 'Benken', 2014, 145.3)
# (22, 'Benken', 2015, 151.5)
# (22, 'Benken', 2016, 151.3)
# (22, 'Benken', 2017, 151.1)
# (22, 'Benken', 2018, 151.1)
# (22, 'Benken', 2019, 149.6)
# (22, 'Benken', 2020, 150.4)
# (22, 'Benken', 2021, 149.5)
# (22, 'Benken', 2022, 149.6)
# (22, 'Benken', 2023, 150.0)
# (23, 'Berg', 2009, 84.0)
# (23, 'Berg', 2010, 84.8)
# (23, 'Berg', 2011, 83.0)
# (23, 'Berg', 2012, 83.1)
# (23, 'Berg', 2013, 81.6)
# (23, 'Berg', 2014, 82.0)
# (23, 'Berg', 2015, 80.3)
# (23, 'Berg', 2016, 80.3)
# (23, 'Berg', 2017, 79.6)
# (23, 'Berg', 2018, 80.9)
# (23, 'Berg', 2019, 82.2)
# (23, 'Berg', 2020, 84.6)
# (23, 'Berg', 2021, 84.1)
# (23, 'Berg', 2022, 84.2)
# (23, 'Berg', 2023, 85.5)
# (24, 'Buch', 2009, 82.1)
# (24, 'Buch', 2010, 85.7)
# (24, 'Buch', 2011, 87.8)
# (24, 'Buch', 2012, 88.2)
# (24, 'Buch', 2013, 90.3)
# (24, 'Buch', 2014, 90.7)
# (24, 'Buch', 2015, 94.4)
# (24, 'Buch', 2016, 93.8)
# (24, 'Buch', 2017, 95.3)
# (24, 'Buch', 2018, 96.2)
# (24, 'Buch', 2019, 96.4)
# (24, 'Buch', 2020, 100.6)
# (24, 'Buch', 2021, 101.0)
# (24, 'Buch', 2022, 102.2)
# (24, 'Buch', 2023, 101.6)
# (25, 'Dachsen', 2009, 713.4)
# (25, 'Dachsen', 2010, 721.6)
# (25, 'Dachsen', 2011, 726.4)
# (25, 'Dachsen', 2012, 726.8)
# (25, 'Dachsen', 2013, 735.7)
# (25, 'Dachsen', 2014, 743.9)
# (25, 'Dachsen', 2015, 738.3)
# (25, 'Dachsen', 2016, 739.0)
# (25, 'Dachsen', 2017, 717.8)
# (25, 'Dachsen', 2018, 720.3)
# (25, 'Dachsen', 2019, 720.3)
# (25, 'Dachsen', 2020, 718.8)
# (25, 'Dachsen', 2021, 732.3)
# (25, 'Dachsen', 2022, 733.5)
# (25, 'Dachsen', 2023, 742.1)
# (26, 'Dorf', 2009, 114.4)
# (26, 'Dorf', 2010, 114.3)
# (26, 'Dorf', 2011, 114.3)
# (26, 'Dorf', 2012, 114.4)
# (26, 'Dorf', 2013, 111.9)
# (26, 'Dorf', 2014, 116.1)
# (26, 'Dorf', 2015, 113.2)
# (26, 'Dorf', 2016, 113.0)
# (26, 'Dorf', 2017, 123.5)
# (26, 'Dorf', 2018, 118.8)
# (26, 'Dorf', 2019, 118.8)
# (26, 'Dorf', 2020, 120.0)
# (26, 'Dorf', 2021, 125.5)
# (26, 'Dorf', 2022, 128.5)
# (26, 'Dorf', 2023, 130.1)
# (27, 'Feuerthalen', 2009, 1376.0)
# (27, 'Feuerthalen', 2010, 1386.8)
# (27, 'Feuerthalen', 2011, 1385.6)
# (27, 'Feuerthalen', 2012, 1383.6)
# (27, 'Feuerthalen', 2013, 1393.2)
# (27, 'Feuerthalen', 2014, 1398.8)
# (27, 'Feuerthalen', 2015, 1425.6)
# (27, 'Feuerthalen', 2016, 1435.6)
# (27, 'Feuerthalen', 2017, 1454.4)
# (27, 'Feuerthalen', 2018, 1448.8)
# (27, 'Feuerthalen', 2019, 1442.0)
# (27, 'Feuerthalen', 2020, 1480.0)
# (27, 'Feuerthalen', 2021, 1505.6)
# (27, 'Feuerthalen', 2022, 1506.4)
# (27, 'Feuerthalen', 2023, 1524.4)
# (28, 'Flaach', 2009, 120.4)
# (28, 'Flaach', 2010, 119.9)
# (28, 'Flaach', 2011, 122.3)
# (28, 'Flaach', 2012, 130.4)
# (28, 'Flaach', 2013, 132.5)
# (28, 'Flaach', 2014, 133.4)
# (28, 'Flaach', 2015, 133.0)
# (28, 'Flaach', 2016, 132.7)
# (28, 'Flaach', 2017, 134.8)
# (28, 'Flaach', 2018, 137.9)
# (28, 'Flaach', 2019, 139.2)
# (28, 'Flaach', 2020, 139.9)
# (28, 'Flaach', 2021, 141.1)
# (28, 'Flaach', 2022, 144.5)
# (28, 'Flaach', 2023, 146.0)
# (29, 'Flurlingen', 2009, 585.8)
# (29, 'Flurlingen', 2010, 595.8)
# (29, 'Flurlingen', 2011, 595.8)
# (29, 'Flurlingen', 2012, 589.6)
# (29, 'Flurlingen', 2013, 583.8)
# (29, 'Flurlingen', 2014, 591.7)
# (29, 'Flurlingen', 2015, 598.8)
# (29, 'Flurlingen', 2016, 597.1)
# (29, 'Flurlingen', 2017, 598.8)
# (29, 'Flurlingen', 2018, 598.8)
# (29, 'Flurlingen', 2019, 615.4)
# (29, 'Flurlingen', 2020, 648.3)
# (29, 'Flurlingen', 2021, 631.7)
# (29, 'Flurlingen', 2022, 630.8)
# (29, 'Flurlingen', 2023, 629.2)
# (31, 'Henggart', 2009, 709.8)
# (31, 'Henggart', 2010, 723.5)
# (31, 'Henggart', 2011, 731.7)
# (31, 'Henggart', 2012, 734.6)
# (31, 'Henggart', 2013, 742.8)
# (31, 'Henggart', 2014, 743.1)
# (31, 'Henggart', 2015, 735.3)
# (31, 'Henggart', 2016, 732.0)
# (31, 'Henggart', 2017, 737.3)
# (31, 'Henggart', 2018, 737.8)
# (31, 'Henggart', 2019, 735.2)
# (31, 'Henggart', 2020, 754.6)
# (31, 'Henggart', 2021, 757.2)
# (31, 'Henggart', 2022, 742.4)
# (31, 'Henggart', 2023, 762.5)
# (33, 'Kleinandelfingen', 2009, 201.2)
# (33, 'Kleinandelfingen', 2010, 201.8)
# (33, 'Kleinandelfingen', 2011, 196.5)
# (33, 'Kleinandelfingen', 2012, 195.1)
# (33, 'Kleinandelfingen', 2013, 198.1)
# (33, 'Kleinandelfingen', 2014, 200.5)
# (33, 'Kleinandelfingen', 2015, 201.0)
# (33, 'Kleinandelfingen', 2016, 200.5)
# (33, 'Kleinandelfingen', 2017, 201.8)
# (33, 'Kleinandelfingen', 2018, 205.0)
# (33, 'Kleinandelfingen', 2019, 201.8)
# (33, 'Kleinandelfingen', 2020, 204.6)
# (33, 'Kleinandelfingen', 2021, 207.2)
# (33, 'Kleinandelfingen', 2022, 207.1)
# (33, 'Kleinandelfingen', 2023, 212.9)
# (34, 'Laufen-Uhwiesen', 2009, 242.6)
# (34, 'Laufen-Uhwiesen', 2010, 241.8)
# (34, 'Laufen-Uhwiesen', 2011, 245.3)
# (34, 'Laufen-Uhwiesen', 2012, 249.6)
# (34, 'Laufen-Uhwiesen', 2013, 259.5)
# (34, 'Laufen-Uhwiesen', 2014, 261.6)
# (34, 'Laufen-Uhwiesen', 2015, 262.2)
# (34, 'Laufen-Uhwiesen', 2016, 263.0)
# (34, 'Laufen-Uhwiesen', 2017, 267.0)
# (34, 'Laufen-Uhwiesen', 2018, 271.4)
# (34, 'Laufen-Uhwiesen', 2019, 279.7)
# (34, 'Laufen-Uhwiesen', 2020, 283.0)
# (34, 'Laufen-Uhwiesen', 2021, 283.0)
# (34, 'Laufen-Uhwiesen', 2022, 283.0)
# (34, 'Laufen-Uhwiesen', 2023, 287.8)
# (35, 'Marthalen', 2009, 134.0)
# (35, 'Marthalen', 2010, 136.7)
# (35, 'Marthalen', 2011, 139.6)
# (35, 'Marthalen', 2012, 138.8)
# (35, 'Marthalen', 2013, 139.8)
# (35, 'Marthalen', 2014, 140.4)
# (35, 'Marthalen', 2015, 137.8)
# (35, 'Marthalen', 2016, 137.0)
# (35, 'Marthalen', 2017, 137.7)
# (35, 'Marthalen', 2018, 134.3)
# (35, 'Marthalen', 2019, 134.7)
# (35, 'Marthalen', 2020, 136.2)
# (35, 'Marthalen', 2021, 136.1)
# (35, 'Marthalen', 2022, 137.6)
# (35, 'Marthalen', 2023, 137.6)
# (37, 'Ossingen', 2009, 102.9)
# (37, 'Ossingen', 2010, 102.3)
# (37, 'Ossingen', 2011, 103.0)
# (37, 'Ossingen', 2012, 102.8)
# (37, 'Ossingen', 2013, 103.6)
# (37, 'Ossingen', 2014, 105.9)
# (37, 'Ossingen', 2015, 108.5)
# (37, 'Ossingen', 2016, 110.7)
# (37, 'Ossingen', 2017, 119.5)
# (37, 'Ossingen', 2018, 124.8)
# (37, 'Ossingen', 2019, 127.2)
# (37, 'Ossingen', 2020, 131.9)
# (37, 'Ossingen', 2021, 129.6)
# (37, 'Ossingen', 2022, 130.6)
# (37, 'Ossingen', 2023, 129.6)
# (38, 'Rheinau', 2009, 149.0)
# (38, 'Rheinau', 2010, 145.6)
# (38, 'Rheinau', 2011, 147.4)
# (38, 'Rheinau', 2012, 150.7)
# (38, 'Rheinau', 2013, 147.9)
# (38, 'Rheinau', 2014, 146.9)
# (38, 'Rheinau', 2015, 147.4)
# (38, 'Rheinau', 2016, 145.7)
# (38, 'Rheinau', 2017, 145.4)
# (38, 'Rheinau', 2018, 147.7)
# (38, 'Rheinau', 2019, 146.8)
# (38, 'Rheinau', 2020, 144.1)
# (38, 'Rheinau', 2021, 144.5)
# (38, 'Rheinau', 2022, 143.4)
# (38, 'Rheinau', 2023, 143.3)
# (39, 'Thalheim', 2009, 125.0)
# (39, 'Thalheim', 2010, 127.0)
# (39, 'Thalheim', 2011, 136.0)
# (39, 'Thalheim', 2012, 139.4)
# (39, 'Thalheim', 2013, 142.2)
# (39, 'Thalheim', 2014, 142.2)
# (39, 'Thalheim', 2015, 140.2)
# (39, 'Thalheim', 2016, 140.5)
# (39, 'Thalheim', 2017, 143.2)
# (39, 'Thalheim', 2018, 142.2)
# (39, 'Thalheim', 2019, 146.0)
# (39, 'Thalheim', 2020, 147.8)
# (39, 'Thalheim', 2021, 151.3)
# (39, 'Thalheim', 2022, 151.8)
# (39, 'Thalheim', 2023, 159.2)
# (40, 'Trüllikon', 2009, 104.2)
# (40, 'Trüllikon', 2010, 103.9)
# (40, 'Trüllikon', 2011, 103.8)
# (40, 'Trüllikon', 2012, 102.7)
# (40, 'Trüllikon', 2013, 103.5)
# (40, 'Trüllikon', 2014, 106.0)
# (40, 'Trüllikon', 2015, 106.1)
# (40, 'Trüllikon', 2016, 111.3)
# (40, 'Trüllikon', 2017, 110.3)
# (40, 'Trüllikon', 2018, 111.1)
# (40, 'Trüllikon', 2019, 110.5)
# (40, 'Trüllikon', 2020, 110.4)
# (40, 'Trüllikon', 2021, 110.9)
# (40, 'Trüllikon', 2022, 111.4)
# (40, 'Trüllikon', 2023, 114.0)
# (41, 'Truttikon', 2009, 107.0)
# (41, 'Truttikon', 2010, 107.2)
# (41, 'Truttikon', 2011, 105.9)
# (41, 'Truttikon', 2012, 105.0)
# (41, 'Truttikon', 2013, 101.8)
# (41, 'Truttikon', 2014, 104.5)
# (41, 'Truttikon', 2015, 106.8)
# (41, 'Truttikon', 2016, 105.9)
# (41, 'Truttikon', 2017, 107.7)
# (41, 'Truttikon', 2018, 108.6)
# (41, 'Truttikon', 2019, 105.5)
# (41, 'Truttikon', 2020, 102.3)
# (41, 'Truttikon', 2021, 102.7)
# (41, 'Truttikon', 2022, 105.5)
# (41, 'Truttikon', 2023, 107.0)
# (43, 'Volken', 2009, 94.5)
# (43, 'Volken', 2010, 94.8)
# (43, 'Volken', 2011, 93.9)
# (43, 'Volken', 2012, 95.1)
# (43, 'Volken', 2013, 93.3)
# (43, 'Volken', 2014, 103.7)
# (43, 'Volken', 2015, 103.7)
# (43, 'Volken', 2016, 102.8)
# (43, 'Volken', 2017, 103.1)
# (43, 'Volken', 2018, 110.4)
# (43, 'Volken', 2019, 115.9)
# (43, 'Volken', 2020, 116.8)
# (43, 'Volken', 2021, 119.5)
# (43, 'Volken', 2022, 116.2)
# (43, 'Volken', 2023, 115.9)
# (51, 'Bachenbülach', 2009, 884.1)
# (51, 'Bachenbülach', 2010, 901.9)
# (51, 'Bachenbülach', 2011, 930.5)
# (51, 'Bachenbülach', 2012, 934.5)
# (51, 'Bachenbülach', 2013, 941.3)
# (51, 'Bachenbülach', 2014, 947.3)
# (51, 'Bachenbülach', 2015, 938.5)
# (51, 'Bachenbülach', 2016, 945.9)
# (51, 'Bachenbülach', 2017, 953.8)
# (51, 'Bachenbülach', 2018, 969.5)
# (51, 'Bachenbülach', 2019, 971.8)
# (51, 'Bachenbülach', 2020, 979.7)
# (51, 'Bachenbülach', 2021, 983.9)
# (51, 'Bachenbülach', 2022, 979.3)
# (51, 'Bachenbülach', 2023, 1005.8)
# (52, 'Bassersdorf', 2009, 1209.1)
# (52, 'Bassersdorf', 2010, 1229.4)
# (52, 'Bassersdorf', 2011, 1241.0)
# (52, 'Bassersdorf', 2012, 1249.1)
# (52, 'Bassersdorf', 2013, 1259.0)
# (52, 'Bassersdorf', 2014, 1264.8)
# (52, 'Bassersdorf', 2015, 1286.0)
# (52, 'Bassersdorf', 2016, 1284.9)
# (52, 'Bassersdorf', 2017, 1289.5)
# (52, 'Bassersdorf', 2018, 1297.9)
# (52, 'Bassersdorf', 2019, 1316.1)
# (52, 'Bassersdorf', 2020, 1327.1)
# (52, 'Bassersdorf', 2021, 1329.6)
# (52, 'Bassersdorf', 2022, 1340.7)
# (52, 'Bassersdorf', 2023, 1351.9)
# (53, 'Bülach', 2009, 1058.0)
# (53, 'Bülach', 2010, 1085.6)
# (53, 'Bülach', 2011, 1085.2)
# (53, 'Bülach', 2012, 1113.5)
# (53, 'Bülach', 2013, 1139.6)
# (53, 'Bülach', 2014, 1170.7)
# (53, 'Bülach', 2015, 1201.4)
# (53, 'Bülach', 2016, 1211.4)
# (53, 'Bülach', 2017, 1230.9)
# (53, 'Bülach', 2018, 1269.4)
# (53, 'Bülach', 2019, 1328.5)
# (53, 'Bülach', 2020, 1368.2)
# (53, 'Bülach', 2021, 1381.7)
# (53, 'Bülach', 2022, 1469.1)
# (53, 'Bülach', 2023, 1502.0)
# (54, 'Dietlikon', 2009, 1670.4)
# (54, 'Dietlikon', 2010, 1671.3)
# (54, 'Dietlikon', 2011, 1681.8)
# (54, 'Dietlikon', 2012, 1697.6)
# (54, 'Dietlikon', 2013, 1710.7)
# (54, 'Dietlikon', 2014, 1792.4)
# (54, 'Dietlikon', 2015, 1802.1)
# (54, 'Dietlikon', 2016, 1789.3)
# (54, 'Dietlikon', 2017, 1821.1)
# (54, 'Dietlikon', 2018, 1832.1)
# (54, 'Dietlikon', 2019, 1848.8)
# (54, 'Dietlikon', 2020, 1855.4)
# (54, 'Dietlikon', 2021, 1856.8)
# (54, 'Dietlikon', 2022, 1850.5)
# (54, 'Dietlikon', 2023, 1893.6)
# (55, 'Eglisau', 2009, 431.5)
# (55, 'Eglisau', 2010, 464.0)
# (55, 'Eglisau', 2011, 494.5)
# (55, 'Eglisau', 2012, 517.7)
# (55, 'Eglisau', 2013, 543.4)
# (55, 'Eglisau', 2014, 546.4)
# (55, 'Eglisau', 2015, 553.0)
# (55, 'Eglisau', 2016, 567.0)
# (55, 'Eglisau', 2017, 569.4)
# (55, 'Eglisau', 2018, 572.2)
# (55, 'Eglisau', 2019, 586.3)
# (55, 'Eglisau', 2020, 604.3)
# (55, 'Eglisau', 2021, 605.9)
# (55, 'Eglisau', 2022, 607.5)
# (55, 'Eglisau', 2023, 620.1)
# (56, 'Embrach', 2009, 687.4)
# (56, 'Embrach', 2010, 695.1)
# (56, 'Embrach', 2011, 699.8)
# (56, 'Embrach', 2012, 704.5)
# (56, 'Embrach', 2013, 700.6)
# (56, 'Embrach', 2014, 713.0)
# (56, 'Embrach', 2015, 717.7)
# (56, 'Embrach', 2016, 719.1)
# (56, 'Embrach', 2017, 739.3)
# (56, 'Embrach', 2018, 741.7)
# (56, 'Embrach', 2019, 739.8)
# (56, 'Embrach', 2020, 754.7)
# (56, 'Embrach', 2021, 775.2)
# (56, 'Embrach', 2022, 786.2)
# (56, 'Embrach', 2023, 808.6)
# (57, 'Freienstein-Teufen', 2009, 273.7)
# (57, 'Freienstein-Teufen', 2010, 274.8)
# (57, 'Freienstein-Teufen', 2011, 273.7)
# (57, 'Freienstein-Teufen', 2012, 278.2)
# (57, 'Freienstein-Teufen', 2013, 274.5)
# (57, 'Freienstein-Teufen', 2014, 276.7)
# (57, 'Freienstein-Teufen', 2015, 276.5)
# (57, 'Freienstein-Teufen', 2016, 280.1)
# (57, 'Freienstein-Teufen', 2017, 284.6)
# (57, 'Freienstein-Teufen', 2018, 283.8)
# (57, 'Freienstein-Teufen', 2019, 286.6)
# (57, 'Freienstein-Teufen', 2020, 287.5)
# (57, 'Freienstein-Teufen', 2021, 287.3)
# (57, 'Freienstein-Teufen', 2022, 286.1)
# (57, 'Freienstein-Teufen', 2023, 283.8)
# (58, 'Glattfelden', 2009, 339.8)
# (58, 'Glattfelden', 2010, 346.1)
# (58, 'Glattfelden', 2011, 362.6)
# (58, 'Glattfelden', 2012, 369.3)
# (58, 'Glattfelden', 2013, 376.2)
# (58, 'Glattfelden', 2014, 391.9)
# (58, 'Glattfelden', 2015, 401.7)
# (58, 'Glattfelden', 2016, 409.5)
# (58, 'Glattfelden', 2017, 421.5)
# (58, 'Glattfelden', 2018, 424.1)
# (58, 'Glattfelden', 2019, 426.0)
# (58, 'Glattfelden', 2020, 430.4)
# (58, 'Glattfelden', 2021, 436.5)
# (58, 'Glattfelden', 2022, 429.2)
# (58, 'Glattfelden', 2023, 441.9)
# (59, 'Hochfelden', 2009, 311.2)
# (59, 'Hochfelden', 2010, 325.0)
# (59, 'Hochfelden', 2011, 326.3)
# (59, 'Hochfelden', 2012, 328.6)
# (59, 'Hochfelden', 2013, 326.5)
# (59, 'Hochfelden', 2014, 328.1)
# (59, 'Hochfelden', 2015, 323.4)
# (59, 'Hochfelden', 2016, 318.2)
# (59, 'Hochfelden', 2017, 313.3)
# (59, 'Hochfelden', 2018, 311.8)
# (59, 'Hochfelden', 2019, 320.1)
# (59, 'Hochfelden', 2020, 326.7)
# (59, 'Hochfelden', 2021, 326.1)
# (59, 'Hochfelden', 2022, 322.7)
# (59, 'Hochfelden', 2023, 323.1)
# (60, 'Höri', 2009, 505.0)
# (60, 'Höri', 2010, 515.1)
# (60, 'Höri', 2011, 513.6)
# (60, 'Höri', 2012, 547.4)
# (60, 'Höri', 2013, 552.2)
# (60, 'Höri', 2014, 558.1)
# (60, 'Höri', 2015, 553.2)
# (60, 'Höri', 2016, 563.9)
# (60, 'Höri', 2017, 570.4)
# (60, 'Höri', 2018, 593.5)
# (60, 'Höri', 2019, 603.1)
# (60, 'Höri', 2020, 619.9)
# (60, 'Höri', 2021, 634.8)
# (60, 'Höri', 2022, 691.2)
# (60, 'Höri', 2023, 732.1)
# (61, 'Hüntwangen', 2009, 196.8)
# (61, 'Hüntwangen', 2010, 191.9)
# (61, 'Hüntwangen', 2011, 194.3)
# (61, 'Hüntwangen', 2012, 203.2)
# (61, 'Hüntwangen', 2013, 203.9)
# (61, 'Hüntwangen', 2014, 205.7)
# (61, 'Hüntwangen', 2015, 205.5)
# (61, 'Hüntwangen', 2016, 207.3)
# (61, 'Hüntwangen', 2017, 206.9)
# (61, 'Hüntwangen', 2018, 209.8)
# (61, 'Hüntwangen', 2019, 215.7)
# (61, 'Hüntwangen', 2020, 217.6)
# (61, 'Hüntwangen', 2021, 220.8)
# (61, 'Hüntwangen', 2022, 222.9)
# (61, 'Hüntwangen', 2023, 226.1)
# (62, 'Kloten', 2009, 922.7)
# (62, 'Kloten', 2010, 932.4)
# (62, 'Kloten', 2011, 942.1)
# (62, 'Kloten', 2012, 952.0)
# (62, 'Kloten', 2013, 951.0)
# (62, 'Kloten', 2014, 949.7)
# (62, 'Kloten', 2015, 954.0)
# (62, 'Kloten', 2016, 985.5)
# (62, 'Kloten', 2017, 1003.2)
# (62, 'Kloten', 2018, 1016.4)
# (62, 'Kloten', 2019, 1038.7)
# (62, 'Kloten', 2020, 1053.5)
# (62, 'Kloten', 2021, 1071.7)
# (62, 'Kloten', 2022, 1081.7)
# (62, 'Kloten', 2023, 1097.8)
# (63, 'Lufingen', 2009, 327.4)
# (63, 'Lufingen', 2010, 338.3)
# (63, 'Lufingen', 2011, 351.3)
# (63, 'Lufingen', 2012, 353.8)
# (63, 'Lufingen', 2013, 360.7)
# (63, 'Lufingen', 2014, 368.8)
# (63, 'Lufingen', 2015, 398.1)
# (63, 'Lufingen', 2016, 424.3)
# (63, 'Lufingen', 2017, 457.2)
# (63, 'Lufingen', 2018, 462.7)
# (63, 'Lufingen', 2019, 466.0)
# (63, 'Lufingen', 2020, 494.4)
# (63, 'Lufingen', 2021, 504.6)
# (63, 'Lufingen', 2022, 533.4)
# (63, 'Lufingen', 2023, 548.5)
# (64, 'Nürensdorf', 2009, 510.6)
# (64, 'Nürensdorf', 2010, 512.4)
# (64, 'Nürensdorf', 2011, 517.7)
# (64, 'Nürensdorf', 2012, 521.4)
# (64, 'Nürensdorf', 2013, 526.4)
# (64, 'Nürensdorf', 2014, 533.5)
# (64, 'Nürensdorf', 2015, 541.5)
# (64, 'Nürensdorf', 2016, 553.1)
# (64, 'Nürensdorf', 2017, 554.1)
# (64, 'Nürensdorf', 2018, 556.2)
# (64, 'Nürensdorf', 2019, 554.3)
# (64, 'Nürensdorf', 2020, 556.6)
# (64, 'Nürensdorf', 2021, 566.7)
# (64, 'Nürensdorf', 2022, 564.7)
# (64, 'Nürensdorf', 2023, 570.4)
# (65, 'Oberembrach', 2009, 96.1)
# (65, 'Oberembrach', 2010, 94.9)
# (65, 'Oberembrach', 2011, 98.3)
# (65, 'Oberembrach', 2012, 100.7)
# (65, 'Oberembrach', 2013, 107.5)
# (65, 'Oberembrach', 2014, 107.2)
# (65, 'Oberembrach', 2015, 104.7)
# (65, 'Oberembrach', 2016, 104.9)
# (65, 'Oberembrach', 2017, 103.8)
# (65, 'Oberembrach', 2018, 103.4)
# (65, 'Oberembrach', 2019, 108.0)
# (65, 'Oberembrach', 2020, 107.7)
# (65, 'Oberembrach', 2021, 105.5)
# (65, 'Oberembrach', 2022, 106.3)
# (65, 'Oberembrach', 2023, 105.9)
# (66, 'Opfikon', 2009, 2687.2)
# (66, 'Opfikon', 2010, 2777.5)
# (66, 'Opfikon', 2011, 2846.2)
# (66, 'Opfikon', 2012, 2860.1)
# (66, 'Opfikon', 2013, 2912.3)
# (66, 'Opfikon', 2014, 3045.5)
# (66, 'Opfikon', 2015, 3294.5)
# (66, 'Opfikon', 2016, 3469.0)
# (66, 'Opfikon', 2017, 3540.8)
# (66, 'Opfikon', 2018, 3616.4)
# (66, 'Opfikon', 2019, 3730.2)
# (66, 'Opfikon', 2020, 3733.0)
# (66, 'Opfikon', 2021, 3743.6)
# (66, 'Opfikon', 2022, 3772.7)
# (66, 'Opfikon', 2023, 3825.9)
# (67, 'Rafz', 2009, 371.5)
# (67, 'Rafz', 2010, 375.5)
# (67, 'Rafz', 2011, 378.2)
# (67, 'Rafz', 2012, 381.1)
# (67, 'Rafz', 2013, 388.2)
# (67, 'Rafz', 2014, 395.1)
# (67, 'Rafz', 2015, 404.9)
# (67, 'Rafz', 2016, 409.4)
# (67, 'Rafz', 2017, 416.2)
# (67, 'Rafz', 2018, 426.5)
# (67, 'Rafz', 2019, 434.2)
# (67, 'Rafz', 2020, 431.7)
# (67, 'Rafz', 2021, 436.4)
# (67, 'Rafz', 2022, 436.0)
# (67, 'Rafz', 2023, 444.2)
# (68, 'Rorbas', 2009, 504.9)
# (68, 'Rorbas', 2010, 525.3)
# (68, 'Rorbas', 2011, 555.6)
# (68, 'Rorbas', 2012, 561.2)
# (68, 'Rorbas', 2013, 579.1)
# (68, 'Rorbas', 2014, 605.6)
# (68, 'Rorbas', 2015, 614.8)
# (68, 'Rorbas', 2016, 626.5)
# (68, 'Rorbas', 2017, 636.1)
# (68, 'Rorbas', 2018, 627.6)
# (68, 'Rorbas', 2019, 640.7)
# (68, 'Rorbas', 2020, 640.7)
# (68, 'Rorbas', 2021, 644.9)
# (68, 'Rorbas', 2022, 646.2)
# (68, 'Rorbas', 2023, 667.3)
# (69, 'Wallisellen', 2009, 2063.9)
# (69, 'Wallisellen', 2010, 2107.7)
# (69, 'Wallisellen', 2011, 2171.5)
# (69, 'Wallisellen', 2012, 2190.2)
# (69, 'Wallisellen', 2013, 2289.0)
# (69, 'Wallisellen', 2014, 2370.7)
# (69, 'Wallisellen', 2015, 2415.3)
# (69, 'Wallisellen', 2016, 2453.4)
# (69, 'Wallisellen', 2017, 2454.3)
# (69, 'Wallisellen', 2018, 2518.3)
# (69, 'Wallisellen', 2019, 2600.6)
# (69, 'Wallisellen', 2020, 2662.2)
# (69, 'Wallisellen', 2021, 2672.7)
# (69, 'Wallisellen', 2022, 2678.6)
# (69, 'Wallisellen', 2023, 2721.4)
# (70, 'Wasterkingen', 2009, 139.1)
# (70, 'Wasterkingen', 2010, 141.9)
# (70, 'Wasterkingen', 2011, 138.8)
# (70, 'Wasterkingen', 2012, 138.8)
# (70, 'Wasterkingen', 2013, 145.2)
# (70, 'Wasterkingen', 2014, 144.2)
# (70, 'Wasterkingen', 2015, 145.4)
# (70, 'Wasterkingen', 2016, 141.9)
# (70, 'Wasterkingen', 2017, 145.7)
# (70, 'Wasterkingen', 2018, 140.6)
# (70, 'Wasterkingen', 2019, 142.1)
# (70, 'Wasterkingen', 2020, 143.1)
# (70, 'Wasterkingen', 2021, 148.5)
# (70, 'Wasterkingen', 2022, 149.0)
# (70, 'Wasterkingen', 2023, 146.4)
# (71, 'Wil', 2009, 144.3)
# (71, 'Wil', 2010, 142.8)
# (71, 'Wil', 2011, 144.5)
# (71, 'Wil', 2012, 144.7)
# (71, 'Wil', 2013, 146.3)
# (71, 'Wil', 2014, 150.6)
# (71, 'Wil', 2015, 153.3)
# (71, 'Wil', 2016, 152.1)
# (71, 'Wil', 2017, 156.9)
# (71, 'Wil', 2018, 158.6)
# (71, 'Wil', 2019, 164.3)
# (71, 'Wil', 2020, 166.0)
# (71, 'Wil', 2021, 169.2)
# (71, 'Wil', 2022, 174.6)
# (71, 'Wil', 2023, 175.9)
# (72, 'Winkel', 2009, 478.6)
# (72, 'Winkel', 2010, 484.8)
# (72, 'Winkel', 2011, 481.9)
# (72, 'Winkel', 2012, 504.2)
# (72, 'Winkel', 2013, 516.4)
# (72, 'Winkel', 2014, 514.0)
# (72, 'Winkel', 2015, 523.1)
# (72, 'Winkel', 2016, 538.8)
# (72, 'Winkel', 2017, 556.9)
# (72, 'Winkel', 2018, 557.1)
# (72, 'Winkel', 2019, 559.2)
# (72, 'Winkel', 2020, 574.7)
# (72, 'Winkel', 2021, 601.0)
# (72, 'Winkel', 2022, 600.1)
# (72, 'Winkel', 2023, 608.5)
# (81, 'Bachs', 2009, 62.5)
# (81, 'Bachs', 2010, 62.6)
# (81, 'Bachs', 2011, 62.0)
# (81, 'Bachs', 2012, 62.7)
# (81, 'Bachs', 2013, 66.3)
# (81, 'Bachs', 2014, 65.4)
# (81, 'Bachs', 2015, 63.9)
# (81, 'Bachs', 2016, 65.7)
# (81, 'Bachs', 2017, 64.3)
# (81, 'Bachs', 2018, 63.2)
# (81, 'Bachs', 2019, 64.9)
# (81, 'Bachs', 2020, 67.0)
# (81, 'Bachs', 2021, 69.0)
# (81, 'Bachs', 2022, 69.6)
# (81, 'Bachs', 2023, 71.0)
# (82, 'Boppelsen', 2009, 329.8)
# (82, 'Boppelsen', 2010, 328.1)
# (82, 'Boppelsen', 2011, 328.1)
# (82, 'Boppelsen', 2012, 325.0)
# (82, 'Boppelsen', 2013, 332.7)
# (82, 'Boppelsen', 2014, 326.5)
# (82, 'Boppelsen', 2015, 336.0)
# (82, 'Boppelsen', 2016, 336.2)
# (82, 'Boppelsen', 2017, 348.2)
# (82, 'Boppelsen', 2018, 348.2)
# (82, 'Boppelsen', 2019, 361.4)
# (82, 'Boppelsen', 2020, 371.8)
# (82, 'Boppelsen', 2021, 369.8)
# (82, 'Boppelsen', 2022, 369.0)
# (82, 'Boppelsen', 2023, 364.0)
# (83, 'Buchs', 2009, 897.1)
# (83, 'Buchs', 2010, 939.1)
# (83, 'Buchs', 2011, 968.0)
# (83, 'Buchs', 2012, 1028.4)
# (83, 'Buchs', 2013, 1050.0)
# (83, 'Buchs', 2014, 1046.3)
# (83, 'Buchs', 2015, 1066.2)
# (83, 'Buchs', 2016, 1074.8)
# (83, 'Buchs', 2017, 1071.9)
# (83, 'Buchs', 2018, 1088.6)
# (83, 'Buchs', 2019, 1117.5)
# (83, 'Buchs', 2020, 1116.5)
# (83, 'Buchs', 2021, 1122.1)
# (83, 'Buchs', 2022, 1124.0)
# (83, 'Buchs', 2023, 1132.2)
# (84, 'Dällikon', 2009, 797.5)
# (84, 'Dällikon', 2010, 804.7)
# (84, 'Dällikon', 2011, 812.7)
# (84, 'Dällikon', 2012, 830.8)
# (84, 'Dällikon', 2013, 836.2)
# (84, 'Dällikon', 2014, 870.3)
# (84, 'Dällikon', 2015, 881.7)
# (84, 'Dällikon', 2016, 907.8)
# (84, 'Dällikon', 2017, 915.2)
# (84, 'Dällikon', 2018, 920.7)
# (84, 'Dällikon', 2019, 928.7)
# (84, 'Dällikon', 2020, 950.8)
# (84, 'Dällikon', 2021, 955.7)
# (84, 'Dällikon', 2022, 950.6)
# (84, 'Dällikon', 2023, 973.1)
# (85, 'Dänikon', 2009, 679.6)
# (85, 'Dänikon', 2010, 679.6)
# (85, 'Dänikon', 2011, 683.2)
# (85, 'Dänikon', 2012, 688.9)
# (85, 'Dänikon', 2013, 695.0)
# (85, 'Dänikon', 2014, 694.3)
# (85, 'Dänikon', 2015, 674.3)
# (85, 'Dänikon', 2016, 670.4)
# (85, 'Dänikon', 2017, 667.5)
# (85, 'Dänikon', 2018, 664.2)
# (85, 'Dänikon', 2019, 659.6)
# (85, 'Dänikon', 2020, 655.0)
# (85, 'Dänikon', 2021, 655.7)
# (85, 'Dänikon', 2022, 660.3)
# (85, 'Dänikon', 2023, 661.0)
# (86, 'Dielsdorf', 2009, 938.0)
# (86, 'Dielsdorf', 2010, 961.8)
# (86, 'Dielsdorf', 2011, 982.5)
# (86, 'Dielsdorf', 2012, 985.9)
# (86, 'Dielsdorf', 2013, 1000.2)
# (86, 'Dielsdorf', 2014, 1006.6)
# (86, 'Dielsdorf', 2015, 1008.0)
# (86, 'Dielsdorf', 2016, 1015.7)
# (86, 'Dielsdorf', 2017, 1011.9)
# (86, 'Dielsdorf', 2018, 1018.4)
# (86, 'Dielsdorf', 2019, 1013.6)
# (86, 'Dielsdorf', 2020, 1014.6)
# (86, 'Dielsdorf', 2021, 1027.4)
# (86, 'Dielsdorf', 2022, 1044.6)
# (86, 'Dielsdorf', 2023, 1081.6)
# (87, 'Hüttikon', 2009, 408.8)
# (87, 'Hüttikon', 2010, 415.6)
# (87, 'Hüttikon', 2011, 415.0)
# (87, 'Hüttikon', 2012, 417.5)
# (87, 'Hüttikon', 2013, 424.4)
# (87, 'Hüttikon', 2014, 439.4)
# (87, 'Hüttikon', 2015, 549.4)
# (87, 'Hüttikon', 2016, 572.5)
# (87, 'Hüttikon', 2017, 578.1)
# (87, 'Hüttikon', 2018, 576.3)
# (87, 'Hüttikon', 2019, 593.1)
# (87, 'Hüttikon', 2020, 591.9)
# (87, 'Hüttikon', 2021, 577.5)
# (87, 'Hüttikon', 2022, 599.4)
# (87, 'Hüttikon', 2023, 608.1)
# (88, 'Neerach', 2009, 491.0)
# (88, 'Neerach', 2010, 494.8)
# (88, 'Neerach', 2011, 502.3)
# (88, 'Neerach', 2012, 503.2)
# (88, 'Neerach', 2013, 503.5)
# (88, 'Neerach', 2014, 500.8)
# (88, 'Neerach', 2015, 507.3)
# (88, 'Neerach', 2016, 517.7)
# (88, 'Neerach', 2017, 523.3)
# (88, 'Neerach', 2018, 528.3)
# (88, 'Neerach', 2019, 529.0)
# (88, 'Neerach', 2020, 537.5)
# (88, 'Neerach', 2021, 544.8)
# (88, 'Neerach', 2022, 552.7)
# (88, 'Neerach', 2023, 552.3)
# (89, 'Niederglatt', 2009, 1263.1)
# (89, 'Niederglatt', 2010, 1269.4)
# (89, 'Niederglatt', 2011, 1261.9)
# (89, 'Niederglatt', 2012, 1268.9)
# (89, 'Niederglatt', 2013, 1289.4)
# (89, 'Niederglatt', 2014, 1309.2)
# (89, 'Niederglatt', 2015, 1319.7)
# (89, 'Niederglatt', 2016, 1358.1)
# (89, 'Niederglatt', 2017, 1365.8)
# (89, 'Niederglatt', 2018, 1366.8)
# (89, 'Niederglatt', 2019, 1382.5)
# (89, 'Niederglatt', 2020, 1367.6)
# (89, 'Niederglatt', 2021, 1373.7)
# (89, 'Niederglatt', 2022, 1431.3)
# (89, 'Niederglatt', 2023, 1475.1)
# (90, 'Niederhasli', 2009, 743.3)
# (90, 'Niederhasli', 2010, 753.8)
# (90, 'Niederhasli', 2011, 759.9)
# (90, 'Niederhasli', 2012, 770.1)
# (90, 'Niederhasli', 2013, 782.1)
# (90, 'Niederhasli', 2014, 798.2)
# (90, 'Niederhasli', 2015, 803.3)
# (90, 'Niederhasli', 2016, 810.6)
# (90, 'Niederhasli', 2017, 812.4)
# (90, 'Niederhasli', 2018, 819.1)
# (90, 'Niederhasli', 2019, 827.3)
# (90, 'Niederhasli', 2020, 836.7)
# (90, 'Niederhasli', 2021, 836.8)
# (90, 'Niederhasli', 2022, 839.9)
# (90, 'Niederhasli', 2023, 849.3)
# (91, 'Niederweningen', 2009, 385.0)
# (91, 'Niederweningen', 2010, 396.7)
# (91, 'Niederweningen', 2011, 401.3)
# (91, 'Niederweningen', 2012, 400.9)
# (91, 'Niederweningen', 2013, 405.1)
# (91, 'Niederweningen', 2014, 417.3)
# (91, 'Niederweningen', 2015, 415.1)
# (91, 'Niederweningen', 2016, 423.8)
# (91, 'Niederweningen', 2017, 439.5)
# (91, 'Niederweningen', 2018, 445.7)
# (91, 'Niederweningen', 2019, 448.5)
# (91, 'Niederweningen', 2020, 450.9)
# (91, 'Niederweningen', 2021, 453.9)
# (91, 'Niederweningen', 2022, 449.8)
# (91, 'Niederweningen', 2023, 470.8)
# (92, 'Oberglatt', 2009, 676.8)
# (92, 'Oberglatt', 2010, 712.3)
# (92, 'Oberglatt', 2011, 726.5)
# (92, 'Oberglatt', 2012, 736.3)
# (92, 'Oberglatt', 2013, 784.9)
# (92, 'Oberglatt', 2014, 805.8)
# (92, 'Oberglatt', 2015, 824.9)
# (92, 'Oberglatt', 2016, 843.3)
# (92, 'Oberglatt', 2017, 846.2)
# (92, 'Oberglatt', 2018, 858.1)
# (92, 'Oberglatt', 2019, 872.6)
# (92, 'Oberglatt', 2020, 891.2)
# (92, 'Oberglatt', 2021, 901.8)
# (92, 'Oberglatt', 2022, 909.0)
# (92, 'Oberglatt', 2023, 916.8)
# (93, 'Oberweningen', 2009, 340.6)
# (93, 'Oberweningen', 2010, 357.6)
# (93, 'Oberweningen', 2011, 355.1)
# (93, 'Oberweningen', 2012, 358.4)
# (93, 'Oberweningen', 2013, 358.2)
# (93, 'Oberweningen', 2014, 373.6)
# (93, 'Oberweningen', 2015, 368.0)
# (93, 'Oberweningen', 2016, 363.9)
# (93, 'Oberweningen', 2017, 368.2)
# (93, 'Oberweningen', 2018, 366.4)
# (93, 'Oberweningen', 2019, 364.8)
# (93, 'Oberweningen', 2020, 386.2)
# (93, 'Oberweningen', 2021, 385.1)
# (93, 'Oberweningen', 2022, 383.3)
# (93, 'Oberweningen', 2023, 383.7)
# (94, 'Otelfingen', 2009, 322.5)
# (94, 'Otelfingen', 2010, 339.7)
# (94, 'Otelfingen', 2011, 361.7)
# (94, 'Otelfingen', 2012, 381.6)
# (94, 'Otelfingen', 2013, 378.5)
# (94, 'Otelfingen', 2014, 386.4)
# (94, 'Otelfingen', 2015, 385.2)
# (94, 'Otelfingen', 2016, 391.3)
# (94, 'Otelfingen', 2017, 392.6)
# (94, 'Otelfingen', 2018, 407.8)
# (94, 'Otelfingen', 2019, 415.0)
# (94, 'Otelfingen', 2020, 409.5)
# (94, 'Otelfingen', 2021, 408.1)
# (94, 'Otelfingen', 2022, 408.8)
# (94, 'Otelfingen', 2023, 416.6)
# (95, 'Regensberg', 2009, 200.8)
# (95, 'Regensberg', 2010, 205.0)
# (95, 'Regensberg', 2011, 209.2)
# (95, 'Regensberg', 2012, 205.9)
# (95, 'Regensberg', 2013, 203.8)
# (95, 'Regensberg', 2014, 205.5)
# (95, 'Regensberg', 2015, 195.4)
# (95, 'Regensberg', 2016, 197.1)
# (95, 'Regensberg', 2017, 198.7)
# (95, 'Regensberg', 2018, 203.3)
# (95, 'Regensberg', 2019, 194.6)
# (95, 'Regensberg', 2020, 192.9)
# (95, 'Regensberg', 2021, 192.5)
# (95, 'Regensberg', 2022, 195.0)
# (95, 'Regensberg', 2023, 193.7)
# (96, 'Regensdorf', 2009, 1112.1)
# (96, 'Regensdorf', 2010, 1129.0)
# (96, 'Regensdorf', 2011, 1150.0)
# (96, 'Regensdorf', 2012, 1158.6)
# (96, 'Regensdorf', 2013, 1171.0)
# (96, 'Regensdorf', 2014, 1192.3)
# (96, 'Regensdorf', 2015, 1231.0)
# (96, 'Regensdorf', 2016, 1238.0)
# (96, 'Regensdorf', 2017, 1247.6)
# (96, 'Regensdorf', 2018, 1261.0)
# (96, 'Regensdorf', 2019, 1266.7)
# (96, 'Regensdorf', 2020, 1270.6)
# (96, 'Regensdorf', 2021, 1268.4)
# (96, 'Regensdorf', 2022, 1281.2)
# (96, 'Regensdorf', 2023, 1345.0)
# (97, 'Rümlang', 2009, 530.5)
# (97, 'Rümlang', 2010, 537.6)
# (97, 'Rümlang', 2011, 555.7)
# (97, 'Rümlang', 2012, 562.3)
# (97, 'Rümlang', 2013, 579.2)
# (97, 'Rümlang', 2014, 605.2)
# (97, 'Rümlang', 2015, 622.2)
# (97, 'Rümlang', 2016, 641.3)
# (97, 'Rümlang', 2017, 636.4)
# (97, 'Rümlang', 2018, 656.9)
# (97, 'Rümlang', 2019, 662.6)
# (97, 'Rümlang', 2020, 666.7)
# (97, 'Rümlang', 2021, 668.0)
# (97, 'Rümlang', 2022, 658.6)
# (97, 'Rümlang', 2023, 659.3)
# (98, 'Schleinikon', 2009, 125.0)
# (98, 'Schleinikon', 2010, 126.9)
# (98, 'Schleinikon', 2011, 127.8)
# (98, 'Schleinikon', 2012, 127.1)
# (98, 'Schleinikon', 2013, 125.1)
# (98, 'Schleinikon', 2014, 129.2)
# (98, 'Schleinikon', 2015, 127.4)
# (98, 'Schleinikon', 2016, 128.3)
# (98, 'Schleinikon', 2017, 130.3)
# (98, 'Schleinikon', 2018, 128.6)
# (98, 'Schleinikon', 2019, 133.7)
# (98, 'Schleinikon', 2020, 151.2)
# (98, 'Schleinikon', 2021, 151.9)
# (98, 'Schleinikon', 2022, 152.1)
# (98, 'Schleinikon', 2023, 153.7)
# (99, 'Schöfflisdorf', 2009, 329.1)
# (99, 'Schöfflisdorf', 2010, 339.1)
# (99, 'Schöfflisdorf', 2011, 339.8)
# (99, 'Schöfflisdorf', 2012, 344.1)
# (99, 'Schöfflisdorf', 2013, 341.4)
# (99, 'Schöfflisdorf', 2014, 346.9)
# (99, 'Schöfflisdorf', 2015, 349.6)
# (99, 'Schöfflisdorf', 2016, 346.9)
# (99, 'Schöfflisdorf', 2017, 350.4)
# (99, 'Schöfflisdorf', 2018, 348.6)
# (99, 'Schöfflisdorf', 2019, 348.6)
# (99, 'Schöfflisdorf', 2020, 352.9)
# (99, 'Schöfflisdorf', 2021, 347.8)
# (99, 'Schöfflisdorf', 2022, 344.6)
# (99, 'Schöfflisdorf', 2023, 351.6)
# (100, 'Stadel', 2009, 151.0)
# (100, 'Stadel', 2010, 153.5)
# (100, 'Stadel', 2011, 153.6)
# (100, 'Stadel', 2012, 155.9)
# (100, 'Stadel', 2013, 157.2)
# (100, 'Stadel', 2014, 167.5)
# (100, 'Stadel', 2015, 171.5)
# (100, 'Stadel', 2016, 172.5)
# (100, 'Stadel', 2017, 176.2)
# (100, 'Stadel', 2018, 177.8)
# (100, 'Stadel', 2019, 178.3)
# (100, 'Stadel', 2020, 181.3)
# (100, 'Stadel', 2021, 181.8)
# (100, 'Stadel', 2022, 182.3)
# (100, 'Stadel', 2023, 183.2)
# (101, 'Steinmaur', 2009, 331.2)
# (101, 'Steinmaur', 2010, 334.6)
# (101, 'Steinmaur', 2011, 341.0)
# (101, 'Steinmaur', 2012, 345.9)
# (101, 'Steinmaur', 2013, 353.2)
# (101, 'Steinmaur', 2014, 356.5)
# (101, 'Steinmaur', 2015, 357.9)
# (101, 'Steinmaur', 2016, 363.1)
# (101, 'Steinmaur', 2017, 365.4)
# (101, 'Steinmaur', 2018, 372.4)
# (101, 'Steinmaur', 2019, 381.3)
# (101, 'Steinmaur', 2020, 378.4)
# (101, 'Steinmaur', 2021, 381.0)
# (101, 'Steinmaur', 2022, 380.5)
# (101, 'Steinmaur', 2023, 391.7)
# (102, 'Weiach', 2009, 103.8)
# (102, 'Weiach', 2010, 102.3)
# (102, 'Weiach', 2011, 106.7)
# (102, 'Weiach', 2012, 112.3)
# (102, 'Weiach', 2013, 112.1)
# (102, 'Weiach', 2014, 120.4)
# (102, 'Weiach', 2015, 143.7)
# (102, 'Weiach', 2016, 153.5)
# (102, 'Weiach', 2017, 182.7)
# (102, 'Weiach', 2018, 188.6)
# (102, 'Weiach', 2019, 198.6)
# (102, 'Weiach', 2020, 207.2)
# (102, 'Weiach', 2021, 213.8)
# (102, 'Weiach', 2022, 216.3)
# (102, 'Weiach', 2023, 220.6)
# (111, 'Bäretswil', 2009, 208.8)
# (111, 'Bäretswil', 2010, 216.4)
# (111, 'Bäretswil', 2011, 219.9)
# (111, 'Bäretswil', 2012, 222.1)
# (111, 'Bäretswil', 2013, 220.8)
# (111, 'Bäretswil', 2014, 225.0)
# (111, 'Bäretswil', 2015, 223.4)
# (111, 'Bäretswil', 2016, 227.4)
# (111, 'Bäretswil', 2017, 226.5)
# (111, 'Bäretswil', 2018, 225.6)
# (111, 'Bäretswil', 2019, 227.7)
# (111, 'Bäretswil', 2020, 227.4)
# (111, 'Bäretswil', 2021, 225.7)
# (111, 'Bäretswil', 2022, 230.0)
# (111, 'Bäretswil', 2023, 231.7)
# (112, 'Bubikon', 2009, 549.3)
# (112, 'Bubikon', 2010, 564.7)
# (112, 'Bubikon', 2011, 581.7)
# (112, 'Bubikon', 2012, 589.0)
# (112, 'Bubikon', 2013, 595.9)
# (112, 'Bubikon', 2014, 599.6)
# (112, 'Bubikon', 2015, 603.7)
# (112, 'Bubikon', 2016, 611.6)
# (112, 'Bubikon', 2017, 618.0)
# (112, 'Bubikon', 2018, 631.8)
# (112, 'Bubikon', 2019, 633.0)
# (112, 'Bubikon', 2020, 634.5)
# (112, 'Bubikon', 2021, 636.7)
# (112, 'Bubikon', 2022, 645.2)
# (112, 'Bubikon', 2023, 653.6)
# (113, 'Dürnten', 2009, 641.9)
# (113, 'Dürnten', 2010, 652.8)
# (113, 'Dürnten', 2011, 691.0)
# (113, 'Dürnten', 2012, 701.2)
# (113, 'Dürnten', 2013, 701.0)
# (113, 'Dürnten', 2014, 722.2)
# (113, 'Dürnten', 2015, 724.0)
# (113, 'Dürnten', 2016, 731.6)
# (113, 'Dürnten', 2017, 736.3)
# (113, 'Dürnten', 2018, 743.4)
# (113, 'Dürnten', 2019, 743.8)
# (113, 'Dürnten', 2020, 748.8)
# (113, 'Dürnten', 2021, 751.9)
# (113, 'Dürnten', 2022, 761.9)
# (113, 'Dürnten', 2023, 770.6)
# (114, 'Fischenthal', 2009, 75.7)
# (114, 'Fischenthal', 2010, 75.9)
# (114, 'Fischenthal', 2011, 77.1)
# (114, 'Fischenthal', 2012, 77.3)
# (114, 'Fischenthal', 2013, 77.0)
# (114, 'Fischenthal', 2014, 77.1)
# (114, 'Fischenthal', 2015, 80.4)
# (114, 'Fischenthal', 2016, 82.0)
# (114, 'Fischenthal', 2017, 83.0)
# (114, 'Fischenthal', 2018, 82.7)
# (114, 'Fischenthal', 2019, 83.0)
# (114, 'Fischenthal', 2020, 82.7)
# (114, 'Fischenthal', 2021, 85.6)
# (114, 'Fischenthal', 2022, 86.1)
# (114, 'Fischenthal', 2023, 86.7)
# (115, 'Gossau', 2009, 520.4)
# (115, 'Gossau', 2010, 521.8)
# (115, 'Gossau', 2011, 528.1)
# (115, 'Gossau', 2012, 531.1)
# (115, 'Gossau', 2013, 530.2)
# (115, 'Gossau', 2014, 533.7)
# (115, 'Gossau', 2015, 533.0)
# (115, 'Gossau', 2016, 535.6)
# (115, 'Gossau', 2017, 543.6)
# (115, 'Gossau', 2018, 556.7)
# (115, 'Gossau', 2019, 559.7)
# (115, 'Gossau', 2020, 559.9)
# (115, 'Gossau', 2021, 558.3)
# (115, 'Gossau', 2022, 563.2)
# (115, 'Gossau', 2023, 575.8)
# (116, 'Grüningen', 2009, 337.7)
# (116, 'Grüningen', 2010, 359.7)
# (116, 'Grüningen', 2011, 361.9)
# (116, 'Grüningen', 2012, 366.1)
# (116, 'Grüningen', 2013, 371.5)
# (116, 'Grüningen', 2014, 382.4)
# (116, 'Grüningen', 2015, 381.6)
# (116, 'Grüningen', 2016, 384.2)
# (116, 'Grüningen', 2017, 381.9)
# (116, 'Grüningen', 2018, 396.7)
# (116, 'Grüningen', 2019, 415.8)
# (116, 'Grüningen', 2020, 424.6)
# (116, 'Grüningen', 2021, 436.9)
# (116, 'Grüningen', 2022, 438.3)
# (116, 'Grüningen', 2023, 438.5)
# (117, 'Hinwil', 2009, 453.2)
# (117, 'Hinwil', 2010, 464.5)
# (117, 'Hinwil', 2011, 472.6)
# (117, 'Hinwil', 2012, 475.2)
# (117, 'Hinwil', 2013, 482.0)
# (117, 'Hinwil', 2014, 483.1)
# (117, 'Hinwil', 2015, 485.4)
# (117, 'Hinwil', 2016, 496.3)
# (117, 'Hinwil', 2017, 501.1)
# (117, 'Hinwil', 2018, 499.2)
# (117, 'Hinwil', 2019, 506.1)
# (117, 'Hinwil', 2020, 509.4)
# (117, 'Hinwil', 2021, 522.0)
# (117, 'Hinwil', 2022, 519.2)
# (117, 'Hinwil', 2023, 530.9)
# (118, 'Rüti', 2009, 1171.9)
# (118, 'Rüti', 2010, 1183.9)
# (118, 'Rüti', 2011, 1170.8)
# (118, 'Rüti', 2012, 1183.3)
# (118, 'Rüti', 2013, 1183.3)
# (118, 'Rüti', 2014, 1188.4)
# (118, 'Rüti', 2015, 1191.6)
# (118, 'Rüti', 2016, 1191.7)
# (118, 'Rüti', 2017, 1200.2)
# (118, 'Rüti', 2018, 1201.6)
# (118, 'Rüti', 2019, 1214.5)
# (118, 'Rüti', 2020, 1237.4)
# (118, 'Rüti', 2021, 1251.8)
# (118, 'Rüti', 2022, 1257.1)
# (118, 'Rüti', 2023, 1270.8)
# (119, 'Seegräben', 2009, 344.3)
# (119, 'Seegräben', 2010, 343.8)
# (119, 'Seegräben', 2011, 344.3)
# (119, 'Seegräben', 2012, 346.7)
# (119, 'Seegräben', 2013, 353.3)
# (119, 'Seegräben', 2014, 371.1)
# (119, 'Seegräben', 2015, 380.6)
# (119, 'Seegräben', 2016, 380.9)
# (119, 'Seegräben', 2017, 378.2)
# (119, 'Seegräben', 2018, 380.7)
# (119, 'Seegräben', 2019, 377.2)
# (119, 'Seegräben', 2020, 376.5)
# (119, 'Seegräben', 2021, 376.5)
# (119, 'Seegräben', 2022, 375.4)
# (119, 'Seegräben', 2023, 385.4)
# (120, 'Wald', 2009, 353.3)
# (120, 'Wald', 2010, 355.0)
# (120, 'Wald', 2011, 364.5)
# (120, 'Wald', 2012, 369.3)
# (120, 'Wald', 2013, 369.0)
# (120, 'Wald', 2014, 374.2)
# (120, 'Wald', 2015, 373.3)
# (120, 'Wald', 2016, 380.0)
# (120, 'Wald', 2017, 386.6)
# (120, 'Wald', 2018, 392.6)
# (120, 'Wald', 2019, 398.7)
# (120, 'Wald', 2020, 402.8)
# (120, 'Wald', 2021, 406.3)
# (120, 'Wald', 2022, 408.8)
# (120, 'Wald', 2023, 416.3)
# (121, 'Wetzikon', 2009, 1288.6)
# (121, 'Wetzikon', 2010, 1321.4)
# (121, 'Wetzikon', 2011, 1354.6)
# (121, 'Wetzikon', 2012, 1391.6)
# (121, 'Wetzikon', 2013, 1415.9)
# (121, 'Wetzikon', 2014, 1429.5)
# (121, 'Wetzikon', 2015, 1458.6)
# (121, 'Wetzikon', 2016, 1470.0)
# (121, 'Wetzikon', 2017, 1463.3)
# (121, 'Wetzikon', 2018, 1480.2)
# (121, 'Wetzikon', 2019, 1493.4)
# (121, 'Wetzikon', 2020, 1496.6)
# (121, 'Wetzikon', 2021, 1521.3)
# (121, 'Wetzikon', 2022, 1553.4)
# (121, 'Wetzikon', 2023, 1579.3)
# (131, 'Adliswil', 2009, 2057.8)
# (131, 'Adliswil', 2010, 2113.8)
# (131, 'Adliswil', 2011, 2240.0)
# (131, 'Adliswil', 2012, 2307.3)
# (131, 'Adliswil', 2013, 2335.4)
# (131, 'Adliswil', 2014, 2356.5)
# (131, 'Adliswil', 2015, 2378.3)
# (131, 'Adliswil', 2016, 2391.2)
# (131, 'Adliswil', 2017, 2401.4)
# (131, 'Adliswil', 2018, 2401.2)
# (131, 'Adliswil', 2019, 2425.3)
# (131, 'Adliswil', 2020, 2442.7)
# (131, 'Adliswil', 2021, 2441.9)
# (131, 'Adliswil', 2022, 2465.3)
# (131, 'Adliswil', 2023, 2527.0)
# (135, 'Kilchberg', 2009, 2840.4)
# (135, 'Kilchberg', 2010, 2866.9)
# (135, 'Kilchberg', 2011, 2900.4)
# (135, 'Kilchberg', 2012, 2938.8)
# (135, 'Kilchberg', 2013, 2987.3)
# (135, 'Kilchberg', 2014, 3020.4)
# (135, 'Kilchberg', 2015, 3106.5)
# (135, 'Kilchberg', 2016, 3200.0)
# (135, 'Kilchberg', 2017, 3245.0)
# (135, 'Kilchberg', 2018, 3404.6)
# (135, 'Kilchberg', 2019, 3445.9)
# (135, 'Kilchberg', 2020, 3547.9)
# (135, 'Kilchberg', 2021, 3588.4)
# (135, 'Kilchberg', 2022, 3581.5)
# (135, 'Kilchberg', 2023, 3639.0)
# (136, 'Langnau', 2009, 829.8)
# (136, 'Langnau', 2010, 838.2)
# (136, 'Langnau', 2011, 832.0)
# (136, 'Langnau', 2012, 835.0)
# (136, 'Langnau', 2013, 844.9)
# (136, 'Langnau', 2014, 857.0)
# (136, 'Langnau', 2015, 861.2)
# (136, 'Langnau', 2016, 864.3)
# (136, 'Langnau', 2017, 867.1)
# (136, 'Langnau', 2018, 867.6)
# (136, 'Langnau', 2019, 891.2)
# (136, 'Langnau', 2020, 908.9)
# (136, 'Langnau', 2021, 920.1)
# (136, 'Langnau', 2022, 927.2)
# (136, 'Langnau', 2023, 938.9)
# (137, 'Oberrieden', 2009, 1768.6)
# (137, 'Oberrieden', 2010, 1781.9)
# (137, 'Oberrieden', 2011, 1793.9)
# (137, 'Oberrieden', 2012, 1792.4)
# (137, 'Oberrieden', 2013, 1791.0)
# (137, 'Oberrieden', 2014, 1810.8)
# (137, 'Oberrieden', 2015, 1814.8)
# (137, 'Oberrieden', 2016, 1811.2)
# (137, 'Oberrieden', 2017, 1830.7)
# (137, 'Oberrieden', 2018, 1842.4)
# (137, 'Oberrieden', 2019, 1810.1)
# (137, 'Oberrieden', 2020, 1854.3)
# (137, 'Oberrieden', 2021, 1852.9)
# (137, 'Oberrieden', 2022, 1913.0)
# (137, 'Oberrieden', 2023, 1951.1)
# (138, 'Richterswil', 2009, 1597.5)
# (138, 'Richterswil', 2010, 1633.9)
# (138, 'Richterswil', 2011, 1665.4)
# (138, 'Richterswil', 2012, 1698.7)
# (138, 'Richterswil', 2013, 1721.7)
# (138, 'Richterswil', 2014, 1722.9)
# (138, 'Richterswil', 2015, 1745.3)
# (138, 'Richterswil', 2016, 1762.1)
# (138, 'Richterswil', 2017, 1775.8)
# (138, 'Richterswil', 2018, 1786.1)
# (138, 'Richterswil', 2019, 1803.4)
# (138, 'Richterswil', 2020, 1809.9)
# (138, 'Richterswil', 2021, 1830.2)
# (138, 'Richterswil', 2022, 1852.3)
# (138, 'Richterswil', 2023, 1880.9)
# (139, 'Rüschlikon', 2009, 1777.7)
# (139, 'Rüschlikon', 2010, 1790.1)
# (139, 'Rüschlikon', 2011, 1844.2)
# (139, 'Rüschlikon', 2012, 1855.5)
# (139, 'Rüschlikon', 2013, 1897.9)
# (139, 'Rüschlikon', 2014, 1908.6)
# (139, 'Rüschlikon', 2015, 1939.7)
# (139, 'Rüschlikon', 2016, 1958.9)
# (139, 'Rüschlikon', 2017, 1996.6)
# (139, 'Rüschlikon', 2018, 2057.3)
# (139, 'Rüschlikon', 2019, 2082.9)
# (139, 'Rüschlikon', 2020, 2088.7)
# (139, 'Rüschlikon', 2021, 2094.9)
# (139, 'Rüschlikon', 2022, 2121.2)
# (139, 'Rüschlikon', 2023, 2139.2)
# (141, 'Thalwil', 2009, 3054.8)
# (141, 'Thalwil', 2010, 3119.6)
# (141, 'Thalwil', 2011, 3131.8)
# (141, 'Thalwil', 2012, 3141.4)
# (141, 'Thalwil', 2013, 3175.3)
# (141, 'Thalwil', 2014, 3196.0)
# (141, 'Thalwil', 2015, 3217.6)
# (141, 'Thalwil', 2016, 3217.4)
# (141, 'Thalwil', 2017, 3227.6)
# (141, 'Thalwil', 2018, 3254.3)
# (141, 'Thalwil', 2019, 3282.8)
# (141, 'Thalwil', 2020, 3308.5)
# (141, 'Thalwil', 2021, 3356.0)
# (141, 'Thalwil', 2022, 3330.6)
# (141, 'Thalwil', 2023, 3360.5)
# (151, 'Erlenbach', 2009, 1754.4)
# (151, 'Erlenbach', 2010, 1772.6)
# (151, 'Erlenbach', 2011, 1779.1)
# (151, 'Erlenbach', 2012, 1796.6)
# (151, 'Erlenbach', 2013, 1802.7)
# (151, 'Erlenbach', 2014, 1838.9)
# (151, 'Erlenbach', 2015, 1848.6)
# (151, 'Erlenbach', 2016, 1858.8)
# (151, 'Erlenbach', 2017, 1880.7)
# (151, 'Erlenbach', 2018, 1887.2)
# (151, 'Erlenbach', 2019, 1880.8)
# (151, 'Erlenbach', 2020, 1885.5)
# (151, 'Erlenbach', 2021, 1891.9)
# (151, 'Erlenbach', 2022, 1908.4)
# (151, 'Erlenbach', 2023, 1880.5)
# (152, 'Herrliberg', 2009, 662.9)
# (152, 'Herrliberg', 2010, 677.3)
# (152, 'Herrliberg', 2011, 682.9)
# (152, 'Herrliberg', 2012, 683.8)
# (152, 'Herrliberg', 2013, 687.4)
# (152, 'Herrliberg', 2014, 696.4)
# (152, 'Herrliberg', 2015, 701.9)
# (152, 'Herrliberg', 2016, 701.6)
# (152, 'Herrliberg', 2017, 702.0)
# (152, 'Herrliberg', 2018, 711.7)
# (152, 'Herrliberg', 2019, 719.2)
# (152, 'Herrliberg', 2020, 731.2)
# (152, 'Herrliberg', 2021, 742.9)
# (152, 'Herrliberg', 2022, 750.6)
# (152, 'Herrliberg', 2023, 752.0)
# (153, 'Hombrechtikon', 2009, 645.7)
# (153, 'Hombrechtikon', 2010, 657.4)
# (153, 'Hombrechtikon', 2011, 665.2)
# (153, 'Hombrechtikon', 2012, 666.1)
# (153, 'Hombrechtikon', 2013, 672.9)
# (153, 'Hombrechtikon', 2014, 692.4)
# (153, 'Hombrechtikon', 2015, 696.0)
# (153, 'Hombrechtikon', 2016, 706.8)
# (153, 'Hombrechtikon', 2017, 706.8)
# (153, 'Hombrechtikon', 2018, 715.7)
# (153, 'Hombrechtikon', 2019, 718.0)
# (153, 'Hombrechtikon', 2020, 722.5)
# (153, 'Hombrechtikon', 2021, 721.6)
# (153, 'Hombrechtikon', 2022, 733.8)
# (153, 'Hombrechtikon', 2023, 736.6)
# (154, 'Küsnacht', 2009, 1086.7)
# (154, 'Küsnacht', 2010, 1094.8)
# (154, 'Küsnacht', 2011, 1095.4)
# (154, 'Küsnacht', 2012, 1093.7)
# (154, 'Küsnacht', 2013, 1104.9)
# (154, 'Küsnacht', 2014, 1120.8)
# (154, 'Küsnacht', 2015, 1118.9)
# (154, 'Küsnacht', 2016, 1147.0)
# (154, 'Küsnacht', 2017, 1155.7)
# (154, 'Küsnacht', 2018, 1164.6)
# (154, 'Küsnacht', 2019, 1180.0)
# (154, 'Küsnacht', 2020, 1201.8)
# (154, 'Küsnacht', 2021, 1200.8)
# (154, 'Küsnacht', 2022, 1203.7)
# (154, 'Küsnacht', 2023, 1225.8)
# (155, 'Männedorf', 2009, 2150.1)
# (155, 'Männedorf', 2010, 2197.3)
# (155, 'Männedorf', 2011, 2196.6)
# (155, 'Männedorf', 2012, 2202.5)
# (155, 'Männedorf', 2013, 2204.8)
# (155, 'Männedorf', 2014, 2215.2)
# (155, 'Männedorf', 2015, 2229.1)
# (155, 'Männedorf', 2016, 2273.5)
# (155, 'Männedorf', 2017, 2297.5)
# (155, 'Männedorf', 2018, 2354.4)
# (155, 'Männedorf', 2019, 2377.5)
# (155, 'Männedorf', 2020, 2392.6)
# (155, 'Männedorf', 2021, 2387.8)
# (155, 'Männedorf', 2022, 2400.0)
# (155, 'Männedorf', 2023, 2450.0)
# (156, 'Meilen', 2009, 1026.6)
# (156, 'Meilen', 2010, 1052.8)
# (156, 'Meilen', 2011, 1065.1)
# (156, 'Meilen', 2012, 1072.8)
# (156, 'Meilen', 2013, 1095.4)
# (156, 'Meilen', 2014, 1109.1)
# (156, 'Meilen', 2015, 1134.8)
# (156, 'Meilen', 2016, 1150.4)
# (156, 'Meilen', 2017, 1172.0)
# (156, 'Meilen', 2018, 1194.4)
# (156, 'Meilen', 2019, 1205.9)
# (156, 'Meilen', 2020, 1222.6)
# (156, 'Meilen', 2021, 1236.0)
# (156, 'Meilen', 2022, 1241.1)
# (156, 'Meilen', 2023, 1240.9)
# (157, 'Oetwil', 2009, 719.8)
# (157, 'Oetwil', 2010, 719.8)
# (157, 'Oetwil', 2011, 739.9)
# (157, 'Oetwil', 2012, 748.9)
# (157, 'Oetwil', 2013, 754.0)
# (157, 'Oetwil', 2014, 754.7)
# (157, 'Oetwil', 2015, 767.9)
# (157, 'Oetwil', 2016, 779.6)
# (157, 'Oetwil', 2017, 783.2)
# (157, 'Oetwil', 2018, 790.5)
# (157, 'Oetwil', 2019, 795.4)
# (157, 'Oetwil', 2020, 796.1)
# (157, 'Oetwil', 2021, 811.7)
# (157, 'Oetwil', 2022, 812.0)
# (157, 'Oetwil', 2023, 833.3)
# (158, 'Stäfa', 2009, 1599.5)
# (158, 'Stäfa', 2010, 1617.1)
# (158, 'Stäfa', 2011, 1610.2)
# (158, 'Stäfa', 2012, 1610.5)
# (158, 'Stäfa', 2013, 1613.7)
# (158, 'Stäfa', 2014, 1618.0)
# (158, 'Stäfa', 2015, 1643.7)
# (158, 'Stäfa', 2016, 1653.1)
# (158, 'Stäfa', 2017, 1671.2)
# (158, 'Stäfa', 2018, 1680.3)
# (158, 'Stäfa', 2019, 1708.2)
# (158, 'Stäfa', 2020, 1716.8)
# (158, 'Stäfa', 2021, 1718.1)
# (158, 'Stäfa', 2022, 1729.0)
# (158, 'Stäfa', 2023, 1749.0)
# (159, 'Uetikon', 2009, 1627.1)
# (159, 'Uetikon', 2010, 1631.9)
# (159, 'Uetikon', 2011, 1663.0)
# (159, 'Uetikon', 2012, 1690.0)
# (159, 'Uetikon', 2013, 1674.9)
# (159, 'Uetikon', 2014, 1694.6)
# (159, 'Uetikon', 2015, 1704.0)
# (159, 'Uetikon', 2016, 1721.4)
# (159, 'Uetikon', 2017, 1750.7)
# (159, 'Uetikon', 2018, 1754.4)
# (159, 'Uetikon', 2019, 1763.8)
# (159, 'Uetikon', 2020, 1772.6)
# (159, 'Uetikon', 2021, 1796.9)
# (159, 'Uetikon', 2022, 1802.3)
# (159, 'Uetikon', 2023, 1807.1)
# (160, 'Zumikon', 2009, 917.2)
# (160, 'Zumikon', 2010, 928.3)
# (160, 'Zumikon', 2011, 939.2)
# (160, 'Zumikon', 2012, 942.0)
# (160, 'Zumikon', 2013, 942.3)
# (160, 'Zumikon', 2014, 936.5)
# (160, 'Zumikon', 2015, 943.1)
# (160, 'Zumikon', 2016, 938.3)
# (160, 'Zumikon', 2017, 934.3)
# (160, 'Zumikon', 2018, 962.7)
# ...
# (215, 'Dättlikon', 2015, 256.9)
# (215, 'Dättlikon', 2016, 269.0)
# (215, 'Dättlikon', 2017, 270.0)
# (215, 'Dättlikon', 2018, 271.5)
# (215, 'Dättlikon', 2019, 267.0)
# (215, 'Dättlikon', 2020, 274.6)
# (215, 'Dättlikon', 2021, 272.5)
# (215, 'Dättlikon', 2022, 284.9)
# (215, 'Dättlikon', 2023, 289.3)
# (216, 'Dinhard', 2009, 197.5)
# (216, 'Dinhard', 2010, 195.9)
# (216, 'Dinhard', 2011, 199.4)
# (216, 'Dinhard', 2012, 204.9)
# (216, 'Dinhard', 2013, 211.4)
# (216, 'Dinhard', 2014, 209.3)
# (216, 'Dinhard', 2015, 210.5)
# (216, 'Dinhard', 2016, 216.0)
# (216, 'Dinhard', 2017, 219.1)
# (216, 'Dinhard', 2018, 233.9)
# (216, 'Dinhard', 2019, 238.5)
# (216, 'Dinhard', 2020, 246.1)
# (216, 'Dinhard', 2021, 244.7)
# (216, 'Dinhard', 2022, 244.7)
# (216, 'Dinhard', 2023, 245.7)
# (218, 'Ellikon', 2009, 170.6)
# (218, 'Ellikon', 2010, 177.8)
# (218, 'Ellikon', 2011, 178.4)
# (218, 'Ellikon', 2012, 182.8)
# (218, 'Ellikon', 2013, 180.6)
# (218, 'Ellikon', 2014, 181.4)
# (218, 'Ellikon', 2015, 177.0)
# (218, 'Ellikon', 2016, 176.4)
# (218, 'Ellikon', 2017, 180.6)
# (218, 'Ellikon', 2018, 181.7)
# (218, 'Ellikon', 2019, 181.3)
# (218, 'Ellikon', 2020, 188.1)
# (218, 'Ellikon', 2021, 210.1)
# (218, 'Ellikon', 2022, 208.2)
# (218, 'Ellikon', 2023, 206.0)
# (219, 'Elsau', 2009, 407.3)
# (219, 'Elsau', 2010, 413.7)
# (219, 'Elsau', 2011, 417.9)
# (219, 'Elsau', 2012, 416.8)
# (219, 'Elsau', 2013, 425.4)
# (219, 'Elsau', 2014, 430.8)
# (219, 'Elsau', 2015, 432.5)
# (219, 'Elsau', 2016, 439.4)
# (219, 'Elsau', 2017, 449.8)
# (219, 'Elsau', 2018, 454.6)
# (219, 'Elsau', 2019, 453.4)
# (219, 'Elsau', 2020, 454.5)
# (219, 'Elsau', 2021, 459.2)
# (219, 'Elsau', 2022, 460.1)
# (219, 'Elsau', 2023, 467.3)
# (220, 'Hagenbuch', 2009, 135.5)
# (220, 'Hagenbuch', 2010, 134.4)
# (220, 'Hagenbuch', 2011, 133.9)
# (220, 'Hagenbuch', 2012, 135.3)
# (220, 'Hagenbuch', 2013, 132.8)
# (220, 'Hagenbuch', 2014, 136.3)
# (220, 'Hagenbuch', 2015, 135.7)
# (220, 'Hagenbuch', 2016, 133.9)
# (220, 'Hagenbuch', 2017, 135.4)
# (220, 'Hagenbuch', 2018, 132.9)
# (220, 'Hagenbuch', 2019, 132.4)
# (220, 'Hagenbuch', 2020, 134.4)
# (220, 'Hagenbuch', 2021, 137.9)
# (220, 'Hagenbuch', 2022, 140.6)
# (220, 'Hagenbuch', 2023, 142.7)
# (221, 'Hettlingen', 2009, 508.6)
# (221, 'Hettlingen', 2010, 510.7)
# (221, 'Hettlingen', 2011, 518.1)
# (221, 'Hettlingen', 2012, 515.9)
# (221, 'Hettlingen', 2013, 518.5)
# (221, 'Hettlingen', 2014, 529.4)
# (221, 'Hettlingen', 2015, 537.7)
# (221, 'Hettlingen', 2016, 545.6)
# (221, 'Hettlingen', 2017, 548.2)
# (221, 'Hettlingen', 2018, 540.5)
# (221, 'Hettlingen', 2019, 544.2)
# (221, 'Hettlingen', 2020, 532.5)
# (221, 'Hettlingen', 2021, 536.8)
# (221, 'Hettlingen', 2022, 534.7)
# (221, 'Hettlingen', 2023, 553.1)
# (223, 'Neftenbach', 2009, 336.6)
# (223, 'Neftenbach', 2010, 347.6)
# (223, 'Neftenbach', 2011, 353.3)
# (223, 'Neftenbach', 2012, 360.5)
# (223, 'Neftenbach', 2013, 361.8)
# (223, 'Neftenbach', 2014, 365.8)
# (223, 'Neftenbach', 2015, 365.9)
# (223, 'Neftenbach', 2016, 368.4)
# (223, 'Neftenbach', 2017, 368.1)
# (223, 'Neftenbach', 2018, 376.9)
# (223, 'Neftenbach', 2019, 380.0)
# (223, 'Neftenbach', 2020, 382.3)
# (223, 'Neftenbach', 2021, 385.2)
# (223, 'Neftenbach', 2022, 382.2)
# (223, 'Neftenbach', 2023, 382.6)
# (224, 'Pfungen', 2009, 551.6)
# (224, 'Pfungen', 2010, 597.2)
# (224, 'Pfungen', 2011, 667.1)
# (224, 'Pfungen', 2012, 681.9)
# (224, 'Pfungen', 2013, 711.9)
# (224, 'Pfungen', 2014, 736.9)
# (224, 'Pfungen', 2015, 756.0)
# (224, 'Pfungen', 2016, 756.0)
# (224, 'Pfungen', 2017, 772.4)
# (224, 'Pfungen', 2018, 770.5)
# (224, 'Pfungen', 2019, 780.6)
# (224, 'Pfungen', 2020, 790.6)
# (224, 'Pfungen', 2021, 799.0)
# (224, 'Pfungen', 2022, 811.8)
# (224, 'Pfungen', 2023, 826.5)
# (225, 'Rickenbach', 2009, 411.4)
# (225, 'Rickenbach', 2010, 412.5)
# (225, 'Rickenbach', 2011, 418.3)
# (225, 'Rickenbach', 2012, 420.6)
# (225, 'Rickenbach', 2013, 415.0)
# (225, 'Rickenbach', 2014, 421.5)
# (225, 'Rickenbach', 2015, 427.6)
# (225, 'Rickenbach', 2016, 442.7)
# (225, 'Rickenbach', 2017, 438.1)
# (225, 'Rickenbach', 2018, 446.8)
# (225, 'Rickenbach', 2019, 453.4)
# (225, 'Rickenbach', 2020, 462.6)
# (225, 'Rickenbach', 2021, 460.0)
# (225, 'Rickenbach', 2022, 457.9)
# (225, 'Rickenbach', 2023, 464.8)
# (226, 'Schlatt', 2009, 81.0)
# (226, 'Schlatt', 2010, 81.0)
# (226, 'Schlatt', 2011, 81.3)
# (226, 'Schlatt', 2012, 81.5)
# (226, 'Schlatt', 2013, 80.9)
# (226, 'Schlatt', 2014, 83.2)
# (226, 'Schlatt', 2015, 81.1)
# (226, 'Schlatt', 2016, 81.6)
# (226, 'Schlatt', 2017, 80.6)
# (226, 'Schlatt', 2018, 84.4)
# (226, 'Schlatt', 2019, 86.8)
# (226, 'Schlatt', 2020, 86.1)
# (226, 'Schlatt', 2021, 84.7)
# (226, 'Schlatt', 2022, 84.0)
# (226, 'Schlatt', 2023, 85.7)
# (227, 'Seuzach', 2009, 905.7)
# (227, 'Seuzach', 2010, 927.6)
# (227, 'Seuzach', 2011, 929.2)
# (227, 'Seuzach', 2012, 937.9)
# (227, 'Seuzach', 2013, 945.5)
# (227, 'Seuzach', 2014, 951.3)
# (227, 'Seuzach', 2015, 947.1)
# (227, 'Seuzach', 2016, 953.0)
# (227, 'Seuzach', 2017, 959.3)
# (227, 'Seuzach', 2018, 963.2)
# (227, 'Seuzach', 2019, 977.2)
# (227, 'Seuzach', 2020, 976.6)
# (227, 'Seuzach', 2021, 1003.6)
# (227, 'Seuzach', 2022, 1012.0)
# (227, 'Seuzach', 2023, 1032.4)
# (228, 'Turbenthal', 2009, 163.1)
# (228, 'Turbenthal', 2010, 166.4)
# (228, 'Turbenthal', 2011, 168.9)
# (228, 'Turbenthal', 2012, 170.4)
# (228, 'Turbenthal', 2013, 171.7)
# (228, 'Turbenthal', 2014, 176.0)
# (228, 'Turbenthal', 2015, 177.1)
# (228, 'Turbenthal', 2016, 184.7)
# (228, 'Turbenthal', 2017, 188.1)
# (228, 'Turbenthal', 2018, 193.7)
# (228, 'Turbenthal', 2019, 193.7)
# (228, 'Turbenthal', 2020, 197.6)
# (228, 'Turbenthal', 2021, 200.0)
# (228, 'Turbenthal', 2022, 199.6)
# (228, 'Turbenthal', 2023, 205.0)
# (230, 'Winterthur', 2009, 1452.6)
# (230, 'Winterthur', 2010, 1485.7)
# (230, 'Winterthur', 2011, 1511.5)
# (230, 'Winterthur', 2012, 1532.1)
# (230, 'Winterthur', 2013, 1548.2)
# (230, 'Winterthur', 2014, 1564.2)
# (230, 'Winterthur', 2015, 1586.1)
# (230, 'Winterthur', 2016, 1605.7)
# (230, 'Winterthur', 2017, 1623.2)
# (230, 'Winterthur', 2018, 1637.7)
# (230, 'Winterthur', 2019, 1657.5)
# (230, 'Winterthur', 2020, 1674.8)
# (230, 'Winterthur', 2021, 1687.7)
# (230, 'Winterthur', 2022, 1711.8)
# (230, 'Winterthur', 2023, 1746.8)
# (231, 'Zell', 2009, 405.0)
# (231, 'Zell', 2010, 412.7)
# (231, 'Zell', 2011, 418.0)
# (231, 'Zell', 2012, 422.6)
# (231, 'Zell', 2013, 434.3)
# (231, 'Zell', 2014, 438.3)
# (231, 'Zell', 2015, 438.4)
# (231, 'Zell', 2016, 442.6)
# (231, 'Zell', 2017, 456.8)
# (231, 'Zell', 2018, 463.6)
# (231, 'Zell', 2019, 485.0)
# (231, 'Zell', 2020, 494.8)
# (231, 'Zell', 2021, 496.1)
# (231, 'Zell', 2022, 499.8)
# (231, 'Zell', 2023, 517.1)
# (241, 'Aesch', 2009, 192.5)
# (241, 'Aesch', 2010, 198.8)
# (241, 'Aesch', 2011, 208.3)
# (241, 'Aesch', 2012, 222.7)
# (241, 'Aesch', 2013, 227.5)
# (241, 'Aesch', 2014, 227.3)
# (241, 'Aesch', 2015, 230.4)
# (241, 'Aesch', 2016, 244.0)
# (241, 'Aesch', 2017, 257.9)
# (241, 'Aesch', 2018, 298.5)
# (241, 'Aesch', 2019, 318.8)
# (241, 'Aesch', 2020, 327.6)
# (241, 'Aesch', 2021, 324.8)
# (241, 'Aesch', 2022, 319.0)
# (241, 'Aesch', 2023, 325.5)
# (242, 'Birmensdorf', 2009, 510.2)
# (242, 'Birmensdorf', 2010, 514.1)
# (242, 'Birmensdorf', 2011, 518.1)
# (242, 'Birmensdorf', 2012, 520.6)
# (242, 'Birmensdorf', 2013, 529.8)
# (242, 'Birmensdorf', 2014, 539.5)
# (242, 'Birmensdorf', 2015, 545.5)
# (242, 'Birmensdorf', 2016, 548.9)
# (242, 'Birmensdorf', 2017, 558.6)
# (242, 'Birmensdorf', 2018, 568.9)
# (242, 'Birmensdorf', 2019, 587.9)
# (242, 'Birmensdorf', 2020, 603.6)
# (242, 'Birmensdorf', 2021, 607.2)
# (242, 'Birmensdorf', 2022, 616.7)
# (242, 'Birmensdorf', 2023, 634.2)
# (243, 'Dietikon', 2009, 2489.9)
# (243, 'Dietikon', 2010, 2540.7)
# (243, 'Dietikon', 2011, 2598.5)
# (243, 'Dietikon', 2012, 2669.4)
# (243, 'Dietikon', 2013, 2729.1)
# (243, 'Dietikon', 2014, 2820.9)
# (243, 'Dietikon', 2015, 2869.9)
# (243, 'Dietikon', 2016, 2901.8)
# (243, 'Dietikon', 2017, 2902.6)
# (243, 'Dietikon', 2018, 2925.2)
# (243, 'Dietikon', 2019, 2980.7)
# (243, 'Dietikon', 2020, 3020.3)
# (243, 'Dietikon', 2021, 3020.6)
# (243, 'Dietikon', 2022, 3026.6)
# (243, 'Dietikon', 2023, 3027.2)
# (244, 'Geroldswil', 2009, 2404.2)
# (244, 'Geroldswil', 2010, 2448.4)
# (244, 'Geroldswil', 2011, 2472.6)
# (244, 'Geroldswil', 2012, 2495.8)
# (244, 'Geroldswil', 2013, 2497.4)
# (244, 'Geroldswil', 2014, 2537.9)
# (244, 'Geroldswil', 2015, 2556.8)
# (244, 'Geroldswil', 2016, 2591.1)
# (244, 'Geroldswil', 2017, 2588.4)
# (244, 'Geroldswil', 2018, 2601.1)
# (244, 'Geroldswil', 2019, 2593.7)
# (244, 'Geroldswil', 2020, 2655.8)
# (244, 'Geroldswil', 2021, 2712.1)
# (244, 'Geroldswil', 2022, 2762.1)
# (244, 'Geroldswil', 2023, 2758.9)
# (245, 'Oberengstringen', 2009, 2921.0)
# (245, 'Oberengstringen', 2010, 2981.8)
# (245, 'Oberengstringen', 2011, 2983.2)
# (245, 'Oberengstringen', 2012, 2989.3)
# (245, 'Oberengstringen', 2013, 3011.2)
# (245, 'Oberengstringen', 2014, 3055.6)
# (245, 'Oberengstringen', 2015, 3060.3)
# (245, 'Oberengstringen', 2016, 3066.8)
# (245, 'Oberengstringen', 2017, 3069.6)
# (245, 'Oberengstringen', 2018, 3084.5)
# (245, 'Oberengstringen', 2019, 3163.8)
# (245, 'Oberengstringen', 2020, 3156.8)
# (245, 'Oberengstringen', 2021, 3192.0)
# (245, 'Oberengstringen', 2022, 3207.0)
# (245, 'Oberengstringen', 2023, 3191.5)
# (246, 'Oetwil an der Limmat', 2009, 826.0)
# (246, 'Oetwil an der Limmat', 2010, 828.5)
# (246, 'Oetwil an der Limmat', 2011, 841.2)
# (246, 'Oetwil an der Limmat', 2012, 839.7)
# (246, 'Oetwil an der Limmat', 2013, 827.8)
# (246, 'Oetwil an der Limmat', 2014, 833.9)
# (246, 'Oetwil an der Limmat', 2015, 853.1)
# (246, 'Oetwil an der Limmat', 2016, 878.0)
# (246, 'Oetwil an der Limmat', 2017, 889.5)
# (246, 'Oetwil an der Limmat', 2018, 919.5)
# (246, 'Oetwil an der Limmat', 2019, 909.0)
# (246, 'Oetwil an der Limmat', 2020, 913.0)
# (246, 'Oetwil an der Limmat', 2021, 922.4)
# (246, 'Oetwil an der Limmat', 2022, 925.6)
# (246, 'Oetwil an der Limmat', 2023, 933.2)
# (247, 'Schlieren', 2009, 2326.0)
# (247, 'Schlieren', 2010, 2462.2)
# (247, 'Schlieren', 2011, 2551.2)
# (247, 'Schlieren', 2012, 2625.4)
# (247, 'Schlieren', 2013, 2690.8)
# (247, 'Schlieren', 2014, 2732.9)
# (247, 'Schlieren', 2015, 2815.6)
# (247, 'Schlieren', 2016, 2856.4)
# (247, 'Schlieren', 2017, 2854.1)
# (247, 'Schlieren', 2018, 2854.7)
# (247, 'Schlieren', 2019, 2867.6)
# (247, 'Schlieren', 2020, 3038.5)
# (247, 'Schlieren', 2021, 3043.3)
# (247, 'Schlieren', 2022, 3107.0)
# (247, 'Schlieren', 2023, 3135.8)
# (248, 'Uitikon', 2009, 877.6)
# (248, 'Uitikon', 2010, 887.4)
# (248, 'Uitikon', 2011, 898.6)
# (248, 'Uitikon', 2012, 900.5)
# (248, 'Uitikon', 2013, 893.2)
# (248, 'Uitikon', 2014, 904.1)
# (248, 'Uitikon', 2015, 937.7)
# (248, 'Uitikon', 2016, 946.3)
# (248, 'Uitikon', 2017, 967.8)
# (248, 'Uitikon', 2018, 986.3)
# (248, 'Uitikon', 2019, 1062.2)
# (248, 'Uitikon', 2020, 1093.2)
# (248, 'Uitikon', 2021, 1144.4)
# (248, 'Uitikon', 2022, 1160.8)
# (248, 'Uitikon', 2023, 1250.8)
# (249, 'Unterengstringen', 2009, 963.2)
# (249, 'Unterengstringen', 2010, 999.1)
# (249, 'Unterengstringen', 2011, 994.1)
# (249, 'Unterengstringen', 2012, 1006.8)
# (249, 'Unterengstringen', 2013, 1023.1)
# (249, 'Unterengstringen', 2014, 1058.8)
# (249, 'Unterengstringen', 2015, 1076.3)
# (249, 'Unterengstringen', 2016, 1111.0)
# (249, 'Unterengstringen', 2017, 1124.0)
# (249, 'Unterengstringen', 2018, 1153.9)
# (249, 'Unterengstringen', 2019, 1167.9)
# (249, 'Unterengstringen', 2020, 1185.1)
# (249, 'Unterengstringen', 2021, 1221.1)
# (249, 'Unterengstringen', 2022, 1224.1)
# (249, 'Unterengstringen', 2023, 1279.2)
# (250, 'Urdorf', 2009, 1195.8)
# (250, 'Urdorf', 2010, 1186.1)
# (250, 'Urdorf', 2011, 1221.8)
# (250, 'Urdorf', 2012, 1249.1)
# (250, 'Urdorf', 2013, 1255.6)
# (250, 'Urdorf', 2014, 1269.6)
# (250, 'Urdorf', 2015, 1277.8)
# (250, 'Urdorf', 2016, 1273.6)
# (250, 'Urdorf', 2017, 1290.4)
# (250, 'Urdorf', 2018, 1297.2)
# (250, 'Urdorf', 2019, 1316.0)
# (250, 'Urdorf', 2020, 1320.4)
# (250, 'Urdorf', 2021, 1347.1)
# (250, 'Urdorf', 2022, 1362.4)
# (250, 'Urdorf', 2023, 1370.7)
# (251, 'Weiningen', 2009, 772.6)
# (251, 'Weiningen', 2010, 783.1)
# (251, 'Weiningen', 2011, 789.1)
# (251, 'Weiningen', 2012, 792.8)
# (251, 'Weiningen', 2013, 803.7)
# (251, 'Weiningen', 2014, 816.1)
# (251, 'Weiningen', 2015, 835.2)
# (251, 'Weiningen', 2016, 879.3)
# (251, 'Weiningen', 2017, 881.5)
# (251, 'Weiningen', 2018, 890.2)
# (251, 'Weiningen', 2019, 887.2)
# (251, 'Weiningen', 2020, 897.8)
# (251, 'Weiningen', 2021, 898.7)
# (251, 'Weiningen', 2022, 901.5)
# (251, 'Weiningen', 2023, 935.1)
# (261, 'Zürich', 2009, 4153.6)
# (261, 'Zürich', 2010, 4232.6)
# (261, 'Zürich', 2011, 4277.7)
# (261, 'Zürich', 2012, 4322.1)
# (261, 'Zürich', 2013, 4365.3)
# (261, 'Zürich', 2014, 4442.3)
# (261, 'Zürich', 2015, 4505.4)
# (261, 'Zürich', 2016, 4563.6)
# (261, 'Zürich', 2017, 4635.3)
# (261, 'Zürich', 2018, 4707.8)
# (261, 'Zürich', 2019, 4765.8)
# (261, 'Zürich', 2020, 4787.2)
# (261, 'Zürich', 2021, 4802.1)
# (261, 'Zürich', 2022, 4855.4)
# (261, 'Zürich', 2023, 4919.8)
# (291, 'Andelfingen', 2018, 200.0)
# (291, 'Andelfingen', 2019, 201.0)
# (291, 'Andelfingen', 2020, 200.0)
# (291, 'Andelfingen', 2021, 201.7)
# (291, 'Andelfingen', 2022, 201.6)
# (291, 'Andelfingen', 2023, 210.0)
# (292, 'Stammheim', 2009, 109.8)
# (292, 'Stammheim', 2010, 110.4)
# (292, 'Stammheim', 2011, 111.6)
# (292, 'Stammheim', 2012, 111.1)
# (292, 'Stammheim', 2013, 113.1)
# (292, 'Stammheim', 2014, 113.8)
# (292, 'Stammheim', 2015, 115.7)
# (292, 'Stammheim', 2016, 114.6)
# (292, 'Stammheim', 2017, 114.4)
# (292, 'Stammheim', 2018, 114.4)
# (292, 'Stammheim', 2019, 116.2)
# (292, 'Stammheim', 2020, 119.3)
# (292, 'Stammheim', 2021, 119.0)
# (292, 'Stammheim', 2022, 119.9)
# (292, 'Stammheim', 2023, 121.0)
# (293, 'Wädenswil', 2009, 645.0)
# (293, 'Wädenswil', 2010, 651.4)
# (293, 'Wädenswil', 2011, 664.1)
# (293, 'Wädenswil', 2012, 665.9)
# (293, 'Wädenswil', 2013, 666.5)
# (293, 'Wädenswil', 2014, 673.7)
# (293, 'Wädenswil', 2015, 683.6)
# (293, 'Wädenswil', 2016, 686.3)
# (293, 'Wädenswil', 2017, 687.1)
# (293, 'Wädenswil', 2018, 683.4)
# (293, 'Wädenswil', 2019, 690.3)
# (293, 'Wädenswil', 2020, 697.0)
# (293, 'Wädenswil', 2021, 700.5)
# (293, 'Wädenswil', 2022, 706.9)
# (293, 'Wädenswil', 2023, 722.9)
# (294, 'Elgg', 2009, 175.2)
# (294, 'Elgg', 2010, 179.0)
# (294, 'Elgg', 2011, 183.4)
# (294, 'Elgg', 2012, 184.9)
# (294, 'Elgg', 2013, 188.2)
# (294, 'Elgg', 2014, 189.6)
# (294, 'Elgg', 2015, 192.1)
# (294, 'Elgg', 2016, 196.9)
# (294, 'Elgg', 2017, 200.9)
# (294, 'Elgg', 2018, 200.7)
# (294, 'Elgg', 2019, 202.2)
# (294, 'Elgg', 2020, 202.8)
# (294, 'Elgg', 2021, 205.4)
# (294, 'Elgg', 2022, 207.7)
# (294, 'Elgg', 2023, 209.4)
# (295, 'Horgen', 2009, 670.2)
# (295, 'Horgen', 2010, 682.5)
# (295, 'Horgen', 2011, 686.7)
# (295, 'Horgen', 2012, 693.7)
# (295, 'Horgen', 2013, 703.8)
# (295, 'Horgen', 2014, 718.0)
# (295, 'Horgen', 2015, 723.6)
# (295, 'Horgen', 2016, 725.8)
# (295, 'Horgen', 2017, 726.9)
# (295, 'Horgen', 2018, 733.2)
# (295, 'Horgen', 2019, 745.1)
# (295, 'Horgen', 2020, 748.2)
# (295, 'Horgen', 2021, 755.1)
# (295, 'Horgen', 2022, 764.9)
# (295, 'Horgen', 2023, 767.1)
# (296, 'Illnau-Effretikon', 2009, 479.5)
# (296, 'Illnau-Effretikon', 2010, 486.7)
# (296, 'Illnau-Effretikon', 2011, 497.7)
# (296, 'Illnau-Effretikon', 2012, 501.5)
# (296, 'Illnau-Effretikon', 2013, 506.1)
# (296, 'Illnau-Effretikon', 2014, 506.7)
# (296, 'Illnau-Effretikon', 2015, 507.7)
# (296, 'Illnau-Effretikon', 2016, 508.5)
# (296, 'Illnau-Effretikon', 2017, 514.4)
# (296, 'Illnau-Effretikon', 2018, 517.7)
# (296, 'Illnau-Effretikon', 2019, 526.2)
# (296, 'Illnau-Effretikon', 2020, 527.0)
# (296, 'Illnau-Effretikon', 2021, 528.6)
# (296, 'Illnau-Effretikon', 2022, 533.6)
# (296, 'Illnau-Effretikon', 2023, 536.5)
# (297, 'Bauma', 2009, 153.1)
# (297, 'Bauma', 2010, 153.3)
# (297, 'Bauma', 2011, 154.3)
# (297, 'Bauma', 2012, 154.9)
# (297, 'Bauma', 2013, 157.7)
# (297, 'Bauma', 2014, 160.0)
# (297, 'Bauma', 2015, 164.0)
# (297, 'Bauma', 2016, 166.0)
# (297, 'Bauma', 2017, 167.0)
# (297, 'Bauma', 2018, 168.1)
# (297, 'Bauma', 2019, 165.0)
# (297, 'Bauma', 2020, 165.3)
# (297, 'Bauma', 2021, 165.4)
# (297, 'Bauma', 2022, 166.8)
# (297, 'Bauma', 2023, 171.0)
# (298, 'Wiesendangen', 2009, 298.0)
# (298, 'Wiesendangen', 2010, 306.1)
# (298, 'Wiesendangen', 2011, 309.7)
# (298, 'Wiesendangen', 2012, 312.6)
# (298, 'Wiesendangen', 2013, 315.8)
# (298, 'Wiesendangen', 2014, 319.8)
# (298, 'Wiesendangen', 2015, 325.6)
# (298, 'Wiesendangen', 2016, 328.5)
# (298, 'Wiesendangen', 2017, 332.4)
# (298, 'Wiesendangen', 2018, 340.4)
# (298, 'Wiesendangen', 2019, 345.1)
# (298, 'Wiesendangen', 2020, 346.9)
# (298, 'Wiesendangen', 2021, 348.1)
# (298, 'Wiesendangen', 2022, 350.2)
# (298, 'Wiesendangen', 2023, 351.4)
# MySQL connection closed
