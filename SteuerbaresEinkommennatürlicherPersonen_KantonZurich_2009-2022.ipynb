# %% [markdown]
# Connect to the Swiss Open Data API to retrieve the Income Data for the Canton of Zurich. Afterwards load the Data into a Dataframe and save the originally retrieved data into csv, before the cleaning of the Data.

# %%
import requests    
import json         
import pandas as pd 
import os

package = 'o-steuerbares-einkommen-naturliche-pers-fr'

base_url = 'https://opendata.swiss/api/3/action/package_show?id='

package_information_url = base_url + package
package_information = requests.get(package_information_url)

package_dict = json.loads(package_information.content)

assert package_dict['success'] is True  
package_dict = package_dict['result']   
print(package_dict)
# Out:
# {'license_title': None, 'maintainer': 'Statistisches Amt des Kantons Zürich, Data Shop', 'issued': '2016-01-20T20:16:00+01:00', 'title_for_slug': 'o-steuerbares-einkommen-naturliche-pers-fr', 'qualified_relations': [], 'private': False, 'maintainer_email': 'datashop@statistik.zh.ch', 'num_tags': 5, 'contact_points': [{'email': 'datashop@statistik.zh.ch', 'name': 'Statistisches Amt des Kantons Zürich, Data Shop'}], 'keywords': {'fr': [], 'de': ['bezirke', 'kantonzuerich', 'steuerbareseinkommen', 'natuerlichepersonen', 'gemeinden'], 'en': [], 'it': []}, 'temporals': [{'start_date': '1990-12-31T00:00:00', 'end_date': '2022-12-31T23:59:59.999999'}], 'id': '38c79917-5439-4bfb-8065-816344241af3', 'metadata_created': '2021-01-14T17:38:00.017252', 'documentation': [], 'conforms_to': [], 'metadata_modified': '2024-05-19T03:19:18.725139', 'author': None, 'author_email': None, 'isopen': False, 'relations': [{'url': 'https://openzh.github.io/starter-code-openZH/', 'label': 'Vorbereiteter Code in R oder Python für jedes Dataset mit csv-Datei(en)'}, {'url': 'https://www.zh.ch/de/politik-staat/gesetze-beschluesse/gesetzessammlung/zhlex-os/erlass-431_1-70-359.html', 'label': 'legal_basis'}], 'state': 'active', 'version': None, 'relationships_as_object': [], 'license_id': None, 'see_alsos': [{'dataset_identifier': '190@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '55@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '187@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '137@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '29@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '189@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '188@statistisches-amt-kanton-zuerich'}, {'dataset_identifier': '30@statistisches-amt-kanton-zuerich'}], 'type': 'dataset', 'resources': [{'byte_size': 758010, 'cache_last_updated': None, 'issued': '2016-01-21T16:30:35+01:00', 'uri': '', 'package_id': '38c79917-5439-4bfb-8065-816344241af3', 'temporal_resolution': '', 'datastore_contains_all_records_of_source_file': False, 'datastore_active': False, 'id': '79b03343-9588-48dd-b7ec-8fa6de39c65f', 'size': None, 'rights': 'NonCommercialAllowed-CommercialAllowed-ReferenceRequired', 'display_name': {'fr': '', 'de': 'Ø steuerbares Einkommen natürliche Pers. [Fr.]', 'en': '', 'it': ''}, 'title': {'fr': '', 'de': 'Ø steuerbares Einkommen natürliche Pers. [Fr.]', 'en': '', 'it': ''}, 'download_url': 'https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_282.csv', 'state': 'active', 'media_type': 'text/csv', 'hash': '', 'description': {'fr': '', 'de': '', 'en': '', 'it': ''}, 'format': 'CSV', 'language': ['de'], 'mimetype_inner': None, 'url_type': None, 'name': {'fr': '', 'de': 'Ø steuerbares Einkommen natürliche Pers. [Fr.]', 'en': '', 'it': ''}, 'mimetype': 'text/csv', 'cache_url': None, 'license': 'NonCommercialAllowed-CommercialAllowed-ReferenceRequired', 'access_services': [], 'created': '2022-12-12T03:05:47.211751', 'url': 'https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_282.csv', 'documentation': [], 'modified': '2023-05-16T14:02:27+01:00', 'last_modified': None, 'position': 0, 'revision_id': '930938f3-0bba-4557-a38f-27fbbc9e5a87', 'resource_type': None}], 'num_resources': 1, 'description': {'fr': '', 'de': 'Durchschnittliches steuerbares Einkommen ordentlich besteuerter natürlichen Personen (exkl. Quellensteuerpflichtige und ausserhalb des Kt. wohnhafte). Hinweis: Sehr hohe Beträge einiger weniger Steuerpflichtigen wirken sich entsprechend stark auf den Mittelwert aus. Bis 1998: Reineinkommen.', 'en': '', 'it': ''}, 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'bezirke', 'id': '1545b490-60bb-4ea8-bbf7-ae3169ab0d5e', 'name': 'bezirke'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'gemeinden', 'id': 'bd203e69-5ef0-453a-ac6e-86790de68cdf', 'name': 'gemeinden'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'kantonzuerich', 'id': '52fecd10-5cac-4fbc-a6ac-71 ...

# %%
# Get the url for the data from the dictionary
data_url = package_dict['resources'][0]['url']
print('Data url:' + data_url)

# Print the data format
data_format = package_dict['resources'][0]['format']
print('Data format:' + data_format)
# Out:
# Data url:https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_282.csv
# Data format:CSV

# %%
csv = ['comma-separated-values', 'CSV', 'csv']
if any(s in data_format for s in csv):     
     Einkommensdaten_df = pd.read_csv(data_url)
else:
    print('Sorry, the data format is not supported')
Einkommensdaten_df
# Out:
#       BFS_NR             GEBIET_NAME            THEMA_NAME         SET_NAME  \
# 0          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 1          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 2          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 3          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 4          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# ...      ...                     ...                   ...              ...
# 6554       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6555       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6556       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6557       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6558       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
#
#            SUBSET_NAME  INDIKATOR_ID  \
# 0     Steuergrundlagen           282
# 1     Steuergrundlagen           282
# 2     Steuergrundlagen           282
# 3     Steuergrundlagen           282
# 4     Steuergrundlagen           282
# ...                ...           ...
# 6554  Steuergrundlagen           282
# 6555  Steuergrundlagen           282
# 6556  Steuergrundlagen           282
# 6557  Steuergrundlagen           282
# 6558  Steuergrundlagen           282
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1990
# 1     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1991
# 2     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1992
# 3     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1993
# 4     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1994
# ...                                              ...             ...
# 6554  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2018
# 6555  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2019
# 6556  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2020
# 6557  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2021
# 6558  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2022
#
#       INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG  Unnamed: 11
# 0               61057          Fr.      Franken          NaN
# 1               65860          Fr.      Franken          NaN
# 2               68042          Fr.      Franken          NaN
# 3               72606          Fr.      Franken          NaN
# 4               72495          Fr.      Franken          NaN
# ...               ...          ...          ...          ...
# 6554            67937          Fr.      Franken          NaN
# 6555            68818          Fr.      Franken          NaN
# 6556            69393          Fr.      Franken          NaN
# 6557            69538          Fr.      Franken          NaN
# 6558            68710          Fr.      Franken          NaN
#
# [6559 rows x 12 columns]

# %%
#Save original data files to csv, if the folder is not aleady created, it will be created
directory = 'Original_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Einkommensdaten_KantonZurich_2009_2023.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

Einkommensdaten_df.to_csv(csv_path, index=False)
print(Einkommensdaten_df)
# Out:
#       BFS_NR             GEBIET_NAME            THEMA_NAME         SET_NAME  \
# 0          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 1          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 2          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 3          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# 4          1             Aeugst a.A.  Öffentliche Finanzen  Gemeindesteuern
# ...      ...                     ...                   ...              ...
# 6554       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6555       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6556       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6557       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
# 6558       0  Zürich - ganzer Kanton  Öffentliche Finanzen  Gemeindesteuern
#
#            SUBSET_NAME  INDIKATOR_ID  \
# 0     Steuergrundlagen           282
# 1     Steuergrundlagen           282
# 2     Steuergrundlagen           282
# 3     Steuergrundlagen           282
# 4     Steuergrundlagen           282
# ...                ...           ...
# 6554  Steuergrundlagen           282
# 6555  Steuergrundlagen           282
# 6556  Steuergrundlagen           282
# 6557  Steuergrundlagen           282
# 6558  Steuergrundlagen           282
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1990
# 1     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1991
# 2     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1992
# 3     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1993
# 4     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1994
# ...                                              ...             ...
# 6554  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2018
# 6555  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2019
# 6556  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2020
# 6557  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2021
# 6558  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2022
#
#       INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG  Unnamed: 11
# 0               61057          Fr.      Franken          NaN
# 1               65860          Fr.      Franken          NaN
# 2               68042          Fr.      Franken          NaN
# 3               72606          Fr.      Franken          NaN
# 4               72495          Fr.      Franken          NaN
# ...               ...          ...          ...          ...
# 6554            67937          Fr.      Franken          NaN
# 6555            68818          Fr.      Franken          NaN
# 6556            69393          Fr.      Franken          NaN
# 6557            69538          Fr.      Franken          NaN
# 6558            68710          Fr.      Franken          NaN
#
# [6559 rows x 12 columns]

# %% [markdown]
# Drop not needed Columns, Filter the Data to the years 2009-2023, Delete the summarized Datarows an as well unify the Region Names so the data can be analyzed with the other available datasets. Afterwards save a Cleaned csv file to the Cleaned CSV Files folder.

# %%
Einkommensdaten_df.drop(['THEMA_NAME','SET_NAME','SUBSET_NAME','INDIKATOR_ID','EINHEIT_KURZ','Unnamed: 11'], axis=1, inplace=True)
Einkommensdaten_df
# Out:
#       BFS_NR             GEBIET_NAME  \
# 0          1             Aeugst a.A.
# 1          1             Aeugst a.A.
# 2          1             Aeugst a.A.
# 3          1             Aeugst a.A.
# 4          1             Aeugst a.A.
# ...      ...                     ...
# 6554       0  Zürich - ganzer Kanton
# 6555       0  Zürich - ganzer Kanton
# 6556       0  Zürich - ganzer Kanton
# 6557       0  Zürich - ganzer Kanton
# 6558       0  Zürich - ganzer Kanton
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1990
# 1     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1991
# 2     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1992
# 3     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1993
# 4     Ø steuerbares Einkommen natürliche Pers. [Fr.]            1994
# ...                                              ...             ...
# 6554  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2018
# 6555  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2019
# 6556  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2020
# 6557  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2021
# 6558  Ø steuerbares Einkommen natürliche Pers. [Fr.]            2022
#
#       INDIKATOR_VALUE EINHEIT_LANG
# 0               61057      Franken
# 1               65860      Franken
# 2               68042      Franken
# 3               72606      Franken
# 4               72495      Franken
# ...               ...          ...
# 6554            67937      Franken
# 6555            68818      Franken
# 6556            69393      Franken
# 6557            69538      Franken
# 6558            68710      Franken
#
# [6559 rows x 6 columns]

# %%
# Loesche alle Indizes, die den Wert '0' in der Spalte 'BFS_NR' haben da diese zusammengefasste Informationen pro Bezirk/Region enthalten
indizes_zu_loeschen = Einkommensdaten_df[Einkommensdaten_df['BFS_NR'] == 0].index
Einkommensdaten_df.drop(indizes_zu_loeschen, inplace=True)
Einkommensdaten_df
# Out:
#       BFS_NR   GEBIET_NAME                                  INDIKATOR_NAME  \
# 0          1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 1          1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 2          1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 3          1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 4          1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# ...      ...           ...                                             ...
# 5762     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5763     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5764     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5765     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5766     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
#
#       INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_LANG
# 0               1990            61057      Franken
# 1               1991            65860      Franken
# 2               1992            68042      Franken
# 3               1993            72606      Franken
# 4               1994            72495      Franken
# ...              ...              ...          ...
# 5762            2018            72357      Franken
# 5763            2019            74154      Franken
# 5764            2020            74697      Franken
# 5765            2021            75281      Franken
# 5766            2022            73135      Franken
#
# [5767 rows x 6 columns]

# %%
Jahresindizes_zu_loeschen = Einkommensdaten_df[Einkommensdaten_df['INDIKATOR_JAHR'] < 2009].index
Einkommensdaten_df.drop(Jahresindizes_zu_loeschen, inplace=True)
Einkommensdaten_df
# Out:
#       BFS_NR   GEBIET_NAME                                  INDIKATOR_NAME  \
# 19         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 20         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 21         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 22         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 23         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# ...      ...           ...                                             ...
# 5762     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5763     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5764     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5765     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5766     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
#
#       INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_LANG
# 19              2009            82027      Franken
# 20              2010            87080      Franken
# 21              2011            79841      Franken
# 22              2012            81087      Franken
# 23              2013            80720      Franken
# ...              ...              ...          ...
# 5762            2018            72357      Franken
# 5763            2019            74154      Franken
# 5764            2020            74697      Franken
# 5765            2021            75281      Franken
# 5766            2022            73135      Franken
#
# [2404 rows x 6 columns]

# %%
#Einige Datensätze beinhalten im Gemeindenamen (bis *) um zu indizieren dass die Rechnung sich auf die angegbenen JAhre bezieht. Um Redundanzen zu vermeiden, werden diese entfernt
indizesBis_zu_loeschen = Einkommensdaten_df[Einkommensdaten_df['GEBIET_NAME'].str.contains("\(bis ", na=False)].index
Einkommensdaten_df.drop(indizesBis_zu_loeschen, inplace=True)
Einkommensdaten_df
# Out:
#       BFS_NR   GEBIET_NAME                                  INDIKATOR_NAME  \
# 19         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 20         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 21         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 22         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 23         1   Aeugst a.A.  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# ...      ...           ...                                             ...
# 5762     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5763     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5764     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5765     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5766     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
#
#       INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_LANG
# 19              2009            82027      Franken
# 20              2010            87080      Franken
# 21              2011            79841      Franken
# 22              2012            81087      Franken
# 23              2013            80720      Franken
# ...              ...              ...          ...
# 5762            2018            72357      Franken
# 5763            2019            74154      Franken
# 5764            2020            74697      Franken
# 5765            2021            75281      Franken
# 5766            2022            73135      Franken
#
# [2240 rows x 6 columns]

# %%
# Vereinheitlichen der Gemeindenamen
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Aeugst a.A.', 'Aeugst', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Affoltern a.A.', 'Affoltern', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Hausen a.A.', 'Hausen', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Kappel a.A.', 'Kappel', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Wettswil a.A.', 'Wettswil', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Berg a.I.', 'Berg', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Buch a.I.', 'Buch', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Thalheim a.d.Th.', 'Thalheim', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Langnau a.A.', 'Langnau', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Oetwil a.S.', 'Oetwil', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Uetikon a.S.', 'Uetikon', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Ellikon a.d.Th.', 'Ellikon', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Oetwil a.d.L.', 'Oetwil an der Limmat', regex=False)
Einkommensdaten_df['GEBIET_NAME'] = Einkommensdaten_df['GEBIET_NAME'].str.replace('Aesch ZH', 'Aesch', regex=False)
Einkommensdaten_df
# Out:
#       BFS_NR   GEBIET_NAME                                  INDIKATOR_NAME  \
# 19         1        Aeugst  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 20         1        Aeugst  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 21         1        Aeugst  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 22         1        Aeugst  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 23         1        Aeugst  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# ...      ...           ...                                             ...
# 5762     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5763     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5764     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5765     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
# 5766     298  Wiesendangen  Ø steuerbares Einkommen natürliche Pers. [Fr.]
#
#       INDIKATOR_JAHR  INDIKATOR_VALUE EINHEIT_LANG
# 19              2009            82027      Franken
# 20              2010            87080      Franken
# 21              2011            79841      Franken
# 22              2012            81087      Franken
# 23              2013            80720      Franken
# ...              ...              ...          ...
# 5762            2018            72357      Franken
# 5763            2019            74154      Franken
# 5764            2020            74697      Franken
# 5765            2021            75281      Franken
# 5766            2022            73135      Franken
#
# [2240 rows x 6 columns]

# %%
# Tabelle umformen mit pivot_table
pivot_df = Einkommensdaten_df.pivot_table(index=['BFS_NR', 'GEBIET_NAME', 'INDIKATOR_JAHR'], 
                                     columns='INDIKATOR_NAME', 
                                     values=['INDIKATOR_VALUE'])

pivot_df.columns = [f'{col[0]}_{col[1]}' for col in pivot_df.columns]

pivot_df.reset_index(inplace=True)

# Spalte umbenennen
pivot_df.rename(columns={'INDIKATOR_VALUE_Ø steuerbares Einkommen natürliche Pers. [Fr.]': 'durchschnittliches steuerbares Einkommen pro Einwohner'}, inplace=True)
pivot_df.rename(columns={'GEBIET_NAME': 'Gemeindename'}, inplace=True)
pivot_df.rename(columns={'INDIKATOR_JAHR': 'Jahr'}, inplace=True)

print(pivot_df)
# Out:
#       BFS_NR  Gemeindename  Jahr  \
# 0          1        Aeugst  2009
# 1          1        Aeugst  2010
# 2          1        Aeugst  2011
# 3          1        Aeugst  2012
# 4          1        Aeugst  2013
# ...      ...           ...   ...
# 2235     298  Wiesendangen  2018
# 2236     298  Wiesendangen  2019
# 2237     298  Wiesendangen  2020
# 2238     298  Wiesendangen  2021
# 2239     298  Wiesendangen  2022
#
#       durchschnittliches steuerbares Einkommen pro Einwohner
# 0                                               82027.0
# 1                                               87080.0
# 2                                               79841.0
# 3                                               81087.0
# 4                                               80720.0
# ...                                                 ...
# 2235                                            72357.0
# 2236                                            74154.0
# 2237                                            74697.0
# 2238                                            75281.0
# 2239                                            73135.0
#
# [2240 rows x 4 columns]

# %%
directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Einkommensdaten_KantonZurich_2009_2023_Cleaned.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

pivot_df.to_csv(csv_path, index=False)
print(pivot_df)
# Out:
#       BFS_NR  Gemeindename  Jahr  \
# 0          1        Aeugst  2009
# 1          1        Aeugst  2010
# 2          1        Aeugst  2011
# 3          1        Aeugst  2012
# 4          1        Aeugst  2013
# ...      ...           ...   ...
# 2235     298  Wiesendangen  2018
# 2236     298  Wiesendangen  2019
# 2237     298  Wiesendangen  2020
# 2238     298  Wiesendangen  2021
# 2239     298  Wiesendangen  2022
#
#       durchschnittliches steuerbares Einkommen pro Einwohner
# 0                                               82027.0
# 1                                               87080.0
# 2                                               79841.0
# 3                                               81087.0
# 4                                               80720.0
# ...                                                 ...
# 2235                                            72357.0
# 2236                                            74154.0
# 2237                                            74697.0
# 2238                                            75281.0
# 2239                                            73135.0
#
# [2240 rows x 4 columns]

# %% [markdown]
# Print the Information for the Dataframe so we can create the Table for the Database correspondingly.

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 4 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   BFS_NR                                                  2240 non-null   int64
#  1   Gemeindename                                            2240 non-null   object
#  2   Jahr                                                    2240 non-null   int64
#  3   durchschnittliches steuerbares Einkommen pro Einwohner  2240 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 70.1+ KB

# %% [markdown]
# Connect to the database and create a new table called Einkommensdaten. If the table is already existing drop it.

# %%
import mysql.connector
from mysql.connector import Error

# MySQL connection parameters
host = 'localhost'
user = 'admin'
password = 'Criminal1234'
database = 'CriminalDataDB'  
try:
    connection = mysql.connector.connect(host=host,
                                         user=user,
                                         password=password,
                                         database=database)

    if connection.is_connected():
        print("Connected to MySQL server")
        cursor = connection.cursor()

        # SQL command to drop the table if it already exists becuase before that line of code the data was already inserted multiple times
        drop_table_query = "DROP TABLE IF EXISTS Einkommensdaten;"
        cursor.execute(drop_table_query)
        print("Table 'Einkommensdaten' dropped if it existed alreadyy")

        create_table_query = """
        CREATE TABLE IF NOT EXISTS Einkommensdaten (
            BFS_NR INT,
            Gemeindename VARCHAR(255),
            Jahr INT,
            durchschnittliches_steuerbares_Einkommen_pro_Einwohner FLOAT
        )
        """

        cursor.execute(create_table_query)
        print("Table 'Einkommensdaten' created successfully")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Table 'Einkommensdaten' dropped if it existed alreadyy
# Table 'Einkommensdaten' created successfully
# MySQL connection closed

# %% [markdown]
# Insert the Cleanaed data from the Cleaned Csv file which was created before.

# %%
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB',
    'allow_local_infile': True
}

directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()
csv_file_path = os.path.join(current_directory, directory, 'Einkommensdaten_KantonZurich_2009_2023_Cleaned.csv')

try:
    with mysql.connector.connect(**connection_params) as connection:
        print("Connected to MySQL server")

        Bevoelkerungsdichte_df_to_sql = pd.read_csv(csv_file_path)

        cursor = connection.cursor()
        insert_query = """
        LOAD DATA LOCAL INFILE %s 
        INTO TABLE Einkommensdaten 
        FIELDS TERMINATED BY ',' 
        ENCLOSED BY '"' 
        LINES TERMINATED BY '\n' 
        IGNORE 1 LINES
        """

        cursor.execute(insert_query, (csv_file_path,))
        connection.commit()

        print("Data from CSV file successfully inserted into MySQL table 'Einkommensdaten'")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Data from CSV file successfully inserted into MySQL table 'Einkommensdaten'

# %% [markdown]
# Check if the Data upload to the table was successfully by creating a query to the sql table.

# %%
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB'
}

try:
    connection = mysql.connector.connect(**connection_params)
    print("Connected to MySQL server")

    with connection.cursor() as cursor:
        select_query = "SELECT * FROM Einkommensdaten"

        cursor.execute(select_query)
        rows = cursor.fetchall()

        for row in rows:
            print(row)

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if 'connection' in locals() and connection.is_connected():
        # Close connection
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# (1, 'Aeugst', 2009, 82027.0)
# (1, 'Aeugst', 2010, 87080.0)
# (1, 'Aeugst', 2011, 79841.0)
# (1, 'Aeugst', 2012, 81087.0)
# (1, 'Aeugst', 2013, 80720.0)
# (1, 'Aeugst', 2014, 81527.0)
# (1, 'Aeugst', 2015, 80713.0)
# (1, 'Aeugst', 2016, 82001.0)
# (1, 'Aeugst', 2017, 86751.0)
# (1, 'Aeugst', 2018, 87321.0)
# (1, 'Aeugst', 2019, 93918.0)
# (1, 'Aeugst', 2020, 88390.0)
# (1, 'Aeugst', 2021, 86312.0)
# (1, 'Aeugst', 2022, 86111.0)
# (2, 'Affoltern', 2009, 55095.0)
# (2, 'Affoltern', 2010, 55409.0)
# (2, 'Affoltern', 2011, 54879.0)
# (2, 'Affoltern', 2012, 55488.0)
# (2, 'Affoltern', 2013, 56321.0)
# (2, 'Affoltern', 2014, 56175.0)
# (2, 'Affoltern', 2015, 55852.0)
# (2, 'Affoltern', 2016, 56240.0)
# (2, 'Affoltern', 2017, 58443.0)
# (2, 'Affoltern', 2018, 57975.0)
# (2, 'Affoltern', 2019, 58556.0)
# (2, 'Affoltern', 2020, 60816.0)
# (2, 'Affoltern', 2021, 60345.0)
# (2, 'Affoltern', 2022, 60095.0)
# (3, 'Bonstetten', 2009, 67739.0)
# (3, 'Bonstetten', 2010, 67333.0)
# (3, 'Bonstetten', 2011, 68843.0)
# (3, 'Bonstetten', 2012, 68082.0)
# (3, 'Bonstetten', 2013, 68909.0)
# (3, 'Bonstetten', 2014, 67574.0)
# (3, 'Bonstetten', 2015, 74566.0)
# (3, 'Bonstetten', 2016, 72953.0)
# (3, 'Bonstetten', 2017, 71343.0)
# (3, 'Bonstetten', 2018, 72473.0)
# (3, 'Bonstetten', 2019, 74336.0)
# (3, 'Bonstetten', 2020, 76263.0)
# (3, 'Bonstetten', 2021, 73247.0)
# (3, 'Bonstetten', 2022, 73784.0)
# (4, 'Hausen', 2009, 60444.0)
# (4, 'Hausen', 2010, 61850.0)
# (4, 'Hausen', 2011, 62933.0)
# (4, 'Hausen', 2012, 62894.0)
# (4, 'Hausen', 2013, 63116.0)
# (4, 'Hausen', 2014, 62371.0)
# (4, 'Hausen', 2015, 63317.0)
# (4, 'Hausen', 2016, 65355.0)
# (4, 'Hausen', 2017, 68433.0)
# (4, 'Hausen', 2018, 68885.0)
# (4, 'Hausen', 2019, 69795.0)
# (4, 'Hausen', 2020, 71160.0)
# (4, 'Hausen', 2021, 79017.0)
# (4, 'Hausen', 2022, 72055.0)
# (5, 'Hedingen', 2009, 65210.0)
# (5, 'Hedingen', 2010, 67074.0)
# (5, 'Hedingen', 2011, 73116.0)
# (5, 'Hedingen', 2012, 72404.0)
# (5, 'Hedingen', 2013, 73519.0)
# (5, 'Hedingen', 2014, 69842.0)
# (5, 'Hedingen', 2015, 70871.0)
# (5, 'Hedingen', 2016, 72877.0)
# (5, 'Hedingen', 2017, 73840.0)
# (5, 'Hedingen', 2018, 73808.0)
# (5, 'Hedingen', 2019, 74838.0)
# (5, 'Hedingen', 2020, 75867.0)
# (5, 'Hedingen', 2021, 83225.0)
# (5, 'Hedingen', 2022, 78570.0)
# (6, 'Kappel', 2009, 58727.0)
# (6, 'Kappel', 2010, 61554.0)
# (6, 'Kappel', 2011, 67476.0)
# (6, 'Kappel', 2012, 65627.0)
# (6, 'Kappel', 2013, 69900.0)
# (6, 'Kappel', 2014, 70685.0)
# (6, 'Kappel', 2015, 67858.0)
# (6, 'Kappel', 2016, 67718.0)
# (6, 'Kappel', 2017, 69506.0)
# (6, 'Kappel', 2018, 68678.0)
# (6, 'Kappel', 2019, 69951.0)
# (6, 'Kappel', 2020, 71406.0)
# (6, 'Kappel', 2021, 73516.0)
# (6, 'Kappel', 2022, 72970.0)
# (7, 'Knonau', 2009, 52062.0)
# (7, 'Knonau', 2010, 53680.0)
# (7, 'Knonau', 2011, 56028.0)
# (7, 'Knonau', 2012, 56631.0)
# (7, 'Knonau', 2013, 58540.0)
# (7, 'Knonau', 2014, 58848.0)
# (7, 'Knonau', 2015, 58761.0)
# (7, 'Knonau', 2016, 59827.0)
# (7, 'Knonau', 2017, 64953.0)
# (7, 'Knonau', 2018, 70380.0)
# (7, 'Knonau', 2019, 65768.0)
# (7, 'Knonau', 2020, 69312.0)
# (7, 'Knonau', 2021, 77835.0)
# (7, 'Knonau', 2022, 72943.0)
# (8, 'Maschwanden', 2009, 48922.0)
# (8, 'Maschwanden', 2010, 48459.0)
# (8, 'Maschwanden', 2011, 50981.0)
# (8, 'Maschwanden', 2012, 53127.0)
# (8, 'Maschwanden', 2013, 56272.0)
# (8, 'Maschwanden', 2014, 53697.0)
# (8, 'Maschwanden', 2015, 57080.0)
# (8, 'Maschwanden', 2016, 52482.0)
# (8, 'Maschwanden', 2017, 37385.0)
# (8, 'Maschwanden', 2018, 37411.0)
# (8, 'Maschwanden', 2019, 55005.0)
# (8, 'Maschwanden', 2020, 58789.0)
# (8, 'Maschwanden', 2021, 60097.0)
# (8, 'Maschwanden', 2022, 58041.0)
# (9, 'Mettmenstetten', 2009, 67970.0)
# (9, 'Mettmenstetten', 2010, 66211.0)
# (9, 'Mettmenstetten', 2011, 68155.0)
# (9, 'Mettmenstetten', 2012, 69649.0)
# (9, 'Mettmenstetten', 2013, 68173.0)
# (9, 'Mettmenstetten', 2014, 68008.0)
# (9, 'Mettmenstetten', 2015, 70416.0)
# (9, 'Mettmenstetten', 2016, 70609.0)
# (9, 'Mettmenstetten', 2017, 73971.0)
# (9, 'Mettmenstetten', 2018, 72609.0)
# (9, 'Mettmenstetten', 2019, 73511.0)
# (9, 'Mettmenstetten', 2020, 73101.0)
# (9, 'Mettmenstetten', 2021, 73206.0)
# (9, 'Mettmenstetten', 2022, 73738.0)
# (10, 'Obfelden', 2009, 56348.0)
# (10, 'Obfelden', 2010, 58122.0)
# (10, 'Obfelden', 2011, 58880.0)
# (10, 'Obfelden', 2012, 63623.0)
# (10, 'Obfelden', 2013, 63206.0)
# (10, 'Obfelden', 2014, 63453.0)
# (10, 'Obfelden', 2015, 63366.0)
# (10, 'Obfelden', 2016, 62623.0)
# (10, 'Obfelden', 2017, 64093.0)
# (10, 'Obfelden', 2018, 65513.0)
# (10, 'Obfelden', 2019, 64913.0)
# (10, 'Obfelden', 2020, 65745.0)
# (10, 'Obfelden', 2021, 64538.0)
# (10, 'Obfelden', 2022, 65390.0)
# (11, 'Ottenbach', 2009, 65742.0)
# (11, 'Ottenbach', 2010, 62748.0)
# (11, 'Ottenbach', 2011, 63292.0)
# (11, 'Ottenbach', 2012, 64102.0)
# (11, 'Ottenbach', 2013, 70025.0)
# (11, 'Ottenbach', 2014, 71186.0)
# (11, 'Ottenbach', 2015, 69160.0)
# (11, 'Ottenbach', 2016, 70400.0)
# (11, 'Ottenbach', 2017, 74377.0)
# (11, 'Ottenbach', 2018, 75108.0)
# (11, 'Ottenbach', 2019, 74631.0)
# (11, 'Ottenbach', 2020, 72736.0)
# (11, 'Ottenbach', 2021, 72928.0)
# (11, 'Ottenbach', 2022, 73323.0)
# (12, 'Rifferswil', 2009, 56804.0)
# (12, 'Rifferswil', 2010, 59875.0)
# (12, 'Rifferswil', 2011, 60365.0)
# (12, 'Rifferswil', 2012, 64246.0)
# (12, 'Rifferswil', 2013, 62712.0)
# (12, 'Rifferswil', 2014, 61275.0)
# (12, 'Rifferswil', 2015, 62527.0)
# (12, 'Rifferswil', 2016, 61617.0)
# (12, 'Rifferswil', 2017, 64876.0)
# (12, 'Rifferswil', 2018, 64325.0)
# (12, 'Rifferswil', 2019, 70374.0)
# (12, 'Rifferswil', 2020, 72749.0)
# (12, 'Rifferswil', 2021, 75090.0)
# (12, 'Rifferswil', 2022, 75248.0)
# (13, 'Stallikon', 2009, 77241.0)
# (13, 'Stallikon', 2010, 81024.0)
# (13, 'Stallikon', 2011, 79828.0)
# (13, 'Stallikon', 2012, 82891.0)
# (13, 'Stallikon', 2013, 82427.0)
# (13, 'Stallikon', 2014, 84440.0)
# (13, 'Stallikon', 2015, 81667.0)
# (13, 'Stallikon', 2016, 83115.0)
# (13, 'Stallikon', 2017, 82654.0)
# (13, 'Stallikon', 2018, 83096.0)
# (13, 'Stallikon', 2019, 85295.0)
# (13, 'Stallikon', 2020, 87899.0)
# (13, 'Stallikon', 2021, 85802.0)
# (13, 'Stallikon', 2022, 84284.0)
# (14, 'Wettswil', 2009, 83805.0)
# (14, 'Wettswil', 2010, 87797.0)
# (14, 'Wettswil', 2011, 90040.0)
# (14, 'Wettswil', 2012, 90789.0)
# (14, 'Wettswil', 2013, 93821.0)
# (14, 'Wettswil', 2014, 92592.0)
# (14, 'Wettswil', 2015, 93833.0)
# (14, 'Wettswil', 2016, 99738.0)
# (14, 'Wettswil', 2017, 101065.0)
# (14, 'Wettswil', 2018, 106307.0)
# (14, 'Wettswil', 2019, 104214.0)
# (14, 'Wettswil', 2020, 102499.0)
# (14, 'Wettswil', 2021, 97781.0)
# (14, 'Wettswil', 2022, 98510.0)
# (22, 'Benken', 2009, 52202.0)
# (22, 'Benken', 2010, 53074.0)
# (22, 'Benken', 2011, 54420.0)
# (22, 'Benken', 2012, 52848.0)
# (22, 'Benken', 2013, 55086.0)
# (22, 'Benken', 2014, 58681.0)
# (22, 'Benken', 2015, 58263.0)
# (22, 'Benken', 2016, 58282.0)
# (22, 'Benken', 2017, 62548.0)
# (22, 'Benken', 2018, 61957.0)
# (22, 'Benken', 2019, 64675.0)
# (22, 'Benken', 2020, 67270.0)
# (22, 'Benken', 2021, 65331.0)
# (22, 'Benken', 2022, 70346.0)
# (23, 'Berg', 2009, 58544.0)
# (23, 'Berg', 2010, 60167.0)
# (23, 'Berg', 2011, 55748.0)
# (23, 'Berg', 2012, 60358.0)
# (23, 'Berg', 2013, 61533.0)
# (23, 'Berg', 2014, 61932.0)
# (23, 'Berg', 2015, 62581.0)
# (23, 'Berg', 2016, 82704.0)
# (23, 'Berg', 2017, 85287.0)
# (23, 'Berg', 2018, 112383.0)
# (23, 'Berg', 2019, 97468.0)
# (23, 'Berg', 2020, 93987.0)
# (23, 'Berg', 2021, 93141.0)
# (23, 'Berg', 2022, 97830.0)
# (24, 'Buch', 2009, 56875.0)
# (24, 'Buch', 2010, 59034.0)
# (24, 'Buch', 2011, 61383.0)
# (24, 'Buch', 2012, 61423.0)
# (24, 'Buch', 2013, 63903.0)
# (24, 'Buch', 2014, 63985.0)
# (24, 'Buch', 2015, 64776.0)
# (24, 'Buch', 2016, 66966.0)
# (24, 'Buch', 2017, 69082.0)
# (24, 'Buch', 2018, 70012.0)
# (24, 'Buch', 2019, 70226.0)
# (24, 'Buch', 2020, 70701.0)
# (24, 'Buch', 2021, 68692.0)
# (24, 'Buch', 2022, 67982.0)
# (25, 'Dachsen', 2009, 60013.0)
# (25, 'Dachsen', 2010, 60552.0)
# (25, 'Dachsen', 2011, 59113.0)
# (25, 'Dachsen', 2012, 60101.0)
# (25, 'Dachsen', 2013, 60629.0)
# (25, 'Dachsen', 2014, 62774.0)
# (25, 'Dachsen', 2015, 63126.0)
# (25, 'Dachsen', 2016, 62632.0)
# (25, 'Dachsen', 2017, 62573.0)
# (25, 'Dachsen', 2018, 59179.0)
# (25, 'Dachsen', 2019, 69416.0)
# (25, 'Dachsen', 2020, 68288.0)
# (25, 'Dachsen', 2021, 70269.0)
# (25, 'Dachsen', 2022, 67553.0)
# (26, 'Dorf', 2009, 65045.0)
# (26, 'Dorf', 2010, 62682.0)
# (26, 'Dorf', 2011, 65640.0)
# (26, 'Dorf', 2012, 64957.0)
# (26, 'Dorf', 2013, 65056.0)
# (26, 'Dorf', 2014, 61559.0)
# (26, 'Dorf', 2015, 67175.0)
# (26, 'Dorf', 2016, 65782.0)
# (26, 'Dorf', 2017, 65957.0)
# (26, 'Dorf', 2018, 67583.0)
# (26, 'Dorf', 2019, 66374.0)
# (26, 'Dorf', 2020, 65877.0)
# (26, 'Dorf', 2021, 67211.0)
# (26, 'Dorf', 2022, 67550.0)
# (27, 'Feuerthalen', 2009, 52515.0)
# (27, 'Feuerthalen', 2010, 53718.0)
# (27, 'Feuerthalen', 2011, 54069.0)
# (27, 'Feuerthalen', 2012, 54944.0)
# (27, 'Feuerthalen', 2013, 52189.0)
# (27, 'Feuerthalen', 2014, 53953.0)
# (27, 'Feuerthalen', 2015, 53791.0)
# (27, 'Feuerthalen', 2016, 55893.0)
# (27, 'Feuerthalen', 2017, 56705.0)
# (27, 'Feuerthalen', 2018, 58645.0)
# (27, 'Feuerthalen', 2019, 59971.0)
# (27, 'Feuerthalen', 2020, 61062.0)
# (27, 'Feuerthalen', 2021, 61225.0)
# (27, 'Feuerthalen', 2022, 60018.0)
# (28, 'Flaach', 2009, 59063.0)
# (28, 'Flaach', 2010, 60526.0)
# (28, 'Flaach', 2011, 60425.0)
# (28, 'Flaach', 2012, 61643.0)
# (28, 'Flaach', 2013, 62409.0)
# (28, 'Flaach', 2014, 61974.0)
# (28, 'Flaach', 2015, 62006.0)
# (28, 'Flaach', 2016, 62423.0)
# (28, 'Flaach', 2017, 61998.0)
# (28, 'Flaach', 2018, 62250.0)
# (28, 'Flaach', 2019, 65124.0)
# (28, 'Flaach', 2020, 66039.0)
# (28, 'Flaach', 2021, 66978.0)
# (28, 'Flaach', 2022, 66223.0)
# (29, 'Flurlingen', 2009, 59964.0)
# (29, 'Flurlingen', 2010, 60885.0)
# (29, 'Flurlingen', 2011, 63578.0)
# (29, 'Flurlingen', 2012, 66619.0)
# (29, 'Flurlingen', 2013, 66287.0)
# (29, 'Flurlingen', 2014, 70060.0)
# (29, 'Flurlingen', 2015, 72127.0)
# (29, 'Flurlingen', 2016, 69128.0)
# (29, 'Flurlingen', 2017, 74106.0)
# (29, 'Flurlingen', 2018, 74192.0)
# (29, 'Flurlingen', 2019, 73705.0)
# (29, 'Flurlingen', 2020, 72525.0)
# (29, 'Flurlingen', 2021, 72490.0)
# (29, 'Flurlingen', 2022, 73682.0)
# (31, 'Henggart', 2009, 64653.0)
# (31, 'Henggart', 2010, 65983.0)
# (31, 'Henggart', 2011, 65299.0)
# (31, 'Henggart', 2012, 68547.0)
# (31, 'Henggart', 2013, 67134.0)
# (31, 'Henggart', 2014, 66441.0)
# (31, 'Henggart', 2015, 65580.0)
# (31, 'Henggart', 2016, 66625.0)
# (31, 'Henggart', 2017, 65877.0)
# (31, 'Henggart', 2018, 65290.0)
# (31, 'Henggart', 2019, 66347.0)
# (31, 'Henggart', 2020, 67778.0)
# (31, 'Henggart', 2021, 68273.0)
# (31, 'Henggart', 2022, 65723.0)
# (33, 'Kleinandelfingen', 2009, 57170.0)
# (33, 'Kleinandelfingen', 2010, 58073.0)
# (33, 'Kleinandelfingen', 2011, 58663.0)
# (33, 'Kleinandelfingen', 2012, 60370.0)
# (33, 'Kleinandelfingen', 2013, 60202.0)
# (33, 'Kleinandelfingen', 2014, 58555.0)
# (33, 'Kleinandelfingen', 2015, 58834.0)
# (33, 'Kleinandelfingen', 2016, 59851.0)
# (33, 'Kleinandelfingen', 2017, 61556.0)
# (33, 'Kleinandelfingen', 2018, 61924.0)
# (33, 'Kleinandelfingen', 2019, 63267.0)
# (33, 'Kleinandelfingen', 2020, 60493.0)
# (33, 'Kleinandelfingen', 2021, 61431.0)
# (33, 'Kleinandelfingen', 2022, 65382.0)
# (34, 'Laufen-Uhwiesen', 2009, 64408.0)
# (34, 'Laufen-Uhwiesen', 2010, 73722.0)
# (34, 'Laufen-Uhwiesen', 2011, 69871.0)
# (34, 'Laufen-Uhwiesen', 2012, 69470.0)
# (34, 'Laufen-Uhwiesen', 2013, 71427.0)
# (34, 'Laufen-Uhwiesen', 2014, 76910.0)
# (34, 'Laufen-Uhwiesen', 2015, 78365.0)
# (34, 'Laufen-Uhwiesen', 2016, 81600.0)
# (34, 'Laufen-Uhwiesen', 2017, 80228.0)
# (34, 'Laufen-Uhwiesen', 2018, 82432.0)
# (34, 'Laufen-Uhwiesen', 2019, 98433.0)
# (34, 'Laufen-Uhwiesen', 2020, 79595.0)
# (34, 'Laufen-Uhwiesen', 2021, 80007.0)
# (34, 'Laufen-Uhwiesen', 2022, 77603.0)
# (35, 'Marthalen', 2009, 55128.0)
# (35, 'Marthalen', 2010, 56542.0)
# (35, 'Marthalen', 2011, 58663.0)
# (35, 'Marthalen', 2012, 56523.0)
# (35, 'Marthalen', 2013, 58411.0)
# (35, 'Marthalen', 2014, 59931.0)
# (35, 'Marthalen', 2015, 59813.0)
# (35, 'Marthalen', 2016, 59987.0)
# (35, 'Marthalen', 2017, 65203.0)
# (35, 'Marthalen', 2018, 66491.0)
# (35, 'Marthalen', 2019, 69759.0)
# (35, 'Marthalen', 2020, 70187.0)
# (35, 'Marthalen', 2021, 70597.0)
# (35, 'Marthalen', 2022, 67851.0)
# (37, 'Ossingen', 2009, 50658.0)
# (37, 'Ossingen', 2010, 51693.0)
# (37, 'Ossingen', 2011, 51381.0)
# (37, 'Ossingen', 2012, 51463.0)
# (37, 'Ossingen', 2013, 52941.0)
# (37, 'Ossingen', 2014, 52162.0)
# (37, 'Ossingen', 2015, 55446.0)
# (37, 'Ossingen', 2016, 53958.0)
# (37, 'Ossingen', 2017, 55622.0)
# (37, 'Ossingen', 2018, 56017.0)
# (37, 'Ossingen', 2019, 55823.0)
# (37, 'Ossingen', 2020, 57093.0)
# (37, 'Ossingen', 2021, 59166.0)
# (37, 'Ossingen', 2022, 59639.0)
# (38, 'Rheinau', 2009, 55352.0)
# (38, 'Rheinau', 2010, 58873.0)
# (38, 'Rheinau', 2011, 56883.0)
# (38, 'Rheinau', 2012, 61201.0)
# (38, 'Rheinau', 2013, 56747.0)
# (38, 'Rheinau', 2014, 57048.0)
# (38, 'Rheinau', 2015, 56731.0)
# (38, 'Rheinau', 2016, 57419.0)
# (38, 'Rheinau', 2017, 61019.0)
# (38, 'Rheinau', 2018, 59289.0)
# (38, 'Rheinau', 2019, 60378.0)
# (38, 'Rheinau', 2020, 61469.0)
# (38, 'Rheinau', 2021, 59805.0)
# (38, 'Rheinau', 2022, 60282.0)
# (39, 'Thalheim', 2009, 54070.0)
# (39, 'Thalheim', 2010, 55188.0)
# (39, 'Thalheim', 2011, 55590.0)
# (39, 'Thalheim', 2012, 56656.0)
# (39, 'Thalheim', 2013, 56908.0)
# (39, 'Thalheim', 2014, 58869.0)
# (39, 'Thalheim', 2015, 58795.0)
# (39, 'Thalheim', 2016, 58252.0)
# (39, 'Thalheim', 2017, 63985.0)
# (39, 'Thalheim', 2018, 66986.0)
# (39, 'Thalheim', 2019, 65443.0)
# (39, 'Thalheim', 2020, 67020.0)
# (39, 'Thalheim', 2021, 66058.0)
# (39, 'Thalheim', 2022, 64296.0)
# (40, 'Trüllikon', 2009, 62826.0)
# (40, 'Trüllikon', 2010, 52640.0)
# (40, 'Trüllikon', 2011, 54689.0)
# (40, 'Trüllikon', 2012, 53062.0)
# (40, 'Trüllikon', 2013, 48620.0)
# (40, 'Trüllikon', 2014, 61189.0)
# (40, 'Trüllikon', 2015, 59197.0)
# (40, 'Trüllikon', 2016, 60528.0)
# (40, 'Trüllikon', 2017, 60326.0)
# (40, 'Trüllikon', 2018, 64646.0)
# (40, 'Trüllikon', 2019, 59759.0)
# (40, 'Trüllikon', 2020, 61060.0)
# (40, 'Trüllikon', 2021, 61869.0)
# (40, 'Trüllikon', 2022, 59288.0)
# (41, 'Truttikon', 2009, 47616.0)
# (41, 'Truttikon', 2010, 47266.0)
# (41, 'Truttikon', 2011, 50790.0)
# (41, 'Truttikon', 2012, 52112.0)
# (41, 'Truttikon', 2013, 49936.0)
# (41, 'Truttikon', 2014, 52624.0)
# (41, 'Truttikon', 2015, 50212.0)
# (41, 'Truttikon', 2016, 51406.0)
# (41, 'Truttikon', 2017, 55090.0)
# (41, 'Truttikon', 2018, 53270.0)
# (41, 'Truttikon', 2019, 54393.0)
# (41, 'Truttikon', 2020, 57629.0)
# (41, 'Truttikon', 2021, 58323.0)
# (41, 'Truttikon', 2022, 59049.0)
# (43, 'Volken', 2009, 54774.0)
# (43, 'Volken', 2010, 59873.0)
# (43, 'Volken', 2011, 56928.0)
# (43, 'Volken', 2012, 64835.0)
# (43, 'Volken', 2013, 63760.0)
# (43, 'Volken', 2014, 62909.0)
# (43, 'Volken', 2015, 63279.0)
# (43, 'Volken', 2016, 65416.0)
# (43, 'Volken', 2017, 62900.0)
# (43, 'Volken', 2018, 69266.0)
# (43, 'Volken', 2019, 65513.0)
# (43, 'Volken', 2020, 66873.0)
# (43, 'Volken', 2021, 70943.0)
# (43, 'Volken', 2022, 69317.0)
# (51, 'Bachenbülach', 2009, 59640.0)
# (51, 'Bachenbülach', 2010, 61678.0)
# (51, 'Bachenbülach', 2011, 59996.0)
# (51, 'Bachenbülach', 2012, 61043.0)
# (51, 'Bachenbülach', 2013, 62514.0)
# (51, 'Bachenbülach', 2014, 61104.0)
# (51, 'Bachenbülach', 2015, 63887.0)
# (51, 'Bachenbülach', 2016, 63393.0)
# (51, 'Bachenbülach', 2017, 62647.0)
# (51, 'Bachenbülach', 2018, 64106.0)
# (51, 'Bachenbülach', 2019, 64708.0)
# (51, 'Bachenbülach', 2020, 66530.0)
# (51, 'Bachenbülach', 2021, 65354.0)
# (51, 'Bachenbülach', 2022, 62913.0)
# (52, 'Bassersdorf', 2009, 63132.0)
# (52, 'Bassersdorf', 2010, 64678.0)
# (52, 'Bassersdorf', 2011, 65054.0)
# (52, 'Bassersdorf', 2012, 66742.0)
# (52, 'Bassersdorf', 2013, 66860.0)
# (52, 'Bassersdorf', 2014, 65400.0)
# (52, 'Bassersdorf', 2015, 66190.0)
# (52, 'Bassersdorf', 2016, 65631.0)
# (52, 'Bassersdorf', 2017, 65220.0)
# (52, 'Bassersdorf', 2018, 65775.0)
# (52, 'Bassersdorf', 2019, 65862.0)
# (52, 'Bassersdorf', 2020, 66167.0)
# (52, 'Bassersdorf', 2021, 64782.0)
# (52, 'Bassersdorf', 2022, 63420.0)
# (53, 'Bülach', 2009, 53917.0)
# (53, 'Bülach', 2010, 56206.0)
# (53, 'Bülach', 2011, 56972.0)
# (53, 'Bülach', 2012, 57150.0)
# (53, 'Bülach', 2013, 57782.0)
# (53, 'Bülach', 2014, 57282.0)
# (53, 'Bülach', 2015, 58368.0)
# (53, 'Bülach', 2016, 58441.0)
# (53, 'Bülach', 2017, 60570.0)
# (53, 'Bülach', 2018, 61286.0)
# (53, 'Bülach', 2019, 60992.0)
# (53, 'Bülach', 2020, 61020.0)
# (53, 'Bülach', 2021, 60729.0)
# (53, 'Bülach', 2022, 60282.0)
# (54, 'Dietlikon', 2009, 65120.0)
# (54, 'Dietlikon', 2010, 67703.0)
# (54, 'Dietlikon', 2011, 67223.0)
# (54, 'Dietlikon', 2012, 68719.0)
# (54, 'Dietlikon', 2013, 67029.0)
# (54, 'Dietlikon', 2014, 68397.0)
# (54, 'Dietlikon', 2015, 66581.0)
# (54, 'Dietlikon', 2016, 66822.0)
# (54, 'Dietlikon', 2017, 66880.0)
# (54, 'Dietlikon', 2018, 68081.0)
# (54, 'Dietlikon', 2019, 68167.0)
# (54, 'Dietlikon', 2020, 67323.0)
# (54, 'Dietlikon', 2021, 67011.0)
# (54, 'Dietlikon', 2022, 66234.0)
# (55, 'Eglisau', 2009, 62632.0)
# (55, 'Eglisau', 2010, 63442.0)
# (55, 'Eglisau', 2011, 66000.0)
# (55, 'Eglisau', 2012, 65969.0)
# (55, 'Eglisau', 2013, 67643.0)
# (55, 'Eglisau', 2014, 67189.0)
# (55, 'Eglisau', 2015, 67917.0)
# (55, 'Eglisau', 2016, 68701.0)
# (55, 'Eglisau', 2017, 69900.0)
# (55, 'Eglisau', 2018, 69974.0)
# (55, 'Eglisau', 2019, 70378.0)
# (55, 'Eglisau', 2020, 70472.0)
# (55, 'Eglisau', 2021, 70795.0)
# (55, 'Eglisau', 2022, 72745.0)
# (56, 'Embrach', 2009, 56558.0)
# (56, 'Embrach', 2010, 57602.0)
# (56, 'Embrach', 2011, 57205.0)
# (56, 'Embrach', 2012, 58899.0)
# (56, 'Embrach', 2013, 59014.0)
# (56, 'Embrach', 2014, 58798.0)
# (56, 'Embrach', 2015, 57255.0)
# (56, 'Embrach', 2016, 58295.0)
# (56, 'Embrach', 2017, 57773.0)
# (56, 'Embrach', 2018, 59639.0)
# (56, 'Embrach', 2019, 61398.0)
# (56, 'Embrach', 2020, 60011.0)
# (56, 'Embrach', 2021, 59052.0)
# (56, 'Embrach', 2022, 58334.0)
# (57, 'Freienstein-Teufen', 2009, 62599.0)
# (57, 'Freienstein-Teufen', 2010, 62080.0)
# (57, 'Freienstein-Teufen', 2011, 64070.0)
# (57, 'Freienstein-Teufen', 2012, 66095.0)
# (57, 'Freienstein-Teufen', 2013, 67335.0)
# (57, 'Freienstein-Teufen', 2014, 64374.0)
# (57, 'Freienstein-Teufen', 2015, 64901.0)
# (57, 'Freienstein-Teufen', 2016, 65722.0)
# (57, 'Freienstein-Teufen', 2017, 64588.0)
# (57, 'Freienstein-Teufen', 2018, 66927.0)
# (57, 'Freienstein-Teufen', 2019, 70590.0)
# (57, 'Freienstein-Teufen', 2020, 69593.0)
# (57, 'Freienstein-Teufen', 2021, 69044.0)
# (57, 'Freienstein-Teufen', 2022, 70300.0)
# (58, 'Glattfelden', 2009, 56592.0)
# (58, 'Glattfelden', 2010, 57002.0)
# (58, 'Glattfelden', 2011, 57654.0)
# (58, 'Glattfelden', 2012, 57153.0)
# (58, 'Glattfelden', 2013, 58326.0)
# (58, 'Glattfelden', 2014, 57046.0)
# (58, 'Glattfelden', 2015, 58578.0)
# (58, 'Glattfelden', 2016, 58270.0)
# (58, 'Glattfelden', 2017, 58002.0)
# (58, 'Glattfelden', 2018, 61668.0)
# (58, 'Glattfelden', 2019, 64378.0)
# (58, 'Glattfelden', 2020, 63438.0)
# (58, 'Glattfelden', 2021, 62561.0)
# (58, 'Glattfelden', 2022, 63008.0)
# (59, 'Hochfelden', 2009, 62346.0)
# (59, 'Hochfelden', 2010, 65038.0)
# (59, 'Hochfelden', 2011, 65936.0)
# (59, 'Hochfelden', 2012, 67240.0)
# (59, 'Hochfelden', 2013, 67714.0)
# (59, 'Hochfelden', 2014, 66731.0)
# (59, 'Hochfelden', 2015, 65100.0)
# (59, 'Hochfelden', 2016, 67912.0)
# (59, 'Hochfelden', 2017, 71202.0)
# (59, 'Hochfelden', 2018, 70626.0)
# (59, 'Hochfelden', 2019, 68763.0)
# (59, 'Hochfelden', 2020, 65157.0)
# (59, 'Hochfelden', 2021, 63865.0)
# (59, 'Hochfelden', 2022, 64606.0)
# (60, 'Höri', 2009, 49033.0)
# (60, 'Höri', 2010, 54373.0)
# (60, 'Höri', 2011, 53598.0)
# (60, 'Höri', 2012, 55729.0)
# (60, 'Höri', 2013, 54364.0)
# (60, 'Höri', 2014, 52811.0)
# (60, 'Höri', 2015, 53522.0)
# (60, 'Höri', 2016, 58553.0)
# (60, 'Höri', 2017, 55654.0)
# (60, 'Höri', 2018, 57363.0)
# (60, 'Höri', 2019, 58668.0)
# (60, 'Höri', 2020, 58080.0)
# (60, 'Höri', 2021, 57505.0)
# (60, 'Höri', 2022, 56611.0)
# (61, 'Hüntwangen', 2009, 60550.0)
# (61, 'Hüntwangen', 2010, 62292.0)
# (61, 'Hüntwangen', 2011, 63896.0)
# (61, 'Hüntwangen', 2012, 66165.0)
# (61, 'Hüntwangen', 2013, 71515.0)
# (61, 'Hüntwangen', 2014, 70577.0)
# (61, 'Hüntwangen', 2015, 68160.0)
# (61, 'Hüntwangen', 2016, 71451.0)
# (61, 'Hüntwangen', 2017, 67222.0)
# (61, 'Hüntwangen', 2018, 65514.0)
# (61, 'Hüntwangen', 2019, 69890.0)
# (61, 'Hüntwangen', 2020, 72575.0)
# (61, 'Hüntwangen', 2021, 68389.0)
# (61, 'Hüntwangen', 2022, 70739.0)
# (62, 'Kloten', 2009, 55567.0)
# (62, 'Kloten', 2010, 56699.0)
# (62, 'Kloten', 2011, 56532.0)
# (62, 'Kloten', 2012, 57588.0)
# (62, 'Kloten', 2013, 57118.0)
# (62, 'Kloten', 2014, 57630.0)
# (62, 'Kloten', 2015, 57249.0)
# (62, 'Kloten', 2016, 57336.0)
# (62, 'Kloten', 2017, 56880.0)
# (62, 'Kloten', 2018, 57542.0)
# (62, 'Kloten', 2019, 57986.0)
# (62, 'Kloten', 2020, 58948.0)
# (62, 'Kloten', 2021, 57341.0)
# (62, 'Kloten', 2022, 55823.0)
# (63, 'Lufingen', 2009, 74014.0)
# (63, 'Lufingen', 2010, 76103.0)
# (63, 'Lufingen', 2011, 75105.0)
# (63, 'Lufingen', 2012, 67567.0)
# (63, 'Lufingen', 2013, 74550.0)
# (63, 'Lufingen', 2014, 74815.0)
# (63, 'Lufingen', 2015, 78603.0)
# (63, 'Lufingen', 2016, 79152.0)
# (63, 'Lufingen', 2017, 79079.0)
# (63, 'Lufingen', 2018, 75857.0)
# (63, 'Lufingen', 2019, 79567.0)
# (63, 'Lufingen', 2020, 78432.0)
# (63, 'Lufingen', 2021, 79176.0)
# (63, 'Lufingen', 2022, 77011.0)
# (64, 'Nürensdorf', 2009, 79964.0)
# (64, 'Nürensdorf', 2010, 79432.0)
# (64, 'Nürensdorf', 2011, 79303.0)
# (64, 'Nürensdorf', 2012, 79287.0)
# (64, 'Nürensdorf', 2013, 82811.0)
# (64, 'Nürensdorf', 2014, 83926.0)
# (64, 'Nürensdorf', 2015, 84324.0)
# (64, 'Nürensdorf', 2016, 84457.0)
# (64, 'Nürensdorf', 2017, 84997.0)
# (64, 'Nürensdorf', 2018, 82389.0)
# (64, 'Nürensdorf', 2019, 84852.0)
# (64, 'Nürensdorf', 2020, 80698.0)
# (64, 'Nürensdorf', 2021, 83576.0)
# (64, 'Nürensdorf', 2022, 80030.0)
# (65, 'Oberembrach', 2009, 61198.0)
# (65, 'Oberembrach', 2010, 64370.0)
# (65, 'Oberembrach', 2011, 62639.0)
# (65, 'Oberembrach', 2012, 63829.0)
# (65, 'Oberembrach', 2013, 66392.0)
# (65, 'Oberembrach', 2014, 65412.0)
# (65, 'Oberembrach', 2015, 67145.0)
# (65, 'Oberembrach', 2016, 67822.0)
# (65, 'Oberembrach', 2017, 71278.0)
# (65, 'Oberembrach', 2018, 72109.0)
# (65, 'Oberembrach', 2019, 72077.0)
# (65, 'Oberembrach', 2020, 73487.0)
# (65, 'Oberembrach', 2021, 70700.0)
# (65, 'Oberembrach', 2022, 73539.0)
# (66, 'Opfikon', 2009, 51597.0)
# (66, 'Opfikon', 2010, 49303.0)
# (66, 'Opfikon', 2011, 51049.0)
# (66, 'Opfikon', 2012, 52924.0)
# (66, 'Opfikon', 2013, 51974.0)
# (66, 'Opfikon', 2014, 53040.0)
# (66, 'Opfikon', 2015, 55415.0)
# (66, 'Opfikon', 2016, 54871.0)
# (66, 'Opfikon', 2017, 54347.0)
# (66, 'Opfikon', 2018, 54678.0)
# (66, 'Opfikon', 2019, 54545.0)
# (66, 'Opfikon', 2020, 53380.0)
# (66, 'Opfikon', 2021, 56321.0)
# (66, 'Opfikon', 2022, 56398.0)
# (67, 'Rafz', 2009, 61598.0)
# (67, 'Rafz', 2010, 59485.0)
# (67, 'Rafz', 2011, 61507.0)
# (67, 'Rafz', 2012, 61862.0)
# (67, 'Rafz', 2013, 61858.0)
# (67, 'Rafz', 2014, 63285.0)
# (67, 'Rafz', 2015, 62997.0)
# (67, 'Rafz', 2016, 62493.0)
# (67, 'Rafz', 2017, 63431.0)
# (67, 'Rafz', 2018, 61235.0)
# (67, 'Rafz', 2019, 66004.0)
# (67, 'Rafz', 2020, 67294.0)
# (67, 'Rafz', 2021, 65741.0)
# (67, 'Rafz', 2022, 64551.0)
# (68, 'Rorbas', 2009, 52000.0)
# (68, 'Rorbas', 2010, 52399.0)
# (68, 'Rorbas', 2011, 55267.0)
# (68, 'Rorbas', 2012, 55051.0)
# (68, 'Rorbas', 2013, 54691.0)
# (68, 'Rorbas', 2014, 57052.0)
# (68, 'Rorbas', 2015, 53755.0)
# (68, 'Rorbas', 2016, 55008.0)
# (68, 'Rorbas', 2017, 56049.0)
# (68, 'Rorbas', 2018, 56133.0)
# (68, 'Rorbas', 2019, 55571.0)
# (68, 'Rorbas', 2020, 59501.0)
# (68, 'Rorbas', 2021, 59448.0)
# (68, 'Rorbas', 2022, 60911.0)
# (69, 'Wallisellen', 2009, 67977.0)
# (69, 'Wallisellen', 2010, 68465.0)
# (69, 'Wallisellen', 2011, 68542.0)
# (69, 'Wallisellen', 2012, 69034.0)
# (69, 'Wallisellen', 2013, 68560.0)
# (69, 'Wallisellen', 2014, 68318.0)
# (69, 'Wallisellen', 2015, 68835.0)
# (69, 'Wallisellen', 2016, 70082.0)
# (69, 'Wallisellen', 2017, 69350.0)
# (69, 'Wallisellen', 2018, 69467.0)
# (69, 'Wallisellen', 2019, 71221.0)
# (69, 'Wallisellen', 2020, 69452.0)
# (69, 'Wallisellen', 2021, 70083.0)
# (69, 'Wallisellen', 2022, 70596.0)
# (70, 'Wasterkingen', 2009, 57251.0)
# (70, 'Wasterkingen', 2010, 58280.0)
# (70, 'Wasterkingen', 2011, 57658.0)
# (70, 'Wasterkingen', 2012, 56457.0)
# (70, 'Wasterkingen', 2013, 56320.0)
# (70, 'Wasterkingen', 2014, 59309.0)
# (70, 'Wasterkingen', 2015, 59620.0)
# (70, 'Wasterkingen', 2016, 60804.0)
# (70, 'Wasterkingen', 2017, 60708.0)
# (70, 'Wasterkingen', 2018, 59359.0)
# (70, 'Wasterkingen', 2019, 60505.0)
# (70, 'Wasterkingen', 2020, 61696.0)
# (70, 'Wasterkingen', 2021, 61970.0)
# (70, 'Wasterkingen', 2022, 62581.0)
# (71, 'Wil', 2009, 59686.0)
# (71, 'Wil', 2010, 59766.0)
# (71, 'Wil', 2011, 59484.0)
# (71, 'Wil', 2012, 63733.0)
# (71, 'Wil', 2013, 69748.0)
# (71, 'Wil', 2014, 63260.0)
# (71, 'Wil', 2015, 65071.0)
# (71, 'Wil', 2016, 70745.0)
# (71, 'Wil', 2017, 78232.0)
# (71, 'Wil', 2018, 75588.0)
# (71, 'Wil', 2019, 76536.0)
# (71, 'Wil', 2020, 74315.0)
# (71, 'Wil', 2021, 76715.0)
# (71, 'Wil', 2022, 73476.0)
# (72, 'Winkel', 2009, 86139.0)
# (72, 'Winkel', 2010, 88397.0)
# (72, 'Winkel', 2011, 89953.0)
# (72, 'Winkel', 2012, 95245.0)
# (72, 'Winkel', 2013, 93206.0)
# (72, 'Winkel', 2014, 91290.0)
# (72, 'Winkel', 2015, 91887.0)
# (72, 'Winkel', 2016, 98364.0)
# (72, 'Winkel', 2017, 97315.0)
# (72, 'Winkel', 2018, 96216.0)
# (72, 'Winkel', 2019, 99987.0)
# (72, 'Winkel', 2020, 101334.0)
# (72, 'Winkel', 2021, 98977.0)
# (72, 'Winkel', 2022, 94926.0)
# (81, 'Bachs', 2009, 52237.0)
# (81, 'Bachs', 2010, 53704.0)
# (81, 'Bachs', 2011, 55369.0)
# (81, 'Bachs', 2012, 58402.0)
# (81, 'Bachs', 2013, 55066.0)
# (81, 'Bachs', 2014, 59046.0)
# (81, 'Bachs', 2015, 59938.0)
# (81, 'Bachs', 2016, 58754.0)
# (81, 'Bachs', 2017, 58137.0)
# (81, 'Bachs', 2018, 62405.0)
# (81, 'Bachs', 2019, 60015.0)
# (81, 'Bachs', 2020, 61417.0)
# (81, 'Bachs', 2021, 63579.0)
# (81, 'Bachs', 2022, 64478.0)
# (82, 'Boppelsen', 2009, 80596.0)
# (82, 'Boppelsen', 2010, 83478.0)
# (82, 'Boppelsen', 2011, 86969.0)
# (82, 'Boppelsen', 2012, 90138.0)
# (82, 'Boppelsen', 2013, 91754.0)
# (82, 'Boppelsen', 2014, 92707.0)
# (82, 'Boppelsen', 2015, 92742.0)
# (82, 'Boppelsen', 2016, 94334.0)
# (82, 'Boppelsen', 2017, 99498.0)
# (82, 'Boppelsen', 2018, 92083.0)
# (82, 'Boppelsen', 2019, 97636.0)
# (82, 'Boppelsen', 2020, 89335.0)
# (82, 'Boppelsen', 2021, 90715.0)
# (82, 'Boppelsen', 2022, 90381.0)
# (83, 'Buchs', 2009, 61119.0)
# (83, 'Buchs', 2010, 60118.0)
# (83, 'Buchs', 2011, 60543.0)
# (83, 'Buchs', 2012, 60313.0)
# (83, 'Buchs', 2013, 61263.0)
# (83, 'Buchs', 2014, 62418.0)
# (83, 'Buchs', 2015, 64848.0)
# (83, 'Buchs', 2016, 64553.0)
# (83, 'Buchs', 2017, 64297.0)
# (83, 'Buchs', 2018, 66353.0)
# (83, 'Buchs', 2019, 64394.0)
# (83, 'Buchs', 2020, 64634.0)
# (83, 'Buchs', 2021, 64146.0)
# (83, 'Buchs', 2022, 63175.0)
# (84, 'Dällikon', 2009, 59238.0)
# (84, 'Dällikon', 2010, 58713.0)
# (84, 'Dällikon', 2011, 54811.0)
# (84, 'Dällikon', 2012, 60120.0)
# (84, 'Dällikon', 2013, 60524.0)
# (84, 'Dällikon', 2014, 59478.0)
# (84, 'Dällikon', 2015, 60264.0)
# (84, 'Dällikon', 2016, 60253.0)
# (84, 'Dällikon', 2017, 61365.0)
# (84, 'Dällikon', 2018, 62756.0)
# (84, 'Dällikon', 2019, 62330.0)
# (84, 'Dällikon', 2020, 63870.0)
# (84, 'Dällikon', 2021, 64218.0)
# (84, 'Dällikon', 2022, 60328.0)
# (85, 'Dänikon', 2009, 62982.0)
# (85, 'Dänikon', 2010, 64538.0)
# (85, 'Dänikon', 2011, 63148.0)
# (85, 'Dänikon', 2012, 63643.0)
# (85, 'Dänikon', 2013, 65107.0)
# (85, 'Dänikon', 2014, 68056.0)
# (85, 'Dänikon', 2015, 65600.0)
# (85, 'Dänikon', 2016, 66039.0)
# (85, 'Dänikon', 2017, 71092.0)
# (85, 'Dänikon', 2018, 69273.0)
# (85, 'Dänikon', 2019, 70535.0)
# (85, 'Dänikon', 2020, 68884.0)
# (85, 'Dänikon', 2021, 69696.0)
# (85, 'Dänikon', 2022, 68804.0)
# (86, 'Dielsdorf', 2009, 58631.0)
# (86, 'Dielsdorf', 2010, 57870.0)
# (86, 'Dielsdorf', 2011, 60613.0)
# (86, 'Dielsdorf', 2012, 61620.0)
# (86, 'Dielsdorf', 2013, 64643.0)
# (86, 'Dielsdorf', 2014, 63172.0)
# (86, 'Dielsdorf', 2015, 61787.0)
# (86, 'Dielsdorf', 2016, 62516.0)
# (86, 'Dielsdorf', 2017, 62189.0)
# (86, 'Dielsdorf', 2018, 63973.0)
# (86, 'Dielsdorf', 2019, 62755.0)
# (86, 'Dielsdorf', 2020, 63547.0)
# (86, 'Dielsdorf', 2021, 61593.0)
# (86, 'Dielsdorf', 2022, 59587.0)
# (87, 'Hüttikon', 2009, 65754.0)
# (87, 'Hüttikon', 2010, 66010.0)
# (87, 'Hüttikon', 2011, 66391.0)
# (87, 'Hüttikon', 2012, 75328.0)
# (87, 'Hüttikon', 2013, 74295.0)
# (87, 'Hüttikon', 2014, 78130.0)
# (87, 'Hüttikon', 2015, 79535.0)
# (87, 'Hüttikon', 2016, 84273.0)
# (87, 'Hüttikon', 2017, 79992.0)
# (87, 'Hüttikon', 2018, 82556.0)
# (87, 'Hüttikon', 2019, 82506.0)
# (87, 'Hüttikon', 2020, 87077.0)
# (87, 'Hüttikon', 2021, 91028.0)
# (87, 'Hüttikon', 2022, 85209.0)
# (88, 'Neerach', 2009, 91299.0)
# (88, 'Neerach', 2010, 90874.0)
# (88, 'Neerach', 2011, 91569.0)
# (88, 'Neerach', 2012, 89336.0)
# (88, 'Neerach', 2013, 90588.0)
# (88, 'Neerach', 2014, 90859.0)
# (88, 'Neerach', 2015, 91461.0)
# (88, 'Neerach', 2016, 91079.0)
# (88, 'Neerach', 2017, 90725.0)
# (88, 'Neerach', 2018, 59941.0)
# (88, 'Neerach', 2019, 86327.0)
# (88, 'Neerach', 2020, 91486.0)
# (88, 'Neerach', 2021, 92565.0)
# (88, 'Neerach', 2022, 9634.0)
# (89, 'Niederglatt', 2009, 56572.0)
# (89, 'Niederglatt', 2010, 56644.0)
# (89, 'Niederglatt', 2011, 57558.0)
# (89, 'Niederglatt', 2012, 56862.0)
# (89, 'Niederglatt', 2013, 56315.0)
# (89, 'Niederglatt', 2014, 56189.0)
# (89, 'Niederglatt', 2015, 56105.0)
# (89, 'Niederglatt', 2016, 60338.0)
# (89, 'Niederglatt', 2017, 59403.0)
# (89, 'Niederglatt', 2018, 54616.0)
# (89, 'Niederglatt', 2019, 64070.0)
# (89, 'Niederglatt', 2020, 62518.0)
# (89, 'Niederglatt', 2021, 60376.0)
# (89, 'Niederglatt', 2022, 60791.0)
# (90, 'Niederhasli', 2009, 58907.0)
# (90, 'Niederhasli', 2010, 58241.0)
# (90, 'Niederhasli', 2011, 60381.0)
# (90, 'Niederhasli', 2012, 60871.0)
# (90, 'Niederhasli', 2013, 61487.0)
# (90, 'Niederhasli', 2014, 60690.0)
# (90, 'Niederhasli', 2015, 60650.0)
# (90, 'Niederhasli', 2016, 60832.0)
# (90, 'Niederhasli', 2017, 60422.0)
# (90, 'Niederhasli', 2018, 62213.0)
# (90, 'Niederhasli', 2019, 63305.0)
# (90, 'Niederhasli', 2020, 64041.0)
# (90, 'Niederhasli', 2021, 62860.0)
# (90, 'Niederhasli', 2022, 61630.0)
# (91, 'Niederweningen', 2009, 64148.0)
# (91, 'Niederweningen', 2010, 65362.0)
# (91, 'Niederweningen', 2011, 68125.0)
# (91, 'Niederweningen', 2012, 64745.0)
# (91, 'Niederweningen', 2013, 66446.0)
# (91, 'Niederweningen', 2014, 66447.0)
# (91, 'Niederweningen', 2015, 67416.0)
# (91, 'Niederweningen', 2016, 66996.0)
# (91, 'Niederweningen', 2017, 65955.0)
# (91, 'Niederweningen', 2018, 68474.0)
# (91, 'Niederweningen', 2019, 71485.0)
# (91, 'Niederweningen', 2020, 70935.0)
# (91, 'Niederweningen', 2021, 70345.0)
# (91, 'Niederweningen', 2022, 69408.0)
# (92, 'Oberglatt', 2009, 48328.0)
# (92, 'Oberglatt', 2010, 49527.0)
# (92, 'Oberglatt', 2011, 50364.0)
# (92, 'Oberglatt', 2012, 50557.0)
# (92, 'Oberglatt', 2013, 50281.0)
# (92, 'Oberglatt', 2014, 49222.0)
# (92, 'Oberglatt', 2015, 48687.0)
# (92, 'Oberglatt', 2016, 48873.0)
# (92, 'Oberglatt', 2017, 50372.0)
# (92, 'Oberglatt', 2018, 51005.0)
# (92, 'Oberglatt', 2019, 52577.0)
# (92, 'Oberglatt', 2020, 53033.0)
# (92, 'Oberglatt', 2021, 52755.0)
# (92, 'Oberglatt', 2022, 51573.0)
# (93, 'Oberweningen', 2009, 61840.0)
# (93, 'Oberweningen', 2010, 60399.0)
# (93, 'Oberweningen', 2011, 60051.0)
# (93, 'Oberweningen', 2012, 64844.0)
# (93, 'Oberweningen', 2013, 66637.0)
# (93, 'Oberweningen', 2014, 72079.0)
# (93, 'Oberweningen', 2015, 69973.0)
# (93, 'Oberweningen', 2016, 71364.0)
# (93, 'Oberweningen', 2017, 74571.0)
# (93, 'Oberweningen', 2018, 74229.0)
# (93, 'Oberweningen', 2019, 71477.0)
# (93, 'Oberweningen', 2020, 72330.0)
# (93, 'Oberweningen', 2021, 69516.0)
# (93, 'Oberweningen', 2022, 68739.0)
# (94, 'Otelfingen', 2009, 63340.0)
# (94, 'Otelfingen', 2010, 61390.0)
# (94, 'Otelfingen', 2011, 63166.0)
# (94, 'Otelfingen', 2012, 69458.0)
# (94, 'Otelfingen', 2013, 68551.0)
# (94, 'Otelfingen', 2014, 69460.0)
# (94, 'Otelfingen', 2015, 69733.0)
# (94, 'Otelfingen', 2016, 70390.0)
# (94, 'Otelfingen', 2017, 68781.0)
# (94, 'Otelfingen', 2018, 68541.0)
# (94, 'Otelfingen', 2019, 67713.0)
# (94, 'Otelfingen', 2020, 71631.0)
# (94, 'Otelfingen', 2021, 71034.0)
# (94, 'Otelfingen', 2022, 67818.0)
# (95, 'Regensberg', 2009, 69076.0)
# (95, 'Regensberg', 2010, 71910.0)
# (95, 'Regensberg', 2011, 71930.0)
# (95, 'Regensberg', 2012, 73458.0)
# (95, 'Regensberg', 2013, 74874.0)
# (95, 'Regensberg', 2014, 71663.0)
# (95, 'Regensberg', 2015, 73537.0)
# (95, 'Regensberg', 2016, 79349.0)
# (95, 'Regensberg', 2017, 71564.0)
# (95, 'Regensberg', 2018, 76180.0)
# (95, 'Regensberg', 2019, 76735.0)
# (95, 'Regensberg', 2020, 79017.0)
# (95, 'Regensberg', 2021, 86160.0)
# (95, 'Regensberg', 2022, 75801.0)
# (96, 'Regensdorf', 2009, 55589.0)
# (96, 'Regensdorf', 2010, 57524.0)
# (96, 'Regensdorf', 2011, 58703.0)
# (96, 'Regensdorf', 2012, 59103.0)
# (96, 'Regensdorf', 2013, 58619.0)
# (96, 'Regensdorf', 2014, 57021.0)
# (96, 'Regensdorf', 2015, 57335.0)
# (96, 'Regensdorf', 2016, 57251.0)
# (96, 'Regensdorf', 2017, 57422.0)
# (96, 'Regensdorf', 2018, 57806.0)
# (96, 'Regensdorf', 2019, 58443.0)
# (96, 'Regensdorf', 2020, 58840.0)
# (96, 'Regensdorf', 2021, 59340.0)
# (96, 'Regensdorf', 2022, 57976.0)
# (97, 'Rümlang', 2009, 56163.0)
# (97, 'Rümlang', 2010, 56379.0)
# (97, 'Rümlang', 2011, 56942.0)
# (97, 'Rümlang', 2012, 57370.0)
# (97, 'Rümlang', 2013, 56230.0)
# (97, 'Rümlang', 2014, 54905.0)
# (97, 'Rümlang', 2015, 58935.0)
# (97, 'Rümlang', 2016, 57082.0)
# (97, 'Rümlang', 2017, 58340.0)
# (97, 'Rümlang', 2018, 58611.0)
# (97, 'Rümlang', 2019, 59403.0)
# (97, 'Rümlang', 2020, 60049.0)
# (97, 'Rümlang', 2021, 60577.0)
# (97, 'Rümlang', 2022, 60329.0)
# (98, 'Schleinikon', 2009, 54544.0)
# (98, 'Schleinikon', 2010, 57215.0)
# (98, 'Schleinikon', 2011, 59217.0)
# (98, 'Schleinikon', 2012, 59981.0)
# (98, 'Schleinikon', 2013, 59582.0)
# (98, 'Schleinikon', 2014, 59570.0)
# (98, 'Schleinikon', 2015, 58551.0)
# (98, 'Schleinikon', 2016, 59437.0)
# (98, 'Schleinikon', 2017, 62079.0)
# (98, 'Schleinikon', 2018, 55001.0)
# (98, 'Schleinikon', 2019, 62691.0)
# (98, 'Schleinikon', 2020, 65208.0)
# (98, 'Schleinikon', 2021, 63584.0)
# (98, 'Schleinikon', 2022, 64244.0)
# (99, 'Schöfflisdorf', 2009, 61884.0)
# (99, 'Schöfflisdorf', 2010, 62779.0)
# (99, 'Schöfflisdorf', 2011, 64499.0)
# (99, 'Schöfflisdorf', 2012, 63708.0)
# (99, 'Schöfflisdorf', 2013, 62519.0)
# (99, 'Schöfflisdorf', 2014, 67510.0)
# (99, 'Schöfflisdorf', 2015, 65917.0)
# (99, 'Schöfflisdorf', 2016, 69095.0)
# (99, 'Schöfflisdorf', 2017, 73499.0)
# (99, 'Schöfflisdorf', 2018, 72403.0)
# (99, 'Schöfflisdorf', 2019, 74289.0)
# (99, 'Schöfflisdorf', 2020, 73793.0)
# (99, 'Schöfflisdorf', 2021, 72363.0)
# (99, 'Schöfflisdorf', 2022, 73158.0)
# (100, 'Stadel', 2009, 57345.0)
# (100, 'Stadel', 2010, 60997.0)
# (100, 'Stadel', 2011, 61266.0)
# (100, 'Stadel', 2012, 61537.0)
# (100, 'Stadel', 2013, 61991.0)
# (100, 'Stadel', 2014, 61854.0)
# (100, 'Stadel', 2015, 62553.0)
# (100, 'Stadel', 2016, 63108.0)
# (100, 'Stadel', 2017, 62446.0)
# (100, 'Stadel', 2018, 64281.0)
# (100, 'Stadel', 2019, 63160.0)
# (100, 'Stadel', 2020, 65621.0)
# (100, 'Stadel', 2021, 63790.0)
# (100, 'Stadel', 2022, 64205.0)
# (101, 'Steinmaur', 2009, 61928.0)
# (101, 'Steinmaur', 2010, 62215.0)
# (101, 'Steinmaur', 2011, 64566.0)
# (101, 'Steinmaur', 2012, 65638.0)
# (101, 'Steinmaur', 2013, 64675.0)
# (101, 'Steinmaur', 2014, 65051.0)
# (101, 'Steinmaur', 2015, 65908.0)
# (101, 'Steinmaur', 2016, 66083.0)
# (101, 'Steinmaur', 2017, 66658.0)
# (101, 'Steinmaur', 2018, 65964.0)
# (101, 'Steinmaur', 2019, 67758.0)
# (101, 'Steinmaur', 2020, 67720.0)
# (101, 'Steinmaur', 2021, 68504.0)
# (101, 'Steinmaur', 2022, 66035.0)
# (102, 'Weiach', 2009, 56883.0)
# (102, 'Weiach', 2010, 57049.0)
# (102, 'Weiach', 2011, 56627.0)
# (102, 'Weiach', 2012, 58530.0)
# (102, 'Weiach', 2013, 55803.0)
# (102, 'Weiach', 2014, 56733.0)
# (102, 'Weiach', 2015, 54561.0)
# (102, 'Weiach', 2016, 57488.0)
# (102, 'Weiach', 2017, 87094.0)
# (102, 'Weiach', 2018, 55965.0)
# (102, 'Weiach', 2019, 56580.0)
# (102, 'Weiach', 2020, 60088.0)
# (102, 'Weiach', 2021, 59174.0)
# (102, 'Weiach', 2022, 58069.0)
# (111, 'Bäretswil', 2009, 52704.0)
# (111, 'Bäretswil', 2010, 53640.0)
# (111, 'Bäretswil', 2011, 54876.0)
# (111, 'Bäretswil', 2012, 56778.0)
# (111, 'Bäretswil', 2013, 57263.0)
# (111, 'Bäretswil', 2014, 58094.0)
# (111, 'Bäretswil', 2015, 57412.0)
# (111, 'Bäretswil', 2016, 58901.0)
# (111, 'Bäretswil', 2017, 59732.0)
# (111, 'Bäretswil', 2018, 59702.0)
# (111, 'Bäretswil', 2019, 61546.0)
# (111, 'Bäretswil', 2020, 60612.0)
# (111, 'Bäretswil', 2021, 60771.0)
# (111, 'Bäretswil', 2022, 60966.0)
# (112, 'Bubikon', 2009, 60186.0)
# (112, 'Bubikon', 2010, 61116.0)
# (112, 'Bubikon', 2011, 62506.0)
# (112, 'Bubikon', 2012, 64539.0)
# (112, 'Bubikon', 2013, 65915.0)
# (112, 'Bubikon', 2014, 63666.0)
# (112, 'Bubikon', 2015, 64272.0)
# (112, 'Bubikon', 2016, 64467.0)
# (112, 'Bubikon', 2017, 67909.0)
# (112, 'Bubikon', 2018, 67537.0)
# (112, 'Bubikon', 2019, 67020.0)
# (112, 'Bubikon', 2020, 68962.0)
# (112, 'Bubikon', 2021, 68405.0)
# (112, 'Bubikon', 2022, 67746.0)
# (113, 'Dürnten', 2009, 51366.0)
# (113, 'Dürnten', 2010, 52736.0)
# (113, 'Dürnten', 2011, 55575.0)
# (113, 'Dürnten', 2012, 56837.0)
# (113, 'Dürnten', 2013, 58367.0)
# (113, 'Dürnten', 2014, 56652.0)
# (113, 'Dürnten', 2015, 57467.0)
# (113, 'Dürnten', 2016, 57912.0)
# (113, 'Dürnten', 2017, 57832.0)
# (113, 'Dürnten', 2018, 57735.0)
# (113, 'Dürnten', 2019, 59586.0)
# (113, 'Dürnten', 2020, 59899.0)
# (113, 'Dürnten', 2021, 61497.0)
# (113, 'Dürnten', 2022, 60311.0)
# (114, 'Fischenthal', 2009, 45819.0)
# (114, 'Fischenthal', 2010, 47229.0)
# (114, 'Fischenthal', 2011, 48413.0)
# (114, 'Fischenthal', 2012, 49806.0)
# (114, 'Fischenthal', 2013, 49452.0)
# (114, 'Fischenthal', 2014, 49787.0)
# (114, 'Fischenthal', 2015, 48418.0)
# (114, 'Fischenthal', 2016, 47838.0)
# (114, 'Fischenthal', 2017, 52699.0)
# (114, 'Fischenthal', 2018, 53633.0)
# (114, 'Fischenthal', 2019, 52873.0)
# (114, 'Fischenthal', 2020, 54319.0)
# (114, 'Fischenthal', 2021, 54081.0)
# (114, 'Fischenthal', 2022, 54715.0)
# (115, 'Gossau', 2009, 61897.0)
# (115, 'Gossau', 2010, 61341.0)
# (115, 'Gossau', 2011, 63760.0)
# (115, 'Gossau', 2012, 62802.0)
# (115, 'Gossau', 2013, 64047.0)
# (115, 'Gossau', 2014, 65178.0)
# (115, 'Gossau', 2015, 64854.0)
# (115, 'Gossau', 2016, 64193.0)
# (115, 'Gossau', 2017, 66261.0)
# (115, 'Gossau', 2018, 66110.0)
# (115, 'Gossau', 2019, 67891.0)
# (115, 'Gossau', 2020, 67838.0)
# (115, 'Gossau', 2021, 67940.0)
# (115, 'Gossau', 2022, 67515.0)
# (116, 'Grüningen', 2009, 57760.0)
# (116, 'Grüningen', 2010, 60884.0)
# (116, 'Grüningen', 2011, 62951.0)
# (116, 'Grüningen', 2012, 65835.0)
# (116, 'Grüningen', 2013, 66197.0)
# (116, 'Grüningen', 2014, 63836.0)
# (116, 'Grüningen', 2015, 65816.0)
# (116, 'Grüningen', 2016, 65493.0)
# (116, 'Grüningen', 2017, 66581.0)
# (116, 'Grüningen', 2018, 68652.0)
# (116, 'Grüningen', 2019, 69200.0)
# (116, 'Grüningen', 2020, 73172.0)
# (116, 'Grüningen', 2021, 69464.0)
# (116, 'Grüningen', 2022, 64781.0)
# (117, 'Hinwil', 2009, 55919.0)
# (117, 'Hinwil', 2010, 57406.0)
# (117, 'Hinwil', 2011, 58990.0)
# (117, 'Hinwil', 2012, 58871.0)
# (117, 'Hinwil', 2013, 58393.0)
# (117, 'Hinwil', 2014, 58005.0)
# (117, 'Hinwil', 2015, 58996.0)
# (117, 'Hinwil', 2016, 59285.0)
# (117, 'Hinwil', 2017, 59459.0)
# (117, 'Hinwil', 2018, 60111.0)
# (117, 'Hinwil', 2019, 60353.0)
# (117, 'Hinwil', 2020, 61144.0)
# (117, 'Hinwil', 2021, 61489.0)
# (117, 'Hinwil', 2022, 60378.0)
# (118, 'Rüti', 2009, 48201.0)
# (118, 'Rüti', 2010, 48394.0)
# (118, 'Rüti', 2011, 50978.0)
# (118, 'Rüti', 2012, 52035.0)
# (118, 'Rüti', 2013, 52421.0)
# (118, 'Rüti', 2014, 52975.0)
# (118, 'Rüti', 2015, 54050.0)
# (118, 'Rüti', 2016, 54936.0)
# (118, 'Rüti', 2017, 55665.0)
# (118, 'Rüti', 2018, 56351.0)
# (118, 'Rüti', 2019, 55594.0)
# (118, 'Rüti', 2020, 56347.0)
# (118, 'Rüti', 2021, 56111.0)
# (118, 'Rüti', 2022, 55004.0)
# (119, 'Seegräben', 2009, 62761.0)
# (119, 'Seegräben', 2010, 63435.0)
# (119, 'Seegräben', 2011, 66318.0)
# (119, 'Seegräben', 2012, 65920.0)
# (119, 'Seegräben', 2013, 65976.0)
# (119, 'Seegräben', 2014, 66011.0)
# (119, 'Seegräben', 2015, 65426.0)
# (119, 'Seegräben', 2016, 65640.0)
# (119, 'Seegräben', 2017, 64819.0)
# (119, 'Seegräben', 2018, 67902.0)
# (119, 'Seegräben', 2019, 67150.0)
# (119, 'Seegräben', 2020, 70494.0)
# (119, 'Seegräben', 2021, 69148.0)
# (119, 'Seegräben', 2022, 68943.0)
# (120, 'Wald', 2009, 46908.0)
# (120, 'Wald', 2010, 49379.0)
# (120, 'Wald', 2011, 49242.0)
# (120, 'Wald', 2012, 49821.0)
# (120, 'Wald', 2013, 49941.0)
# (120, 'Wald', 2014, 50842.0)
# (120, 'Wald', 2015, 51497.0)
# (120, 'Wald', 2016, 52522.0)
# (120, 'Wald', 2017, 52813.0)
# (120, 'Wald', 2018, 53699.0)
# (120, 'Wald', 2019, 54038.0)
# (120, 'Wald', 2020, 54813.0)
# (120, 'Wald', 2021, 54992.0)
# (120, 'Wald', 2022, 52594.0)
# (121, 'Wetzikon', 2009, 51304.0)
# (121, 'Wetzikon', 2010, 51993.0)
# (121, 'Wetzikon', 2011, 52120.0)
# (121, 'Wetzikon', 2012, 52967.0)
# (121, 'Wetzikon', 2013, 54637.0)
# (121, 'Wetzikon', 2014, 53345.0)
# (121, 'Wetzikon', 2015, 55018.0)
# (121, 'Wetzikon', 2016, 55152.0)
# (121, 'Wetzikon', 2017, 56303.0)
# (121, 'Wetzikon', 2018, 56718.0)
# (121, 'Wetzikon', 2019, 55830.0)
# (121, 'Wetzikon', 2020, 57023.0)
# (121, 'Wetzikon', 2021, 56496.0)
# (121, 'Wetzikon', 2022, 55688.0)
# (131, 'Adliswil', 2009, 61420.0)
# (131, 'Adliswil', 2010, 61456.0)
# (131, 'Adliswil', 2011, 63839.0)
# (131, 'Adliswil', 2012, 62315.0)
# (131, 'Adliswil', 2013, 62808.0)
# (131, 'Adliswil', 2014, 62717.0)
# (131, 'Adliswil', 2015, 62323.0)
# (131, 'Adliswil', 2016, 62860.0)
# (131, 'Adliswil', 2017, 62794.0)
# (131, 'Adliswil', 2018, 81263.0)
# (131, 'Adliswil', 2019, 67302.0)
# (131, 'Adliswil', 2020, 67779.0)
# (131, 'Adliswil', 2021, 66515.0)
# (131, 'Adliswil', 2022, 67236.0)
# (135, 'Kilchberg', 2009, 112950.0)
# (135, 'Kilchberg', 2010, 116868.0)
# (135, 'Kilchberg', 2011, 115697.0)
# (135, 'Kilchberg', 2012, 117774.0)
# (135, 'Kilchberg', 2013, 133112.0)
# (135, 'Kilchberg', 2014, 119591.0)
# (135, 'Kilchberg', 2015, 119780.0)
# (135, 'Kilchberg', 2016, 126632.0)
# (135, 'Kilchberg', 2017, 196849.0)
# (135, 'Kilchberg', 2018, 132048.0)
# (135, 'Kilchberg', 2019, 136705.0)
# (135, 'Kilchberg', 2020, 141216.0)
# (135, 'Kilchberg', 2021, 139804.0)
# (135, 'Kilchberg', 2022, 137305.0)
# (136, 'Langnau', 2009, 67101.0)
# (136, 'Langnau', 2010, 71703.0)
# (136, 'Langnau', 2011, 70189.0)
# (136, 'Langnau', 2012, 71235.0)
# (136, 'Langnau', 2013, 75233.0)
# (136, 'Langnau', 2014, 72316.0)
# (136, 'Langnau', 2015, 69885.0)
# (136, 'Langnau', 2016, 71527.0)
# (136, 'Langnau', 2017, 73248.0)
# (136, 'Langnau', 2018, 73520.0)
# (136, 'Langnau', 2019, 74379.0)
# (136, 'Langnau', 2020, 76080.0)
# (136, 'Langnau', 2021, 77631.0)
# (136, 'Langnau', 2022, 76899.0)
# (137, 'Oberrieden', 2009, 89853.0)
# (137, 'Oberrieden', 2010, 96940.0)
# (137, 'Oberrieden', 2011, 102493.0)
# (137, 'Oberrieden', 2012, 101174.0)
# (137, 'Oberrieden', 2013, 99401.0)
# (137, 'Oberrieden', 2014, 101230.0)
# (137, 'Oberrieden', 2015, 91447.0)
# (137, 'Oberrieden', 2016, 90502.0)
# (137, 'Oberrieden', 2017, 90913.0)
# (137, 'Oberrieden', 2018, 92758.0)
# (137, 'Oberrieden', 2019, 96018.0)
# (137, 'Oberrieden', 2020, 97213.0)
# (137, 'Oberrieden', 2021, 95956.0)
# (137, 'Oberrieden', 2022, 96091.0)
# (138, 'Richterswil', 2009, 66195.0)
# (138, 'Richterswil', 2010, 67301.0)
# (138, 'Richterswil', 2011, 66935.0)
# (138, 'Richterswil', 2012, 67218.0)
# (138, 'Richterswil', 2013, 67979.0)
# (138, 'Richterswil', 2014, 67871.0)
# (138, 'Richterswil', 2015, 68143.0)
# (138, 'Richterswil', 2016, 67839.0)
# (138, 'Richterswil', 2017, 69939.0)
# (138, 'Richterswil', 2018, 70899.0)
# (138, 'Richterswil', 2019, 71486.0)
# (138, 'Richterswil', 2020, 73780.0)
# (138, 'Richterswil', 2021, 74839.0)
# (138, 'Richterswil', 2022, 73195.0)
# (139, 'Rüschlikon', 2009, 119513.0)
# (139, 'Rüschlikon', 2010, 125363.0)
# (139, 'Rüschlikon', 2011, 581506.0)
# (139, 'Rüschlikon', 2012, 124575.0)
# (139, 'Rüschlikon', 2013, 113504.0)
# (139, 'Rüschlikon', 2014, 117982.0)
# (139, 'Rüschlikon', 2015, 125281.0)
# (139, 'Rüschlikon', 2016, 127737.0)
# (139, 'Rüschlikon', 2017, 120390.0)
# (139, 'Rüschlikon', 2018, 121417.0)
# (139, 'Rüschlikon', 2019, 130385.0)
# (139, 'Rüschlikon', 2020, 129787.0)
# (139, 'Rüschlikon', 2021, 132525.0)
# (139, 'Rüschlikon', 2022, 138709.0)
# (141, 'Thalwil', 2009, 78191.0)
# (141, 'Thalwil', 2010, 80786.0)
# (141, 'Thalwil', 2011, 85271.0)
# (141, 'Thalwil', 2012, 84439.0)
# (141, 'Thalwil', 2013, 84252.0)
# (141, 'Thalwil', 2014, 83297.0)
# (141, 'Thalwil', 2015, 84997.0)
# (141, 'Thalwil', 2016, 85469.0)
# (141, 'Thalwil', 2017, 81110.0)
# (141, 'Thalwil', 2018, 83107.0)
# (141, 'Thalwil', 2019, 85423.0)
# (141, 'Thalwil', 2020, 86133.0)
# (141, 'Thalwil', 2021, 88701.0)
# (141, 'Thalwil', 2022, 90870.0)
# (151, 'Erlenbach', 2009, 123450.0)
# (151, 'Erlenbach', 2010, 125901.0)
# (151, 'Erlenbach', 2011, 128112.0)
# (151, 'Erlenbach', 2012, 135728.0)
# (151, 'Erlenbach', 2013, 149004.0)
# (151, 'Erlenbach', 2014, 149252.0)
# (151, 'Erlenbach', 2015, 141843.0)
# (151, 'Erlenbach', 2016, 131585.0)
# (151, 'Erlenbach', 2017, 142111.0)
# (151, 'Erlenbach', 2018, 142688.0)
# (151, 'Erlenbach', 2019, 144379.0)
# (151, 'Erlenbach', 2020, 144122.0)
# (151, 'Erlenbach', 2021, 147215.0)
# (151, 'Erlenbach', 2022, 147446.0)
# (152, 'Herrliberg', 2009, 144899.0)
# (152, 'Herrliberg', 2010, 137122.0)
# (152, 'Herrliberg', 2011, 141658.0)
# (152, 'Herrliberg', 2012, 143414.0)
# (152, 'Herrliberg', 2013, 143098.0)
# (152, 'Herrliberg', 2014, 137917.0)
# (152, 'Herrliberg', 2015, 139174.0)
# (152, 'Herrliberg', 2016, 143909.0)
# (152, 'Herrliberg', 2017, 142744.0)
# (152, 'Herrliberg', 2018, 142851.0)
# (152, 'Herrliberg', 2019, 151544.0)
# (152, 'Herrliberg', 2020, 152713.0)
# (152, 'Herrliberg', 2021, 151533.0)
# (152, 'Herrliberg', 2022, 147821.0)
# (153, 'Hombrechtikon', 2009, 61794.0)
# (153, 'Hombrechtikon', 2010, 61624.0)
# (153, 'Hombrechtikon', 2011, 63223.0)
# (153, 'Hombrechtikon', 2012, 63048.0)
# (153, 'Hombrechtikon', 2013, 65326.0)
# (153, 'Hombrechtikon', 2014, 64000.0)
# (153, 'Hombrechtikon', 2015, 64895.0)
# (153, 'Hombrechtikon', 2016, 64185.0)
# (153, 'Hombrechtikon', 2017, 65217.0)
# (153, 'Hombrechtikon', 2018, 63019.0)
# (153, 'Hombrechtikon', 2019, 63080.0)
# (153, 'Hombrechtikon', 2020, 64452.0)
# (153, 'Hombrechtikon', 2021, 64590.0)
# (153, 'Hombrechtikon', 2022, 62717.0)
# (154, 'Küsnacht', 2009, 122507.0)
# (154, 'Küsnacht', 2010, 131339.0)
# (154, 'Küsnacht', 2011, 135257.0)
# (154, 'Küsnacht', 2012, 136851.0)
# (154, 'Küsnacht', 2013, 134923.0)
# (154, 'Küsnacht', 2014, 134738.0)
# (154, 'Küsnacht', 2015, 133115.0)
# (154, 'Küsnacht', 2016, 134164.0)
# (154, 'Küsnacht', 2017, 133219.0)
# (154, 'Küsnacht', 2018, 140636.0)
# (154, 'Küsnacht', 2019, 151792.0)
# (154, 'Küsnacht', 2020, 142114.0)
# (154, 'Küsnacht', 2021, 150233.0)
# (154, 'Küsnacht', 2022, 146168.0)
# (155, 'Männedorf', 2009, 76243.0)
# (155, 'Männedorf', 2010, 78464.0)
# (155, 'Männedorf', 2011, 81706.0)
# (155, 'Männedorf', 2012, 82185.0)
# (155, 'Männedorf', 2013, 82397.0)
# (155, 'Männedorf', 2014, 81877.0)
# (155, 'Männedorf', 2015, 82829.0)
# (155, 'Männedorf', 2016, 83363.0)
# (155, 'Männedorf', 2017, 83145.0)
# (155, 'Männedorf', 2018, 83209.0)
# (155, 'Männedorf', 2019, 85898.0)
# (155, 'Männedorf', 2020, 86676.0)
# (155, 'Männedorf', 2021, 88166.0)
# (155, 'Männedorf', 2022, 86970.0)
# (156, 'Meilen', 2009, 92403.0)
# (156, 'Meilen', 2010, 98357.0)
# (156, 'Meilen', 2011, 98396.0)
# (156, 'Meilen', 2012, 103015.0)
# (156, 'Meilen', 2013, 104573.0)
# (156, 'Meilen', 2014, 106423.0)
# (156, 'Meilen', 2015, 108912.0)
# (156, 'Meilen', 2016, 108402.0)
# (156, 'Meilen', 2017, 106784.0)
# (156, 'Meilen', 2018, 111083.0)
# (156, 'Meilen', 2019, 114667.0)
# (156, 'Meilen', 2020, 113141.0)
# (156, 'Meilen', 2021, 112864.0)
# (156, 'Meilen', 2022, 112225.0)
# (157, 'Oetwil', 2009, 52770.0)
# (157, 'Oetwil', 2010, 53227.0)
# (157, 'Oetwil', 2011, 53741.0)
# (157, 'Oetwil', 2012, 54447.0)
# (157, 'Oetwil', 2013, 55513.0)
# (157, 'Oetwil', 2014, 54864.0)
# (157, 'Oetwil', 2015, 53843.0)
# (157, 'Oetwil', 2016, 56095.0)
# (157, 'Oetwil', 2017, 56682.0)
# (157, 'Oetwil', 2018, 56452.0)
# (157, 'Oetwil', 2019, 59066.0)
# (157, 'Oetwil', 2020, 58703.0)
# (157, 'Oetwil', 2021, 56967.0)
# (157, 'Oetwil', 2022, 56686.0)
# (158, 'Stäfa', 2009, 75651.0)
# (158, 'Stäfa', 2010, 78206.0)
# (158, 'Stäfa', 2011, 76347.0)
# (158, 'Stäfa', 2012, 77134.0)
# (158, 'Stäfa', 2013, 80459.0)
# (158, 'Stäfa', 2014, 81012.0)
# (158, 'Stäfa', 2015, 80397.0)
# (158, 'Stäfa', 2016, 78402.0)
# (158, 'Stäfa', 2017, 75368.0)
# (158, 'Stäfa', 2018, 78197.0)
# (158, 'Stäfa', 2019, 83909.0)
# (158, 'Stäfa', 2020, 85895.0)
# (158, 'Stäfa', 2021, 87588.0)
# (158, 'Stäfa', 2022, 85113.0)
# (159, 'Uetikon', 2009, 86939.0)
# (159, 'Uetikon', 2010, 91188.0)
# (159, 'Uetikon', 2011, 91706.0)
# (159, 'Uetikon', 2012, 94570.0)
# (159, 'Uetikon', 2013, 93778.0)
# (159, 'Uetikon', 2014, 95634.0)
# (159, 'Uetikon', 2015, 98169.0)
# (159, 'Uetikon', 2016, 95677.0)
# (159, 'Uetikon', 2017, 92462.0)
# (159, 'Uetikon', 2018, 95948.0)
# (159, 'Uetikon', 2019, 96802.0)
# (159, 'Uetikon', 2020, 99257.0)
# (159, 'Uetikon', 2021, 96888.0)
# (159, 'Uetikon', 2022, 96231.0)
# (160, 'Zumikon', 2009, 148881.0)
# (160, 'Zumikon', 2010, 155333.0)
# (160, 'Zumikon', 2011, 158611.0)
# (160, 'Zumikon', 2012, 160249.0)
# (160, 'Zumikon', 2013, 150513.0)
# (160, 'Zumikon', 2014, 151479.0)
# (160, 'Zumikon', 2015, 145948.0)
# (160, 'Zumikon', 2016, 148601.0)
# (160, 'Zumikon', 2017, 149626.0)
# (160, 'Zumikon', 2018, 146258.0)
# (160, 'Zumikon', 2019, 145226.0)
# (160, 'Zumikon', 2020, 138164.0)
# (160, 'Zumikon', 2021, 137359.0)
# (160, 'Zumikon', 2022, 134636.0)
# (161, 'Zollikon', 2009, 119104.0)
# (161, 'Zollikon', 2010, 127722.0)
# (161, 'Zollikon', 2011, 128484.0)
# (161, 'Zollikon', 2012, 129938.0)
# (161, 'Zollikon', 2013, 132474.0)
# (161, 'Zollikon', 2014, 135359.0)
# (161, 'Zollikon', 2015, 131554.0)
# (161, 'Zollikon', 2016, 133538.0)
# (161, 'Zollikon', 2017, 130546.0)
# (161, 'Zollikon', 2018, 129416.0)
# ...
# (215, 'Dättlikon', 2016, 75908.0)
# (215, 'Dättlikon', 2017, 79593.0)
# (215, 'Dättlikon', 2018, 85522.0)
# (215, 'Dättlikon', 2019, 85163.0)
# (215, 'Dättlikon', 2020, 82274.0)
# (215, 'Dättlikon', 2021, 81266.0)
# (215, 'Dättlikon', 2022, 80925.0)
# (216, 'Dinhard', 2009, 63059.0)
# (216, 'Dinhard', 2010, 63636.0)
# (216, 'Dinhard', 2011, 68737.0)
# (216, 'Dinhard', 2012, 70164.0)
# (216, 'Dinhard', 2013, 69784.0)
# (216, 'Dinhard', 2014, 69709.0)
# (216, 'Dinhard', 2015, 67813.0)
# (216, 'Dinhard', 2016, 70739.0)
# (216, 'Dinhard', 2017, 70615.0)
# (216, 'Dinhard', 2018, 70344.0)
# (216, 'Dinhard', 2019, 71262.0)
# (216, 'Dinhard', 2020, 74806.0)
# (216, 'Dinhard', 2021, 72955.0)
# (216, 'Dinhard', 2022, 72058.0)
# (218, 'Ellikon', 2009, 61963.0)
# (218, 'Ellikon', 2010, 67661.0)
# (218, 'Ellikon', 2011, 63262.0)
# (218, 'Ellikon', 2012, 63784.0)
# (218, 'Ellikon', 2013, 66932.0)
# (218, 'Ellikon', 2014, 67721.0)
# (218, 'Ellikon', 2015, 67897.0)
# (218, 'Ellikon', 2016, 67409.0)
# (218, 'Ellikon', 2017, 69538.0)
# (218, 'Ellikon', 2018, 66751.0)
# (218, 'Ellikon', 2019, 66234.0)
# (218, 'Ellikon', 2020, 69748.0)
# (218, 'Ellikon', 2021, 65323.0)
# (218, 'Ellikon', 2022, 67079.0)
# (219, 'Elsau', 2009, 54397.0)
# (219, 'Elsau', 2010, 57945.0)
# (219, 'Elsau', 2011, 59470.0)
# (219, 'Elsau', 2012, 59126.0)
# (219, 'Elsau', 2013, 60573.0)
# (219, 'Elsau', 2014, 60706.0)
# (219, 'Elsau', 2015, 60515.0)
# (219, 'Elsau', 2016, 62393.0)
# (219, 'Elsau', 2017, 63143.0)
# (219, 'Elsau', 2018, 61935.0)
# (219, 'Elsau', 2019, 63731.0)
# (219, 'Elsau', 2020, 61550.0)
# (219, 'Elsau', 2021, 63031.0)
# (219, 'Elsau', 2022, 62758.0)
# (220, 'Hagenbuch', 2009, 49680.0)
# (220, 'Hagenbuch', 2010, 46165.0)
# (220, 'Hagenbuch', 2011, 48731.0)
# (220, 'Hagenbuch', 2012, 51289.0)
# (220, 'Hagenbuch', 2013, 54897.0)
# (220, 'Hagenbuch', 2014, 54349.0)
# (220, 'Hagenbuch', 2015, 58552.0)
# (220, 'Hagenbuch', 2016, 55299.0)
# (220, 'Hagenbuch', 2017, 58225.0)
# (220, 'Hagenbuch', 2018, 59988.0)
# (220, 'Hagenbuch', 2019, 62081.0)
# (220, 'Hagenbuch', 2020, 61404.0)
# (220, 'Hagenbuch', 2021, 60457.0)
# (220, 'Hagenbuch', 2022, 60314.0)
# (221, 'Hettlingen', 2009, 74908.0)
# (221, 'Hettlingen', 2010, 76029.0)
# (221, 'Hettlingen', 2011, 76490.0)
# (221, 'Hettlingen', 2012, 77467.0)
# (221, 'Hettlingen', 2013, 75764.0)
# (221, 'Hettlingen', 2014, 75250.0)
# (221, 'Hettlingen', 2015, 80097.0)
# (221, 'Hettlingen', 2016, 79345.0)
# (221, 'Hettlingen', 2017, 81404.0)
# (221, 'Hettlingen', 2018, 80998.0)
# (221, 'Hettlingen', 2019, 82785.0)
# (221, 'Hettlingen', 2020, 81554.0)
# (221, 'Hettlingen', 2021, 81495.0)
# (221, 'Hettlingen', 2022, 80074.0)
# (223, 'Neftenbach', 2009, 63574.0)
# (223, 'Neftenbach', 2010, 65339.0)
# (223, 'Neftenbach', 2011, 67585.0)
# (223, 'Neftenbach', 2012, 69114.0)
# (223, 'Neftenbach', 2013, 69335.0)
# (223, 'Neftenbach', 2014, 69635.0)
# (223, 'Neftenbach', 2015, 72072.0)
# (223, 'Neftenbach', 2016, 70181.0)
# (223, 'Neftenbach', 2017, 73584.0)
# (223, 'Neftenbach', 2018, 74222.0)
# (223, 'Neftenbach', 2019, 76012.0)
# (223, 'Neftenbach', 2020, 72864.0)
# (223, 'Neftenbach', 2021, 73877.0)
# (223, 'Neftenbach', 2022, 74646.0)
# (224, 'Pfungen', 2009, 50271.0)
# (224, 'Pfungen', 2010, 50757.0)
# (224, 'Pfungen', 2011, 50836.0)
# (224, 'Pfungen', 2012, 51291.0)
# (224, 'Pfungen', 2013, 52410.0)
# (224, 'Pfungen', 2014, 52491.0)
# (224, 'Pfungen', 2015, 52783.0)
# (224, 'Pfungen', 2016, 53561.0)
# (224, 'Pfungen', 2017, 55302.0)
# (224, 'Pfungen', 2018, 55880.0)
# (224, 'Pfungen', 2019, 55716.0)
# (224, 'Pfungen', 2020, 55605.0)
# (224, 'Pfungen', 2021, 56649.0)
# (224, 'Pfungen', 2022, 57264.0)
# (225, 'Rickenbach', 2009, 60924.0)
# (225, 'Rickenbach', 2010, 60400.0)
# (225, 'Rickenbach', 2011, 60310.0)
# (225, 'Rickenbach', 2012, 61781.0)
# (225, 'Rickenbach', 2013, 62787.0)
# (225, 'Rickenbach', 2014, 61232.0)
# (225, 'Rickenbach', 2015, 59625.0)
# (225, 'Rickenbach', 2016, 58343.0)
# (225, 'Rickenbach', 2017, 54237.0)
# (225, 'Rickenbach', 2018, 61156.0)
# (225, 'Rickenbach', 2019, 59802.0)
# (225, 'Rickenbach', 2020, 60206.0)
# (225, 'Rickenbach', 2021, 63148.0)
# (225, 'Rickenbach', 2022, 62386.0)
# (226, 'Schlatt', 2009, 52264.0)
# (226, 'Schlatt', 2010, 52196.0)
# (226, 'Schlatt', 2011, 52993.0)
# (226, 'Schlatt', 2012, 57220.0)
# (226, 'Schlatt', 2013, 56739.0)
# (226, 'Schlatt', 2014, 58788.0)
# (226, 'Schlatt', 2015, 56983.0)
# (226, 'Schlatt', 2016, 57951.0)
# (226, 'Schlatt', 2017, 54863.0)
# (226, 'Schlatt', 2018, 59307.0)
# (226, 'Schlatt', 2019, 58219.0)
# (226, 'Schlatt', 2020, 60127.0)
# (226, 'Schlatt', 2021, 60384.0)
# (226, 'Schlatt', 2022, 59038.0)
# (227, 'Seuzach', 2009, 65295.0)
# (227, 'Seuzach', 2010, 66773.0)
# (227, 'Seuzach', 2011, 68858.0)
# (227, 'Seuzach', 2012, 70347.0)
# (227, 'Seuzach', 2013, 71549.0)
# (227, 'Seuzach', 2014, 73523.0)
# (227, 'Seuzach', 2015, 73670.0)
# (227, 'Seuzach', 2016, 74183.0)
# (227, 'Seuzach', 2017, 76073.0)
# (227, 'Seuzach', 2018, 75801.0)
# (227, 'Seuzach', 2019, 75019.0)
# (227, 'Seuzach', 2020, 77736.0)
# (227, 'Seuzach', 2021, 76322.0)
# (227, 'Seuzach', 2022, 74855.0)
# (228, 'Turbenthal', 2009, 49450.0)
# (228, 'Turbenthal', 2010, 48737.0)
# (228, 'Turbenthal', 2011, 48313.0)
# (228, 'Turbenthal', 2012, 49356.0)
# (228, 'Turbenthal', 2013, 50966.0)
# (228, 'Turbenthal', 2014, 50367.0)
# (228, 'Turbenthal', 2015, 51579.0)
# (228, 'Turbenthal', 2016, 52424.0)
# (228, 'Turbenthal', 2017, 51086.0)
# (228, 'Turbenthal', 2018, 52516.0)
# (228, 'Turbenthal', 2019, 52356.0)
# (228, 'Turbenthal', 2020, 53990.0)
# (228, 'Turbenthal', 2021, 54022.0)
# (228, 'Turbenthal', 2022, 53572.0)
# (230, 'Winterthur', 2009, 51654.0)
# (230, 'Winterthur', 2010, 52999.0)
# (230, 'Winterthur', 2011, 53236.0)
# (230, 'Winterthur', 2012, 54190.0)
# (230, 'Winterthur', 2013, 54541.0)
# (230, 'Winterthur', 2014, 54786.0)
# (230, 'Winterthur', 2015, 54791.0)
# (230, 'Winterthur', 2016, 54674.0)
# (230, 'Winterthur', 2017, 55361.0)
# (230, 'Winterthur', 2018, 55308.0)
# (230, 'Winterthur', 2019, 55969.0)
# (230, 'Winterthur', 2020, 56666.0)
# (230, 'Winterthur', 2021, 55973.0)
# (230, 'Winterthur', 2022, 55950.0)
# (231, 'Zell', 2009, 46721.0)
# (231, 'Zell', 2010, 48657.0)
# (231, 'Zell', 2011, 50370.0)
# (231, 'Zell', 2012, 51302.0)
# (231, 'Zell', 2013, 52278.0)
# (231, 'Zell', 2014, 52828.0)
# (231, 'Zell', 2015, 52359.0)
# (231, 'Zell', 2016, 52470.0)
# (231, 'Zell', 2017, 53854.0)
# (231, 'Zell', 2018, 54810.0)
# (231, 'Zell', 2019, 55764.0)
# (231, 'Zell', 2020, 55520.0)
# (231, 'Zell', 2021, 54493.0)
# (231, 'Zell', 2022, 53910.0)
# (241, 'Aesch', 2009, 84695.0)
# (241, 'Aesch', 2010, 88193.0)
# (241, 'Aesch', 2011, 88760.0)
# (241, 'Aesch', 2012, 87693.0)
# (241, 'Aesch', 2013, 97325.0)
# (241, 'Aesch', 2014, 96986.0)
# (241, 'Aesch', 2015, 99240.0)
# (241, 'Aesch', 2016, 99294.0)
# (241, 'Aesch', 2017, 90742.0)
# (241, 'Aesch', 2018, 92198.0)
# (241, 'Aesch', 2019, 95163.0)
# (241, 'Aesch', 2020, 90008.0)
# (241, 'Aesch', 2021, 88057.0)
# (241, 'Aesch', 2022, 91213.0)
# (242, 'Birmensdorf', 2009, 69544.0)
# (242, 'Birmensdorf', 2010, 71206.0)
# (242, 'Birmensdorf', 2011, 69682.0)
# (242, 'Birmensdorf', 2012, 70887.0)
# (242, 'Birmensdorf', 2013, 71464.0)
# (242, 'Birmensdorf', 2014, 72253.0)
# (242, 'Birmensdorf', 2015, 72785.0)
# (242, 'Birmensdorf', 2016, 71336.0)
# (242, 'Birmensdorf', 2017, 72263.0)
# (242, 'Birmensdorf', 2018, 69943.0)
# (242, 'Birmensdorf', 2019, 73849.0)
# (242, 'Birmensdorf', 2020, 74033.0)
# (242, 'Birmensdorf', 2021, 73146.0)
# (242, 'Birmensdorf', 2022, 70107.0)
# (243, 'Dietikon', 2009, 47706.0)
# (243, 'Dietikon', 2010, 48127.0)
# (243, 'Dietikon', 2011, 48986.0)
# (243, 'Dietikon', 2012, 49051.0)
# (243, 'Dietikon', 2013, 49484.0)
# (243, 'Dietikon', 2014, 50103.0)
# (243, 'Dietikon', 2015, 49603.0)
# (243, 'Dietikon', 2016, 50363.0)
# (243, 'Dietikon', 2017, 49535.0)
# (243, 'Dietikon', 2018, 49378.0)
# (243, 'Dietikon', 2019, 50382.0)
# (243, 'Dietikon', 2020, 51149.0)
# (243, 'Dietikon', 2021, 51384.0)
# (243, 'Dietikon', 2022, 50557.0)
# (244, 'Geroldswil', 2009, 66919.0)
# (244, 'Geroldswil', 2010, 66141.0)
# (244, 'Geroldswil', 2011, 66578.0)
# (244, 'Geroldswil', 2012, 68925.0)
# (244, 'Geroldswil', 2013, 68609.0)
# (244, 'Geroldswil', 2014, 69253.0)
# (244, 'Geroldswil', 2015, 70035.0)
# (244, 'Geroldswil', 2016, 73201.0)
# (244, 'Geroldswil', 2017, 72775.0)
# (244, 'Geroldswil', 2018, 73274.0)
# (244, 'Geroldswil', 2019, 72762.0)
# (244, 'Geroldswil', 2020, 72031.0)
# (244, 'Geroldswil', 2021, 69493.0)
# (244, 'Geroldswil', 2022, 69944.0)
# (245, 'Oberengstringen', 2009, 63544.0)
# (245, 'Oberengstringen', 2010, 63419.0)
# (245, 'Oberengstringen', 2011, 64059.0)
# (245, 'Oberengstringen', 2012, 62149.0)
# (245, 'Oberengstringen', 2013, 62622.0)
# (245, 'Oberengstringen', 2014, 62778.0)
# (245, 'Oberengstringen', 2015, 64099.0)
# (245, 'Oberengstringen', 2016, 66504.0)
# (245, 'Oberengstringen', 2017, 63972.0)
# (245, 'Oberengstringen', 2018, 64930.0)
# (245, 'Oberengstringen', 2019, 64531.0)
# (245, 'Oberengstringen', 2020, 63776.0)
# (245, 'Oberengstringen', 2021, 63624.0)
# (245, 'Oberengstringen', 2022, 62166.0)
# (246, 'Oetwil an der Limmat', 2009, 72749.0)
# (246, 'Oetwil an der Limmat', 2010, 76534.0)
# (246, 'Oetwil an der Limmat', 2011, 75943.0)
# (246, 'Oetwil an der Limmat', 2012, 78417.0)
# (246, 'Oetwil an der Limmat', 2013, 77054.0)
# (246, 'Oetwil an der Limmat', 2014, 75541.0)
# (246, 'Oetwil an der Limmat', 2015, 79578.0)
# (246, 'Oetwil an der Limmat', 2016, 79574.0)
# (246, 'Oetwil an der Limmat', 2017, 78011.0)
# (246, 'Oetwil an der Limmat', 2018, 78054.0)
# (246, 'Oetwil an der Limmat', 2019, 77409.0)
# (246, 'Oetwil an der Limmat', 2020, 78738.0)
# (246, 'Oetwil an der Limmat', 2021, 81933.0)
# (246, 'Oetwil an der Limmat', 2022, 80751.0)
# (247, 'Schlieren', 2009, 48334.0)
# (247, 'Schlieren', 2010, 48420.0)
# (247, 'Schlieren', 2011, 50371.0)
# (247, 'Schlieren', 2012, 51024.0)
# (247, 'Schlieren', 2013, 52353.0)
# (247, 'Schlieren', 2014, 51622.0)
# (247, 'Schlieren', 2015, 51933.0)
# (247, 'Schlieren', 2016, 52412.0)
# (247, 'Schlieren', 2017, 53310.0)
# (247, 'Schlieren', 2018, 53619.0)
# (247, 'Schlieren', 2019, 53812.0)
# (247, 'Schlieren', 2020, 53715.0)
# (247, 'Schlieren', 2021, 53376.0)
# (247, 'Schlieren', 2022, 53319.0)
# (248, 'Uitikon', 2009, 134579.0)
# (248, 'Uitikon', 2010, 155116.0)
# (248, 'Uitikon', 2011, 148081.0)
# (248, 'Uitikon', 2012, 147017.0)
# (248, 'Uitikon', 2013, 155870.0)
# (248, 'Uitikon', 2014, 145743.0)
# (248, 'Uitikon', 2015, 147785.0)
# (248, 'Uitikon', 2016, 141163.0)
# (248, 'Uitikon', 2017, 138818.0)
# (248, 'Uitikon', 2018, 136618.0)
# (248, 'Uitikon', 2019, 130722.0)
# (248, 'Uitikon', 2020, 127185.0)
# (248, 'Uitikon', 2021, 128739.0)
# (248, 'Uitikon', 2022, 131465.0)
# (249, 'Unterengstringen', 2009, 76472.0)
# (249, 'Unterengstringen', 2010, 73566.0)
# (249, 'Unterengstringen', 2011, 74588.0)
# (249, 'Unterengstringen', 2012, 74207.0)
# (249, 'Unterengstringen', 2013, 75853.0)
# (249, 'Unterengstringen', 2014, 71904.0)
# (249, 'Unterengstringen', 2015, 75567.0)
# (249, 'Unterengstringen', 2016, 74640.0)
# (249, 'Unterengstringen', 2017, 76160.0)
# (249, 'Unterengstringen', 2018, 78857.0)
# (249, 'Unterengstringen', 2019, 80651.0)
# (249, 'Unterengstringen', 2020, 76827.0)
# (249, 'Unterengstringen', 2021, 77984.0)
# (249, 'Unterengstringen', 2022, 75769.0)
# (250, 'Urdorf', 2009, 58512.0)
# (250, 'Urdorf', 2010, 61152.0)
# (250, 'Urdorf', 2011, 62356.0)
# (250, 'Urdorf', 2012, 63869.0)
# (250, 'Urdorf', 2013, 64763.0)
# (250, 'Urdorf', 2014, 64679.0)
# (250, 'Urdorf', 2015, 62145.0)
# (250, 'Urdorf', 2016, 63625.0)
# (250, 'Urdorf', 2017, 64086.0)
# (250, 'Urdorf', 2018, 64000.0)
# (250, 'Urdorf', 2019, 63332.0)
# (250, 'Urdorf', 2020, 63465.0)
# (250, 'Urdorf', 2021, 62646.0)
# (250, 'Urdorf', 2022, 61915.0)
# (251, 'Weiningen', 2009, 61843.0)
# (251, 'Weiningen', 2010, 67924.0)
# (251, 'Weiningen', 2011, 67268.0)
# (251, 'Weiningen', 2012, 72548.0)
# (251, 'Weiningen', 2013, 67468.0)
# (251, 'Weiningen', 2014, 66367.0)
# (251, 'Weiningen', 2015, 65680.0)
# (251, 'Weiningen', 2016, 67289.0)
# (251, 'Weiningen', 2017, 65861.0)
# (251, 'Weiningen', 2018, 69721.0)
# (251, 'Weiningen', 2019, 70709.0)
# (251, 'Weiningen', 2020, 69362.0)
# (251, 'Weiningen', 2021, 68652.0)
# (251, 'Weiningen', 2022, 67447.0)
# (261, 'Zürich', 2009, 58643.0)
# (261, 'Zürich', 2010, 60703.0)
# (261, 'Zürich', 2011, 61701.0)
# (261, 'Zürich', 2012, 61995.0)
# (261, 'Zürich', 2013, 63236.0)
# (261, 'Zürich', 2014, 63804.0)
# (261, 'Zürich', 2015, 64024.0)
# (261, 'Zürich', 2016, 63505.0)
# (261, 'Zürich', 2017, 62355.0)
# (261, 'Zürich', 2018, 63315.0)
# (261, 'Zürich', 2019, 63622.0)
# (261, 'Zürich', 2020, 64779.0)
# (261, 'Zürich', 2021, 64871.0)
# (261, 'Zürich', 2022, 64619.0)
# (291, 'Andelfingen', 2009, 60990.0)
# (291, 'Andelfingen', 2010, 67629.0)
# (291, 'Andelfingen', 2011, 62690.0)
# (291, 'Andelfingen', 2012, 63300.0)
# (291, 'Andelfingen', 2013, 63954.0)
# (291, 'Andelfingen', 2014, 63557.0)
# (291, 'Andelfingen', 2015, 63484.0)
# (291, 'Andelfingen', 2016, 62924.0)
# (291, 'Andelfingen', 2017, 70535.0)
# (291, 'Andelfingen', 2018, 71541.0)
# (291, 'Andelfingen', 2019, 67819.0)
# (291, 'Andelfingen', 2020, 68001.0)
# (291, 'Andelfingen', 2021, 68067.0)
# (291, 'Andelfingen', 2022, 67084.0)
# (292, 'Stammheim', 2009, 50030.0)
# (292, 'Stammheim', 2010, 52115.0)
# (292, 'Stammheim', 2011, 51301.0)
# (292, 'Stammheim', 2012, 52742.0)
# (292, 'Stammheim', 2013, 53217.0)
# (292, 'Stammheim', 2014, 55311.0)
# (292, 'Stammheim', 2015, 55420.0)
# (292, 'Stammheim', 2016, 55956.0)
# (292, 'Stammheim', 2017, 53505.0)
# (292, 'Stammheim', 2018, 53173.0)
# (292, 'Stammheim', 2019, 62083.0)
# (292, 'Stammheim', 2020, 60979.0)
# (292, 'Stammheim', 2021, 62869.0)
# (292, 'Stammheim', 2022, 62299.0)
# (293, 'Wädenswil', 2009, 60059.0)
# (293, 'Wädenswil', 2010, 61777.0)
# (293, 'Wädenswil', 2011, 61674.0)
# (293, 'Wädenswil', 2012, 63578.0)
# (293, 'Wädenswil', 2013, 64571.0)
# (293, 'Wädenswil', 2014, 65520.0)
# (293, 'Wädenswil', 2015, 66769.0)
# (293, 'Wädenswil', 2016, 65494.0)
# (293, 'Wädenswil', 2017, 66858.0)
# (293, 'Wädenswil', 2018, 68579.0)
# (293, 'Wädenswil', 2019, 70124.0)
# (293, 'Wädenswil', 2020, 71043.0)
# (293, 'Wädenswil', 2021, 71381.0)
# (293, 'Wädenswil', 2022, 70172.0)
# (294, 'Elgg', 2009, 56327.0)
# (294, 'Elgg', 2010, 59103.0)
# (294, 'Elgg', 2011, 58114.0)
# (294, 'Elgg', 2012, 58857.0)
# (294, 'Elgg', 2013, 58421.0)
# (294, 'Elgg', 2014, 58547.0)
# (294, 'Elgg', 2015, 59145.0)
# (294, 'Elgg', 2016, 59019.0)
# (294, 'Elgg', 2017, 60436.0)
# (294, 'Elgg', 2018, 64904.0)
# (294, 'Elgg', 2019, 63151.0)
# (294, 'Elgg', 2020, 61372.0)
# (294, 'Elgg', 2021, 61799.0)
# (294, 'Elgg', 2022, 60924.0)
# (295, 'Horgen', 2009, 65582.0)
# (295, 'Horgen', 2010, 66731.0)
# (295, 'Horgen', 2011, 66096.0)
# (295, 'Horgen', 2012, 70489.0)
# (295, 'Horgen', 2013, 72534.0)
# (295, 'Horgen', 2014, 72429.0)
# (295, 'Horgen', 2015, 74983.0)
# (295, 'Horgen', 2016, 76050.0)
# (295, 'Horgen', 2017, 71604.0)
# (295, 'Horgen', 2018, 71704.0)
# (295, 'Horgen', 2019, 75524.0)
# (295, 'Horgen', 2020, 78627.0)
# (295, 'Horgen', 2021, 78048.0)
# (295, 'Horgen', 2022, 76913.0)
# (296, 'Illnau-Effretikon', 2009, 55990.0)
# (296, 'Illnau-Effretikon', 2010, 56073.0)
# (296, 'Illnau-Effretikon', 2011, 56864.0)
# (296, 'Illnau-Effretikon', 2012, 57550.0)
# (296, 'Illnau-Effretikon', 2013, 56823.0)
# (296, 'Illnau-Effretikon', 2014, 57383.0)
# (296, 'Illnau-Effretikon', 2015, 58219.0)
# (296, 'Illnau-Effretikon', 2016, 59147.0)
# (296, 'Illnau-Effretikon', 2017, 59239.0)
# (296, 'Illnau-Effretikon', 2018, 59249.0)
# (296, 'Illnau-Effretikon', 2019, 59695.0)
# (296, 'Illnau-Effretikon', 2020, 58798.0)
# (296, 'Illnau-Effretikon', 2021, 58776.0)
# (296, 'Illnau-Effretikon', 2022, 59147.0)
# (297, 'Bauma', 2009, 46651.0)
# (297, 'Bauma', 2010, 46621.0)
# (297, 'Bauma', 2011, 46399.0)
# (297, 'Bauma', 2012, 50565.0)
# (297, 'Bauma', 2013, 50792.0)
# (297, 'Bauma', 2014, 51788.0)
# (297, 'Bauma', 2015, 50890.0)
# (297, 'Bauma', 2016, 52460.0)
# (297, 'Bauma', 2017, 55095.0)
# (297, 'Bauma', 2018, 55125.0)
# (297, 'Bauma', 2019, 55630.0)
# (297, 'Bauma', 2020, 57119.0)
# (297, 'Bauma', 2021, 56537.0)
# (297, 'Bauma', 2022, 57466.0)
# (298, 'Wiesendangen', 2009, 64024.0)
# (298, 'Wiesendangen', 2010, 66416.0)
# (298, 'Wiesendangen', 2011, 66851.0)
# (298, 'Wiesendangen', 2012, 69211.0)
# (298, 'Wiesendangen', 2013, 68147.0)
# (298, 'Wiesendangen', 2014, 68476.0)
# (298, 'Wiesendangen', 2015, 70660.0)
# (298, 'Wiesendangen', 2016, 73531.0)
# (298, 'Wiesendangen', 2017, 72068.0)
# (298, 'Wiesendangen', 2018, 72357.0)
# (298, 'Wiesendangen', 2019, 74154.0)
# (298, 'Wiesendangen', 2020, 74697.0)
# (298, 'Wiesendangen', 2021, 75281.0)
# (298, 'Wiesendangen', 2022, 73135.0)
# MySQL connection closed
