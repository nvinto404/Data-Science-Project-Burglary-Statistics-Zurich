# %% [markdown]
# # Project in Applied Data Science - Criminal Data
# *Laura Kunz, Natalie Vintonjak, Yannick Sanner*
#
# **SS 2024 - MSc Wirtschaftsinformatik**
#
#
# **Overview**
#
#
#
# **Project Components**

# %% [markdown]
# Connect to the Swiss Open Data API to retrieve the Burglary Data for the Canton of Zurich. Afterwards load the Data into a Dataframe and save the originally retrieved data into csv, before the cleaning of the Data.

# %%
import requests    
import json         
import pandas as pd 
import os

package = 'anzahl-einbruche-nach-gemeinden-des-kantons-zurich'

# Base url for the open data swiss API
base_url = 'https://opendata.swiss/api/3/action/package_show?id='

# Construct the url including the package name  
package_information_url = base_url + package

# HTTP request
package_information = requests.get(package_information_url)

# Use the json module to load CKAN's response into a dictionary
package_dict = json.loads(package_information.content)

# Check the contents of the response.
assert package_dict['success'] is True  # again make sure if response is OK
package_dict = package_dict['result']   # we only need the 'result' part from the dictionary
print(package_dict)
# Out:
# {'license_title': None, 'maintainer': 'Kantonspolizei des Kantons Zürich, Abteilung Kriminalpolizeiliches Datenmanagement', 'issued': '2023-03-22T10:32:20+01:00', 'title_for_slug': 'anzahl-einbruche-nach-gemeinden-des-kantons-zurich', 'qualified_relations': [], 'private': False, 'maintainer_email': 'kdm-kla@kapo.zh.ch', 'num_tags': 6, 'contact_points': [{'email': 'kdm-kla@kapo.zh.ch', 'name': 'Kantonspolizei des Kantons Zürich, Abteilung Kriminalpolizeiliches Datenmanagement'}], 'keywords': {'fr': [], 'de': ['strafbarehandlungen', 'kriminalitaet', 'straftaten', 'gemeinden', 'einbrueche', 'strafdelikte'], 'en': [], 'it': []}, 'temporals': [{'start_date': '2009-01-01T00:00:00', 'end_date': '2023-12-31T23:59:59.999999'}], 'id': '7df9b9e1-67ba-4402-881c-1bea8ab732be', 'metadata_created': '2023-03-23T01:45:39.242565', 'documentation': [], 'conforms_to': [], 'metadata_modified': '2024-04-30T03:27:28.148545', 'author': None, 'author_email': None, 'isopen': False, 'relations': [{'url': 'https://openzh.github.io/starter-code-openZH/', 'label': 'Vorbereiteter Code in R oder Python für jedes Dataset mit csv-Datei(en)'}], 'state': 'active', 'version': None, 'relationships_as_object': [], 'license_id': None, 'see_alsos': [{'dataset_identifier': '1202@kantonspolizei-kanton-zuerich'}], 'type': 'dataset', 'resources': [{'byte_size': 539490, 'cache_last_updated': None, 'issued': '2023-03-22T10:32:20+01:00', 'uri': '', 'package_id': '7df9b9e1-67ba-4402-881c-1bea8ab732be', 'temporal_resolution': '', 'datastore_contains_all_records_of_source_file': False, 'datastore_active': False, 'id': '766d18b0-d959-42ae-8ea2-24150345ea8a', 'size': None, 'rights': 'NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired', 'display_name': {'fr': '', 'de': 'Anzahl Einbrüche nach Gemeinden und in den Stadtkreisen der Stadt Zürich', 'en': '', 'it': ''}, 'title': {'fr': '', 'de': 'Anzahl Einbrüche nach Gemeinden und in den Stadtkreisen der Stadt Zürich', 'en': '', 'it': ''}, 'download_url': 'https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00002042_00004083.csv', 'state': 'active', 'media_type': 'text/csv', 'hash': '', 'description': {'fr': '', 'de': 'Das Total Einbrüche beinhaltet alle polizeilich bekannten, vollendeten und versuchten Einbruchs- und Einschleichdiebstähle. Die Bevölkerungszahlen sind der Einwohnerstatistik des Bundes am Ende des Vorjahres entnommen (bis 2010 ESPOP, ab 2011 STATPOP). Damit wird die Häufigkeitszahl berechnet (Anzahl registrierten Straftaten pro 1000 Einwohner). ', 'en': '', 'it': ''}, 'format': 'CSV', 'language': ['de'], 'mimetype_inner': None, 'url_type': None, 'name': {'fr': '', 'de': 'Anzahl Einbrüche nach Gemeinden und in den Stadtkreisen der Stadt Zürich', 'en': '', 'it': ''}, 'mimetype': 'text/csv', 'cache_url': None, 'license': 'NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired', 'access_services': [], 'created': '2023-03-23T01:45:39.406636', 'url': 'https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00002042_00004083.csv', 'documentation': [], 'modified': '2024-03-25T08:45:27+01:00', 'last_modified': None, 'position': 0, 'revision_id': '9855fb8a-84c0-47da-a6a9-e7bc3d01d16d', 'resource_type': None}], 'num_resources': 1, 'description': {'fr': '', 'de': 'Anzahl der Einbrüche wie sie in der Kriminalstatistik der Kantonspolizei Zürich erfasst werden. Aufgegliedert nach Gemeinden (im Fall der Stadt Zürich nach Stadtkreisen) und ergänzt mit Angaben zur Bevölkerungszahl. Die polizeiliche Kriminalstatistik (PKS) des Kantons Zürich wird jährlich publiziert. Die polizeiliche Kriminalstatistik verzeichnet nur die polizeilich bekannt gewordene Kriminalität - das sogenannte Hellfeld. Sie ist eine Ausgangsstatistik. D.h. die Straftaten erscheinen nicht zum Tatzeitpunkt in der Statistik. Ausschlaggebend für die Zählung in der PKS ist der Zeitpunkt, an dem die Polizei einen ersten Rapport zur Straftat abgeschlossen hat.', 'en': '', 'it': ''}, 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'ei ...

# %%
# Get the url for the data from the dictionary
data_url = package_dict['resources'][0]['url']
print('Data url:' + data_url)

# Print the data format
data_format = package_dict['resources'][0]['format']
print('Data format:' + data_format)
# Out:
# Data url:https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00002042_00004083.csv
# Data format:CSV

# %%
csv = ['comma-separated-values', 'CSV', 'csv']

if any(s in data_format for s in csv):     
     Einbrueche_df = pd.read_csv(data_url)
else:
    print('Sorry, the data format is not supported')
Einbrueche_df
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr  Gemeindename  Stadtkreis_BFS_Nr  \
# 0             2009              131      Adliswil                NaN
# 1             2009              131      Adliswil                NaN
# 2             2009              131      Adliswil                NaN
# 3             2009              241         Aesch                NaN
# 4             2009              241         Aesch                NaN
# ...            ...              ...           ...                ...
# 7777          2023              261        Zürich                NaN
# 7778          2023              261        Zürich                NaN
# 7779          2023             7601  unbekannt ZH                NaN
# 7780          2023             7601  unbekannt ZH                NaN
# 7781          2023             7601  unbekannt ZH                NaN
#
#      Stadtkreis_Name  Gesetz_Nummer Gesetz_Abk            Tatbestand  \
# 0                NaN          311.0       StGB     Einbruchdiebstahl
# 1                NaN          311.0       StGB  Einschleichdiebstahl
# 2                NaN          311.0       StGB   Einbrüche insgesamt
# 3                NaN          311.0       StGB     Einbruchdiebstahl
# 4                NaN          311.0       StGB  Einschleichdiebstahl
# ...              ...            ...        ...                   ...
# 7777       unbekannt          311.0       StGB  Einschleichdiebstahl
# 7778       unbekannt          311.0       StGB   Einbrüche insgesamt
# 7779             NaN          311.0       StGB     Einbruchdiebstahl
# 7780             NaN          311.0       StGB  Einschleichdiebstahl
# 7781             NaN          311.0       StGB   Einbrüche insgesamt
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner  \
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 2                  192                   146                   46    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# ...                ...                   ...                  ...        ...
# 7777                 0                     0                    0     1601.0
# 7778                 0                     0                    0     1601.0
# 7779                 1                     1                    0        NaN
# 7780                 1                     1                    0        NaN
# 7781                 2                     2                    0        NaN
#
#       Häufigkeitszahl
# 0                 9.9
# 1                 2.1
# 2                12.0
# 3                10.1
# 4                 2.0
# ...               ...
# 7777              NaN
# 7778              NaN
# 7779              NaN
# 7780              NaN
# 7781              NaN
#
# [7782 rows x 13 columns]

# %%
#Save original data files to csv, if the folder is not aleady created, it will be created
directory = 'Original_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Einbrueche.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

Einbrueche_df.to_csv(csv_path, index=False)
print(Einbrueche_df)
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr  Gemeindename  Stadtkreis_BFS_Nr  \
# 0             2009              131      Adliswil                NaN
# 1             2009              131      Adliswil                NaN
# 2             2009              131      Adliswil                NaN
# 3             2009              241         Aesch                NaN
# 4             2009              241         Aesch                NaN
# ...            ...              ...           ...                ...
# 7777          2023              261        Zürich                NaN
# 7778          2023              261        Zürich                NaN
# 7779          2023             7601  unbekannt ZH                NaN
# 7780          2023             7601  unbekannt ZH                NaN
# 7781          2023             7601  unbekannt ZH                NaN
#
#      Stadtkreis_Name  Gesetz_Nummer Gesetz_Abk            Tatbestand  \
# 0                NaN          311.0       StGB     Einbruchdiebstahl
# 1                NaN          311.0       StGB  Einschleichdiebstahl
# 2                NaN          311.0       StGB   Einbrüche insgesamt
# 3                NaN          311.0       StGB     Einbruchdiebstahl
# 4                NaN          311.0       StGB  Einschleichdiebstahl
# ...              ...            ...        ...                   ...
# 7777       unbekannt          311.0       StGB  Einschleichdiebstahl
# 7778       unbekannt          311.0       StGB   Einbrüche insgesamt
# 7779             NaN          311.0       StGB     Einbruchdiebstahl
# 7780             NaN          311.0       StGB  Einschleichdiebstahl
# 7781             NaN          311.0       StGB   Einbrüche insgesamt
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner  \
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 2                  192                   146                   46    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# ...                ...                   ...                  ...        ...
# 7777                 0                     0                    0     1601.0
# 7778                 0                     0                    0     1601.0
# 7779                 1                     1                    0        NaN
# 7780                 1                     1                    0        NaN
# 7781                 2                     2                    0        NaN
#
#       Häufigkeitszahl
# 0                 9.9
# 1                 2.1
# 2                12.0
# 3                10.1
# 4                 2.0
# ...               ...
# 7777              NaN
# 7778              NaN
# 7779              NaN
# 7780              NaN
# 7781              NaN
#
# [7782 rows x 13 columns]

# %% [markdown]
# Drop not needed Columns, Drop NA, Delete the summarized Datarows and Summarize Straftaten_total for each Gemeinde for the year 2023 to check if the retrival was done correctly. Afterwards save a Cleaned csv file to the Cleaned CSV Files folder.

# %%
Einbrueche_df.drop(['Stadtkreis_BFS_Nr','Stadtkreis_Name','Gesetz_Nummer','Gesetz_Abk','Häufigkeitszahl'], axis=1, inplace=True)
Einbrueche_df
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr  Gemeindename            Tatbestand  \
# 0             2009              131      Adliswil     Einbruchdiebstahl
# 1             2009              131      Adliswil  Einschleichdiebstahl
# 2             2009              131      Adliswil   Einbrüche insgesamt
# 3             2009              241         Aesch     Einbruchdiebstahl
# 4             2009              241         Aesch  Einschleichdiebstahl
# ...            ...              ...           ...                   ...
# 7777          2023              261        Zürich  Einschleichdiebstahl
# 7778          2023              261        Zürich   Einbrüche insgesamt
# 7779          2023             7601  unbekannt ZH     Einbruchdiebstahl
# 7780          2023             7601  unbekannt ZH  Einschleichdiebstahl
# 7781          2023             7601  unbekannt ZH   Einbrüche insgesamt
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 2                  192                   146                   46    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# ...                ...                   ...                  ...        ...
# 7777                 0                     0                    0     1601.0
# 7778                 0                     0                    0     1601.0
# 7779                 1                     1                    0        NaN
# 7780                 1                     1                    0        NaN
# 7781                 2                     2                    0        NaN
#
# [7782 rows x 8 columns]

# %%
indizes_zu_loeschen = Einbrueche_df[Einbrueche_df['Tatbestand'] == 'Einbrüche insgesamt'].index
Einbrueche_df.drop(indizes_zu_loeschen, inplace=True)
Einbrueche_df
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr  Gemeindename            Tatbestand  \
# 0             2009              131      Adliswil     Einbruchdiebstahl
# 1             2009              131      Adliswil  Einschleichdiebstahl
# 3             2009              241         Aesch     Einbruchdiebstahl
# 4             2009              241         Aesch  Einschleichdiebstahl
# 6             2009                1        Aeugst     Einbruchdiebstahl
# ...            ...              ...           ...                   ...
# 7774          2023              261        Zürich  Einschleichdiebstahl
# 7776          2023              261        Zürich     Einbruchdiebstahl
# 7777          2023              261        Zürich  Einschleichdiebstahl
# 7779          2023             7601  unbekannt ZH     Einbruchdiebstahl
# 7780          2023             7601  unbekannt ZH  Einschleichdiebstahl
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# 6                    3                     3                    0     1700.0
# ...                ...                   ...                  ...        ...
# 7774                18                    17                    1    31471.0
# 7776                 0                     0                    0     1601.0
# 7777                 0                     0                    0     1601.0
# 7779                 1                     1                    0        NaN
# 7780                 1                     1                    0        NaN
#
# [5188 rows x 8 columns]

# %%
indizes_zu_loeschen = Einbrueche_df[Einbrueche_df['Gemeindename'] == 'unbekannt ZH'].index
Einbrueche_df.drop(indizes_zu_loeschen, inplace=True)
Einbrueche_df
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr Gemeindename            Tatbestand  \
# 0             2009              131     Adliswil     Einbruchdiebstahl
# 1             2009              131     Adliswil  Einschleichdiebstahl
# 3             2009              241        Aesch     Einbruchdiebstahl
# 4             2009              241        Aesch  Einschleichdiebstahl
# 6             2009                1       Aeugst     Einbruchdiebstahl
# ...            ...              ...          ...                   ...
# 7771          2023              261       Zürich  Einschleichdiebstahl
# 7773          2023              261       Zürich     Einbruchdiebstahl
# 7774          2023              261       Zürich  Einschleichdiebstahl
# 7776          2023              261       Zürich     Einbruchdiebstahl
# 7777          2023              261       Zürich  Einschleichdiebstahl
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# 6                    3                     3                    0     1700.0
# ...                ...                   ...                  ...        ...
# 7771                99                    94                    5    73993.0
# 7773                63                    49                   14    31471.0
# 7774                18                    17                    1    31471.0
# 7776                 0                     0                    0     1601.0
# 7777                 0                     0                    0     1601.0
#
# [5158 rows x 8 columns]

# %%
Einbrueche_df.dropna(subset=['Einwohner'], inplace=True)
Einbrueche_df
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr Gemeindename            Tatbestand  \
# 0             2009              131     Adliswil     Einbruchdiebstahl
# 1             2009              131     Adliswil  Einschleichdiebstahl
# 3             2009              241        Aesch     Einbruchdiebstahl
# 4             2009              241        Aesch  Einschleichdiebstahl
# 6             2009                1       Aeugst     Einbruchdiebstahl
# ...            ...              ...          ...                   ...
# 7771          2023              261       Zürich  Einschleichdiebstahl
# 7773          2023              261       Zürich     Einbruchdiebstahl
# 7774          2023              261       Zürich  Einschleichdiebstahl
# 7776          2023              261       Zürich     Einbruchdiebstahl
# 7777          2023              261       Zürich  Einschleichdiebstahl
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# 6                    3                     3                    0     1700.0
# ...                ...                   ...                  ...        ...
# 7771                99                    94                    5    73993.0
# 7773                63                    49                   14    31471.0
# 7774                18                    17                    1    31471.0
# 7776                 0                     0                    0     1601.0
# 7777                 0                     0                    0     1601.0
#
# [5152 rows x 8 columns]

# %%
df_2023 = Einbrueche_df[Einbrueche_df['Ausgangsjahr'] == 2023]
# Summarize Straftaten_total for each Gemeinde for the year 2023
summary_df_2023 = df_2023.groupby(['Gemeinde_BFS_Nr', 'Gemeindename'])['Straftaten_total'].sum().reset_index()
summary_df_2023
# Out:
#      Gemeinde_BFS_Nr       Gemeindename  Straftaten_total
# 0                  1             Aeugst                 7
# 1                  2          Affoltern                54
# 2                  3         Bonstetten                11
# 3                  4             Hausen                12
# 4                  5           Hedingen                19
# ..               ...                ...               ...
# 154              294               Elgg                16
# 155              295             Horgen                50
# 156              296  Illnau-Effretikon                57
# 157              297              Bauma                 9
# 158              298       Wiesendangen                18
#
# [159 rows x 3 columns]

# %%
directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()

csv_path = os.path.join(current_directory, directory, 'Einbrueche_Cleaned.csv')

# Create the directory if it doesn't exist
if not os.path.exists(os.path.join(current_directory, directory)):
    os.makedirs(os.path.join(current_directory, directory))

Einbrueche_df.to_csv(csv_path, index=False)
print(Einbrueche_df)
# Out:
#       Ausgangsjahr  Gemeinde_BFS_Nr Gemeindename            Tatbestand  \
# 0             2009              131     Adliswil     Einbruchdiebstahl
# 1             2009              131     Adliswil  Einschleichdiebstahl
# 3             2009              241        Aesch     Einbruchdiebstahl
# 4             2009              241        Aesch  Einschleichdiebstahl
# 6             2009                1       Aeugst     Einbruchdiebstahl
# ...            ...              ...          ...                   ...
# 7771          2023              261       Zürich  Einschleichdiebstahl
# 7773          2023              261       Zürich     Einbruchdiebstahl
# 7774          2023              261       Zürich  Einschleichdiebstahl
# 7776          2023              261       Zürich     Einbruchdiebstahl
# 7777          2023              261       Zürich  Einschleichdiebstahl
#
#       Straftaten_total  Straftaten_vollendet  Straftaten_versucht  Einwohner
# 0                  159                   114                   45    16052.0
# 1                   33                    32                    1    16052.0
# 3                   10                     7                    3      987.0
# 4                    2                     2                    0      987.0
# 6                    3                     3                    0     1700.0
# ...                ...                   ...                  ...        ...
# 7771                99                    94                    5    73993.0
# 7773                63                    49                   14    31471.0
# 7774                18                    17                    1    31471.0
# 7776                 0                     0                    0     1601.0
# 7777                 0                     0                    0     1601.0
#
# [5152 rows x 8 columns]

# %% [markdown]
# Create a new Database (if it is not existing already) called CriminalDataDB in mysql and connect to it.

# %%
import mysql.connector
from mysql.connector import Error

try:
    connection = mysql.connector.connect(host='localhost',
                                         user='admin',
                                         password='Criminal1234')

    if connection.is_connected():
        print("Connected to MySQL server")

        # Create a cursor object to execute SQL queries
        cursor = connection.cursor()

        # Execute SQL statement to create a new database
        cursor.execute("CREATE DATABASE IF NOT EXISTS CriminalDataDB")

        print("Database created successfully")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Database created successfully
# MySQL connection closed

# %% [markdown]
# Print the Information for the Dataframe so we can create the Table for the Database correspondingly.

# %%
Einbrueche_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5152 entries, 0 to 7777
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ausgangsjahr          5152 non-null   int64
#  1   Gemeinde_BFS_Nr       5152 non-null   int64
#  2   Gemeindename          5152 non-null   object
#  3   Tatbestand            5152 non-null   object
#  4   Straftaten_total      5152 non-null   int64
#  5   Straftaten_vollendet  5152 non-null   int64
#  6   Straftaten_versucht   5152 non-null   int64
#  7   Einwohner             5152 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 362.2+ KB

# %% [markdown]
# Connect to the database and create a new table called Einbrueche. If the data is already existing drop it.

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

# MySQL connection parameters
host = 'localhost'
user = 'admin'
password = 'Criminal1234'
database = 'CriminalDataDB'  
try:
    connection = mysql.connector.connect(host=host,
                                         user=user,
                                         password=password,
                                         database=database)

    if connection.is_connected():
        print("Connected to MySQL server")
        cursor = connection.cursor()

        # SQL command to drop the table if it already exists becuase before that line of code the data was already inserted multiple times
        drop_table_query = "DROP TABLE IF EXISTS Einbrueche;"
        cursor.execute(drop_table_query)
        print("Table 'Einbrueche' dropped if it existed alreadyy")

        create_table_query = """
        CREATE TABLE IF NOT EXISTS Einbrueche (
            Ausgangsjahr INT,
            Gemeinde_BFS_Nr INT,
            Gemeindename VARCHAR(255),
            Tatbestand VARCHAR(255),
            Straftaten_total INT,
            Straftaten_vollendet INT,
            Straftaten_versucht INT,
            Einwohner FLOAT
        )
        """

        cursor.execute(create_table_query)
        print("Table 'Einbrueche' created successfully")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Table 'Einbrueche' dropped if it existed alreadyy
# Table 'Einbrueche' created successfully
# MySQL connection closed

# %% [markdown]
# Insert the Cleanaed data from the Cleaned Csv file which was created before.

# %%
import mysql.connector 
from mysql.connector import Error
import pandas as pd

# MySQL connection parameters
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB',
    'allow_local_infile': True
}

directory = 'Cleaned_CSV_files'
current_directory = os.getcwd()
csv_file_path = os.path.join(current_directory, directory, 'Einbrueche_Cleaned.csv')

try:
    with mysql.connector.connect(**connection_params) as connection:
        print("Connected to MySQL server")

        Einbrueche_df_to_sql = pd.read_csv(csv_file_path)

        cursor = connection.cursor()
        insert_query = """
        LOAD DATA LOCAL INFILE %s 
        INTO TABLE Einbrueche 
        FIELDS TERMINATED BY ',' 
        ENCLOSED BY '"' 
        LINES TERMINATED BY '\n' 
        IGNORE 1 LINES
        """

        cursor.execute(insert_query, (csv_file_path,))
        connection.commit()

        print("Data from CSV file successfully inserted into MySQL table 'Einbrueche'")

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if connection.is_connected():
        # Close cursor and connection
        cursor.close()
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# Data from CSV file successfully inserted into MySQL table 'Einbrueche'

# %% [markdown]
# Check if the Data upload to the table was successfully by creating a query to the sql table.

# %%
import mysql.connector
from mysql.connector import Error

# MySQL connection parameters
connection_params = {
    'host': 'localhost',
    'user': 'admin',
    'password': 'Criminal1234',
    'database': 'CriminalDataDB'
}

try:
    connection = mysql.connector.connect(**connection_params)
    print("Connected to MySQL server")

    with connection.cursor() as cursor:
        select_query = "SELECT * FROM Einbrueche"

        cursor.execute(select_query)
        rows = cursor.fetchall()

        for row in rows:
            print(row)

except Error as e:
    print("Error connecting to MySQL:", e)

finally:
    if 'connection' in locals() and connection.is_connected():
        # Close connection
        connection.close()
        print("MySQL connection closed")
# Out:
# Connected to MySQL server
# (2009, 131, 'Adliswil', 'Einbruchdiebstahl', 159, 114, 45, 16052.0)
# (2009, 131, 'Adliswil', 'Einschleichdiebstahl', 33, 32, 1, 16052.0)
# (2009, 241, 'Aesch', 'Einbruchdiebstahl', 10, 7, 3, 987.0)
# (2009, 241, 'Aesch', 'Einschleichdiebstahl', 2, 2, 0, 987.0)
# (2009, 1, 'Aeugst', 'Einbruchdiebstahl', 3, 3, 0, 1700.0)
# (2009, 1, 'Aeugst', 'Einschleichdiebstahl', 5, 5, 0, 1700.0)
# (2009, 2, 'Affoltern', 'Einbruchdiebstahl', 101, 67, 34, 10630.0)
# (2009, 2, 'Affoltern', 'Einschleichdiebstahl', 20, 18, 2, 10630.0)
# (2009, 211, 'Altikon', 'Einbruchdiebstahl', 0, 0, 0, 615.0)
# (2009, 211, 'Altikon', 'Einschleichdiebstahl', 1, 1, 0, 615.0)
# (2009, 291, 'Andelfingen', 'Einbruchdiebstahl', 12, 10, 2, 2775.0)
# (2009, 291, 'Andelfingen', 'Einschleichdiebstahl', 1, 1, 0, 2775.0)
# (2009, 51, 'Bachenbülach', 'Einbruchdiebstahl', 27, 19, 8, 3796.0)
# (2009, 51, 'Bachenbülach', 'Einschleichdiebstahl', 10, 9, 1, 3796.0)
# (2009, 81, 'Bachs', 'Einbruchdiebstahl', 1, 0, 1, 566.0)
# (2009, 81, 'Bachs', 'Einschleichdiebstahl', 0, 0, 0, 566.0)
# (2009, 52, 'Bassersdorf', 'Einbruchdiebstahl', 60, 43, 17, 10755.0)
# (2009, 52, 'Bassersdorf', 'Einschleichdiebstahl', 30, 30, 0, 10755.0)
# (2009, 297, 'Bauma', 'Einbruchdiebstahl', 22, 16, 6, 4517.0)
# (2009, 297, 'Bauma', 'Einschleichdiebstahl', 7, 7, 0, 4517.0)
# (2009, 22, 'Benken', 'Einbruchdiebstahl', 4, 4, 0, 752.0)
# (2009, 22, 'Benken', 'Einschleichdiebstahl', 0, 0, 0, 752.0)
# (2009, 23, 'Berg', 'Einbruchdiebstahl', 0, 0, 0, 582.0)
# (2009, 23, 'Berg', 'Einschleichdiebstahl', 2, 2, 0, 582.0)
# (2009, 242, 'Birmensdorf', 'Einbruchdiebstahl', 65, 49, 16, 5810.0)
# (2009, 242, 'Birmensdorf', 'Einschleichdiebstahl', 6, 6, 0, 5810.0)
# (2009, 3, 'Bonstetten', 'Einbruchdiebstahl', 20, 10, 10, 4990.0)
# (2009, 3, 'Bonstetten', 'Einschleichdiebstahl', 3, 3, 0, 4990.0)
# (2009, 82, 'Boppelsen', 'Einbruchdiebstahl', 5, 5, 0, 1282.0)
# (2009, 82, 'Boppelsen', 'Einschleichdiebstahl', 0, 0, 0, 1282.0)
# (2009, 213, 'Brütten', 'Einbruchdiebstahl', 5, 3, 2, 1893.0)
# (2009, 213, 'Brütten', 'Einschleichdiebstahl', 2, 2, 0, 1893.0)
# (2009, 112, 'Bubikon', 'Einbruchdiebstahl', 24, 18, 6, 6299.0)
# (2009, 112, 'Bubikon', 'Einschleichdiebstahl', 7, 7, 0, 6299.0)
# (2009, 24, 'Buch', 'Einbruchdiebstahl', 2, 2, 0, 843.0)
# (2009, 24, 'Buch', 'Einschleichdiebstahl', 0, 0, 0, 843.0)
# (2009, 83, 'Buchs', 'Einbruchdiebstahl', 24, 16, 8, 5243.0)
# (2009, 83, 'Buchs', 'Einschleichdiebstahl', 7, 7, 0, 5243.0)
# (2009, 111, 'Bäretswil', 'Einbruchdiebstahl', 22, 11, 11, 4471.0)
# (2009, 111, 'Bäretswil', 'Einschleichdiebstahl', 9, 9, 0, 4471.0)
# (2009, 53, 'Bülach', 'Einbruchdiebstahl', 145, 100, 45, 16774.0)
# (2009, 53, 'Bülach', 'Einschleichdiebstahl', 52, 52, 0, 16774.0)
# (2009, 25, 'Dachsen', 'Einbruchdiebstahl', 2, 2, 0, 1893.0)
# (2009, 25, 'Dachsen', 'Einschleichdiebstahl', 3, 3, 0, 1893.0)
# (2009, 86, 'Dielsdorf', 'Einbruchdiebstahl', 43, 28, 15, 5409.0)
# (2009, 86, 'Dielsdorf', 'Einschleichdiebstahl', 22, 22, 0, 5409.0)
# (2009, 243, 'Dietikon', 'Einbruchdiebstahl', 267, 182, 85, 22954.0)
# (2009, 243, 'Dietikon', 'Einschleichdiebstahl', 56, 53, 3, 22954.0)
# (2009, 54, 'Dietlikon', 'Einbruchdiebstahl', 70, 48, 22, 7030.0)
# (2009, 54, 'Dietlikon', 'Einschleichdiebstahl', 19, 19, 0, 7030.0)
# (2009, 216, 'Dinhard', 'Einbruchdiebstahl', 9, 7, 2, 1396.0)
# (2009, 216, 'Dinhard', 'Einschleichdiebstahl', 1, 0, 1, 1396.0)
# (2009, 26, 'Dorf', 'Einbruchdiebstahl', 1, 1, 0, 628.0)
# (2009, 26, 'Dorf', 'Einschleichdiebstahl', 0, 0, 0, 628.0)
# (2009, 214, 'Dägerlen', 'Einbruchdiebstahl', 2, 2, 0, 972.0)
# (2009, 214, 'Dägerlen', 'Einschleichdiebstahl', 0, 0, 0, 972.0)
# (2009, 84, 'Dällikon', 'Einbruchdiebstahl', 40, 30, 10, 3596.0)
# (2009, 84, 'Dällikon', 'Einschleichdiebstahl', 3, 3, 0, 3596.0)
# (2009, 85, 'Dänikon', 'Einbruchdiebstahl', 6, 3, 3, 1841.0)
# (2009, 85, 'Dänikon', 'Einschleichdiebstahl', 5, 5, 0, 1841.0)
# (2009, 215, 'Dättlikon', 'Einbruchdiebstahl', 1, 1, 0, 649.0)
# (2009, 215, 'Dättlikon', 'Einschleichdiebstahl', 0, 0, 0, 649.0)
# (2009, 191, 'Dübendorf', 'Einbruchdiebstahl', 221, 138, 83, 23852.0)
# (2009, 191, 'Dübendorf', 'Einschleichdiebstahl', 64, 63, 1, 23852.0)
# (2009, 113, 'Dürnten', 'Einbruchdiebstahl', 32, 24, 8, 6421.0)
# (2009, 113, 'Dürnten', 'Einschleichdiebstahl', 7, 5, 2, 6421.0)
# (2009, 192, 'Egg', 'Einbruchdiebstahl', 12, 6, 6, 7975.0)
# (2009, 192, 'Egg', 'Einschleichdiebstahl', 1, 1, 0, 7975.0)
# (2009, 55, 'Eglisau', 'Einbruchdiebstahl', 24, 18, 6, 3684.0)
# (2009, 55, 'Eglisau', 'Einschleichdiebstahl', 7, 7, 0, 3684.0)
# (2009, 294, 'Elgg', 'Einbruchdiebstahl', 29, 16, 13, 4221.0)
# (2009, 294, 'Elgg', 'Einschleichdiebstahl', 3, 3, 0, 4221.0)
# (2009, 218, 'Ellikon', 'Einbruchdiebstahl', 2, 2, 0, 837.0)
# (2009, 218, 'Ellikon', 'Einschleichdiebstahl', 2, 2, 0, 837.0)
# (2009, 219, 'Elsau', 'Einbruchdiebstahl', 21, 11, 10, 3267.0)
# (2009, 219, 'Elsau', 'Einschleichdiebstahl', 5, 5, 0, 3267.0)
# (2009, 56, 'Embrach', 'Einbruchdiebstahl', 29, 20, 9, 8686.0)
# (2009, 56, 'Embrach', 'Einschleichdiebstahl', 13, 12, 1, 8686.0)
# (2009, 151, 'Erlenbach', 'Einbruchdiebstahl', 53, 38, 15, 5179.0)
# (2009, 151, 'Erlenbach', 'Einschleichdiebstahl', 8, 8, 0, 5179.0)
# (2009, 172, 'Fehraltorf', 'Einbruchdiebstahl', 46, 27, 19, 5208.0)
# (2009, 172, 'Fehraltorf', 'Einschleichdiebstahl', 10, 10, 0, 5208.0)
# (2009, 27, 'Feuerthalen', 'Einbruchdiebstahl', 16, 5, 11, 3389.0)
# (2009, 27, 'Feuerthalen', 'Einschleichdiebstahl', 3, 3, 0, 3389.0)
# (2009, 114, 'Fischenthal', 'Einbruchdiebstahl', 4, 2, 2, 2222.0)
# (2009, 114, 'Fischenthal', 'Einschleichdiebstahl', 2, 2, 0, 2222.0)
# (2009, 28, 'Flaach', 'Einbruchdiebstahl', 1, 0, 1, 1237.0)
# (2009, 28, 'Flaach', 'Einschleichdiebstahl', 0, 0, 0, 1237.0)
# (2009, 29, 'Flurlingen', 'Einbruchdiebstahl', 16, 9, 7, 1356.0)
# (2009, 29, 'Flurlingen', 'Einschleichdiebstahl', 2, 1, 1, 1356.0)
# (2009, 57, 'Freienstein-Teufen', 'Einbruchdiebstahl', 7, 6, 1, 2249.0)
# (2009, 57, 'Freienstein-Teufen', 'Einschleichdiebstahl', 3, 3, 0, 2249.0)
# (2009, 193, 'Fällanden', 'Einbruchdiebstahl', 48, 30, 18, 7774.0)
# (2009, 193, 'Fällanden', 'Einschleichdiebstahl', 29, 29, 0, 7774.0)
# (2009, 244, 'Geroldswil', 'Einbruchdiebstahl', 29, 20, 9, 4518.0)
# (2009, 244, 'Geroldswil', 'Einschleichdiebstahl', 7, 7, 0, 4518.0)
# (2009, 58, 'Glattfelden', 'Einbruchdiebstahl', 7, 3, 4, 4122.0)
# (2009, 58, 'Glattfelden', 'Einschleichdiebstahl', 1, 1, 0, 4122.0)
# (2009, 115, 'Gossau', 'Einbruchdiebstahl', 26, 19, 7, 9397.0)
# (2009, 115, 'Gossau', 'Einschleichdiebstahl', 9, 9, 0, 9397.0)
# (2009, 194, 'Greifensee', 'Einbruchdiebstahl', 5, 3, 2, 4964.0)
# (2009, 194, 'Greifensee', 'Einschleichdiebstahl', 6, 6, 0, 4964.0)
# (2009, 116, 'Grüningen', 'Einbruchdiebstahl', 9, 8, 1, 2883.0)
# (2009, 116, 'Grüningen', 'Einschleichdiebstahl', 4, 3, 1, 2883.0)
# (2009, 220, 'Hagenbuch', 'Einbruchdiebstahl', 1, 1, 0, 1107.0)
# (2009, 220, 'Hagenbuch', 'Einschleichdiebstahl', 0, 0, 0, 1107.0)
# (2009, 4, 'Hausen', 'Einbruchdiebstahl', 12, 10, 2, 3253.0)
# (2009, 4, 'Hausen', 'Einschleichdiebstahl', 2, 2, 0, 3253.0)
# (2009, 5, 'Hedingen', 'Einbruchdiebstahl', 24, 14, 10, 3403.0)
# (2009, 5, 'Hedingen', 'Einschleichdiebstahl', 5, 5, 0, 3403.0)
# (2009, 31, 'Henggart', 'Einbruchdiebstahl', 20, 13, 7, 2068.0)
# (2009, 31, 'Henggart', 'Einschleichdiebstahl', 2, 2, 0, 2068.0)
# (2009, 152, 'Herrliberg', 'Einbruchdiebstahl', 43, 22, 21, 5815.0)
# (2009, 152, 'Herrliberg', 'Einschleichdiebstahl', 10, 10, 0, 5815.0)
# (2009, 221, 'Hettlingen', 'Einbruchdiebstahl', 2, 2, 0, 2943.0)
# (2009, 221, 'Hettlingen', 'Einschleichdiebstahl', 2, 2, 0, 2943.0)
# (2009, 117, 'Hinwil', 'Einbruchdiebstahl', 35, 22, 13, 9873.0)
# (2009, 117, 'Hinwil', 'Einschleichdiebstahl', 6, 6, 0, 9873.0)
# (2009, 173, 'Hittnau', 'Einbruchdiebstahl', 2, 2, 0, 3374.0)
# (2009, 173, 'Hittnau', 'Einschleichdiebstahl', 2, 2, 0, 3374.0)
# (2009, 59, 'Hochfelden', 'Einbruchdiebstahl', 3, 1, 2, 1876.0)
# (2009, 59, 'Hochfelden', 'Einschleichdiebstahl', 0, 0, 0, 1876.0)
# (2009, 153, 'Hombrechtikon', 'Einbruchdiebstahl', 60, 40, 20, 7822.0)
# (2009, 153, 'Hombrechtikon', 'Einschleichdiebstahl', 7, 6, 1, 7822.0)
# (2009, 295, 'Horgen', 'Einbruchdiebstahl', 64, 41, 23, 20467.0)
# (2009, 295, 'Horgen', 'Einschleichdiebstahl', 19, 17, 2, 20467.0)
# (2009, 60, 'Höri', 'Einbruchdiebstahl', 10, 6, 4, 2460.0)
# (2009, 60, 'Höri', 'Einschleichdiebstahl', 3, 3, 0, 2460.0)
# (2009, 61, 'Hüntwangen', 'Einbruchdiebstahl', 2, 2, 0, 971.0)
# (2009, 61, 'Hüntwangen', 'Einschleichdiebstahl', 2, 2, 0, 971.0)
# (2009, 87, 'Hüttikon', 'Einbruchdiebstahl', 2, 1, 1, 675.0)
# (2009, 87, 'Hüttikon', 'Einschleichdiebstahl', 0, 0, 0, 675.0)
# (2009, 296, 'Illnau-Effretikon', 'Einbruchdiebstahl', 124, 66, 58, 15740.0)
# (2009, 296, 'Illnau-Effretikon', 'Einschleichdiebstahl', 16, 15, 1, 15740.0)
# (2009, 6, 'Kappel', 'Einbruchdiebstahl', 3, 3, 0, 865.0)
# (2009, 6, 'Kappel', 'Einschleichdiebstahl', 1, 1, 0, 865.0)
# (2009, 135, 'Kilchberg', 'Einbruchdiebstahl', 102, 63, 39, 7427.0)
# (2009, 135, 'Kilchberg', 'Einschleichdiebstahl', 12, 12, 0, 7427.0)
# (2009, 33, 'Kleinandelfingen', 'Einbruchdiebstahl', 8, 5, 3, 2032.0)
# (2009, 33, 'Kleinandelfingen', 'Einschleichdiebstahl', 3, 2, 1, 2032.0)
# (2009, 62, 'Kloten', 'Einbruchdiebstahl', 124, 88, 36, 17504.0)
# (2009, 62, 'Kloten', 'Einschleichdiebstahl', 46, 45, 1, 17504.0)
# (2009, 7, 'Knonau', 'Einbruchdiebstahl', 5, 3, 2, 1733.0)
# (2009, 7, 'Knonau', 'Einschleichdiebstahl', 1, 1, 0, 1733.0)
# (2009, 154, 'Küsnacht', 'Einbruchdiebstahl', 135, 90, 45, 13283.0)
# (2009, 154, 'Küsnacht', 'Einschleichdiebstahl', 24, 21, 3, 13283.0)
# (2009, 136, 'Langnau', 'Einbruchdiebstahl', 47, 37, 10, 7148.0)
# (2009, 136, 'Langnau', 'Einschleichdiebstahl', 7, 7, 0, 7148.0)
# (2009, 34, 'Laufen-Uhwiesen', 'Einbruchdiebstahl', 8, 5, 3, 1512.0)
# (2009, 34, 'Laufen-Uhwiesen', 'Einschleichdiebstahl', 1, 1, 0, 1512.0)
# (2009, 176, 'Lindau', 'Einbruchdiebstahl', 26, 17, 9, 4913.0)
# (2009, 176, 'Lindau', 'Einschleichdiebstahl', 10, 10, 0, 4913.0)
# (2009, 63, 'Lufingen', 'Einbruchdiebstahl', 11, 10, 1, 1610.0)
# (2009, 63, 'Lufingen', 'Einschleichdiebstahl', 3, 3, 0, 1610.0)
# (2009, 35, 'Marthalen', 'Einbruchdiebstahl', 8, 4, 4, 1883.0)
# (2009, 35, 'Marthalen', 'Einschleichdiebstahl', 4, 4, 0, 1883.0)
# (2009, 8, 'Maschwanden', 'Einbruchdiebstahl', 1, 1, 0, 568.0)
# (2009, 8, 'Maschwanden', 'Einschleichdiebstahl', 0, 0, 0, 568.0)
# (2009, 195, 'Maur', 'Einbruchdiebstahl', 43, 26, 17, 9275.0)
# (2009, 195, 'Maur', 'Einschleichdiebstahl', 11, 10, 1, 9275.0)
# (2009, 156, 'Meilen', 'Einbruchdiebstahl', 56, 39, 17, 12194.0)
# (2009, 156, 'Meilen', 'Einschleichdiebstahl', 20, 20, 0, 12194.0)
# (2009, 9, 'Mettmenstetten', 'Einbruchdiebstahl', 8, 6, 2, 4109.0)
# (2009, 9, 'Mettmenstetten', 'Einschleichdiebstahl', 1, 1, 0, 4109.0)
# (2009, 155, 'Männedorf', 'Einbruchdiebstahl', 80, 56, 24, 10015.0)
# (2009, 155, 'Männedorf', 'Einschleichdiebstahl', 8, 8, 0, 10015.0)
# (2009, 196, 'Mönchaltorf', 'Einbruchdiebstahl', 23, 16, 7, 3375.0)
# (2009, 196, 'Mönchaltorf', 'Einschleichdiebstahl', 7, 7, 0, 3375.0)
# (2009, 88, 'Neerach', 'Einbruchdiebstahl', 13, 9, 4, 2908.0)
# (2009, 88, 'Neerach', 'Einschleichdiebstahl', 1, 1, 0, 2908.0)
# (2009, 223, 'Neftenbach', 'Einbruchdiebstahl', 19, 17, 2, 4882.0)
# (2009, 223, 'Neftenbach', 'Einschleichdiebstahl', 3, 2, 1, 4882.0)
# (2009, 89, 'Niederglatt', 'Einbruchdiebstahl', 26, 18, 8, 4467.0)
# (2009, 89, 'Niederglatt', 'Einschleichdiebstahl', 6, 6, 0, 4467.0)
# (2009, 90, 'Niederhasli', 'Einbruchdiebstahl', 94, 63, 31, 8294.0)
# (2009, 90, 'Niederhasli', 'Einschleichdiebstahl', 26, 26, 0, 8294.0)
# (2009, 91, 'Niederweningen', 'Einbruchdiebstahl', 15, 10, 5, 2652.0)
# (2009, 91, 'Niederweningen', 'Einschleichdiebstahl', 2, 1, 1, 2652.0)
# (2009, 64, 'Nürensdorf', 'Einbruchdiebstahl', 29, 17, 12, 4953.0)
# (2009, 64, 'Nürensdorf', 'Einschleichdiebstahl', 2, 2, 0, 4953.0)
# (2009, 65, 'Oberembrach', 'Einbruchdiebstahl', 7, 4, 3, 987.0)
# (2009, 65, 'Oberembrach', 'Einschleichdiebstahl', 3, 3, 0, 987.0)
# (2009, 245, 'Oberengstringen', 'Einbruchdiebstahl', 56, 34, 22, 6198.0)
# (2009, 245, 'Oberengstringen', 'Einschleichdiebstahl', 8, 7, 1, 6198.0)
# (2009, 92, 'Oberglatt', 'Einbruchdiebstahl', 39, 24, 15, 5518.0)
# (2009, 92, 'Oberglatt', 'Einschleichdiebstahl', 14, 13, 1, 5518.0)
# (2009, 137, 'Oberrieden', 'Einbruchdiebstahl', 25, 14, 11, 4932.0)
# (2009, 137, 'Oberrieden', 'Einschleichdiebstahl', 7, 7, 0, 4932.0)
# (2009, 93, 'Oberweningen', 'Einbruchdiebstahl', 5, 4, 1, 1611.0)
# (2009, 93, 'Oberweningen', 'Einschleichdiebstahl', 0, 0, 0, 1611.0)
# (2009, 10, 'Obfelden', 'Einbruchdiebstahl', 24, 10, 14, 4520.0)
# (2009, 10, 'Obfelden', 'Einschleichdiebstahl', 1, 1, 0, 4520.0)
# (2009, 157, 'Oetwil', 'Einbruchdiebstahl', 15, 7, 8, 4381.0)
# (2009, 157, 'Oetwil', 'Einschleichdiebstahl', 1, 1, 0, 4381.0)
# (2009, 246, 'Oetwil an der Limmat', 'Einbruchdiebstahl', 25, 18, 7, 2247.0)
# (2009, 246, 'Oetwil an der Limmat', 'Einschleichdiebstahl', 5, 5, 0, 2247.0)
# (2009, 66, 'Opfikon', 'Einbruchdiebstahl', 170, 117, 53, 14675.0)
# (2009, 66, 'Opfikon', 'Einschleichdiebstahl', 85, 69, 16, 14675.0)
# (2009, 37, 'Ossingen', 'Einbruchdiebstahl', 7, 6, 1, 1364.0)
# (2009, 37, 'Ossingen', 'Einschleichdiebstahl', 1, 1, 0, 1364.0)
# (2009, 94, 'Otelfingen', 'Einbruchdiebstahl', 14, 11, 3, 2278.0)
# (2009, 94, 'Otelfingen', 'Einschleichdiebstahl', 5, 5, 0, 2278.0)
# (2009, 11, 'Ottenbach', 'Einbruchdiebstahl', 13, 7, 6, 2311.0)
# (2009, 11, 'Ottenbach', 'Einschleichdiebstahl', 4, 4, 0, 2311.0)
# (2009, 224, 'Pfungen', 'Einbruchdiebstahl', 29, 18, 11, 2660.0)
# (2009, 224, 'Pfungen', 'Einschleichdiebstahl', 3, 3, 0, 2660.0)
# (2009, 177, 'Pfäffikon', 'Einbruchdiebstahl', 73, 49, 24, 10291.0)
# (2009, 177, 'Pfäffikon', 'Einschleichdiebstahl', 11, 11, 0, 10291.0)
# (2009, 67, 'Rafz', 'Einbruchdiebstahl', 11, 10, 1, 3961.0)
# (2009, 67, 'Rafz', 'Einschleichdiebstahl', 4, 4, 0, 3961.0)
# (2009, 95, 'Regensberg', 'Einbruchdiebstahl', 6, 5, 1, 458.0)
# (2009, 95, 'Regensberg', 'Einschleichdiebstahl', 0, 0, 0, 458.0)
# (2009, 96, 'Regensdorf', 'Einbruchdiebstahl', 179, 106, 73, 16040.0)
# (2009, 96, 'Regensdorf', 'Einschleichdiebstahl', 65, 64, 1, 16040.0)
# (2009, 38, 'Rheinau', 'Einbruchdiebstahl', 2, 2, 0, 1320.0)
# (2009, 38, 'Rheinau', 'Einschleichdiebstahl', 1, 1, 0, 1320.0)
# (2009, 138, 'Richterswil', 'Einbruchdiebstahl', 34, 21, 13, 11920.0)
# (2009, 138, 'Richterswil', 'Einschleichdiebstahl', 9, 7, 2, 11920.0)
# (2009, 225, 'Rickenbach', 'Einbruchdiebstahl', 11, 7, 4, 2464.0)
# (2009, 225, 'Rickenbach', 'Einschleichdiebstahl', 3, 3, 0, 2464.0)
# (2009, 12, 'Rifferswil', 'Einbruchdiebstahl', 1, 1, 0, 843.0)
# (2009, 12, 'Rifferswil', 'Einschleichdiebstahl', 1, 1, 0, 843.0)
# (2009, 68, 'Rorbas', 'Einbruchdiebstahl', 18, 12, 6, 2249.0)
# (2009, 68, 'Rorbas', 'Einschleichdiebstahl', 6, 6, 0, 2249.0)
# (2009, 178, 'Russikon', 'Einbruchdiebstahl', 7, 5, 2, 3963.0)
# (2009, 178, 'Russikon', 'Einschleichdiebstahl', 5, 5, 0, 3963.0)
# (2009, 97, 'Rümlang', 'Einbruchdiebstahl', 77, 49, 28, 6333.0)
# (2009, 97, 'Rümlang', 'Einschleichdiebstahl', 32, 32, 0, 6333.0)
# (2009, 139, 'Rüschlikon', 'Einbruchdiebstahl', 47, 34, 13, 5109.0)
# (2009, 139, 'Rüschlikon', 'Einschleichdiebstahl', 14, 13, 1, 5109.0)
# (2009, 118, 'Rüti', 'Einbruchdiebstahl', 40, 28, 12, 11678.0)
# (2009, 118, 'Rüti', 'Einschleichdiebstahl', 19, 19, 0, 11678.0)
# (2009, 226, 'Schlatt', 'Einbruchdiebstahl', 0, 0, 0, 718.0)
# (2009, 226, 'Schlatt', 'Einschleichdiebstahl', 0, 0, 0, 718.0)
# (2009, 98, 'Schleinikon', 'Einbruchdiebstahl', 2, 1, 1, 701.0)
# (2009, 98, 'Schleinikon', 'Einschleichdiebstahl', 0, 0, 0, 701.0)
# (2009, 247, 'Schlieren', 'Einbruchdiebstahl', 194, 131, 63, 14234.0)
# (2009, 247, 'Schlieren', 'Einschleichdiebstahl', 44, 44, 0, 14234.0)
# (2009, 197, 'Schwerzenbach', 'Einbruchdiebstahl', 33, 15, 18, 4414.0)
# (2009, 197, 'Schwerzenbach', 'Einschleichdiebstahl', 7, 6, 1, 4414.0)
# (2009, 99, 'Schöfflisdorf', 'Einbruchdiebstahl', 12, 4, 8, 1259.0)
# (2009, 99, 'Schöfflisdorf', 'Einschleichdiebstahl', 0, 0, 0, 1259.0)
# (2009, 119, 'Seegräben', 'Einbruchdiebstahl', 5, 3, 2, 1269.0)
# (2009, 119, 'Seegräben', 'Einschleichdiebstahl', 2, 2, 0, 1269.0)
# (2009, 227, 'Seuzach', 'Einbruchdiebstahl', 22, 12, 10, 6790.0)
# (2009, 227, 'Seuzach', 'Einschleichdiebstahl', 3, 3, 0, 6790.0)
# (2009, 100, 'Stadel', 'Einbruchdiebstahl', 1, 1, 0, 1922.0)
# (2009, 100, 'Stadel', 'Einschleichdiebstahl', 2, 1, 1, 1922.0)
# (2009, 13, 'Stallikon', 'Einbruchdiebstahl', 11, 6, 5, 2869.0)
# (2009, 13, 'Stallikon', 'Einschleichdiebstahl', 5, 5, 0, 2869.0)
# (2009, 292, 'Stammheim', 'Einbruchdiebstahl', 13, 10, 3, 2636.0)
# (2009, 292, 'Stammheim', 'Einschleichdiebstahl', 0, 0, 0, 2636.0)
# (2009, 101, 'Steinmaur', 'Einbruchdiebstahl', 20, 16, 4, 3151.0)
# (2009, 101, 'Steinmaur', 'Einschleichdiebstahl', 6, 6, 0, 3151.0)
# (2009, 158, 'Stäfa', 'Einbruchdiebstahl', 90, 63, 27, 13616.0)
# (2009, 158, 'Stäfa', 'Einschleichdiebstahl', 16, 15, 1, 13616.0)
# (2009, 39, 'Thalheim', 'Einbruchdiebstahl', 1, 1, 0, 799.0)
# (2009, 39, 'Thalheim', 'Einschleichdiebstahl', 1, 1, 0, 799.0)
# (2009, 141, 'Thalwil', 'Einbruchdiebstahl', 103, 60, 43, 16631.0)
# (2009, 141, 'Thalwil', 'Einschleichdiebstahl', 27, 25, 2, 16631.0)
# (2009, 41, 'Truttikon', 'Einbruchdiebstahl', 0, 0, 0, 460.0)
# (2009, 41, 'Truttikon', 'Einschleichdiebstahl', 1, 1, 0, 460.0)
# (2009, 40, 'Trüllikon', 'Einbruchdiebstahl', 2, 1, 1, 1007.0)
# (2009, 40, 'Trüllikon', 'Einschleichdiebstahl', 1, 1, 0, 1007.0)
# (2009, 228, 'Turbenthal', 'Einbruchdiebstahl', 25, 21, 4, 4116.0)
# (2009, 228, 'Turbenthal', 'Einschleichdiebstahl', 4, 4, 0, 4116.0)
# (2009, 159, 'Uetikon', 'Einbruchdiebstahl', 24, 17, 7, 5654.0)
# (2009, 159, 'Uetikon', 'Einschleichdiebstahl', 5, 5, 0, 5654.0)
# (2009, 248, 'Uitikon', 'Einbruchdiebstahl', 42, 30, 12, 3837.0)
# (2009, 248, 'Uitikon', 'Einschleichdiebstahl', 11, 11, 0, 3837.0)
# (2009, 249, 'Unterengstringen', 'Einbruchdiebstahl', 45, 30, 15, 3070.0)
# (2009, 249, 'Unterengstringen', 'Einschleichdiebstahl', 11, 11, 0, 3070.0)
# (2009, 250, 'Urdorf', 'Einbruchdiebstahl', 98, 54, 44, 9215.0)
# (2009, 250, 'Urdorf', 'Einschleichdiebstahl', 16, 16, 0, 9215.0)
# (2009, 198, 'Uster', 'Einbruchdiebstahl', 194, 134, 60, 31406.0)
# (2009, 198, 'Uster', 'Einschleichdiebstahl', 45, 45, 0, 31406.0)
# (2009, 43, 'Volken', 'Einbruchdiebstahl', 0, 0, 0, 296.0)
# (2009, 43, 'Volken', 'Einschleichdiebstahl', 0, 0, 0, 296.0)
# (2009, 199, 'Volketswil', 'Einbruchdiebstahl', 102, 62, 40, 16348.0)
# (2009, 199, 'Volketswil', 'Einschleichdiebstahl', 49, 49, 0, 16348.0)
# (2009, 120, 'Wald', 'Einbruchdiebstahl', 26, 16, 10, 8956.0)
# (2009, 120, 'Wald', 'Einschleichdiebstahl', 3, 3, 0, 8956.0)
# (2009, 69, 'Wallisellen', 'Einbruchdiebstahl', 132, 89, 43, 12817.0)
# (2009, 69, 'Wallisellen', 'Einschleichdiebstahl', 25, 23, 2, 12817.0)
# (2009, 200, 'Wangen-Brüttisellen', 'Einbruchdiebstahl', 43, 25, 18, 7259.0)
# (2009, 200, 'Wangen-Brüttisellen', 'Einschleichdiebstahl', 21, 20, 1, 7259.0)
# (2009, 70, 'Wasterkingen', 'Einbruchdiebstahl', 0, 0, 0, 557.0)
# (2009, 70, 'Wasterkingen', 'Einschleichdiebstahl', 0, 0, 0, 557.0)
# (2009, 102, 'Weiach', 'Einbruchdiebstahl', 2, 2, 0, 982.0)
# (2009, 102, 'Weiach', 'Einschleichdiebstahl', 0, 0, 0, 982.0)
# (2009, 251, 'Weiningen', 'Einbruchdiebstahl', 34, 22, 12, 4153.0)
# (2009, 251, 'Weiningen', 'Einschleichdiebstahl', 18, 18, 0, 4153.0)
# (2009, 180, 'Weisslingen', 'Einbruchdiebstahl', 11, 5, 6, 3117.0)
# (2009, 180, 'Weisslingen', 'Einschleichdiebstahl', 1, 1, 0, 3117.0)
# (2009, 14, 'Wettswil', 'Einbruchdiebstahl', 24, 17, 7, 4323.0)
# (2009, 14, 'Wettswil', 'Einschleichdiebstahl', 3, 3, 0, 4323.0)
# (2009, 121, 'Wetzikon', 'Einbruchdiebstahl', 140, 83, 57, 21276.0)
# (2009, 121, 'Wetzikon', 'Einschleichdiebstahl', 37, 34, 3, 21276.0)
# (2009, 298, 'Wiesendangen', 'Einbruchdiebstahl', 25, 19, 6, 5540.0)
# (2009, 298, 'Wiesendangen', 'Einschleichdiebstahl', 6, 6, 0, 5540.0)
# (2009, 71, 'Wil', 'Einbruchdiebstahl', 0, 0, 0, 1275.0)
# (2009, 71, 'Wil', 'Einschleichdiebstahl', 1, 1, 0, 1275.0)
# (2009, 181, 'Wila', 'Einbruchdiebstahl', 7, 4, 3, 1899.0)
# (2009, 181, 'Wila', 'Einschleichdiebstahl', 1, 1, 0, 1899.0)
# (2009, 182, 'Wildberg', 'Einbruchdiebstahl', 5, 4, 1, 939.0)
# (2009, 182, 'Wildberg', 'Einschleichdiebstahl', 2, 2, 0, 939.0)
# (2009, 72, 'Winkel', 'Einbruchdiebstahl', 29, 23, 6, 3880.0)
# (2009, 72, 'Winkel', 'Einschleichdiebstahl', 6, 6, 0, 3880.0)
# (2009, 230, 'Winterthur', 'Einbruchdiebstahl', 680, 447, 233, 98238.0)
# (2009, 230, 'Winterthur', 'Einschleichdiebstahl', 179, 169, 10, 98238.0)
# (2009, 293, 'Wädenswil', 'Einbruchdiebstahl', 88, 56, 32, 22754.0)
# (2009, 293, 'Wädenswil', 'Einschleichdiebstahl', 18, 17, 1, 22754.0)
# (2009, 231, 'Zell', 'Einbruchdiebstahl', 19, 11, 8, 5167.0)
# (2009, 231, 'Zell', 'Einschleichdiebstahl', 6, 6, 0, 5167.0)
# (2009, 161, 'Zollikon', 'Einbruchdiebstahl', 142, 92, 50, 12154.0)
# (2009, 161, 'Zollikon', 'Einschleichdiebstahl', 12, 11, 1, 12154.0)
# (2009, 160, 'Zumikon', 'Einbruchdiebstahl', 30, 21, 9, 4990.0)
# (2009, 160, 'Zumikon', 'Einschleichdiebstahl', 8, 8, 0, 4990.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 297, 190, 107, 5536.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 83, 77, 6, 5536.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 435, 286, 149, 29531.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 50, 48, 2, 29531.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 646, 429, 217, 46595.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 89, 87, 2, 46595.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 554, 370, 184, 27354.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 93, 90, 3, 27354.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 355, 247, 108, 12722.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 52, 52, 0, 12722.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 445, 294, 151, 30757.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 68, 66, 2, 30757.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 446, 289, 157, 35240.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 75, 71, 4, 35240.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 356, 210, 146, 15315.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 55, 52, 3, 15315.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 640, 384, 256, 47295.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 62, 61, 1, 47295.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 506, 324, 182, 36686.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 78, 74, 4, 36686.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 896, 564, 332, 64283.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 164, 160, 4, 64283.0)
# (2009, 261, 'Zürich', 'Einbruchdiebstahl', 235, 174, 61, 29185.0)
# (2009, 261, 'Zürich', 'Einschleichdiebstahl', 48, 44, 4, 29185.0)
# (2010, 131, 'Adliswil', 'Einbruchdiebstahl', 135, 82, 53, 16161.0)
# (2010, 131, 'Adliswil', 'Einschleichdiebstahl', 29, 28, 1, 16161.0)
# (2010, 241, 'Aesch', 'Einbruchdiebstahl', 1, 1, 0, 1001.0)
# (2010, 241, 'Aesch', 'Einschleichdiebstahl', 0, 0, 0, 1001.0)
# (2010, 1, 'Aeugst', 'Einbruchdiebstahl', 6, 5, 1, 1740.0)
# (2010, 1, 'Aeugst', 'Einschleichdiebstahl', 3, 3, 0, 1740.0)
# (2010, 2, 'Affoltern', 'Einbruchdiebstahl', 100, 62, 38, 10735.0)
# (2010, 2, 'Affoltern', 'Einschleichdiebstahl', 26, 26, 0, 10735.0)
# (2010, 211, 'Altikon', 'Einbruchdiebstahl', 2, 2, 0, 622.0)
# (2010, 211, 'Altikon', 'Einschleichdiebstahl', 3, 3, 0, 622.0)
# (2010, 291, 'Andelfingen', 'Einbruchdiebstahl', 14, 11, 3, 2827.0)
# (2010, 291, 'Andelfingen', 'Einschleichdiebstahl', 2, 2, 0, 2827.0)
# (2010, 51, 'Bachenbülach', 'Einbruchdiebstahl', 25, 20, 5, 3792.0)
# (2010, 51, 'Bachenbülach', 'Einschleichdiebstahl', 14, 13, 1, 3792.0)
# (2010, 81, 'Bachs', 'Einbruchdiebstahl', 1, 1, 0, 574.0)
# (2010, 81, 'Bachs', 'Einschleichdiebstahl', 1, 1, 0, 574.0)
# (2010, 52, 'Bassersdorf', 'Einbruchdiebstahl', 74, 45, 29, 10902.0)
# (2010, 52, 'Bassersdorf', 'Einschleichdiebstahl', 58, 57, 1, 10902.0)
# (2010, 297, 'Bauma', 'Einbruchdiebstahl', 23, 12, 11, 4500.0)
# (2010, 297, 'Bauma', 'Einschleichdiebstahl', 11, 11, 0, 4500.0)
# (2010, 22, 'Benken', 'Einbruchdiebstahl', 0, 0, 0, 774.0)
# (2010, 22, 'Benken', 'Einschleichdiebstahl', 0, 0, 0, 774.0)
# (2010, 23, 'Berg', 'Einbruchdiebstahl', 0, 0, 0, 597.0)
# (2010, 23, 'Berg', 'Einschleichdiebstahl', 0, 0, 0, 597.0)
# (2010, 242, 'Birmensdorf', 'Einbruchdiebstahl', 34, 19, 15, 5840.0)
# (2010, 242, 'Birmensdorf', 'Einschleichdiebstahl', 12, 11, 1, 5840.0)
# (2010, 3, 'Bonstetten', 'Einbruchdiebstahl', 18, 7, 11, 5110.0)
# (2010, 3, 'Bonstetten', 'Einschleichdiebstahl', 3, 3, 0, 5110.0)
# (2010, 82, 'Boppelsen', 'Einbruchdiebstahl', 1, 0, 1, 1297.0)
# (2010, 82, 'Boppelsen', 'Einschleichdiebstahl', 0, 0, 0, 1297.0)
# (2010, 213, 'Brütten', 'Einbruchdiebstahl', 3, 2, 1, 1899.0)
# (2010, 213, 'Brütten', 'Einschleichdiebstahl', 7, 6, 1, 1899.0)
# (2010, 112, 'Bubikon', 'Einbruchdiebstahl', 44, 28, 16, 6399.0)
# (2010, 112, 'Bubikon', 'Einschleichdiebstahl', 10, 9, 1, 6399.0)
# (2010, 24, 'Buch', 'Einbruchdiebstahl', 3, 2, 1, 836.0)
# (2010, 24, 'Buch', 'Einschleichdiebstahl', 1, 1, 0, 836.0)
# (2010, 83, 'Buchs', 'Einbruchdiebstahl', 37, 30, 7, 5280.0)
# (2010, 83, 'Buchs', 'Einschleichdiebstahl', 8, 8, 0, 5280.0)
# (2010, 111, 'Bäretswil', 'Einbruchdiebstahl', 15, 9, 6, 4629.0)
# (2010, 111, 'Bäretswil', 'Einschleichdiebstahl', 3, 3, 0, 4629.0)
# (2010, 53, 'Bülach', 'Einbruchdiebstahl', 104, 64, 40, 16956.0)
# (2010, 53, 'Bülach', 'Einschleichdiebstahl', 61, 61, 0, 16956.0)
# (2010, 25, 'Dachsen', 'Einbruchdiebstahl', 6, 5, 1, 1916.0)
# (2010, 25, 'Dachsen', 'Einschleichdiebstahl', 0, 0, 0, 1916.0)
# (2010, 86, 'Dielsdorf', 'Einbruchdiebstahl', 34, 29, 5, 5519.0)
# (2010, 86, 'Dielsdorf', 'Einschleichdiebstahl', 21, 21, 0, 5519.0)
# (2010, 243, 'Dietikon', 'Einbruchdiebstahl', 198, 133, 65, 23196.0)
# (2010, 243, 'Dietikon', 'Einschleichdiebstahl', 34, 33, 1, 23196.0)
# (2010, 54, 'Dietlikon', 'Einbruchdiebstahl', 76, 49, 27, 7046.0)
# (2010, 54, 'Dietlikon', 'Einschleichdiebstahl', 33, 32, 1, 7046.0)
# (2010, 216, 'Dinhard', 'Einbruchdiebstahl', 2, 2, 0, 1398.0)
# (2010, 216, 'Dinhard', 'Einschleichdiebstahl', 0, 0, 0, 1398.0)
# (2010, 26, 'Dorf', 'Einbruchdiebstahl', 0, 0, 0, 634.0)
# (2010, 26, 'Dorf', 'Einschleichdiebstahl', 0, 0, 0, 634.0)
# (2010, 214, 'Dägerlen', 'Einbruchdiebstahl', 1, 1, 0, 998.0)
# (2010, 214, 'Dägerlen', 'Einschleichdiebstahl', 1, 1, 0, 998.0)
# (2010, 84, 'Dällikon', 'Einbruchdiebstahl', 17, 10, 7, 3577.0)
# (2010, 84, 'Dällikon', 'Einschleichdiebstahl', 8, 8, 0, 3577.0)
# (2010, 85, 'Dänikon', 'Einbruchdiebstahl', 6, 4, 2, 1898.0)
# (2010, 85, 'Dänikon', 'Einschleichdiebstahl', 4, 4, 0, 1898.0)
# (2010, 215, 'Dättlikon', 'Einbruchdiebstahl', 4, 3, 1, 692.0)
# (2010, 215, 'Dättlikon', 'Einschleichdiebstahl', 1, 1, 0, 692.0)
# (2010, 191, 'Dübendorf', 'Einbruchdiebstahl', 200, 132, 68, 24414.0)
# (2010, 191, 'Dübendorf', 'Einschleichdiebstahl', 77, 76, 1, 24414.0)
# (2010, 113, 'Dürnten', 'Einbruchdiebstahl', 37, 27, 10, 6540.0)
# (2010, 113, 'Dürnten', 'Einschleichdiebstahl', 3, 3, 0, 6540.0)
# (2010, 192, 'Egg', 'Einbruchdiebstahl', 51, 32, 19, 7988.0)
# (2010, 192, 'Egg', 'Einschleichdiebstahl', 7, 6, 1, 7988.0)
# (2010, 55, 'Eglisau', 'Einbruchdiebstahl', 7, 5, 2, 3940.0)
# (2010, 55, 'Eglisau', 'Einschleichdiebstahl', 6, 4, 2, 3940.0)
# (2010, 294, 'Elgg', 'Einbruchdiebstahl', 13, 9, 4, 4240.0)
# (2010, 294, 'Elgg', 'Einschleichdiebstahl', 2, 2, 0, 4240.0)
# (2010, 218, 'Ellikon', 'Einbruchdiebstahl', 10, 8, 2, 854.0)
# (2010, 218, 'Ellikon', 'Einschleichdiebstahl', 4, 4, 0, 854.0)
# (2010, 219, 'Elsau', 'Einbruchdiebstahl', 14, 12, 2, 3279.0)
# (2010, 219, 'Elsau', 'Einschleichdiebstahl', 2, 1, 1, 3279.0)
# (2010, 56, 'Embrach', 'Einbruchdiebstahl', 31, 17, 14, 8785.0)
# (2010, 56, 'Embrach', 'Einschleichdiebstahl', 23, 23, 0, 8785.0)
# (2010, 151, 'Erlenbach', 'Einbruchdiebstahl', 38, 24, 14, 5221.0)
# (2010, 151, 'Erlenbach', 'Einschleichdiebstahl', 6, 5, 1, 5221.0)
# (2010, 172, 'Fehraltorf', 'Einbruchdiebstahl', 32, 29, 3, 5668.0)
# (2010, 172, 'Fehraltorf', 'Einschleichdiebstahl', 17, 15, 2, 5668.0)
# (2010, 27, 'Feuerthalen', 'Einbruchdiebstahl', 6, 6, 0, 3450.0)
# (2010, 27, 'Feuerthalen', 'Einschleichdiebstahl', 2, 2, 0, 3450.0)
# (2010, 114, 'Fischenthal', 'Einbruchdiebstahl', 8, 6, 2, 2287.0)
# (2010, 114, 'Fischenthal', 'Einschleichdiebstahl', 2, 2, 0, 2287.0)
# (2010, 28, 'Flaach', 'Einbruchdiebstahl', 3, 3, 0, 1227.0)
# (2010, 28, 'Flaach', 'Einschleichdiebstahl', 0, 0, 0, 1227.0)
# (2010, 29, 'Flurlingen', 'Einbruchdiebstahl', 4, 3, 1, 1407.0)
# (2010, 29, 'Flurlingen', 'Einschleichdiebstahl', 2, 2, 0, 1407.0)
# (2010, 57, 'Freienstein-Teufen', 'Einbruchdiebstahl', 2, 1, 1, 2279.0)
# (2010, 57, 'Freienstein-Teufen', 'Einschleichdiebstahl', 5, 5, 0, 2279.0)
# (2010, 193, 'Fällanden', 'Einbruchdiebstahl', 20, 15, 5, 7821.0)
# (2010, 193, 'Fällanden', 'Einschleichdiebstahl', 19, 19, 0, 7821.0)
# (2010, 244, 'Geroldswil', 'Einbruchdiebstahl', 40, 25, 15, 4570.0)
# (2010, 244, 'Geroldswil', 'Einschleichdiebstahl', 3, 3, 0, 4570.0)
# (2010, 58, 'Glattfelden', 'Einbruchdiebstahl', 8, 4, 4, 4202.0)
# (2010, 58, 'Glattfelden', 'Einschleichdiebstahl', 2, 2, 0, 4202.0)
# (2010, 115, 'Gossau', 'Einbruchdiebstahl', 34, 28, 6, 9509.0)
# (2010, 115, 'Gossau', 'Einschleichdiebstahl', 11, 11, 0, 9509.0)
# (2010, 194, 'Greifensee', 'Einbruchdiebstahl', 26, 17, 9, 4946.0)
# (2010, 194, 'Greifensee', 'Einschleichdiebstahl', 5, 5, 0, 4946.0)
# (2010, 116, 'Grüningen', 'Einbruchdiebstahl', 7, 7, 0, 2969.0)
# (2010, 116, 'Grüningen', 'Einschleichdiebstahl', 4, 4, 0, 2969.0)
# (2010, 220, 'Hagenbuch', 'Einbruchdiebstahl', 8, 5, 3, 1096.0)
# (2010, 220, 'Hagenbuch', 'Einschleichdiebstahl', 1, 1, 0, 1096.0)
# (2010, 4, 'Hausen', 'Einbruchdiebstahl', 10, 5, 5, 3316.0)
# (2010, 4, 'Hausen', 'Einschleichdiebstahl', 4, 4, 0, 3316.0)
# (2010, 5, 'Hedingen', 'Einbruchdiebstahl', 19, 9, 10, 3413.0)
# (2010, 5, 'Hedingen', 'Einschleichdiebstahl', 1, 1, 0, 3413.0)
# (2010, 31, 'Henggart', 'Einbruchdiebstahl', 8, 7, 1, 2171.0)
# (2010, 31, 'Henggart', 'Einschleichdiebstahl', 1, 0, 1, 2171.0)
# (2010, 152, 'Herrliberg', 'Einbruchdiebstahl', 39, 27, 12, 5951.0)
# (2010, 152, 'Herrliberg', 'Einschleichdiebstahl', 12, 11, 1, 5951.0)
# (2010, 221, 'Hettlingen', 'Einbruchdiebstahl', 8, 6, 2, 2945.0)
# (2010, 221, 'Hettlingen', 'Einschleichdiebstahl', 2, 2, 0, 2945.0)
# (2010, 117, 'Hinwil', 'Einbruchdiebstahl', 55, 38, 17, 10128.0)
# (2010, 117, 'Hinwil', 'Einschleichdiebstahl', 5, 5, 0, 10128.0)
# (2010, 173, 'Hittnau', 'Einbruchdiebstahl', 4, 2, 2, 3414.0)
# (2010, 173, 'Hittnau', 'Einschleichdiebstahl', 3, 3, 0, 3414.0)
# (2010, 59, 'Hochfelden', 'Einbruchdiebstahl', 3, 1, 2, 1925.0)
# (2010, 59, 'Hochfelden', 'Einschleichdiebstahl', 0, 0, 0, 1925.0)
# (2010, 153, 'Hombrechtikon', 'Einbruchdiebstahl', 96, 68, 28, 7887.0)
# (2010, 153, 'Hombrechtikon', 'Einschleichdiebstahl', 11, 11, 0, 7887.0)
# (2010, 295, 'Horgen', 'Einbruchdiebstahl', 88, 58, 30, 20550.0)
# (2010, 295, 'Horgen', 'Einschleichdiebstahl', 25, 23, 2, 20550.0)
# (2010, 60, 'Höri', 'Einbruchdiebstahl', 33, 20, 13, 2420.0)
# (2010, 60, 'Höri', 'Einschleichdiebstahl', 8, 8, 0, 2420.0)
# (2010, 61, 'Hüntwangen', 'Einbruchdiebstahl', 3, 2, 1, 968.0)
# (2010, 61, 'Hüntwangen', 'Einschleichdiebstahl', 0, 0, 0, 968.0)
# (2010, 87, 'Hüttikon', 'Einbruchdiebstahl', 1, 1, 0, 668.0)
# (2010, 87, 'Hüttikon', 'Einschleichdiebstahl', 4, 4, 0, 668.0)
# (2010, 296, 'Illnau-Effretikon', 'Einbruchdiebstahl', 139, 90, 49, 15841.0)
# (2010, 296, 'Illnau-Effretikon', 'Einschleichdiebstahl', 28, 26, 2, 15841.0)
# (2010, 6, 'Kappel', 'Einbruchdiebstahl', 5, 2, 3, 881.0)
# (2010, 6, 'Kappel', 'Einschleichdiebstahl', 0, 0, 0, 881.0)
# (2010, 135, 'Kilchberg', 'Einbruchdiebstahl', 87, 47, 40, 7400.0)
# (2010, 135, 'Kilchberg', 'Einschleichdiebstahl', 8, 8, 0, 7400.0)
# (2010, 33, 'Kleinandelfingen', 'Einbruchdiebstahl', 14, 11, 3, 2073.0)
# (2010, 33, 'Kleinandelfingen', 'Einschleichdiebstahl', 5, 5, 0, 2073.0)
# (2010, 62, 'Kloten', 'Einbruchdiebstahl', 121, 76, 45, 17924.0)
# (2010, 62, 'Kloten', 'Einschleichdiebstahl', 50, 50, 0, 17924.0)
# (2010, 7, 'Knonau', 'Einbruchdiebstahl', 10, 6, 4, 1742.0)
# (2010, 7, 'Knonau', 'Einschleichdiebstahl', 2, 2, 0, 1742.0)
# (2010, 154, 'Küsnacht', 'Einbruchdiebstahl', 71, 46, 25, 13455.0)
# (2010, 154, 'Küsnacht', 'Einschleichdiebstahl', 19, 18, 1, 13455.0)
# (2010, 136, 'Langnau', 'Einbruchdiebstahl', 43, 25, 18, 7214.0)
# (2010, 136, 'Langnau', 'Einschleichdiebstahl', 5, 5, 0, 7214.0)
# (2010, 34, 'Laufen-Uhwiesen', 'Einbruchdiebstahl', 3, 3, 0, 1519.0)
# (2010, 34, 'Laufen-Uhwiesen', 'Einschleichdiebstahl', 2, 2, 0, 1519.0)
# (2010, 176, 'Lindau', 'Einbruchdiebstahl', 25, 16, 9, 4937.0)
# (2010, 176, 'Lindau', 'Einschleichdiebstahl', 22, 22, 0, 4937.0)
# (2010, 63, 'Lufingen', 'Einbruchdiebstahl', 9, 9, 0, 1707.0)
# (2010, 63, 'Lufingen', 'Einschleichdiebstahl', 11, 11, 0, 1707.0)
# (2010, 35, 'Marthalen', 'Einbruchdiebstahl', 9, 6, 3, 1892.0)
# (2010, 35, 'Marthalen', 'Einschleichdiebstahl', 3, 3, 0, 1892.0)
# (2010, 8, 'Maschwanden', 'Einbruchdiebstahl', 3, 2, 1, 588.0)
# (2010, 8, 'Maschwanden', 'Einschleichdiebstahl', 0, 0, 0, 588.0)
# (2010, 195, 'Maur', 'Einbruchdiebstahl', 61, 36, 25, 9306.0)
# (2010, 195, 'Maur', 'Einschleichdiebstahl', 16, 16, 0, 9306.0)
# (2010, 156, 'Meilen', 'Einbruchdiebstahl', 95, 65, 30, 12253.0)
# (2010, 156, 'Meilen', 'Einschleichdiebstahl', 26, 24, 2, 12253.0)
# (2010, 9, 'Mettmenstetten', 'Einbruchdiebstahl', 16, 12, 4, 4150.0)
# (2010, 9, 'Mettmenstetten', 'Einschleichdiebstahl', 4, 4, 0, 4150.0)
# (2010, 155, 'Männedorf', 'Einbruchdiebstahl', 87, 65, 22, 10235.0)
# (2010, 155, 'Männedorf', 'Einschleichdiebstahl', 23, 20, 3, 10235.0)
# (2010, 196, 'Mönchaltorf', 'Einbruchdiebstahl', 16, 12, 4, 3424.0)
# (2010, 196, 'Mönchaltorf', 'Einschleichdiebstahl', 2, 2, 0, 3424.0)
# (2010, 88, 'Neerach', 'Einbruchdiebstahl', 11, 7, 4, 2947.0)
# (2010, 88, 'Neerach', 'Einschleichdiebstahl', 4, 4, 0, 2947.0)
# (2010, 223, 'Neftenbach', 'Einbruchdiebstahl', 19, 10, 9, 5054.0)
# (2010, 223, 'Neftenbach', 'Einschleichdiebstahl', 7, 6, 1, 5054.0)
# (2010, 89, 'Niederglatt', 'Einbruchdiebstahl', 27, 16, 11, 4544.0)
# (2010, 89, 'Niederglatt', 'Einschleichdiebstahl', 17, 17, 0, 4544.0)
# (2010, 90, 'Niederhasli', 'Einbruchdiebstahl', 37, 24, 13, 8419.0)
# (2010, 90, 'Niederhasli', 'Einschleichdiebstahl', 22, 22, 0, 8419.0)
# (2010, 91, 'Niederweningen', 'Einbruchdiebstahl', 8, 5, 3, 2649.0)
# (2010, 91, 'Niederweningen', 'Einschleichdiebstahl', 0, 0, 0, 2649.0)
# (2010, 64, 'Nürensdorf', 'Einbruchdiebstahl', 20, 12, 8, 5164.0)
# (2010, 64, 'Nürensdorf', 'Einschleichdiebstahl', 7, 7, 0, 5164.0)
# (2010, 65, 'Oberembrach', 'Einbruchdiebstahl', 3, 3, 0, 980.0)
# (2010, 65, 'Oberembrach', 'Einschleichdiebstahl', 0, 0, 0, 980.0)
# (2010, 245, 'Oberengstringen', 'Einbruchdiebstahl', 57, 42, 15, 6226.0)
# (2010, 245, 'Oberengstringen', 'Einschleichdiebstahl', 8, 8, 0, 6226.0)
# (2010, 92, 'Oberglatt', 'Einbruchdiebstahl', 34, 24, 10, 5621.0)
# (2010, 92, 'Oberglatt', 'Einschleichdiebstahl', 10, 10, 0, 5621.0)
# (2010, 137, 'Oberrieden', 'Einbruchdiebstahl', 10, 7, 3, 4919.0)
# (2010, 137, 'Oberrieden', 'Einschleichdiebstahl', 2, 2, 0, 4919.0)
# (2010, 93, 'Oberweningen', 'Einbruchdiebstahl', 8, 6, 2, 1672.0)
# (2010, 93, 'Oberweningen', 'Einschleichdiebstahl', 3, 3, 0, 1672.0)
# (2010, 10, 'Obfelden', 'Einbruchdiebstahl', 8, 6, 2, 4646.0)
# (2010, 10, 'Obfelden', 'Einschleichdiebstahl', 3, 3, 0, 4646.0)
# (2010, 157, 'Oetwil', 'Einbruchdiebstahl', 9, 4, 5, 4422.0)
# (2010, 157, 'Oetwil', 'Einschleichdiebstahl', 7, 7, 0, 4422.0)
# (2010, 246, 'Oetwil an der Limmat', 'Einbruchdiebstahl', 7, 6, 1, 2283.0)
# (2010, 246, 'Oetwil an der Limmat', 'Einschleichdiebstahl', 6, 6, 0, 2283.0)
# (2010, 66, 'Opfikon', 'Einbruchdiebstahl', 194, 123, 71, 15256.0)
# (2010, 66, 'Opfikon', 'Einschleichdiebstahl', 44, 44, 0, 15256.0)
# (2010, 37, 'Ossingen', 'Einbruchdiebstahl', 3, 1, 2, 1360.0)
# (2010, 37, 'Ossingen', 'Einschleichdiebstahl', 0, 0, 0, 1360.0)
# (2010, 94, 'Otelfingen', 'Einbruchdiebstahl', 16, 14, 2, 2335.0)
# (2010, 94, 'Otelfingen', 'Einschleichdiebstahl', 5, 5, 0, 2335.0)
# (2010, 11, 'Ottenbach', 'Einbruchdiebstahl', 8, 4, 4, 2385.0)
# (2010, 11, 'Ottenbach', 'Einschleichdiebstahl', 1, 1, 0, 2385.0)
# (2010, 224, 'Pfungen', 'Einbruchdiebstahl', 13, 8, 5, 2748.0)
# (2010, 224, 'Pfungen', 'Einschleichdiebstahl', 3, 3, 0, 2748.0)
# (2010, 177, 'Pfäffikon', 'Einbruchdiebstahl', 48, 34, 14, 10388.0)
# (2010, 177, 'Pfäffikon', 'Einschleichdiebstahl', 26, 25, 1, 10388.0)
# (2010, 67, 'Rafz', 'Einbruchdiebstahl', 13, 10, 3, 3977.0)
# (2010, 67, 'Rafz', 'Einschleichdiebstahl', 3, 3, 0, 3977.0)
# (2010, 95, 'Regensberg', 'Einbruchdiebstahl', 0, 0, 0, 479.0)
# (2010, 95, 'Regensberg', 'Einschleichdiebstahl', 0, 0, 0, 479.0)
# (2010, 96, 'Regensdorf', 'Einbruchdiebstahl', 170, 97, 73, 16384.0)
# (2010, 96, 'Regensdorf', 'Einschleichdiebstahl', 44, 41, 3, 16384.0)
# (2010, 38, 'Rheinau', 'Einbruchdiebstahl', 2, 1, 1, 1336.0)
# (2010, 38, 'Rheinau', 'Einschleichdiebstahl', 1, 1, 0, 1336.0)
# (2010, 138, 'Richterswil', 'Einbruchdiebstahl', 42, 30, 12, 12080.0)
# (2010, 138, 'Richterswil', 'Einschleichdiebstahl', 13, 12, 1, 12080.0)
# (2010, 225, 'Rickenbach', 'Einbruchdiebstahl', 11, 7, 4, 2490.0)
# (2010, 225, 'Rickenbach', 'Einschleichdiebstahl', 1, 1, 0, 2490.0)
# (2010, 12, 'Rifferswil', 'Einbruchdiebstahl', 2, 2, 0, 876.0)
# (2010, 12, 'Rifferswil', 'Einschleichdiebstahl', 0, 0, 0, 876.0)
# (2010, 68, 'Rorbas', 'Einbruchdiebstahl', 15, 11, 4, 2255.0)
# (2010, 68, 'Rorbas', 'Einschleichdiebstahl', 2, 2, 0, 2255.0)
# (2010, 178, 'Russikon', 'Einbruchdiebstahl', 15, 12, 3, 4021.0)
# (2010, 178, 'Russikon', 'Einschleichdiebstahl', 4, 4, 0, 4021.0)
# (2010, 97, 'Rümlang', 'Einbruchdiebstahl', 87, 62, 25, 6617.0)
# (2010, 97, 'Rümlang', 'Einschleichdiebstahl', 21, 21, 0, 6617.0)
# (2010, 139, 'Rüschlikon', 'Einbruchdiebstahl', 53, 36, 17, 5210.0)
# (2010, 139, 'Rüschlikon', 'Einschleichdiebstahl', 16, 14, 2, 5210.0)
# (2010, 118, 'Rüti', 'Einbruchdiebstahl', 72, 30, 42, 11833.0)
# (2010, 118, 'Rüti', 'Einschleichdiebstahl', 14, 11, 3, 11833.0)
# (2010, 226, 'Schlatt', 'Einbruchdiebstahl', 0, 0, 0, 735.0)
# (2010, 226, 'Schlatt', 'Einschleichdiebstahl', 0, 0, 0, 735.0)
# (2010, 98, 'Schleinikon', 'Einbruchdiebstahl', 1, 1, 0, 706.0)
# (2010, 98, 'Schleinikon', 'Einschleichdiebstahl', 0, 0, 0, 706.0)
# (2010, 247, 'Schlieren', 'Einbruchdiebstahl', 163, 101, 62, 15293.0)
# (2010, 247, 'Schlieren', 'Einschleichdiebstahl', 58, 58, 0, 15293.0)
# (2010, 197, 'Schwerzenbach', 'Einbruchdiebstahl', 36, 17, 19, 4493.0)
# (2010, 197, 'Schwerzenbach', 'Einschleichdiebstahl', 10, 10, 0, 4493.0)
# (2010, 99, 'Schöfflisdorf', 'Einbruchdiebstahl', 4, 3, 1, 1314.0)
# (2010, 99, 'Schöfflisdorf', 'Einschleichdiebstahl', 4, 4, 0, 1314.0)
# (2010, 119, 'Seegräben', 'Einbruchdiebstahl', 13, 10, 3, 1303.0)
# (2010, 119, 'Seegräben', 'Einschleichdiebstahl', 2, 2, 0, 1303.0)
# (2010, 227, 'Seuzach', 'Einbruchdiebstahl', 28, 19, 9, 6885.0)
# (2010, 227, 'Seuzach', 'Einschleichdiebstahl', 9, 9, 0, 6885.0)
# (2010, 100, 'Stadel', 'Einbruchdiebstahl', 3, 2, 1, 1967.0)
# (2010, 100, 'Stadel', 'Einschleichdiebstahl', 1, 1, 0, 1967.0)
# (2010, 13, 'Stallikon', 'Einbruchdiebstahl', 7, 6, 1, 3024.0)
# (2010, 13, 'Stallikon', 'Einschleichdiebstahl', 2, 2, 0, 3024.0)
# (2010, 292, 'Stammheim', 'Einbruchdiebstahl', 11, 7, 4, 2639.0)
# (2010, 292, 'Stammheim', 'Einschleichdiebstahl', 2, 2, 0, 2639.0)
# (2010, 101, 'Steinmaur', 'Einbruchdiebstahl', 18, 15, 3, 3169.0)
# (2010, 101, 'Steinmaur', 'Einschleichdiebstahl', 9, 9, 0, 3169.0)
# (2010, 158, 'Stäfa', 'Einbruchdiebstahl', 72, 50, 22, 13785.0)
# (2010, 158, 'Stäfa', 'Einschleichdiebstahl', 31, 30, 1, 13785.0)
# (2010, 39, 'Thalheim', 'Einbruchdiebstahl', 1, 1, 0, 806.0)
# (2010, 39, 'Thalheim', 'Einschleichdiebstahl', 1, 1, 0, 806.0)
# (2010, 141, 'Thalwil', 'Einbruchdiebstahl', 65, 45, 20, 16896.0)
# (2010, 141, 'Thalwil', 'Einschleichdiebstahl', 10, 10, 0, 16896.0)
# (2010, 41, 'Truttikon', 'Einbruchdiebstahl', 3, 0, 3, 474.0)
# (2010, 41, 'Truttikon', 'Einschleichdiebstahl', 1, 1, 0, 474.0)
# (2010, 40, 'Trüllikon', 'Einbruchdiebstahl', 6, 2, 4, 1000.0)
# (2010, 40, 'Trüllikon', 'Einschleichdiebstahl', 2, 2, 0, 1000.0)
# (2010, 228, 'Turbenthal', 'Einbruchdiebstahl', 10, 8, 2, 4146.0)
# (2010, 228, 'Turbenthal', 'Einschleichdiebstahl', 6, 5, 1, 4146.0)
# (2010, 159, 'Uetikon', 'Einbruchdiebstahl', 40, 30, 10, 5703.0)
# (2010, 159, 'Uetikon', 'Einschleichdiebstahl', 4, 4, 0, 5703.0)
# (2010, 248, 'Uitikon', 'Einbruchdiebstahl', 17, 8, 9, 3860.0)
# (2010, 248, 'Uitikon', 'Einschleichdiebstahl', 4, 4, 0, 3860.0)
# (2010, 249, 'Unterengstringen', 'Einbruchdiebstahl', 25, 15, 10, 3229.0)
# (2010, 249, 'Unterengstringen', 'Einschleichdiebstahl', 4, 4, 0, 3229.0)
# (2010, 250, 'Urdorf', 'Einbruchdiebstahl', 112, 74, 38, 9094.0)
# (2010, 250, 'Urdorf', 'Einschleichdiebstahl', 28, 26, 2, 9094.0)
# (2010, 198, 'Uster', 'Einbruchdiebstahl', 172, 108, 64, 31954.0)
# (2010, 198, 'Uster', 'Einschleichdiebstahl', 86, 84, 2, 31954.0)
# (2010, 43, 'Volken', 'Einbruchdiebstahl', 0, 0, 0, 309.0)
# (2010, 43, 'Volken', 'Einschleichdiebstahl', 0, 0, 0, 309.0)
# (2010, 199, 'Volketswil', 'Einbruchdiebstahl', 195, 129, 66, 16938.0)
# (2010, 199, 'Volketswil', 'Einschleichdiebstahl', 69, 67, 2, 16938.0)
# (2010, 120, 'Wald', 'Einbruchdiebstahl', 25, 14, 11, 8928.0)
# (2010, 120, 'Wald', 'Einschleichdiebstahl', 9, 7, 2, 8928.0)
# (2010, 69, 'Wallisellen', 'Einbruchdiebstahl', 169, 101, 68, 13283.0)
# (2010, 69, 'Wallisellen', 'Einschleichdiebstahl', 30, 29, 1, 13283.0)
# (2010, 200, 'Wangen-Brüttisellen', 'Einbruchdiebstahl', 48, 32, 16, 7405.0)
# (2010, 200, 'Wangen-Brüttisellen', 'Einschleichdiebstahl', 25, 25, 0, 7405.0)
# (2010, 70, 'Wasterkingen', 'Einbruchdiebstahl', 0, 0, 0, 548.0)
# (2010, 70, 'Wasterkingen', 'Einschleichdiebstahl', 0, 0, 0, 548.0)
# (2010, 102, 'Weiach', 'Einbruchdiebstahl', 5, 4, 1, 992.0)
# (2010, 102, 'Weiach', 'Einschleichdiebstahl', 0, 0, 0, 992.0)
# (2010, 251, 'Weiningen', 'Einbruchdiebstahl', 26, 18, 8, 4182.0)
# (2010, 251, 'Weiningen', 'Einschleichdiebstahl', 13, 13, 0, 4182.0)
# (2010, 180, 'Weisslingen', 'Einbruchdiebstahl', 5, 3, 2, 3161.0)
# (2010, 180, 'Weisslingen', 'Einschleichdiebstahl', 0, 0, 0, 3161.0)
# (2010, 14, 'Wettswil', 'Einbruchdiebstahl', 25, 11, 14, 4457.0)
# (2010, 14, 'Wettswil', 'Einschleichdiebstahl', 3, 3, 0, 4457.0)
# (2010, 121, 'Wetzikon', 'Einbruchdiebstahl', 133, 84, 49, 21586.0)
# (2010, 121, 'Wetzikon', 'Einschleichdiebstahl', 30, 26, 4, 21586.0)
# (2010, 298, 'Wiesendangen', 'Einbruchdiebstahl', 31, 25, 6, 5699.0)
# (2010, 298, 'Wiesendangen', 'Einschleichdiebstahl', 5, 5, 0, 5699.0)
# (2010, 71, 'Wil', 'Einbruchdiebstahl', 0, 0, 0, 1297.0)
# (2010, 71, 'Wil', 'Einschleichdiebstahl', 1, 1, 0, 1297.0)
# (2010, 181, 'Wila', 'Einbruchdiebstahl', 14, 11, 3, 1912.0)
# (2010, 181, 'Wila', 'Einschleichdiebstahl', 1, 1, 0, 1912.0)
# (2010, 182, 'Wildberg', 'Einbruchdiebstahl', 1, 0, 1, 937.0)
# (2010, 182, 'Wildberg', 'Einschleichdiebstahl', 0, 0, 0, 937.0)
# (2010, 72, 'Winkel', 'Einbruchdiebstahl', 38, 25, 13, 3891.0)
# (2010, 72, 'Winkel', 'Einschleichdiebstahl', 24, 24, 0, 3891.0)
# (2010, 230, 'Winterthur', 'Einbruchdiebstahl', 648, 450, 198, 99377.0)
# (2010, 230, 'Winterthur', 'Einschleichdiebstahl', 213, 208, 5, 99377.0)
# (2010, 293, 'Wädenswil', 'Einbruchdiebstahl', 134, 88, 46, 22953.0)
# (2010, 293, 'Wädenswil', 'Einschleichdiebstahl', 26, 25, 1, 22953.0)
# (2010, 231, 'Zell', 'Einbruchdiebstahl', 34, 25, 9, 5259.0)
# (2010, 231, 'Zell', 'Einschleichdiebstahl', 11, 9, 2, 5259.0)
# (2010, 161, 'Zollikon', 'Einbruchdiebstahl', 66, 36, 30, 12049.0)
# (2010, 161, 'Zollikon', 'Einschleichdiebstahl', 6, 6, 0, 12049.0)
# (2010, 160, 'Zumikon', 'Einbruchdiebstahl', 35, 23, 12, 5072.0)
# (2010, 160, 'Zumikon', 'Einschleichdiebstahl', 4, 3, 1, 5072.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 223, 139, 84, 5607.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 69, 67, 2, 5607.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 301, 204, 97, 29421.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 43, 43, 0, 29421.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 535, 314, 221, 46108.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 73, 69, 4, 46108.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 422, 274, 148, 27056.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 83, 80, 3, 27056.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 174, 119, 55, 12714.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 36, 31, 5, 12714.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 351, 232, 119, 30203.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 47, 45, 2, 30203.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 345, 225, 120, 34843.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 51, 49, 2, 34843.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 210, 133, 77, 15431.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 24, 22, 2, 15431.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 549, 337, 212, 46875.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 61, 56, 5, 46875.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 385, 268, 117, 36474.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 33, 33, 0, 36474.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 763, 452, 311, 63092.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 141, 132, 9, 63092.0)
# (2010, 261, 'Zürich', 'Einbruchdiebstahl', 269, 172, 97, 28991.0)
# (2010, 261, 'Zürich', 'Einschleichdiebstahl', 30, 28, 2, 28991.0)
# (2011, 131, 'Adliswil', 'Einbruchdiebstahl', 148, 91, 57, 16502.0)
# (2011, 131, 'Adliswil', 'Einschleichdiebstahl', 40, 39, 1, 16502.0)
# (2011, 241, 'Aesch', 'Einbruchdiebstahl', 1, 1, 0, 1034.0)
# (2011, 241, 'Aesch', 'Einschleichdiebstahl', 0, 0, 0, 1034.0)
# (2011, 1, 'Aeugst', 'Einbruchdiebstahl', 6, 4, 2, 1824.0)
# (2011, 1, 'Aeugst', 'Einschleichdiebstahl', 2, 2, 0, 1824.0)
# (2011, 2, 'Affoltern', 'Einbruchdiebstahl', 103, 67, 36, 11091.0)
# (2011, 2, 'Affoltern', 'Einschleichdiebstahl', 26, 24, 2, 11091.0)
# (2011, 211, 'Altikon', 'Einbruchdiebstahl', 1, 1, 0, 604.0)
# (2011, 211, 'Altikon', 'Einschleichdiebstahl', 1, 1, 0, 604.0)
# (2011, 291, 'Andelfingen', 'Einbruchdiebstahl', 24, 16, 8, 2894.0)
# (2011, 291, 'Andelfingen', 'Einschleichdiebstahl', 5, 4, 1, 2894.0)
# (2011, 51, 'Bachenbülach', 'Einbruchdiebstahl', 20, 10, 10, 3885.0)
# (2011, 51, 'Bachenbülach', 'Einschleichdiebstahl', 5, 5, 0, 3885.0)
# (2011, 81, 'Bachs', 'Einbruchdiebstahl', 0, 0, 0, 574.0)
# (2011, 81, 'Bachs', 'Einschleichdiebstahl', 0, 0, 0, 574.0)
# (2011, 52, 'Bassersdorf', 'Einbruchdiebstahl', 79, 54, 25, 11077.0)
# (2011, 52, 'Bassersdorf', 'Einschleichdiebstahl', 9, 9, 0, 11077.0)
# (2011, 297, 'Bauma', 'Einbruchdiebstahl', 21, 9, 12, 4530.0)
# (2011, 297, 'Bauma', 'Einschleichdiebstahl', 4, 4, 0, 4530.0)
# (2011, 22, 'Benken', 'Einbruchdiebstahl', 6, 5, 1, 798.0)
# (2011, 22, 'Benken', 'Einschleichdiebstahl', 0, 0, 0, 798.0)
# (2011, 23, 'Berg', 'Einbruchdiebstahl', 0, 0, 0, 599.0)
# (2011, 23, 'Berg', 'Einschleichdiebstahl', 0, 0, 0, 599.0)
# (2011, 242, 'Birmensdorf', 'Einbruchdiebstahl', 42, 29, 13, 5882.0)
# (2011, 242, 'Birmensdorf', 'Einschleichdiebstahl', 16, 16, 0, 5882.0)
# (2011, 3, 'Bonstetten', 'Einbruchdiebstahl', 16, 11, 5, 5159.0)
# (2011, 3, 'Bonstetten', 'Einschleichdiebstahl', 8, 8, 0, 5159.0)
# (2011, 82, 'Boppelsen', 'Einbruchdiebstahl', 2, 1, 1, 1288.0)
# (2011, 82, 'Boppelsen', 'Einschleichdiebstahl', 4, 4, 0, 1288.0)
# (2011, 213, 'Brütten', 'Einbruchdiebstahl', 20, 14, 6, 1926.0)
# (2011, 213, 'Brütten', 'Einschleichdiebstahl', 5, 5, 0, 1926.0)
# (2011, 112, 'Bubikon', 'Einbruchdiebstahl', 23, 13, 10, 6586.0)
# (2011, 112, 'Bubikon', 'Einschleichdiebstahl', 13, 10, 3, 6586.0)
# (2011, 24, 'Buch', 'Einbruchdiebstahl', 0, 0, 0, 874.0)
# (2011, 24, 'Buch', 'Einschleichdiebstahl', 0, 0, 0, 874.0)
# (2011, 83, 'Buchs', 'Einbruchdiebstahl', 39, 33, 6, 5529.0)
# (2011, 83, 'Buchs', 'Einschleichdiebstahl', 6, 6, 0, 5529.0)
# (2011, 111, 'Bäretswil', 'Einbruchdiebstahl', 14, 9, 5, 4807.0)
# (2011, 111, 'Bäretswil', 'Einschleichdiebstahl', 4, 4, 0, 4807.0)
# (2011, 53, 'Bülach', 'Einbruchdiebstahl', 84, 57, 27, 17511.0)
# (2011, 53, 'Bülach', 'Einschleichdiebstahl', 50, 50, 0, 17511.0)
# (2011, 25, 'Dachsen', 'Einbruchdiebstahl', 10, 8, 2, 1939.0)
# (2011, 25, 'Dachsen', 'Einschleichdiebstahl', 0, 0, 0, 1939.0)
# (2011, 86, 'Dielsdorf', 'Einbruchdiebstahl', 34, 21, 13, 5643.0)
# (2011, 86, 'Dielsdorf', 'Einschleichdiebstahl', 31, 29, 2, 5643.0)
# (2011, 243, 'Dietikon', 'Einbruchdiebstahl', 199, 117, 82, 23624.0)
# (2011, 243, 'Dietikon', 'Einschleichdiebstahl', 54, 54, 0, 23624.0)
# (2011, 54, 'Dietlikon', 'Einbruchdiebstahl', 65, 41, 24, 7063.0)
# (2011, 54, 'Dietlikon', 'Einschleichdiebstahl', 16, 16, 0, 7063.0)
# (2011, 216, 'Dinhard', 'Einbruchdiebstahl', 4, 3, 1, 1394.0)
# (2011, 216, 'Dinhard', 'Einschleichdiebstahl', 3, 3, 0, 1394.0)
# (2011, 26, 'Dorf', 'Einbruchdiebstahl', 2, 2, 0, 632.0)
# (2011, 26, 'Dorf', 'Einschleichdiebstahl', 0, 0, 0, 632.0)
# (2011, 214, 'Dägerlen', 'Einbruchdiebstahl', 1, 1, 0, 1005.0)
# (2011, 214, 'Dägerlen', 'Einschleichdiebstahl', 1, 1, 0, 1005.0)
# ...
# (2023, 58, 'Glattfelden', 'Einbruchdiebstahl', 5, 2, 3, 5258.0)
# (2023, 58, 'Glattfelden', 'Einschleichdiebstahl', 4, 4, 0, 5258.0)
# (2023, 115, 'Gossau', 'Einbruchdiebstahl', 11, 8, 3, 10336.0)
# (2023, 115, 'Gossau', 'Einschleichdiebstahl', 4, 4, 0, 10336.0)
# (2023, 194, 'Greifensee', 'Einbruchdiebstahl', 9, 4, 5, 5329.0)
# (2023, 194, 'Greifensee', 'Einschleichdiebstahl', 5, 5, 0, 5329.0)
# (2023, 116, 'Grüningen', 'Einbruchdiebstahl', 0, 0, 0, 3845.0)
# (2023, 116, 'Grüningen', 'Einschleichdiebstahl', 4, 4, 0, 3845.0)
# (2023, 220, 'Hagenbuch', 'Einbruchdiebstahl', 0, 0, 0, 1148.0)
# (2023, 220, 'Hagenbuch', 'Einschleichdiebstahl', 1, 0, 1, 1148.0)
# (2023, 4, 'Hausen', 'Einbruchdiebstahl', 5, 5, 0, 3879.0)
# (2023, 4, 'Hausen', 'Einschleichdiebstahl', 7, 6, 1, 3879.0)
# (2023, 5, 'Hedingen', 'Einbruchdiebstahl', 10, 6, 4, 3871.0)
# (2023, 5, 'Hedingen', 'Einschleichdiebstahl', 9, 7, 2, 3871.0)
# (2023, 31, 'Henggart', 'Einbruchdiebstahl', 1, 0, 1, 2257.0)
# (2023, 31, 'Henggart', 'Einschleichdiebstahl', 2, 1, 1, 2257.0)
# (2023, 152, 'Herrliberg', 'Einbruchdiebstahl', 33, 20, 13, 6749.0)
# (2023, 152, 'Herrliberg', 'Einschleichdiebstahl', 7, 7, 0, 6749.0)
# (2023, 221, 'Hettlingen', 'Einbruchdiebstahl', 1, 1, 0, 3118.0)
# (2023, 221, 'Hettlingen', 'Einschleichdiebstahl', 3, 2, 1, 3118.0)
# (2023, 117, 'Hinwil', 'Einbruchdiebstahl', 19, 15, 4, 11576.0)
# (2023, 117, 'Hinwil', 'Einschleichdiebstahl', 11, 9, 2, 11576.0)
# (2023, 173, 'Hittnau', 'Einbruchdiebstahl', 5, 4, 1, 3756.0)
# (2023, 173, 'Hittnau', 'Einschleichdiebstahl', 1, 1, 0, 3756.0)
# (2023, 59, 'Hochfelden', 'Einbruchdiebstahl', 1, 0, 1, 1989.0)
# (2023, 59, 'Hochfelden', 'Einschleichdiebstahl', 0, 0, 0, 1989.0)
# (2023, 153, 'Hombrechtikon', 'Einbruchdiebstahl', 11, 4, 7, 8964.0)
# (2023, 153, 'Hombrechtikon', 'Einschleichdiebstahl', 6, 6, 0, 8964.0)
# (2023, 295, 'Horgen', 'Einbruchdiebstahl', 36, 20, 16, 23628.0)
# (2023, 295, 'Horgen', 'Einschleichdiebstahl', 14, 14, 0, 23628.0)
# (2023, 60, 'Höri', 'Einbruchdiebstahl', 13, 6, 7, 3307.0)
# (2023, 60, 'Höri', 'Einschleichdiebstahl', 2, 2, 0, 3307.0)
# (2023, 61, 'Hüntwangen', 'Einbruchdiebstahl', 5, 2, 3, 1093.0)
# (2023, 61, 'Hüntwangen', 'Einschleichdiebstahl', 1, 1, 0, 1093.0)
# (2023, 87, 'Hüttikon', 'Einbruchdiebstahl', 2, 2, 0, 959.0)
# (2023, 87, 'Hüttikon', 'Einschleichdiebstahl', 0, 0, 0, 959.0)
# (2023, 296, 'Illnau-Effretikon', 'Einbruchdiebstahl', 41, 23, 18, 17564.0)
# (2023, 296, 'Illnau-Effretikon', 'Einschleichdiebstahl', 16, 16, 0, 17564.0)
# (2023, 6, 'Kappel', 'Einbruchdiebstahl', 1, 1, 0, 1321.0)
# (2023, 6, 'Kappel', 'Einschleichdiebstahl', 0, 0, 0, 1321.0)
# (2023, 135, 'Kilchberg', 'Einbruchdiebstahl', 37, 24, 13, 9303.0)
# (2023, 135, 'Kilchberg', 'Einschleichdiebstahl', 8, 7, 1, 9303.0)
# (2023, 33, 'Kleinandelfingen', 'Einbruchdiebstahl', 2, 2, 0, 2132.0)
# (2023, 33, 'Kleinandelfingen', 'Einschleichdiebstahl', 2, 1, 1, 2132.0)
# (2023, 62, 'Kloten', 'Einbruchdiebstahl', 35, 22, 13, 20980.0)
# (2023, 62, 'Kloten', 'Einschleichdiebstahl', 30, 30, 0, 20980.0)
# (2023, 7, 'Knonau', 'Einbruchdiebstahl', 4, 2, 2, 2416.0)
# (2023, 7, 'Knonau', 'Einschleichdiebstahl', 1, 1, 0, 2416.0)
# (2023, 154, 'Küsnacht', 'Einbruchdiebstahl', 86, 52, 34, 14833.0)
# (2023, 154, 'Küsnacht', 'Einschleichdiebstahl', 18, 15, 3, 14833.0)
# (2023, 136, 'Langnau', 'Einbruchdiebstahl', 22, 16, 6, 8056.0)
# (2023, 136, 'Langnau', 'Einschleichdiebstahl', 1, 1, 0, 8056.0)
# (2023, 34, 'Laufen-Uhwiesen', 'Einbruchdiebstahl', 10, 5, 5, 1781.0)
# (2023, 34, 'Laufen-Uhwiesen', 'Einschleichdiebstahl', 5, 5, 0, 1781.0)
# (2023, 176, 'Lindau', 'Einbruchdiebstahl', 19, 9, 10, 5723.0)
# (2023, 176, 'Lindau', 'Einschleichdiebstahl', 14, 12, 2, 5723.0)
# (2023, 63, 'Lufingen', 'Einbruchdiebstahl', 4, 0, 4, 2767.0)
# (2023, 63, 'Lufingen', 'Einschleichdiebstahl', 8, 6, 2, 2767.0)
# (2023, 35, 'Marthalen', 'Einbruchdiebstahl', 1, 1, 0, 1950.0)
# (2023, 35, 'Marthalen', 'Einschleichdiebstahl', 4, 3, 1, 1950.0)
# (2023, 8, 'Maschwanden', 'Einbruchdiebstahl', 0, 0, 0, 644.0)
# (2023, 8, 'Maschwanden', 'Einschleichdiebstahl', 1, 1, 0, 644.0)
# (2023, 195, 'Maur', 'Einbruchdiebstahl', 36, 21, 15, 10757.0)
# (2023, 195, 'Maur', 'Einschleichdiebstahl', 15, 14, 1, 10757.0)
# (2023, 156, 'Meilen', 'Einbruchdiebstahl', 42, 27, 15, 14754.0)
# (2023, 156, 'Meilen', 'Einschleichdiebstahl', 17, 15, 2, 14754.0)
# (2023, 9, 'Mettmenstetten', 'Einbruchdiebstahl', 12, 7, 5, 5635.0)
# (2023, 9, 'Mettmenstetten', 'Einschleichdiebstahl', 8, 8, 0, 5635.0)
# (2023, 155, 'Männedorf', 'Einbruchdiebstahl', 37, 21, 16, 11437.0)
# (2023, 155, 'Männedorf', 'Einschleichdiebstahl', 9, 8, 1, 11437.0)
# (2023, 196, 'Mönchaltorf', 'Einbruchdiebstahl', 10, 7, 3, 4118.0)
# (2023, 196, 'Mönchaltorf', 'Einschleichdiebstahl', 2, 2, 0, 4118.0)
# (2023, 88, 'Neerach', 'Einbruchdiebstahl', 4, 2, 2, 3314.0)
# (2023, 88, 'Neerach', 'Einschleichdiebstahl', 2, 1, 1, 3314.0)
# (2023, 223, 'Neftenbach', 'Einbruchdiebstahl', 11, 7, 4, 5761.0)
# (2023, 223, 'Neftenbach', 'Einschleichdiebstahl', 1, 1, 0, 5761.0)
# (2023, 89, 'Niederglatt', 'Einbruchdiebstahl', 8, 4, 4, 5180.0)
# (2023, 89, 'Niederglatt', 'Einschleichdiebstahl', 3, 3, 0, 5180.0)
# (2023, 90, 'Niederhasli', 'Einbruchdiebstahl', 27, 15, 12, 9497.0)
# (2023, 90, 'Niederhasli', 'Einschleichdiebstahl', 6, 6, 0, 9497.0)
# (2023, 91, 'Niederweningen', 'Einbruchdiebstahl', 9, 6, 3, 3082.0)
# (2023, 91, 'Niederweningen', 'Einschleichdiebstahl', 3, 3, 0, 3082.0)
# (2023, 64, 'Nürensdorf', 'Einbruchdiebstahl', 9, 5, 4, 5710.0)
# (2023, 64, 'Nürensdorf', 'Einschleichdiebstahl', 3, 3, 0, 5710.0)
# (2023, 65, 'Oberembrach', 'Einbruchdiebstahl', 0, 0, 0, 1092.0)
# (2023, 65, 'Oberembrach', 'Einschleichdiebstahl', 2, 2, 0, 1092.0)
# (2023, 245, 'Oberengstringen', 'Einbruchdiebstahl', 29, 14, 15, 6810.0)
# (2023, 245, 'Oberengstringen', 'Einschleichdiebstahl', 3, 3, 0, 6810.0)
# (2023, 92, 'Oberglatt', 'Einbruchdiebstahl', 9, 4, 5, 7520.0)
# (2023, 92, 'Oberglatt', 'Einschleichdiebstahl', 12, 11, 1, 7520.0)
# (2023, 137, 'Oberrieden', 'Einbruchdiebstahl', 15, 10, 5, 5289.0)
# (2023, 137, 'Oberrieden', 'Einschleichdiebstahl', 6, 5, 1, 5289.0)
# (2023, 93, 'Oberweningen', 'Einbruchdiebstahl', 2, 0, 2, 1883.0)
# (2023, 93, 'Oberweningen', 'Einschleichdiebstahl', 0, 0, 0, 1883.0)
# (2023, 10, 'Obfelden', 'Einbruchdiebstahl', 7, 5, 2, 5787.0)
# (2023, 10, 'Obfelden', 'Einschleichdiebstahl', 5, 4, 1, 5787.0)
# (2023, 157, 'Oetwil', 'Einbruchdiebstahl', 6, 4, 2, 4947.0)
# (2023, 157, 'Oetwil', 'Einschleichdiebstahl', 3, 3, 0, 4947.0)
# (2023, 246, 'Oetwil an der Limmat', 'Einbruchdiebstahl', 14, 8, 6, 2560.0)
# (2023, 246, 'Oetwil an der Limmat', 'Einschleichdiebstahl', 3, 3, 0, 2560.0)
# (2023, 66, 'Opfikon', 'Einbruchdiebstahl', 53, 38, 15, 21213.0)
# (2023, 66, 'Opfikon', 'Einschleichdiebstahl', 16, 14, 2, 21213.0)
# (2023, 37, 'Ossingen', 'Einbruchdiebstahl', 3, 3, 0, 1710.0)
# (2023, 37, 'Ossingen', 'Einschleichdiebstahl', 4, 4, 0, 1710.0)
# (2023, 94, 'Otelfingen', 'Einbruchdiebstahl', 9, 5, 4, 2946.0)
# (2023, 94, 'Otelfingen', 'Einschleichdiebstahl', 2, 2, 0, 2946.0)
# (2023, 11, 'Ottenbach', 'Einbruchdiebstahl', 3, 2, 1, 2858.0)
# (2023, 11, 'Ottenbach', 'Einschleichdiebstahl', 1, 1, 0, 2858.0)
# (2023, 224, 'Pfungen', 'Einbruchdiebstahl', 7, 4, 3, 4053.0)
# (2023, 224, 'Pfungen', 'Einschleichdiebstahl', 7, 7, 0, 4053.0)
# (2023, 177, 'Pfäffikon', 'Einbruchdiebstahl', 29, 13, 16, 12379.0)
# (2023, 177, 'Pfäffikon', 'Einschleichdiebstahl', 10, 7, 3, 12379.0)
# (2023, 67, 'Rafz', 'Einbruchdiebstahl', 18, 4, 14, 4672.0)
# (2023, 67, 'Rafz', 'Einschleichdiebstahl', 6, 4, 2, 4672.0)
# (2023, 95, 'Regensberg', 'Einbruchdiebstahl', 0, 0, 0, 464.0)
# (2023, 95, 'Regensberg', 'Einschleichdiebstahl', 1, 1, 0, 464.0)
# (2023, 96, 'Regensdorf', 'Einbruchdiebstahl', 49, 26, 23, 18739.0)
# (2023, 96, 'Regensdorf', 'Einschleichdiebstahl', 29, 28, 1, 18739.0)
# (2023, 38, 'Rheinau', 'Einbruchdiebstahl', 1, 0, 1, 1285.0)
# (2023, 38, 'Rheinau', 'Einschleichdiebstahl', 1, 1, 0, 1285.0)
# (2023, 138, 'Richterswil', 'Einbruchdiebstahl', 29, 17, 12, 13987.0)
# (2023, 138, 'Richterswil', 'Einschleichdiebstahl', 11, 10, 1, 13987.0)
# (2023, 225, 'Rickenbach', 'Einbruchdiebstahl', 9, 4, 5, 2770.0)
# (2023, 225, 'Rickenbach', 'Einschleichdiebstahl', 3, 3, 0, 2770.0)
# (2023, 12, 'Rifferswil', 'Einbruchdiebstahl', 3, 1, 2, 1149.0)
# (2023, 12, 'Rifferswil', 'Einschleichdiebstahl', 0, 0, 0, 1149.0)
# (2023, 68, 'Rorbas', 'Einbruchdiebstahl', 4, 1, 3, 2908.0)
# (2023, 68, 'Rorbas', 'Einschleichdiebstahl', 7, 5, 2, 2908.0)
# (2023, 178, 'Russikon', 'Einbruchdiebstahl', 5, 2, 3, 4511.0)
# (2023, 178, 'Russikon', 'Einschleichdiebstahl', 3, 3, 0, 4511.0)
# (2023, 97, 'Rümlang', 'Einbruchdiebstahl', 38, 28, 10, 8186.0)
# (2023, 97, 'Rümlang', 'Einschleichdiebstahl', 24, 20, 4, 8186.0)
# (2023, 139, 'Rüschlikon', 'Einbruchdiebstahl', 33, 22, 11, 6218.0)
# (2023, 139, 'Rüschlikon', 'Einschleichdiebstahl', 9, 8, 1, 6218.0)
# (2023, 118, 'Rüti', 'Einbruchdiebstahl', 24, 19, 5, 12701.0)
# (2023, 118, 'Rüti', 'Einschleichdiebstahl', 10, 9, 1, 12701.0)
# (2023, 226, 'Schlatt', 'Einbruchdiebstahl', 0, 0, 0, 759.0)
# (2023, 226, 'Schlatt', 'Einschleichdiebstahl', 0, 0, 0, 759.0)
# (2023, 98, 'Schleinikon', 'Einbruchdiebstahl', 0, 0, 0, 863.0)
# (2023, 98, 'Schleinikon', 'Einschleichdiebstahl', 0, 0, 0, 863.0)
# (2023, 247, 'Schlieren', 'Einbruchdiebstahl', 67, 40, 27, 20350.0)
# (2023, 247, 'Schlieren', 'Einschleichdiebstahl', 22, 21, 1, 20350.0)
# (2023, 197, 'Schwerzenbach', 'Einbruchdiebstahl', 20, 13, 7, 5133.0)
# (2023, 197, 'Schwerzenbach', 'Einschleichdiebstahl', 6, 5, 1, 5133.0)
# (2023, 99, 'Schöfflisdorf', 'Einbruchdiebstahl', 5, 3, 2, 1361.0)
# (2023, 99, 'Schöfflisdorf', 'Einschleichdiebstahl', 3, 3, 0, 1361.0)
# (2023, 119, 'Seegräben', 'Einbruchdiebstahl', 5, 3, 2, 1422.0)
# (2023, 119, 'Seegräben', 'Einschleichdiebstahl', 1, 1, 0, 1422.0)
# (2023, 227, 'Seuzach', 'Einbruchdiebstahl', 21, 15, 6, 7692.0)
# (2023, 227, 'Seuzach', 'Einschleichdiebstahl', 3, 2, 1, 7692.0)
# (2023, 100, 'Stadel', 'Einbruchdiebstahl', 5, 3, 2, 2349.0)
# (2023, 100, 'Stadel', 'Einschleichdiebstahl', 5, 5, 0, 2349.0)
# (2023, 13, 'Stallikon', 'Einbruchdiebstahl', 14, 5, 9, 3854.0)
# (2023, 13, 'Stallikon', 'Einschleichdiebstahl', 4, 4, 0, 3854.0)
# (2023, 101, 'Steinmaur', 'Einbruchdiebstahl', 13, 8, 5, 3613.0)
# (2023, 101, 'Steinmaur', 'Einschleichdiebstahl', 5, 5, 0, 3613.0)
# (2023, 158, 'Stäfa', 'Einbruchdiebstahl', 47, 29, 18, 14889.0)
# (2023, 158, 'Stäfa', 'Einschleichdiebstahl', 13, 9, 4, 14889.0)
# (2023, 39, 'Thalheim', 'Einbruchdiebstahl', 1, 0, 1, 977.0)
# (2023, 39, 'Thalheim', 'Einschleichdiebstahl', 0, 0, 0, 977.0)
# (2023, 141, 'Thalwil', 'Einbruchdiebstahl', 56, 31, 25, 18392.0)
# (2023, 141, 'Thalwil', 'Einschleichdiebstahl', 17, 13, 4, 18392.0)
# (2023, 41, 'Truttikon', 'Einbruchdiebstahl', 2, 2, 0, 465.0)
# (2023, 41, 'Truttikon', 'Einschleichdiebstahl', 0, 0, 0, 465.0)
# (2023, 40, 'Trüllikon', 'Einbruchdiebstahl', 1, 1, 0, 1066.0)
# (2023, 40, 'Trüllikon', 'Einschleichdiebstahl', 0, 0, 0, 1066.0)
# (2023, 228, 'Turbenthal', 'Einbruchdiebstahl', 8, 1, 7, 5049.0)
# (2023, 228, 'Turbenthal', 'Einschleichdiebstahl', 3, 3, 0, 5049.0)
# (2023, 159, 'Uetikon', 'Einbruchdiebstahl', 16, 8, 8, 6325.0)
# (2023, 159, 'Uetikon', 'Einschleichdiebstahl', 9, 8, 1, 6325.0)
# (2023, 248, 'Uitikon', 'Einbruchdiebstahl', 34, 11, 23, 5105.0)
# (2023, 248, 'Uitikon', 'Einschleichdiebstahl', 9, 6, 3, 5105.0)
# (2023, 249, 'Unterengstringen', 'Einbruchdiebstahl', 16, 12, 4, 4119.0)
# (2023, 249, 'Unterengstringen', 'Einschleichdiebstahl', 2, 1, 1, 4119.0)
# (2023, 250, 'Urdorf', 'Einbruchdiebstahl', 36, 25, 11, 10332.0)
# (2023, 250, 'Urdorf', 'Einschleichdiebstahl', 16, 15, 1, 10332.0)
# (2023, 198, 'Uster', 'Einbruchdiebstahl', 70, 40, 30, 35748.0)
# (2023, 198, 'Uster', 'Einschleichdiebstahl', 52, 51, 1, 35748.0)
# (2023, 43, 'Volken', 'Einbruchdiebstahl', 0, 0, 0, 381.0)
# (2023, 43, 'Volken', 'Einschleichdiebstahl', 0, 0, 0, 381.0)
# (2023, 199, 'Volketswil', 'Einbruchdiebstahl', 48, 34, 14, 19412.0)
# (2023, 199, 'Volketswil', 'Einschleichdiebstahl', 10, 10, 0, 19412.0)
# (2023, 120, 'Wald', 'Einbruchdiebstahl', 7, 4, 3, 10343.0)
# (2023, 120, 'Wald', 'Einschleichdiebstahl', 5, 4, 1, 10343.0)
# (2023, 69, 'Wallisellen', 'Einbruchdiebstahl', 42, 21, 21, 17299.0)
# (2023, 69, 'Wallisellen', 'Einschleichdiebstahl', 38, 38, 0, 17299.0)
# (2023, 200, 'Wangen-Brüttisellen', 'Einbruchdiebstahl', 15, 10, 5, 8097.0)
# (2023, 200, 'Wangen-Brüttisellen', 'Einschleichdiebstahl', 2, 2, 0, 8097.0)
# (2023, 70, 'Wasterkingen', 'Einbruchdiebstahl', 3, 0, 3, 589.0)
# (2023, 70, 'Wasterkingen', 'Einschleichdiebstahl', 0, 0, 0, 589.0)
# (2023, 102, 'Weiach', 'Einbruchdiebstahl', 1, 1, 0, 2077.0)
# (2023, 102, 'Weiach', 'Einschleichdiebstahl', 1, 1, 0, 2077.0)
# (2023, 251, 'Weiningen', 'Einbruchdiebstahl', 15, 10, 5, 4883.0)
# (2023, 251, 'Weiningen', 'Einschleichdiebstahl', 8, 7, 1, 4883.0)
# (2023, 180, 'Weisslingen', 'Einbruchdiebstahl', 3, 0, 3, 3436.0)
# (2023, 180, 'Weisslingen', 'Einschleichdiebstahl', 1, 1, 0, 3436.0)
# (2023, 14, 'Wettswil', 'Einbruchdiebstahl', 25, 18, 7, 5282.0)
# (2023, 14, 'Wettswil', 'Einschleichdiebstahl', 1, 1, 0, 5282.0)
# (2023, 121, 'Wetzikon', 'Einbruchdiebstahl', 46, 33, 13, 26018.0)
# (2023, 121, 'Wetzikon', 'Einschleichdiebstahl', 16, 15, 1, 26018.0)
# (2023, 298, 'Wiesendangen', 'Einbruchdiebstahl', 14, 8, 6, 6710.0)
# (2023, 298, 'Wiesendangen', 'Einschleichdiebstahl', 4, 4, 0, 6710.0)
# (2023, 71, 'Wil', 'Einbruchdiebstahl', 7, 4, 3, 1564.0)
# (2023, 71, 'Wil', 'Einschleichdiebstahl', 5, 3, 2, 1564.0)
# (2023, 181, 'Wila', 'Einbruchdiebstahl', 1, 1, 0, 2043.0)
# (2023, 181, 'Wila', 'Einschleichdiebstahl', 2, 2, 0, 2043.0)
# (2023, 182, 'Wildberg', 'Einbruchdiebstahl', 1, 0, 1, 1029.0)
# (2023, 182, 'Wildberg', 'Einschleichdiebstahl', 0, 0, 0, 1029.0)
# (2023, 72, 'Winkel', 'Einbruchdiebstahl', 1, 1, 0, 4858.0)
# (2023, 72, 'Winkel', 'Einschleichdiebstahl', 6, 6, 0, 4858.0)
# (2023, 230, 'Winterthur', 'Einbruchdiebstahl', 331, 189, 142, 116906.0)
# (2023, 230, 'Winterthur', 'Einschleichdiebstahl', 184, 172, 12, 116906.0)
# (2023, 293, 'Wädenswil', 'Einbruchdiebstahl', 50, 38, 12, 25193.0)
# (2023, 293, 'Wädenswil', 'Einschleichdiebstahl', 8, 8, 0, 25193.0)
# (2023, 231, 'Zell', 'Einbruchdiebstahl', 6, 6, 0, 6491.0)
# (2023, 231, 'Zell', 'Einschleichdiebstahl', 3, 3, 0, 6491.0)
# (2023, 161, 'Zollikon', 'Einbruchdiebstahl', 70, 38, 32, 13472.0)
# (2023, 161, 'Zollikon', 'Einschleichdiebstahl', 14, 11, 3, 13472.0)
# (2023, 160, 'Zumikon', 'Einbruchdiebstahl', 37, 27, 10, 5633.0)
# (2023, 160, 'Zumikon', 'Einschleichdiebstahl', 3, 2, 1, 5633.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 129, 90, 39, 5492.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 81, 75, 6, 5492.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 186, 138, 48, 36339.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 36, 33, 3, 36339.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 202, 147, 55, 49025.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 84, 81, 3, 49025.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 282, 203, 79, 28344.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 131, 122, 9, 28344.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 135, 100, 35, 15358.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 50, 47, 3, 15358.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 190, 129, 61, 34060.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 58, 58, 0, 34060.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 163, 106, 57, 37967.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 47, 44, 3, 37967.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 115, 70, 45, 17056.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 32, 32, 0, 17056.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 252, 176, 76, 56943.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 60, 53, 7, 56943.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 178, 124, 54, 40072.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 46, 45, 1, 40072.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 304, 206, 98, 73993.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 99, 94, 5, 73993.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 63, 49, 14, 31471.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 18, 17, 1, 31471.0)
# (2023, 261, 'Zürich', 'Einbruchdiebstahl', 0, 0, 0, 1601.0)
# (2023, 261, 'Zürich', 'Einschleichdiebstahl', 0, 0, 0, 1601.0)
# MySQL connection closed
